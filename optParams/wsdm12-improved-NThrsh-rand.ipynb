# %%
from __future__ import print_function 
from bs4 import BeautifulSoup
from BeautifulSoup import SoupStrainer as sopstrain
import subprocess
import os
import re
import sys
import numpy as np
import string
import operator
import csv
import urllib2
import json
from collections import defaultdict
import StringIO
import random
from multiprocessing import Pool

# %%
knowledgGraph = "cnet" # conceptnet5AssocMod, gov, conceptnet5AssocMi, conceptnet5AssocHdl
#knowledgGraph_ = ''.join([k.capitalize() if i>0 else k for i, k in enumerate(knowledgGraph)])
collection = "trec7n8"
method = "wsdmImpr" # hal, mi, assoc, assocMi, assocHal, assoc2
simMeasure = "" # mi, cnet
projectDir = "/home/fj9124/projects/ir/seq_kb_ir/" 
indexDir = "/scratch/index/indri_5_7/"
colMethodConfigsDir = os.path.join(projectDir, "configs", collection, method)
cfgInFileName = os.path.join(projectDir, "configs", collection, "query" + collection.capitalize()) 
print("cfgInFileName =", cfgInFileName)
cfgOutFileName=os.path.join(colMethodConfigsDir, knowledgGraph, "indriRunQuery.cfg") 
print("cfgOutFileName =", cfgOutFileName)
colIndexDir = os.path.join(indexDir, collection) 
print("colIndexDir =", colIndexDir)
if knowledgGraph in {"cnet"}:
    knowledgGraphIndexDir = os.path.join(indexDir, collection)   
else:
    knowledgGraphIndexDir = os.path.join(indexDir, knowledgGraph)   
print("knowledgGraph index Dir =", knowledgGraphIndexDir)
graphsDir = os.path.join(projectDir, "graphs")
#methodGraphsDir = os.path.join(graphsDir, method)
methodGraphsFileName = []
if method == "hal":
    methodGraphsFileName = [os.path.join(graphsDir, method, knowledgGraph + ".txt")]
    print("methodGraphsFileName =", methodGraphsFileName)
elif method.translate(None, string.digits) in {"mi", "assoc"}:
    methodGraphsFileName = [os.path.join(graphsDir, method.translate(None, string.digits), knowledgGraph, "graph.txt")]
    print("methodGraphsFileName =", methodGraphsFileName)
elif method in {"assocMi"}:
    if knowledgGraph == "conceptnet5AssocGov":
        methodGraphsFileName = [os.path.join(graphsDir, "assoc", collection, "conceptnet5AssocMod" + ".txt")]
        methodGraphsFileName += [os.path.join(graphsDir, "mi", collection, "gov" + ".txt")]
        print("methodGraphsFileName =", methodGraphsFileName)
elif method in {"assocHal"}:
    if knowledgGraph == "conceptnet5AssocGov":
        methodGraphsFileName = [os.path.join(graphsDir, "assoc", collection, "conceptnet5AssocMod" + ".txt")]
        methodGraphsFileName += [os.path.join(graphsDir, "hal", "gov" + ".txt")]
        print("methodGraphsFileName =", methodGraphsFileName)
qrelsDir = os.path.join(projectDir, "qrels")
colQrelsDir = os.path.join(qrelsDir, collection)
colQrelsFileName = os.path.join(colQrelsDir, "qrels.csv")
print("col Qrels File Name =", colQrelsFileName)
runsFileName = os.path.join(projectDir, "runs", method, collection, knowledgGraph, "indriRunQuery.runs") 
print("runsFileName =", runsFileName)
evalsFileName = os.path.join(projectDir, "evals", method, collection, knowledgGraph, "indriRunQuery.evals") 
print("evalsFileName =", evalsFileName)
dumpindexStatementFilename = os.path.join("/", "tmp", "sbsb", "statement" + "_" + collection + "_" + method + "_" + knowledgGraph )
print("dumpindexStatementFilename =", dumpindexStatementFilename)
occuranceCountFilename = os.path.join(projectDir, "occuranceCount", "occuranceCount")
print("occuranceCountFilename =", occuranceCountFilename)
countsResultsFile = os.path.join(projectDir,"occuranceCount","results",collection+".txt")
print("countsResultsFile =", countsResultsFile)
conceptnet5RelAllFilename ="/scratch/saeid/data/conceptnet5_simp.csv"
print("conceptnet5RelAllFilename =", conceptnet5RelAllFilename)
cfgTmpOutFileName = cfgOutFileName + ".tmp"
print("cfgTmpOutFileName =", cfgTmpOutFileName)
docIdNameMapFileName = os.path.join(projectDir, "occuranceCount", "results", collection + "_docIdNameMap.txt")
print("docIdNameMapFileName =", docIdNameMapFileName)
#dumpindexResFilename = os.path.join(projectDir,"occuranceCount","results",collection +"_dumpindexRes"+".txt")
#print("dumpindexResFilename =", dumpindexResFilename)
#expansionCount = 25
# Out:
# cfgInFileName = /home/fj9124/projects/ir/seq_kb_ir/configs/trec7n8/queryTrec7n8
# cfgOutFileName = /home/fj9124/projects/ir/seq_kb_ir/configs/trec7n8/wsdmImpr/cnet/indriRunQuery.cfg
# colIndexDir = /scratch/index/indri_5_7/trec7n8
# knowledgGraph index Dir = /scratch/index/indri_5_7/trec7n8
# col Qrels File Name = /home/fj9124/projects/ir/seq_kb_ir/qrels/trec7n8/qrels.csv
# runsFileName = /home/fj9124/projects/ir/seq_kb_ir/runs/wsdmImpr/trec7n8/cnet/indriRunQuery.runs
# evalsFileName = /home/fj9124/projects/ir/seq_kb_ir/evals/wsdmImpr/trec7n8/cnet/indriRunQuery.evals
# dumpindexStatementFilename = /tmp/sbsb/statement_trec7n8_wsdmImpr_cnet
# occuranceCountFilename = /home/fj9124/projects/ir/seq_kb_ir/occuranceCount/occuranceCount
# countsResultsFile = /home/fj9124/projects/ir/seq_kb_ir/occuranceCount/results/trec7n8.txt
# conceptnet5RelAllFilename = /scratch/saeid/data/conceptnet5_simp.csv
# cfgTmpOutFileName = /home/fj9124/projects/ir/seq_kb_ir/configs/trec7n8/wsdmImpr/cnet/indriRunQuery.cfg.tmp
# docIdNameMapFileName = /home/fj9124/projects/ir/seq_kb_ir/occuranceCount/results/trec7n8_docIdNameMap.txt

# %%
# trec_eval -q ../qrels/trec7n8/qrels.csv indriRunQuery.res | grep map | grep -v all | awk '{if ($3 < 0.1) printf $2 ","}'
if collection == "gov":
    diffTopics = [4, 6, 7, 8, 9, 10, 12, 18, 19, 21, 22, 24, 26, 27, 30, 31, 32, 33, 36, 37, 40, 45, 46, 47, 48, 50, 52, 53, 54, 57, 58, 59, 63, 65, 66, 67, 70, 73, 78, 79, 80, 82, 84, 86, 92, 93, 94, 95, 96, 98, 99, 101, 102, 103, 104, 105, 106, 107, 109, 110, 111, 112, 113, 115, 116, 117, 118, 120, 123, 125, 126, 127, 129, 132, 133, 134, 135, 136, 137, 140, 142, 143, 147, 148, 149, 152, 153, 154, 155, 156, 157, 158, 160, 161, 162, 163, 165, 166, 167, 168, 169, 171, 175, 176, 177, 178, 179, 180, 182, 183, 185, 186, 188, 189, 191, 192, 194, 195, 196, 197, 200, 201, 202, 203, 204, 207, 208, 211, 212, 214, 215, 218, 219, 221, 224]
if collection == "robust":
    diffTopics = [301, 305, 309, 314, 315, 318, 319, 320, 322, 325, 327, 332, 336, 340, 342, 343, 344, 345, 346, 347, 350, 352, 354, 355, 356, 359, 363, 367, 371, 372, 376, 378, 379, 380, 381, 383, 386, 388, 389, 390, 393, 394, 397, 398, 401, 405, 409, 412, 419, 421, 426, 432, 435, 436, 437, 439, 440, 442, 448, 449, 605, 608, 610, 620, 622, 625, 626, 627, 638, 650, 651, 655, 659, 666, 668, 680, 683, 684, 688, 689, 690]
if collection == "trec7n8":
    diffTopics = [352,354,356,359,363,367,370,371,372,373,376,378,379,381,383,386,388,389,390,393,394,397,398,401,405,408,419,421,422,426,432,435,436,437,439,440,442,443,445,447,448,449]
diffTopic = [str(i) for i in diffTopics]

# %%
# generate docIdNameMapFileName
if not os.path.isfile(occuranceCountFilename):
    cmd = ' '.join([occuranceCountFilename, colIndexDir, "dm", ">", docIdNameMapFileName])
    res = subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE).stdout.read()

# %%
with open(docIdNameMapFileName, 'r') as f:
    reader = list(csv.reader(f, delimiter = ' '))
    print(reader[0])
    docIdNameMap = {i[1]:i[0] for i in reader}
    docNameIdMap = {i[0]:i[1] for i in reader}
for i, (k, v) in enumerate(docIdNameMap.iteritems()):
    print (k, '\t', v)
    if (i>20):
        break
# Out:
# ['1', 'FR940104-1-00001']
# LA082389-0020 	 441223
# FBIS3-32596 	 246524
# LA011890-0198 	 465144
# LA011890-0199 	 465145
# LA011890-0196 	 465142
# LA011890-0197 	 465143
# LA011890-0194 	 465140
# FT932-3799 	 88713
# LA011890-0192 	 465138
# LA011890-0193 	 465139
# LA011890-0190 	 465136
# LA011890-0191 	 465137
# FT932-3796 	 88710
# FT924-2868 	 187695
# FT924-2869 	 187696
# FT932-3797 	 88711
# FT924-2864 	 187691
# FT924-2865 	 187692
# FT924-2866 	 187693
# FT924-2867 	 187694
# FT924-2860 	 187687
# FT924-2861 	 187688

# %%
count_history = dict()
if os.path.isfile(countsResultsFile):
    with open(countsResultsFile, 'r') as f:
        reader = csv.reader(f, delimiter = "\t")
        count_history = {k:int(float(v)) for k,v in list(reader)}
    print("size of count_history =", len(count_history))
    for i, (k, v) in enumerate(count_history.iteritems()):
        print (k, '\t', v)
        if (i>20):
            break
# Out:
# size of count_history = 81446
# #uw(#4( storm ) #4( be appear in sky )) 	 0
# #uw(#4( work on sundai )) 	 137
# #uw(#4( calm time )) 	 23
# #uw(#4( kill ) #4( prai )) 	 394
# #uw(#4( bank ) #4( teller offic )) 	 5
# #uw(#4( water ) #4( hydrogen )) 	 347
# #uw(#4( drug ) #4( take )) 	 8847
# #uw(#4( space ) #4( mostli empti )) 	 3
# #uw(#4( chang ) #4( edg )) 	 3803
# #uw(#4( happin )) 	 0
# #uw(#4( trade ) #4( countri )) 	 45838
# #uw(#4( game ) #4( leisur activ )) 	 23
# #uw(#4( round in shape )) 	 4
# #uw(#4( good ) #4( other person )) 	 411
# #uw(#4( smoke ) #4( fire )) 	 1842
# #uw(#4( spice up salad )) 	 1
# #uw(#4( be wound )) 	 410
# #uw(#4( good ) #4( hear nice new )) 	 0
# #uw(#4( teacher ) #4( teach student of class )) 	 0
# #uw(#4( deliveri )) 	 11268
# #uw(#4( bank ) #4( teller monei )) 	 23
# #uw(#4( swap share )) 	 106

# %%
conceptnet5RelAll = defaultdict(dict)
conceptnet5RelAllInv = defaultdict(dict)
with open(conceptnet5RelAllFilename, 'r') as f:
    reader = csv.reader(f, delimiter = ",")
    for line in list(reader):
        if line[0].strip() != "" and line[1].strip() != "" and line[2].strip() != "":
            if all(c in string.printable for c in line[0]) and all(c in string.printable for c in line[1]) and all(c in string.printable for c in line[2]):
                conceptnet5RelAll[line[1].strip()][line[2].strip()] = line[0].strip()
                conceptnet5RelAllInv[line[2].strip()][line[1].strip()] = line[0].strip()
print("size of conceptnet5RelAll =", len(conceptnet5RelAll))
for i, (k1, k2v) in enumerate(conceptnet5RelAll.iteritems()):
    for j, (k2, v) in enumerate(k2v.iteritems()):
        if (i>3 or j>3):
            break
        print (k1, '\t', k2, '\t', v)
# Out:
# size of conceptnet5RelAll = 2965684
# tripolitan 	 tripoline 	 Synonym
# tripolitan 	 tripoli 	 RelatedTo
# age of nemesis 	 band 	 IsA
# age of nemesis 	 organisation 	 InstanceOf
# age of nemesis 	 progressive rock 	 dbpedia/genre
# age of nemesis 	 progressive metal 	 dbpedia/genre
# joseph john annabring 	 person 	 InstanceOf
# british rail class 438 	 mean of transportation 	 InstanceOf
# british rail class 438 	 train 	 InstanceOf

# %%
indriRunQuery_hist_= dict()
dumpindex_hist_ = dict()

# %%
def splitStemText(text):
    stemmedWords = []
    text = re.sub('/|-|\"|_',' ', text) # replace - and slash with space
    if method in {"assocRestful", "lr", "wsdmImpr"}:
        for text_ in text.split(' '):
            text = text_.replace(" ", "_")
            url = "http://conceptnet5.media.mit.edu/data/5.4/uri?language=en&text=" + text
            response = urllib2.urlopen(url)
            data = response.read()
            data_j = json.loads(data)
            text = os.path.basename(data_j[u'uri'])
            url = "http://conceptnet5.media.mit.edu/data/5.4/uri?language=en&text=" + text
            response = urllib2.urlopen(url)
            data = response.read()
            data_j = json.loads(data)
            #print("data_j =", data_j)
            #print("data_j[u'uri'] =", data_j[u'uri'])
            stemmedWords += [str(os.path.basename(data_j[u'uri']))]
        #print("stemmedWords =", stemmedWords)
        return (stemmedWords)
    else:
        words = text.split()
        for w in words:
            w = re.sub('\(|\)|\'s|,','', w) # remove paranthesis, apostrophe s, comma
            w = re.sub('\'','', w) # remove apostrophe
            cmd = "dumpindex " + knowledgGraphIndexDir + " t " + w + " | head -n1"
            #print("cmd =", cmd)
            stemmedWords.append(subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE).stdout.read().split()[1])
        return (stemmedWords)

print ("testing:", splitStemText("going reading"))
# Out:
# testing: ['go', 'read']

# %%
def analyseQueries():
    #    #print("intCoeff =", intCoeff)
    with open(cfgInFileName, 'r') as inFile:
        reader = inFile.read()
        soup = BeautifulSoup(reader, 'lxml')
        if collection in {"aquaint", "gov"}:
            tags = soup.find_all(['doc'])
        elif collection in {"robust", "trec7n8", "gov2"}:
            tags = soup.find_all(['top'])
            #print(tags)
        
        origWordsAll = dict()
        for tag in tags:
            
            if collection in {"aquaint", "gov"}:
                docno = (tag.find('docno').string).strip()
            elif collection in {"robust", "trec7n8", "gov2"}:
                result = re.search('<num> Number: (.*)\n', str(tag))                
                docno = result.group(1).strip()
            
            if collection in {"aquaint", "gov"}:
                origWords = splitStemText(tag.find('text').string.strip())
            elif collection in {"robust", "trec7n8", "gov2"}:
                result = re.search('<title>(.*)\n', str(tag))                
                origWords = splitStemText(result.group(1).strip())
            #print("origWords =", origWords)
            origWordsAll[docno] = origWords
            
    return (origWordsAll)

# %%
cmd = ' '.join(["dumpindex", colIndexDir, "s", "|", "awk", "\'NR==2{print $2}\'"])
res = subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE).stdout.read()
colDocumentCount = int(np.float(res))
print("colDocumentCount =", colDocumentCount)
# Out:
# colDocumentCount = 472526

# %%
def genMultSimpQuery(argss):
    #    #print("intCoeff =", intCoeff)
    soupNew = BeautifulSoup("", 'lxml')
    parameters_tag = soupNew.new_tag("parameters")
    index_tag = soupNew.new_tag("index")
    index_tag.string = colIndexDir
    parameters_tag.append(index_tag)
        #print(tags)

    for args in argss:
        #print("args =", args)
        (dist, docno, origWords_, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights, workingset) = args
        #print("(...) =", docno, origWords_, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights, workingset)
        doc_tag = soupNew.new_tag("query")

        docno_tag = soupNew.new_tag("number")
        if relW != "":
            docno_tag.string = '_'.join([dist, docno, ('_'.join(origWords_)).replace(' ', '_'), relW.replace(' ', '_')])
        else:
            docno_tag.string = '_'.join([dist, docno, ('_'.join(origWords_)).replace(' ', '_'), relW.replace(' ', '_')])

        doc_tag.append(docno_tag)

        text_tag = soupNew.new_tag("text")
        text_tag.string = "#weight(\n" 

        text_tag.string += str(intCoeff0) + " #combine(" 
        for ow in set(origWords_):
            ow = re.sub(ur"[^\w\d#(),:\-\s]+", ' ', ow)
            text_tag.string += ow + " "
        text_tag.string += ")\n"

        if len(relW)>0: 
            relText_string1 = re.sub(ur"[^\w\d#(),:\-\s]+",' ',relW)
            text_tag.string += str(intCoeff1) + " #combine(" 
            #print("relText_string1 =", relText_string1)
            text_tag.string += relText_string1.encode('utf-8')
            text_tag.string += ")\n"

        text_tag.string += ") "

        doc_tag.append(text_tag)
        
        if workingset[0] != "all":
            for d in workingset:
                workingSetDocno_tag = soupNew.new_tag("workingSetDocno")
                workingSetDocno_tag.string = d
                doc_tag.append(workingSetDocno_tag)

        parameters_tag.append(doc_tag)
        #print(doc_tag)

    rule_tag = soupNew.new_tag("rule")
    rule_tag.string = "method:dir,mu:" + str(dirCoeff)
    #rule_tag.string = "method:two"
    parameters_tag.append(rule_tag)

    threads_tag = soupNew.new_tag("threads")
    threads_tag.string = "32"
    parameters_tag.append(threads_tag)

    count_tag = soupNew.new_tag("count")
    count_tag.string = "10"
    parameters_tag.append(count_tag)

    trecFormat_tag = soupNew.new_tag("trecFormat")
    trecFormat_tag.string = "true"
    parameters_tag.append(trecFormat_tag)

    soupNew.append(parameters_tag)
    #print(soupNew.prettify())
    #print("cfgTmpOutFileName =", cfgTmpOutFileName)
    with open( cfgTmpOutFileName, 'a+') as outFile:
        soupNewStr = str(soupNew)
        soupNewStr = soupNewStr.replace("</text>", "\n</text>\n").replace("query>", "query>\n").replace("<text>", "\n<text>\n").replace("</index>", "</index>\n").replace("\n<index>", "<index>")

        outFile.write(soupNewStr)

# %%
def genCommandsinHist_i(dist, docno, origWords_, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights):
    
    indriRunQuery_hist = [(dist, docno, origWords_, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, cfgTmpOutFileName, ['all'])]
    return indriRunQuery_hist

# %%
def runCommandsinHist_i(cfgTmpOutFileName, indriRunQuery_hist, indriRunQuery_hist_, featureWeights):
    with open( cfgTmpOutFileName, 'w+') as outFile:
        outFile.write("")
    args = []
    #print("indriRunQuery_hist =", indriRunQuery_hist, "\nlen(indriRunQuery_hist) =",len(indriRunQuery_hist))
    for (dist, docno, origWords_, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, cfgTmpOutFileName, workingset) in indriRunQuery_hist:
        #print("origWords_, relW (before if) =", origWords_, "---", relW)
        if '_'.join([dist, docno, ('_'.join(origWords_)).replace(' ', '_'), relW.replace(' ', '_')]) not in indriRunQuery_hist_:
            #print("origWords_, relW (after if) =", origWords_, "---", relW)
            args += [(dist, docno, origWords_, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights, workingset)]
    #print("args =", args)
    if len(args)>0:
        genMultSimpQuery(args)
    cmd = ' '.join(["IndriRunQuery", cfgTmpOutFileName])
    #print("cmd =", cmd)
    indriRun = subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE).stdout.read()
    #print("indriRun =", indriRun)
    indriRunQuery_hist_tmp = [[j for c, j in enumerate(i.split(' ')) if c in {0, 2, 4}] for i in indriRun.split('\n') if len(i)>0]
    #indriRunQuery_hist_ = dict()
    for i in indriRunQuery_hist_tmp:
        if i[0] in indriRunQuery_hist_:
            indriRunQuery_hist_[i[0]] += [[i[1], i[2]]]
        else:
            indriRunQuery_hist_[i[0]] = [[i[1], i[2]]]
    #indriRunQuery_hist_ = list(set(indriRunQuery_hist_))
    return indriRunQuery_hist_

# %%
def genCommandsinHist_d(indriRunQuery_hist_, dumpindex_hist, dist, docno, origWords_, ow, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights):

    expr = '_'.join([dist, docno, '_'.join(origWords_), ""]).replace(' ', '_')
    #print("expr =", expr)
    indriRunQuery_hist_1 = indriRunQuery_hist_[expr]
    #print("indriRunQuery_hist_1 =", indriRunQuery_hist_1)
    topTDocs = [i[0] for i in indriRunQuery_hist_1]
    
    expr = "#4( " + regex.sub(' ', relW) + " )"
    #expr = '_'.join([dist, docno, '_'.join(origWords_), ""]).replace(' ', '_')
    #print("expr =", expr)
    #cmd2 = [(dist, docno, [expr], "", intCoeff0, intCoeff1, intCoeff2, dirCoeff, cfgTmpOutFileName, topTDocs)]
    #if cmd2 not in indriRunQuery_phCounter_hist:
    #    indriRunQuery_phCounter_hist += cmd2
    cmd2 = ("efb", expr + ":" + ','.join(topTDocs))
    if cmd2 not in dumpindex_hist:
        dumpindex_hist.add(cmd2)
    
    #print("relW =", relW)
    expr = "#4( " + regex.sub(' ', relW) + " )"
    cmd2 = ("fx", expr)
    if cmd2 not in dumpindex_hist:
        dumpindex_hist.add(cmd2)
    #print("dumpindex_hist =", dumpindex_hist)
    
    for documentName in topTDocs:
        cmd2 = ("dcf", docIdNameMap[documentName])
        if cmd2 not in dumpindex_hist:
            dumpindex_hist.add(cmd2)

    for ow in origWords_:
        phrase = ["#uw(#4( " + regex.sub(' ', ow) + " ) #4( " + regex.sub(' ', relW) + " ))"]
        #cmd2 = ("efb", "#uw(#4( " + regex.sub(' ', ow) + " ) #4( " + regex.sub(' ', relW) + " )):" + ','.join(topTDocs))
        #cmd2 = [(dist, docno, phrase, "", intCoeff0, intCoeff1, intCoeff2, dirCoeff, cfgTmpOutFileName, topTDocs)]
        #if cmd2 not in indriRunQuery_phCounter_hist:
        #    indriRunQuery_phCounter_hist += cmd2        
        cmd2 = ("fx", phrase[0])
        if cmd2 not in dumpindex_hist:
            dumpindex_hist.add(cmd2)
        
        cmd2 = ("efb", phrase[0] + ":" + ','.join(topTDocs))
        if cmd2 not in dumpindex_hist:
            dumpindex_hist.add(cmd2)
            
    for j1, ow1 in enumerate(origWords_):
        for j2, ow2 in enumerate(origWords_):
            if j1>j2:
                phrase = ["#uw(#4( " + regex.sub(' ', ow1) + " ) #4( " + regex.sub(' ', ow2) + " ) #4( " + regex.sub(' ', relW) + " ))"]
                #cmd2 = [(dist, docno, phrase, "", intCoeff0, intCoeff1, intCoeff2, dirCoeff, cfgTmpOutFileName, topTDocs)]
                #if cmd2 not in indriRunQuery_phCounter_hist:
                #    indriRunQuery_phCounter_hist += cmd2        
                #cmd2 = ("fx", phrase[0])
                cmd2 = ("fx", phrase[0])
                if cmd2 not in dumpindex_hist:
                    dumpindex_hist.add(cmd2)
                cmd2 = ("efb", phrase[0] + ":" + ','.join(topTDocs))
                if cmd2 not in dumpindex_hist:
                    dumpindex_hist.add(cmd2)
    #print("len(dumpindex_hist) =", len(dumpindex_hist))
    return dumpindex_hist

# %%
regex = re.compile('[%s]' % re.escape(string.punctuation))
def runCommandsinHist_d(dist, docno, dumpindex_hist, dumpindex_hist_):
    args = []
    dumpindex_hist_dict = dict()
    tmp = set()
    #print("dumpindex_hist =", dumpindex_hist)
    for i in dumpindex_hist:
        expr = '_'.join([dist, docno, '_'.join(i[0]), ""]).replace(' ', '_')
        if i[1] not in dumpindex_hist_.get(expr, dict()):
#        if i[1] not in dumpindex_hist_.get(dist + "_" + docno + "_" + i[0], dict()):
            if i[1] in tmp:
                continue
            #print("i =", i)
            tmp.add(i[1])
            if i[0] in dumpindex_hist_dict:
                dumpindex_hist_dict[i[0]] += [[re.sub(ur"[^\w\d#(),:\-\s]+",' ',j) for j in i[1:]]]
            else:
                dumpindex_hist_dict[i[0]] =  [[re.sub(ur"[^\w\d#(),:\-\s]+",' ',j) for j in i[1:]]]
                
    for k, v in dumpindex_hist_dict.iteritems():
        fileName = dumpindexStatementFilename + "_" + k + ".tmp"
        with open(fileName, 'w') as f:
            for i in v:
                f.write(' '.join(i) + '\n')
                #print("i =", i)
        cmd = ' '.join([occuranceCountFilename, colIndexDir, k, fileName])
        #print("cmd =", cmd)
        dumpindex_hist_tmp = subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE).stdout.read()
        #print("dumpindex_hist_tmp =", dumpindex_hist_tmp)
        dumpindex_hist_tmp = dict([tuple(j for c2, j in enumerate(i.split(':')) if c2 in {0,1} ) for i in dumpindex_hist_tmp.split("\n") if len(i)>0])
        #print("dumpindex_hist_tmp.get(\"#od4(travel)\",\"\") =", dumpindex_hist_tmp.get("#od4(travel)", dict()) )
        dumpindex_hist_tmp = {k1:v1.split(',') for k1,v1 in dumpindex_hist_tmp.iteritems()}
        dumpindex_hist_tmp = {dist + "_" + docno + "_" + k1:[i for i in v1 if len(i)>0] for k1,v1 in dumpindex_hist_tmp.iteritems()}
        #dumpindex_hist_tmp = {re.sub(ur"[^\w\d#()\s]+",' ',k1):[i for i in v1 if len(i)>0] for k1,v1 in dumpindex_hist_tmp.iteritems()}
        #dumpindex_tmp = [i for i in dumpindex_tmp.split("\n")]
        #print("dumpindex_hist_tmp =", dumpindex_hist_tmp)
        #dumpindex_hist_[k] = dumpindex_hist_tmp
        #expr = '_'.join([dist, docno, '_'.join(k), ""]).replace(' ', '_')    
        dumpindex_hist_[k] = dict(dumpindex_hist_.get(k, dict()).items() + dumpindex_hist_tmp.items())
        #dumpindex_hist_[dist + "_" + docno + "_" + k] = dict(dumpindex_hist_.get(dist + "_" + docno + "_" + k, dict()).items() + dumpindex_hist_tmp.items())
    #print("dumpindex_hist_['efb'].get('#od4(travel)', dict())]", dumpindex_hist_['efb'].get("#od4(travel)", dict()))
        #print("dumpindex_hist_[k].keys() =", dumpindex_hist_[k].keys())
    #print("dumpindex_hist_ =", dumpindex_hist_)
        
    return dumpindex_hist_

# %%
# keys of rWords are important
# values of rWords1 are important
regex = re.compile('[%s]' % re.escape(string.punctuation))
def getRelWords_train(args, indriRunQuery_hist_, dumpindex_hist_):
    #print("origWords =", origWords)
    text_string = ""
    
    count_history, rWords, dist, docno, origWords, expansionCount, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights = args
        
    relWords = dict()
    #if method == "relAll":
            
    if method in {"lr", "wsdmImpr"}:
        origWords_ = [w.replace(" ", "_") for w in origWords]
        #relWords_l = []
        dumpindex_hist = set()

        indriRunQuery_hist = []
        indriRunQuery_hist += genCommandsinHist_i(dist, docno, origWords_, "", intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights)
        #for relW in conceptnet5RelAll[ow].keys():
        #    indriRunQuery_hist += genCommandsinHist_i(dist, docno, origWords_, ow, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights)

        indriRunQuery_hist_ = runCommandsinHist_i(cfgTmpOutFileName, indriRunQuery_hist, indriRunQuery_hist_, featureWeights)
        #print("indriRunQuery_hist =", indriRunQuery_hist)
        for ow in origWords_:
            #print("ow =", ow)
            #relWords_l += list(conceptnet5RelAll[ow])
            #print(ow, "---", conceptnet5RelAll[ow])

            
            
            for relW in conceptnet5RelAll[ow].keys():
                dumpindex_hist |= genCommandsinHist_d(indriRunQuery_hist_, dumpindex_hist, dist, docno, origWords_, ow, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights)
                #dumpindex_hist |= genCommandsinHist_id(indriRunQuery_hist_, dumpindex_hist, indriRunQuery_phCounter_hist, docno, origWords_, ow, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights)
                #print("indriRunQuery_phCounter_hist =", indriRunQuery_phCounter_hist)
                #indriRunQuery_phCounter_hist = [list(x) for x in set(tuple(x) for x in indriRunQuery_phCounter_hist)]
            
        dumpindex_hist_ = runCommandsinHist_d(dist, docno, dumpindex_hist, dumpindex_hist_)
        
        #indriRunQuery_hist_ = runCommandsinHist_i(cfgTmpOutFileName, indriRunQuery_phCounter_hist, indriRunQuery_hist_, featureWeights)

    return(indriRunQuery_hist_, dumpindex_hist_)

# %%
regex = re.compile('[%s]' % re.escape(string.punctuation))
def documentLength(dist, docno, documentName, dumpindex_hist_):
    #documentLength_ = int(dumpindex_hist_['dcf'][documentName][0])
    documentLength_ = int(dumpindex_hist_['dcf'][dist + "_" + docno + "_" + documentName][0])
    return documentLength_

def weightRelConcept(dist, docno, origWords_, ow, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, count_history, featureWeights, indriRunQuery_hist_, dumpindex_hist_):
    
    features = dict()
    
    expr_i = '_'.join([dist, docno, '_'.join(origWords_), ""]).replace(' ', '_')
    #print("expr_i =", expr_i)
    indriRunQuery_hist_1 = indriRunQuery_hist_[expr_i]
    #print("indriRunQuery_hist_1 =", indriRunQuery_hist_1)
    topTDocs = [i[0] for i in indriRunQuery_hist_1]
    
    topTDocScores_d = {i[0]:np.float(i[1]) for i in indriRunQuery_hist_1}
    
    
    expTDocScore = np.float(indriRunQuery_hist_1[0][1])
    features["expTDocScore"] = expTDocScore
    
    expr = "#4( " + regex.sub(' ', relW) + " )"
    #expr = expr.replace(' ', '_')
    #print("expr =", expr)
    #expr_i = '_'.join([dist, docno, '_'.join([expr.replace(' ', '_')]), ""]).replace(' ', '_')
    #indriRunQuery_hist_1 = indriRunQuery_hist_[expr_i]
    #print("indriRunQuery_hist_1 =", indriRunQuery_hist_1)
    relWTopDocuments = dumpindex_hist_['efb'][dist + "_" + docno + "_" + expr][1:]
    #relWTopDocuments = list([i[0] for i in indriRunQuery_hist_1]) #deep copy
    
    numerator = len(relWTopDocuments) # relW term count in the collection
    denumerator = np.sum([documentLength(dist, docno, i, dumpindex_hist_) for i in topTDocs]) # number of terms in topDocs
    topTermFrac = numerator / np.float(denumerator)
    features["topTermFrac"] = topTermFrac
    
    numCanDocs = len(set([i[0] for i in relWTopDocuments]))
    features["numCanDocs"] = numCanDocs
    
    if numCanDocs > 0:
        avgCDocScore = np.sum([ topTDocScores_d[i] for i in set([i for i in relWTopDocuments])])/np.float(numCanDocs)
    else:
        avgCDocScore = 0
    features["avgCDocScore"] = avgCDocScore

    l = [ topTDocScores_d[i] for i in set(relWTopDocuments)]
    if len(l)>0:
        maxCDocScore = np.max(l)
    else:
        maxCDocScore = 0
    features["maxCDocScore"] = maxCDocScore
    
    colDocFreq = np.float(dumpindex_hist_['fx'][dist + "_" + docno + "_" + expr][0])
    if colDocFreq>0:
        conIdf = np.log(colDocumentCount / colDocFreq)
    else:
        conIdf = np.log(colDocumentCount / 1)
    features["conIdf"] = conIdf
    
    coocurDocumentsTop = dict()
    coocurDocumentsCount = dict()
    for ow in origWords_:
        expr = "#uw(#4( " + regex.sub(' ', ow) + " ) #4( " + regex.sub(' ', relW) + " ))"
        #expr = expr.replace(' ', '_')
        #expr_i = '_'.join([dist, docno, '_'.join([expr.replace(' ', '_')]), ""]).replace(' ', '_')
        #indriRunQuery_hist_1 = indriRunQuery_hist_[expr_i]
        coocurDocumentsTop[ow] = dumpindex_hist_['efb'][dist + "_" + docno + "_" + expr][1:]
        #coocurDocumentsTop[ow] = list([i[0] for i in indriRunQuery_hist_1])
        coocurDocumentsCount[ow] = np.float(dumpindex_hist_['fx'][dist + "_" + docno + "_" + expr][0])

    avgColCor = np.sum(coocurDocumentsCount.values())/np.float(len(coocurDocumentsCount.values())) 
    features["avgColCor"] = avgColCor
    
    maxColCor = np.max(coocurDocumentsCount.values())
    features["maxColCor"] = maxColCor
    
    avgTopColCor = np.sum([len(set(i)) for i in coocurDocumentsTop.values()])/np.float(len(coocurDocumentsTop.values())) 
    features["avgTopColCor"] = avgTopColCor
    
    l = [len(set(i)) for i in coocurDocumentsTop.values()]
    if len(l)>0:
        maxTopColCor = np.max(l)
    else:
        maxTopColCor = 0
    features["maxTopColCor"] = maxTopColCor

    coocurDocumentsTop = dict()
    coocurDocumentsCount = dict()
    for j1, ow1 in enumerate(origWords_):
        for j2, ow2 in enumerate(origWords_):
            if j1>j2:
                expr = "#uw(#4( " + regex.sub(' ', ow1) + " ) #4( " + regex.sub(' ', ow2) + " ) #4( " + regex.sub(' ', relW) + " ))"
                #expr = expr.replace(' ', '_')
                #expr_i = '_'.join([dist, docno, '_'.join([expr.replace(' ', '_')]), ""]).replace(' ', '_')
                #indriRunQuery_hist_1 = indriRunQuery_hist_[expr_i]
                #indriRunQuery_hist_1 = indriRunQuery_hist_['_'.join([dist, docno, expr]).replace(' ', '_')]
                coocurDocumentsTop[ow1+ow2] = dumpindex_hist_['efb'][dist + "_" + docno + "_" + expr][1:]
                #coocurDocumentsTop[ow1+ow2] = list([i[0] for i in indriRunQuery_hist_1])
                coocurDocumentsCount[ow] = np.float(dumpindex_hist_['fx'][dist + "_" + docno + "_" + expr][0])

    avgColPCor = np.sum(coocurDocumentsCount.values())/np.float(len(coocurDocumentsCount.values()))  
    features["avgColPCor"] = avgColPCor

    if len(coocurDocumentsCount.values())>0:
        maxColPCor = np.max(coocurDocumentsCount.values())
    else:
        maxColPCor = 0
    features["maxColPCor"] = maxColPCor
    
    avgTopColPCor = np.sum([len(set(i)) for i in coocurDocumentsTop.values()])/np.float(len(coocurDocumentsTop.values())) 
    features["avgTopColPCor"] = avgTopColPCor

    l = [len(set(i)) for i in coocurDocumentsTop.values()] 
    if len(l)>0:
        maxTopColPCor = np.max(l)
    else:
        maxTopColPCor = 0
    features["maxTopColPCor"] = maxTopColPCor
    
    """
    relWg = 0
    for feature, weight in featureWeights.iteritems():
        relWg += features[feature] * weight
    """
    #print("origWords_ =", origWords_)
    #print("relW =", relW)
    #print("features =", features)
    #print("relWg =", relWg)

    #return relWg
    features = {k:np.abs(np.nan_to_num(v)) for k,v in features.iteritems()}
    return features

# %%
def normDictOfDicts(_dict_):
    dict_ = dict(_dict_)
    dSum = dict()
    #dMax = dict()
    #dMin = dict()
    for k, v in dict_.iteritems():
        """
        for k1, v1 in v.iteritems():
            dMax[k1] = max(dMax.get(k1, -(np.inf)), v1)
            dMin[k1] = min(dMin.get(k1,  (np.inf)), v1)
        """
        #print ("type(v) = ", type(v))
        dSum = { k1:dSum.get(k1,0)+v1 for k1, v1 in v.items()}
        #dMax = { k1:max(dMax.get(k1, -(np.inf)), v1) for k1, v1 in v.items()}
        #dMin = { k1:min(dMin.get(k1,  np.inf), v1) for k1, v1 in v.items()}
    #print("dict_ =", dict_)
    dict_r = dict()
    for k, v in dict_.items():
        dict_r[k] = { k1:v1/dSum[k1] if dSum[k1] != 0 else 0 for k1, v1 in v.items()}
        #dict_[k] = { k1:dict_[k][k1]/dSum[k1] if dSum[k1] != 0 else dict_[k][k1] for k1, v1 in v.items()}
        """
        #dict_r[k] = { k1:(dict_[k][k1]-dMin[k1])/(dMax[k1]-dMin[k1]) if (dMax[k1]-dMin[k1]) != 0 else dict_[k][k1] for k1, v1 in v.items()}
        dict_r1 = dict()
        for k1, v1 in v.items():
            if (dMax[k1]-dMin[k1]) != 0: 
                dict_r1[k1] = (v1-dMin[k1])/(dMax[k1]-dMin[k1])
            elif dict_r1[k1]!=0: 
                dict_r1[k1] = 1
            else: 
                dict_r1[k1] = 0
        dict_r[k] = dict_r1
        """
    return dict_r

d_tst = {1:{2:3, 4:5}, 3:{2:3.2, 4:5.4}, 5:{2:3.4, 4:5.5}}
print("dict of dicts before normalization =", d_tst)
d_tst = normDictOfDicts(d_tst)
print("dict of dicts after normalization =", d_tst)

def weightedCombineDicts(ddict_, dict_):
    dict_cmb = dict()
    for k, v in ddict_.items():
        cmb = 0
        for k1, v1 in v.items():
            cmb += dict_[k1] * v1
        dict_cmb[k] = cmb
    return dict_cmb

cmb_tst = { 2:0.4, 4:0.6}
print("cmb_tst =", cmb_tst)
dCombtst = weightedCombineDicts(d_tst, cmb_tst)
print("dCombtst =", dCombtst)

# keys of rWords are important
# values of rWords1 are important
regex = re.compile('[%s]' % re.escape(string.punctuation))
def getRelWords(args, indriRunQuery_hist_, dumpindex_hist_):
    #print("origWords =", origWords)
    text_string = ""
    
    count_history, rWords, dist, docno, origWords, expansionCount, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights = args
        
    relWords = dict()
    #if method == "relAll":
        
    if method == "assocRestful":
        origWords_ = [w.replace(" ", "_") for w in origWords]
        url = "http://conceptnet5.media.mit.edu/data/5.4/assoc/list/en/"+','.join(origWords_)
        response = urllib2.urlopen(url)
        data = response.read()
        data_j = json.loads(data)
        relWords = {str(d[0].encode('utf-8')).replace('/c/en/', '').replace('-', ' '):np.float(d[1]) for d in data_j[u'similar'] if '/c/en/' in str(d[0].encode('utf-8'))}
    
    elif method in {"lr", "wsdmImpr"}:
        origWords_ = [w.replace(" ", "_") for w in origWords]
        #relWords_l = []

        for ow in origWords_:
            #relWords_l += list(conceptnet5RelAll[ow])
            #print(ow, "---", conceptnet5RelAll[ow])
            """
            for relW in conceptnet5RelAll[ow].keys():
                relWg = weightRelConcept(dist, docno, origWords_, ow, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, count_history, featureWeights, indriRunQuery_hist_, dumpindex_hist_)
                if relW in relWords:
                    relWords[relW] += relWg
                else:
                    relWords[relW] = relWg  
            """
            relWords_unNorm = dict()
            for relW in conceptnet5RelAll[ow].keys():
                feature_ = weightRelConcept(dist, docno, origWords_, ow, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, count_history, featureWeights, indriRunQuery_hist_, dumpindex_hist_)
                if relW in relWords_unNorm:
                    relWords_unNorm[relW] += feature_
                else:
                    relWords_unNorm[relW] = feature_
            #print("relWords before =", relWords_unNorm)
            relWordsNorm = normDictOfDicts(relWords_unNorm)
            #print("relWordsNorm =", relWordsNorm)
            relWords = weightedCombineDicts(relWordsNorm, featureWeights)
            #print("relWords after comb =", relWords)
            
            
    else:
        count_history = countExpr(count_history, origWords, rWords)
        expressions = set()
        for ow in origWords:
            rWords_ow = rWords.get(ow, [])
            expressions.add("#4( " + ow.translate(None, string.punctuation) + " )")
            if ow.strip() == "":
                continue
            if simMeasure == "mi":
                N_w = countExpr_get_1(count_history, ow)
            for rw_wv in rWords_ow:
                (rw_w, rw_v) = rw_wv.items()[0]
                if rw_w.strip() == "":
                    continue           
                if simMeasure == "mi":
                    N_v = countExpr_get_1(count_history, rw_w)
                    N_wv = countExpr_get_2(count_history, ow, rw_w)
                    rw_v_ = mi_(N_w, N_v, N_wv)
                elif simMeasure == "cnet":
                    rw_v_ = rw_v
                relWords[rw_w] = relWords.get(rw_w, 0) + rw_v_
    
    relWords_sorted = sorted(relWords.items(), key=operator.itemgetter(1), reverse=True)
    #print ("origWords =", origWords)
    #print ("relWords_sorted =", relWords_sorted)
    
    #counter = 0
    relWords_sel = []
    for counter, (rw_w, rw_v) in enumerate(relWords_sorted):
        #print ("rw_w, rw_v =", rw_w, rw_v)
        #print ("expansionCount =", expansionCount)
        if (counter >= expansionCount):
        #if (rw_v < expansionCount):
            break
        if  all(c in string.printable for c in rw_w):
            if rw_w not in origWords:
                rw_w = regex.sub(' ', rw_w)
                text_string += rw_w + " "
                relWords_sel += [rw_w]
        #1/0
        #counter += 1
    #print("counter =", counter)
    #rint("relWords_sel =", relWords_sel)
#    return(relWords_sel)
    return(count_history, text_string, relWords_sel)
# Out:
# dict of dicts before normalization = {1: {2: 3, 4: 5}, 3: {2: 3.2, 4: 5.4}, 5: {2: 3.4, 4: 5.5}}
# dict of dicts after normalization = {1: {2: 0.3125, 4: 0.31446540880503143}, 3: {2: 0.33333333333333337, 4: 0.339622641509434}, 5: {2: 0.3541666666666667, 4: 0.34591194968553457}}
# cmb_tst = {2: 0.4, 4: 0.6}
# dCombtst = {1: 0.3136792452830188, 3: 0.33710691823899375, 5: 0.3492138364779874}

# %%
def getAllRelWords_train(dist, count_history, rWords, origWordsAll, expansionCount1, N1, expansionCount2, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights, indriRunQuery_hist_, dumpindex_hist_):
    relText_stringAll = []
    relText_string = dict()
    relWords_sel = dict()
    for c1, (docno, origWords) in enumerate(origWordsAll.iteritems()):
        print("c1 =", c1, "docno =", docno, "--- origWords =", origWords)
        args = (count_history, rWords, dist, docno, origWords, expansionCount1, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights)
        indriRunQuery_hist_, dumpindex_hist_ = getRelWords_train(args, indriRunQuery_hist_, dumpindex_hist_)
        #print("c1 =", c1, "- len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) =", len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())))
    
    #print("relText_stringAll =", relText_stringAll)
    return (indriRunQuery_hist_, dumpindex_hist_)

# %%
def getAllRelWords(dist, count_history, rWords, origWordsAll, expansionCount1, N1, expansionCount2, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights, indriRunQuery_hist_, dumpindex_hist_):
    relText_stringAll = []
    relText_string = dict()
    relWords_sel = dict()
    for c1, (docno, origWords) in enumerate(origWordsAll.iteritems()):
        #print(str(c1), "---", docno, "---", origWords)
        args = (count_history, rWords, dist, docno, origWords, expansionCount1, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights)
        count_history, relText_string_, relWords_sel_ = getRelWords(args, indriRunQuery_hist_, dumpindex_hist_)
        #print("len(indriRunQuery_hist_), len(dumpindex_hist_['dcf']), len(dumpindex_hist_['ef']) =", len(indriRunQuery_hist_), len(dumpindex_hist_['dcf']), len(dumpindex_hist_['ef']))
        relText_string[docno] = relText_string_
        relWords_sel[docno] = relWords_sel_[0:N1]
        #print(docno, "---", origWords, "---", relWords_sel_)
    relText_stringAll += [relText_string]
    """
    relText_string = dict()
    relWords_sel = dict()
    for docno, origWords_new in relWords_sel.iteritems():
        args = (count_history, rWords, docno, origWords, expansionCount1, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights)
        count_history, relText_string_, relWords_sel_ = getRelWords(args, indriRunQuery_hist_, dumpindex_hist_)
        relText_string[docno] = relText_string_
        relWords_sel[docno] = relWords_sel_
    relText_stringAll += [relText_string]
    """
    #print("relText_stringAll =", relText_stringAll)
    return (count_history, relText_stringAll, relWords_sel)

# %%
regex = re.compile('[%s]' % re.escape(string.punctuation))
def genQueries(cfgOutFileName_, origWordsAll, relText_stringAll, intCoeff0, intCoeff1, intCoeff2, dirCoeff):
    #    #print("intCoeff =", intCoeff)
    with open(cfgInFileName, 'r') as inFile:
        reader = inFile.read()
        soupNew = BeautifulSoup("", 'lxml')
        parameters_tag = soupNew.new_tag("parameters")
        index_tag = soupNew.new_tag("index")
        index_tag.string = colIndexDir
        parameters_tag.append(index_tag)
            #print(tags)

        for docno, origWords in origWordsAll.iteritems():
            doc_tag = soupNew.new_tag("query")

            docno_tag = soupNew.new_tag("number")
            docno_tag.string = docno
            doc_tag.append(docno_tag)

            text_tag = soupNew.new_tag("text")
            text_tag.string = "#weight(\n" 
                    
            text_tag.string += str(intCoeff0) + " #combine(" 
            for ow in set(origWords):
                ow = regex.sub(' ', ow)
                text_tag.string += ow + " "
            text_tag.string += ")\n"

            if len(relText_stringAll[0])>0:
                if len(relText_stringAll[0][docno]) > 3: 
                    relText_string1 = regex.sub(' ', relText_stringAll[0][docno])
                    text_tag.string += str(intCoeff1) + " #combine(" 
                    #print("relText_string1 =", relText_string1)
                    text_tag.string += relText_string1.encode('utf-8')
                    text_tag.string += ")\n"
            
            """
            #print(len(relText_stringAll[1]))
            if len(relText_stringAll[1])>0:
                if len(relText_stringAll[1][docno]) > 3: 
                    relText_string2 = regex.sub(' ', relText_stringAll[1][docno])
                    text_tag.string += str(intCoeff2) + " #combine(" 
                    #print("relText_string2 =", relText_string2)
                    text_tag.string += relText_string2.encode('utf-8')
                    text_tag.string += ")\n"
            """
            #print("origWords =", origWords)
            #print("relWords_sel1 =", relWords_sel1)
            #print("relWords_sel2 =", relWords_sel2)
            
            
            text_tag.string += ") "

            doc_tag.append(text_tag)

            parameters_tag.append(doc_tag)
            #print(doc_tag)

        rule_tag = soupNew.new_tag("rule")
        rule_tag.string = "method:dir,mu:" + str(dirCoeff)
        #rule_tag.string = "method:two"
        parameters_tag.append(rule_tag)

        #intCoeff_tag = soupNew.new_tag("intCoeff")
        #intCoeff_tag.string = "0.8"
        #parameters_tag.append(intCoeff_tag)

        threads_tag = soupNew.new_tag("threads")
        threads_tag.string = "32"
        parameters_tag.append(threads_tag)

        count_tag = soupNew.new_tag("count")
        count_tag.string = "1000"
        parameters_tag.append(count_tag)

        trecFormat_tag = soupNew.new_tag("trecFormat")
        trecFormat_tag.string = "true"
        parameters_tag.append(trecFormat_tag)

        soupNew.append(parameters_tag)
        #print(soupNew.prettify())
    #print("outFileName =", outFileName)
    with open( cfgOutFileName_, 'w') as outFile:
        soupNewStr = str(soupNew)
        soupNewStr = soupNewStr.replace("</text>", "\n</text>\n").replace("query>", "query>\n").replace("<text>", "\n<text>\n").replace("</index>", "</index>\n").replace("\n<index>", "<index>")

        outFile.write(soupNewStr)

# %%
def precisionCompute_train(dist, origWordsAll, count_history, intCoeffs0, intCoeffs1, intCoeffs2, expansionCounts1, expansionCounts2, dirCoeffs, N1s, featureWeights_, indriRunQuery_hist_, dumpindex_hist_):
    #randNum = random.randint(1,1e9)
    indriRunQuery_hist_, dumpindex_hist_ = getAllRelWords_train(dist, count_history, rWords, origWordsAll, expansionCounts1[0], N1s[0], expansionCounts2[0], intCoeffs0[0], intCoeffs1[0], intCoeffs2[0], dirCoeffs[0], featureWeights_[0], indriRunQuery_hist_, dumpindex_hist_)
                                    
    return count_history, indriRunQuery_hist_, dumpindex_hist_

# %%
#training
dist = str(1)
intCoeffs0 = [ 0.7 ]
intCoeffs1 = [ 0.3 ]
#intCoeffs2 = [ 0.18 ]
intCoeffs2 = [ 0.5 ]
#intCoeffs1 = np.arange(0.1, 1, 0.1)
expansionCounts1 = [ 85 ]
#expansionCounts2 = [ 145 ]
expansionCounts2 = [ 0 ]
#expansionCounts2 = range(15, 220, 5)
dirCoeffs = [ 1600 ]
#dirCoeffs = range(200, 4000, 200)
N1s = [0]
rWords = dict()
featureWeights_1 = {'maxTopColCor': 0.1, 'expTDocScore': 0.1, 'maxColPCor': 0.1, 'avgCDocScore': 0.1, 'topTermFrac': 0.1, 'avgColCor': 0.1, 'avgTopColCor': 0.1, 'numCanDocs': 0.1, 'maxTopColPCor': 0.1, 'maxCDocScore': 0.1, 'avgColPCor': 0.1, 'conIdf': 0.1, 'avgTopColPCor': 0.1, 'maxColCor': 0.1}
featureWeights_l=[featureWeights_1]
origWordsAll = analyseQueries()

count_history, indriRunQuery_hist_, dumpindex_hist_ = precisionCompute_train(dist, origWordsAll, count_history, intCoeffs0, intCoeffs1, intCoeffs2, expansionCounts1, expansionCounts2, dirCoeffs, N1s, featureWeights_l, indriRunQuery_hist_, dumpindex_hist_)
# Out:
# c1 = 0 docno = 407 --- origWords = ['poach', 'wildlife', 'preserve']
# c1 = 1 docno = 406 --- origWords = ["parkinson's", 'disease']
# c1 = 2 docno = 405 --- origWords = ['cosmic', 'event']
# c1 = 3 docno = 404 --- origWords = ['ireland', 'peace', 'talk']
# c1 = 4 docno = 403 --- origWords = ['osteoporosis']
# c1 = 5 docno = 402 --- origWords = ['behavioral', 'genetics']
# c1 = 6 docno = 401 --- origWords = ['foreign', 'minority', 'germany']
# c1 = 7 docno = 400 --- origWords = ['amazon', 'rain', 'forest']
# c1 = 8 docno = 409 --- origWords = ['legal', 'pan', 'be', '103']
# c1 = 9 docno = 408 --- origWords = ['tropical', 'storm']
# c1 = 10 docno = 366 --- origWords = ['commercial', 'cyanide', 'use']
# c1 = 11 docno = 420 --- origWords = ['carbon', 'monoxide', 'poison']
# c1 = 12 docno = 364 --- origWords = ['rabies']
# c1 = 13 docno = 422 --- origWords = ['art', 'steal', 'forge']
# c1 = 14 docno = 425 --- origWords = ['counterfeit', 'money']
# c1 = 15 docno = 363 --- origWords = ['transportation', 'tunnel', 'disaster']
# c1 = 16 docno = 379 --- origWords = ['mainstreaming']
# c1 = 17 docno = 378 --- origWords = ['euro', 'opposition']
# c1 = 18 docno = 416 --- origWords = ['three', 'gorge', 'project']
# c1 = 19 docno = 417 --- origWords = ['creativity']
# c1 = 20 docno = 410 --- origWords = ['schengen', 'agreement']
# c1 = 21 docno = 427 --- origWords = ['uv', 'damage', 'eye']
# c1 = 22 docno = 412 --- origWords = ['airport', 'security']
# c1 = 23 docno = 413 --- origWords = ['steel', 'production']
# c1 = 24 docno = 371 --- origWords = ['health', 'insurance', 'holistic']
# c1 = 25 docno = 370 --- origWords = ['food', 'drug', 'law']
# c1 = 26 docno = 373 --- origWords = ['encryption', 'equipment', 'export']
# c1 = 27 docno = 361 --- origWords = ['clothe', 'sweatshop']
# c1 = 28 docno = 418 --- origWords = ['quilt', 'income']
# c1 = 29 docno = 419 --- origWords = ['recycle', 'automobile', 'tire']
# c1 = 30 docno = 377 --- origWords = ['cigar', 'smoke']
# c1 = 31 docno = 376 --- origWords = ['world', 'court']
# c1 = 32 docno = 393 --- origWords = ['mercy', 'kill']
# c1 = 33 docno = 392 --- origWords = ['robotics']
# c1 = 34 docno = 391 --- origWords = ['r', 'drug', 'price']
# c1 = 35 docno = 390 --- origWords = ['orphan', 'drug']
# c1 = 36 docno = 397 --- origWords = ['automobile', 'recall']
# c1 = 37 docno = 396 --- origWords = ['sick', 'build', 'syndrome']
# c1 = 38 docno = 395 --- origWords = ['tourism']
# c1 = 39 docno = 394 --- origWords = ['home', 'school']
# c1 = 40 docno = 399 --- origWords = ['oceanographic', 'vessel']
# c1 = 41 docno = 398 --- origWords = ['dismantle', "europe's", 'arsenal']
# c1 = 42 docno = 414 --- origWords = ['cuba', 'sugar', 'export']
# c1 = 43 docno = 415 --- origWords = ['drug', 'golden', 'triangle']
# c1 = 44 docno = 429 --- origWords = ['legionnaire', 'disease']
# c1 = 45 docno = 428 --- origWords = ['decline', 'birth', 'rate']
# c1 = 46 docno = 368 --- origWords = ['in', 'vitro', 'fertilization']
# c1 = 47 docno = 369 --- origWords = ['anorexia', 'nervosa', 'bulimia']
# c1 = 48 docno = 421 --- origWords = ['industrial', 'waste', 'disposal']
# c1 = 49 docno = 367 --- origWords = ['piracy']
# c1 = 50 docno = 423 --- origWords = ['milosevic', 'mirjana', 'markovic']
# c1 = 51 docno = 365 --- origWords = ['el', 'nino']
# c1 = 52 docno = 362 --- origWords = ['human', 'smuggle']
# c1 = 53 docno = 424 --- origWords = ['suicide']
# c1 = 54 docno = 360 --- origWords = ['drug', 'legalization', 'benefit']
# c1 = 55 docno = 426 --- origWords = ['law', 'enforcement', 'dog']
# c1 = 56 docno = 449 --- origWords = ['antibiotic', 'ineffectiveness']
# c1 = 57 docno = 448 --- origWords = ['ship', 'loss']
# c1 = 58 docno = 443 --- origWords = ['u_s', 'investment', 'africa']
# c1 = 59 docno = 442 --- origWords = ['heroic', 'act']
# c1 = 60 docno = 441 --- origWords = ['lyme', 'disease']
# c1 = 61 docno = 440 --- origWords = ['child', 'labor']
# c1 = 62 docno = 447 --- origWords = ['stirling', 'engine']
# c1 = 63 docno = 446 --- origWords = ['tourist', 'violence']
# c1 = 64 docno = 445 --- origWords = ['woman', 'clergy']
# c1 = 65 docno = 444 --- origWords = ['supercritical', 'fluid']
# c1 = 66 docno = 380 --- origWords = ['obesity', 'medical', 'treatment']
# c1 = 67 docno = 381 --- origWords = ['alternative', 'medicine']
# c1 = 68 docno = 382 --- origWords = ['hydrogen', 'fuel', 'automobile']
# c1 = 69 docno = 383 --- origWords = ['mental', 'illness', 'drug']
# c1 = 70 docno = 384 --- origWords = ['space', 'station', 'moon']
# c1 = 71 docno = 385 --- origWords = ['hybrid', 'fuel', 'car']
# c1 = 72 docno = 386 --- origWords = ['teach', 'disable', 'child']
# c1 = 73 docno = 387 --- origWords = ['radioactive', 'waste']
# c1 = 74 docno = 388 --- origWords = ['organic', 'soil', 'enhancement']
# c1 = 75 docno = 389 --- origWords = ['illegal', 'technology', 'transfer']
# c1 = 76 docno = 411 --- origWords = ['salvage', 'shipwreck', 'treasure']
# c1 = 77 docno = 372 --- origWords = ['native', 'american', 'casino']
# c1 = 78 docno = 375 --- origWords = ['hydrogen', 'energy']
# c1 = 79 docno = 374 --- origWords = ['nobel', 'prize', 'winner']
# c1 = 80 docno = 438 --- origWords = ['tourism', 'increase']
# c1 = 81 docno = 439 --- origWords = ['invention', 'scientific', 'discovery']
# c1 = 82 docno = 436 --- origWords = ['railway', 'accident']
# c1 = 83 docno = 437 --- origWords = ['deregulation', 'gas', 'electric']
# c1 = 84 docno = 434 --- origWords = ['estonia', 'economy']
# c1 = 85 docno = 435 --- origWords = ['curb', 'population', 'growth']
# c1 = 86 docno = 432 --- origWords = ['profile', 'motorist', 'police']
# c1 = 87 docno = 433 --- origWords = ['greek', 'philosophy', 'stoicism']
# c1 = 88 docno = 430 --- origWords = ['killer', 'bee', 'attack']
# c1 = 89 docno = 431 --- origWords = ['robotic', 'technology']
# c1 = 90 docno = 450 --- origWords = ['king', 'hussein', 'peace']
# c1 = 91 docno = 357 --- origWords = ['territorial', 'water', 'dispute']
# c1 = 92 docno = 356 --- origWords = ['postmenopausal', 'estrogen', 'britain']
# c1 = 93 docno = 355 --- origWords = ['ocean', 'remote', 'sense']
# c1 = 94 docno = 354 --- origWords = ['journalist', 'risk']
# c1 = 95 docno = 353 --- origWords = ['antarctica', 'exploration']
# c1 = 96 docno = 352 --- origWords = ['british', 'chunnel', 'impact']
# c1 = 97 docno = 351 --- origWords = ['falkland', 'petroleum', 'exploration']
# c1 = 98 docno = 359 --- origWords = ['mutual', 'fund', 'predictor']
# c1 = 99 docno = 358 --- origWords = ['blood', 'alcohol', 'fatality']

# %%
def precisionCompute(dist, origWordsAll, count_history, intCoeffs0, intCoeffs1, intCoeffs2, expansionCounts1, expansionCounts2, dirCoeffs, N1s, featureWeights_, indriRunQuery_hist_, dumpindex_hist_):
    mapPrecs = []
    for featureWeights in featureWeights_:
        for N1 in N1s:
            for intCoeff0 in intCoeffs0:
                for intCoeff1 in intCoeffs1:
                    for intCoeff2 in intCoeffs2:
                        for expansionCount1 in expansionCounts1:
                            for expansionCount2 in expansionCounts2:
                                for dirCoeff in dirCoeffs:
                                    
                                    
                                    #res = getAllRelWords_p(count_history, rWords, origWordsAll, expansionCount1, N1, expansionCount2, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights)
                                    
                                    count_history, relText_stringAll, relWords_sel = getAllRelWords(dist, count_history, rWords, origWordsAll, expansionCount1, N1, expansionCount2, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights, indriRunQuery_hist_, dumpindex_hist_)
                                    
                                    #print("len(relText_stringAll[1]) =", len(relText_stringAll[1]))
                                    ##########
                                    #cfgOutFileName = os.path.join("tmp","sbsb",str(randNum)+".cfg")
                                    #runsFileName = os.path.join("tmp","sbsb",str(randNum)+".run")
                                    #evalsFileName = os.path.join("tmp","sbsb",str(randNum)+".eval")
                                    ##########
                                    genQueries(cfgOutFileName, origWordsAll, relText_stringAll, intCoeff0, intCoeff1, intCoeff2, dirCoeff)
                                    subprocess.Popen("IndriRunQuery " + cfgOutFileName + " > " + runsFileName, shell=True, stdout=subprocess.PIPE).stdout.read()
                                    cmd = "trec_eval -q " + colQrelsFileName + " " + runsFileName + " > " + evalsFileName
                                    subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE).stdout.read()
                                    cmd = "cat " + evalsFileName + " | grep map | grep all | grep -v gm | awk '{print $3}' "
                                    #print ("cmd = ", cmd)
                                    mapPrec = subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE).stdout.read()
                                    mapPrecs += [mapPrec]
                                    print("featureWeights =", featureWeights)
                                    print("intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 =", intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, N1, mapPrec)
                                    #mapPrecs[intCoeff] = mapPrec
    return relText_stringAll, relWords_sel, mapPrecs

# %%
dist = str(1)
intCoeffs0 = [ 0.7 ]
intCoeffs1 = [ 0.5 ]
#intCoeffs2 = [ 0.18 ]
intCoeffs2 = [ 0.5 ]
#intCoeffs1 = np.arange(0.1, 1, 0.1)
#expansionCounts1 = [ 0.00050 ]
expansionCounts1 = [ 20 ]
#expansionCounts2 = [ 145 ]
expansionCounts2 = [ 0 ]
#expansionCounts1 = range(0, 220, 5)
dirCoeffs = [ 1600 ]
#dirCoeffs = range(200, 4000, 200)
N1s_max = [100]
#N1s = range(1, 30, 1)
#mapPrecs = 
rWords = dict()
maxIteration = 1e4
featureWeights_l=[]
featureWeights_1 = {'maxTopColCor': 0.1, 'expTDocScore': 0.1, 'maxColPCor': 0.1, 'avgCDocScore': 0.1, 'topTermFrac': 0.1, 'avgColCor': 0.1, 'avgTopColCor': 0.1, 'numCanDocs': 0.1, 'maxTopColPCor': 0.1, 'maxCDocScore': 0.1, 'avgColPCor': 0.1, 'conIdf': 0.1, 'avgTopColPCor': 0.1, 'maxColCor': 0.1}
"""
for conIdf in [0.1] :
#for conIdf in [-5000, -500, -50, -5, -0.5, -0.05, 0, 0.05, 0.5, 5, 50, 500, 5000] :
#for conIdf in np.arange(-1,1,0.2):
    featureWeights_1["conIdf"] = conIdf
    featureWeights_l += [dict(featureWeights_1)]
relText_stringAll, relWords_sel1, mapPrecs = precisionCompute(dist, origWordsAll, count_history, intCoeffs0, intCoeffs1, intCoeffs2, expansionCounts1, expansionCounts2, dirCoeffs, N1s_max, featureWeights_l, indriRunQuery_hist_, dumpindex_hist_)
"""
#for ft, wg in featureWeights_1.iteritems():
# initialize:
featureWeights_1_new = { k:0.0 for k in featureWeights_1.keys()}
#featureWeights_1_new = {'maxTopColCor': 0.0, 'expTDocScore': 0.0, 'maxColPCor': 0.0, 'avgCDocScore': 0.0, 'topTermFrac': 0.0, 'avgColCor': 0.0, 'avgTopColCor': 0.0, 'numCanDocs': 0.0, 'maxTopColPCor': 0.0, 'maxCDocScore': 0.0, 'avgColPCor': 0.0, 'conIdf': 0.1, 'avgTopColPCor': 0.1, 'maxColCor': 0.1}
#for wg_new in np.arange(-1.0,1.1,1.0):
count = 0
while(count < maxIteration):
    #print("feature =", ft, " weight =", wg_new)
    rNums = np.random.rand(1, len(featureWeights_1))
    rNums = [np.abs(i) for i in rNums]
    rNums = rNums/np.sum(rNums) # normalize
    #print ("rNums =", rNums[0])
    featureWeights_l = [{ k:rNums[0][c1] for c1, k in enumerate(featureWeights_1.keys())}]
    #eatureWeights_l=[]
    #featureWeights_1_new[ft] = wg_new
    #featureWeights_l += [dict(featureWeights_1_new)]
    relText_stringAll, relWords_sel1, mapPrecs = precisionCompute(dist, origWordsAll, count_history, intCoeffs0, intCoeffs1, intCoeffs2, expansionCounts1, expansionCounts2, dirCoeffs, N1s_max, featureWeights_l, indriRunQuery_hist_, dumpindex_hist_)
    count += 1
# Out:
# featureWeights = {'maxTopColCor': 0.087993735999455799, 'maxColPCor': 0.06849827448900403, 'conIdf': 0.061699739135898692, 'avgCDocScore': 0.082435909952930597, 'topTermFrac': 0.10568288139500343, 'avgColCor': 0.10553750018241778, 'avgTopColCor': 0.11398499372402032, 'numCanDocs': 0.014262834284179383, 'maxTopColPCor': 0.037711224176024412, 'expTDocScore': 0.005913537468982084, 'avgColPCor': 0.069928954325999548, 'maxCDocScore': 0.081241050984416988, 'avgTopColPCor': 0.15110498848069168, 'maxColCor': 0.014004375400975246}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2047
#
# featureWeights = {'maxTopColCor': 0.082726961568563018, 'maxColPCor': 0.13148048546867061, 'conIdf': 0.072389533520843208, 'avgCDocScore': 0.12910261598489978, 'topTermFrac': 0.047473380288748819, 'avgColCor': 0.0068869499075973704, 'avgTopColCor': 0.12368733783556034, 'numCanDocs': 0.02666185106401207, 'maxTopColPCor': 0.050142418643430518, 'expTDocScore': 0.0046152148894014183, 'avgColPCor': 0.12761911166697962, 'maxCDocScore': 0.039715946458451341, 'avgTopColPCor': 0.096286886299501537, 'maxColCor': 0.061211306403340528}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2037
#
# featureWeights = {'maxTopColCor': 0.087573169220011751, 'maxColPCor': 0.081058291571499824, 'conIdf': 0.11719578280430687, 'avgCDocScore': 0.021384374537414631, 'topTermFrac': 0.027900412135207723, 'avgColCor': 0.080502787633307579, 'avgTopColCor': 0.11962878493369128, 'numCanDocs': 0.058324776879346646, 'maxTopColPCor': 0.085004869996992707, 'expTDocScore': 0.053286135534099596, 'avgColPCor': 0.09981353346844285, 'maxCDocScore': 0.045722728177545593, 'avgTopColPCor': 0.088209607691625974, 'maxColCor': 0.034394745416506868}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2045
#
# featureWeights = {'maxTopColCor': 0.05832924059362872, 'maxColPCor': 0.10292760769113074, 'conIdf': 0.062551372743006983, 'avgCDocScore': 0.10480881974721219, 'topTermFrac': 0.055853591659931708, 'avgColCor': 0.018360273462470718, 'avgTopColCor': 0.018344471470781887, 'numCanDocs': 0.11250020632591917, 'maxTopColPCor': 0.054276123837204135, 'expTDocScore': 0.11817533895870597, 'avgColPCor': 0.078022782153052778, 'maxCDocScore': 0.11394442405934657, 'avgTopColPCor': 0.059392521989571359, 'maxColCor': 0.042513225308036875}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2042
#
# featureWeights = {'maxTopColCor': 0.10314996730402738, 'maxColPCor': 0.0089079388309562437, 'conIdf': 0.143767385443408, 'avgCDocScore': 0.038987490057292878, 'topTermFrac': 0.056423206091751173, 'avgColCor': 0.030623227502151042, 'avgTopColCor': 0.04191872748227269, 'numCanDocs': 0.12389073636173747, 'maxTopColPCor': 0.056035107023395099, 'expTDocScore': 0.14776276484380158, 'avgColPCor': 0.066613672209894101, 'maxCDocScore': 0.055820236493519762, 'avgTopColPCor': 0.088333341612349167, 'maxColCor': 0.037766198743443398}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2055
#
# featureWeights = {'maxTopColCor': 0.14184590829046653, 'maxColPCor': 0.034729298325074077, 'conIdf': 0.12311874916914343, 'avgCDocScore': 0.029589833621354159, 'topTermFrac': 0.083268400656324376, 'avgColCor': 0.024966858927185337, 'avgTopColCor': 0.10707766153980654, 'numCanDocs': 0.085596170451925829, 'maxTopColPCor': 0.08285537020125211, 'expTDocScore': 0.12210176605258007, 'avgColPCor': 0.018681852718572128, 'maxCDocScore': 0.048849119012889713, 'avgTopColPCor': 0.019445994219899058, 'maxColCor': 0.077873016813526624}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2051
#
# featureWeights = {'maxTopColCor': 0.012650679882765114, 'maxColPCor': 0.056212978212150433, 'conIdf': 0.051725494906295071, 'avgCDocScore': 0.10202759751041819, 'topTermFrac': 0.096998447106855665, 'avgColCor': 0.082778436544447151, 'avgTopColCor': 0.043581240260052168, 'numCanDocs': 0.11439910350734944, 'maxTopColPCor': 0.12334066533875146, 'expTDocScore': 0.093854527362285584, 'avgColPCor': 0.019671355840478775, 'maxCDocScore': 0.1224965408546889, 'avgTopColPCor': 0.028235579487201616, 'maxColCor': 0.052027353186260457}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2051
#
# featureWeights = {'maxTopColCor': 0.053194765070332807, 'maxColPCor': 0.14806369241595213, 'conIdf': 0.10920623428409763, 'avgCDocScore': 0.11611378691755067, 'topTermFrac': 0.093268960848847809, 'avgColCor': 0.094865702487921047, 'avgTopColCor': 0.024212834244811382, 'numCanDocs': 0.044956049147601596, 'maxTopColPCor': 0.08396526105265345, 'expTDocScore': 0.026525165839084229, 'avgColPCor': 0.073211133156243127, 'maxCDocScore': 0.057319530206542353, 'avgTopColPCor': 0.054726856020612717, 'maxColCor': 0.020370028307749161}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2039
#
# featureWeights = {'maxTopColCor': 0.085536543143279062, 'maxColPCor': 0.0038571422483867075, 'conIdf': 0.053628838942265597, 'avgCDocScore': 0.084718740642477863, 'topTermFrac': 0.053704787003460631, 'avgColCor': 0.027360612623945128, 'avgTopColCor': 0.040286448580253389, 'numCanDocs': 0.07350486440119755, 'maxTopColPCor': 0.15431417648791571, 'expTDocScore': 0.10501838991819615, 'avgColPCor': 0.02325083042469446, 'maxCDocScore': 0.084141317221497244, 'avgTopColPCor': 0.047671093780108358, 'maxColCor': 0.16300621458232228}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2041
#
# featureWeights = {'maxTopColCor': 0.067081846035896453, 'maxColPCor': 0.098480705252496845, 'conIdf': 0.075779059810613919, 'avgCDocScore': 0.093545951162957955, 'topTermFrac': 0.093854043936671294, 'avgColCor': 0.10285396956150067, 'avgTopColCor': 0.074895770500236394, 'numCanDocs': 0.026102194233007924, 'maxTopColPCor': 0.053058320708264564, 'expTDocScore': 0.075306851982286274, 'avgColPCor': 0.047081736351553223, 'maxCDocScore': 0.023814709576182778, 'avgTopColPCor': 0.088250849488644381, 'maxColCor': 0.079893991399687322}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2053
#
# featureWeights = {'maxTopColCor': 0.092176549493493742, 'maxColPCor': 0.098107254041742031, 'conIdf': 0.056476992872476754, 'avgCDocScore': 0.091367365085731456, 'topTermFrac': 0.12080325041787843, 'avgColCor': 0.11931090164317139, 'avgTopColCor': 0.01516624289882362, 'numCanDocs': 0.11464806414943128, 'maxTopColPCor': 0.071464786949836073, 'expTDocScore': 0.050420501079667286, 'avgColPCor': 0.10569682161986718, 'maxCDocScore': 0.049715837137708122, 'avgTopColPCor': 0.0084344717330184053, 'maxColCor': 0.0062109608771542231}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2043
#
# featureWeights = {'maxTopColCor': 0.09828529091270484, 'maxColPCor': 0.045601419990268441, 'conIdf': 0.090953368066016047, 'avgCDocScore': 0.051731687518779192, 'topTermFrac': 0.040815834103412177, 'avgColCor': 0.12337779950588783, 'avgTopColCor': 0.10242342525606364, 'numCanDocs': 0.13135978924120717, 'maxTopColPCor': 0.10392758543108196, 'expTDocScore': 0.035465705037701988, 'avgColPCor': 0.017017296166202445, 'maxCDocScore': 0.038383190990963302, 'avgTopColPCor': 0.09476562473711074, 'maxColCor': 0.025891983042600153}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2052
#
# featureWeights = {'maxTopColCor': 0.023083736912259765, 'maxColPCor': 0.085007349458397372, 'conIdf': 0.051649833708764976, 'avgCDocScore': 0.057528334504961642, 'topTermFrac': 0.0072792494120036497, 'avgColCor': 0.0079399057509334688, 'avgTopColCor': 0.080309761515431274, 'numCanDocs': 0.10728738974913929, 'maxTopColPCor': 0.053145490358550332, 'expTDocScore': 0.051177458443953404, 'avgColPCor': 0.12868305953393364, 'maxCDocScore': 0.14684398278074332, 'avgTopColPCor': 0.078092696147187585, 'maxColCor': 0.12197175172374024}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2032
#
# featureWeights = {'maxTopColCor': 0.065203239718649858, 'maxColPCor': 0.0045462558205201396, 'conIdf': 0.056422521619325289, 'avgCDocScore': 0.12873964958673748, 'topTermFrac': 0.015871276540134316, 'avgColCor': 0.10535898175522736, 'avgTopColCor': 0.0089365115524756913, 'numCanDocs': 0.055072262799221262, 'maxTopColPCor': 0.15027980274726591, 'expTDocScore': 0.020472214701215019, 'avgColPCor': 0.047053472540185659, 'maxCDocScore': 0.13170302493995928, 'avgTopColPCor': 0.08537554380981327, 'maxColCor': 0.12496524186926945}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2035
#
# featureWeights = {'maxTopColCor': 0.028625827552152754, 'maxColPCor': 0.054675942199556085, 'conIdf': 0.061819022987710519, 'avgCDocScore': 0.062940926406885631, 'topTermFrac': 0.027177208684964017, 'avgColCor': 0.070166699278218989, 'avgTopColCor': 0.05535330474191049, 'numCanDocs': 0.092892828155999169, 'maxTopColPCor': 0.11587633112598382, 'expTDocScore': 0.11461056442454272, 'avgColPCor': 0.10831835816882117, 'maxCDocScore': 0.0070588258929219225, 'avgTopColPCor': 0.085144248843135817, 'maxColCor': 0.11533991153719698}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2030
#
# featureWeights = {'maxTopColCor': 0.066904107275680372, 'maxColPCor': 0.090572727947910298, 'conIdf': 0.053678520108734612, 'avgCDocScore': 0.012199179921482046, 'topTermFrac': 0.011334315798726255, 'avgColCor': 0.13451275291110948, 'avgTopColCor': 0.12062066262191791, 'numCanDocs': 0.10844669971291257, 'maxTopColPCor': 0.10515276315243197, 'expTDocScore': 0.11077586287907716, 'avgColPCor': 0.055724329589383295, 'maxCDocScore': 0.024430406531816679, 'avgTopColPCor': 0.053144898153970589, 'maxColCor': 0.052502773394846887}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2027
#
# featureWeights = {'maxTopColCor': 0.10570957144132503, 'maxColPCor': 0.12034199560073298, 'conIdf': 0.062134776622439485, 'avgCDocScore': 0.081874228552305653, 'topTermFrac': 0.009115594656567064, 'avgColCor': 0.055294657552070831, 'avgTopColCor': 0.053361129050843621, 'numCanDocs': 0.12380702975369991, 'maxTopColPCor': 0.060999992500903114, 'expTDocScore': 0.029394781734878264, 'avgColPCor': 0.012845093608973469, 'maxCDocScore': 0.13371263928054564, 'avgTopColPCor': 0.12295037164752845, 'maxColCor': 0.028458137997186373}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2041
#
# featureWeights = {'maxTopColCor': 0.001788472015029153, 'maxColPCor': 0.18449618530475786, 'conIdf': 0.036921543140677193, 'avgCDocScore': 0.13831226851020303, 'topTermFrac': 0.014743734820257091, 'avgColCor': 0.0044778046233352412, 'avgTopColCor': 0.067433893279695012, 'numCanDocs': 0.066158075444788994, 'maxTopColPCor': 0.067350671382852584, 'expTDocScore': 0.085453906142029384, 'avgColPCor': 0.12539564795139266, 'maxCDocScore': 0.02584217941696175, 'avgTopColPCor': 0.038400834839180123, 'maxColCor': 0.14322478312883991}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2031
#
# featureWeights = {'maxTopColCor': 0.055918126045969282, 'maxColPCor': 0.12229815866644894, 'conIdf': 0.076803607186458234, 'avgCDocScore': 0.040314955748757188, 'topTermFrac': 0.11332532293596284, 'avgColCor': 0.060263661572846294, 'avgTopColCor': 0.11386150195973496, 'numCanDocs': 0.045193039115774873, 'maxTopColPCor': 0.099329630905261798, 'expTDocScore': 0.032987878827803109, 'avgColPCor': 0.030852815108458418, 'maxCDocScore': 0.008772218093192367, 'avgTopColPCor': 0.075027814870444257, 'maxColCor': 0.12505126896288751}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2054
#
# featureWeights = {'maxTopColCor': 0.012675379165989797, 'maxColPCor': 0.011845151226569928, 'conIdf': 0.11253404278386521, 'avgCDocScore': 0.099089163671764499, 'topTermFrac': 0.11576317273576411, 'avgColCor': 0.16564024099200306, 'avgTopColCor': 0.13621210450710114, 'numCanDocs': 0.057168690908786755, 'maxTopColPCor': 0.012219608714336336, 'expTDocScore': 0.010548770854292502, 'avgColPCor': 0.10840225095802772, 'maxCDocScore': 0.04090029837832234, 'avgTopColPCor': 0.021811247251265129, 'maxColCor': 0.095189877851911686}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2052
#
# featureWeights = {'maxTopColCor': 0.019878108064092175, 'maxColPCor': 0.1101039103685829, 'conIdf': 0.14581280756550313, 'avgCDocScore': 0.082993443803490941, 'topTermFrac': 0.064156375081653824, 'avgColCor': 0.096791163656620799, 'avgTopColCor': 0.14040375859504392, 'numCanDocs': 0.002020456461762877, 'maxTopColPCor': 0.023443592523423505, 'expTDocScore': 0.062333227708565246, 'avgColPCor': 0.058180622106049344, 'maxCDocScore': 0.038261527801698204, 'avgTopColPCor': 0.016599632894612516, 'maxColCor': 0.13902137336890058}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2041
#
# featureWeights = {'maxTopColCor': 0.13497008714432931, 'maxColPCor': 0.014189413703512397, 'conIdf': 0.054427761525654955, 'avgCDocScore': 0.086544408679679205, 'topTermFrac': 0.089066670239205545, 'avgColCor': 0.061325487459074686, 'avgTopColCor': 0.13115973077378718, 'numCanDocs': 0.011041284672750382, 'maxTopColPCor': 0.12066040279370455, 'expTDocScore': 0.070555492850002441, 'avgColPCor': 0.047351580520021322, 'maxCDocScore': 0.099516321856456091, 'avgTopColPCor': 0.012837061061361765, 'maxColCor': 0.066354296720460226}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2052
#
# featureWeights = {'maxTopColCor': 0.11268627140301821, 'maxColPCor': 0.05421457277665339, 'conIdf': 0.045742850669030007, 'avgCDocScore': 0.10187878749397059, 'topTermFrac': 0.079838761609697814, 'avgColCor': 0.041514814406137163, 'avgTopColCor': 0.11445658212743651, 'numCanDocs': 0.023374546926782574, 'maxTopColPCor': 0.12158144462002725, 'expTDocScore': 0.056831652810930181, 'avgColPCor': 0.00018193886473082314, 'maxCDocScore': 0.11350366854096108, 'avgTopColPCor': 0.025811711141680811, 'maxColCor': 0.10838239660894344}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2048
#
# featureWeights = {'maxTopColCor': 0.03578782117007806, 'maxColPCor': 0.020606425800150336, 'conIdf': 0.062502284248489859, 'avgCDocScore': 0.11656730963894125, 'topTermFrac': 0.07671096657272046, 'avgColCor': 0.12267820584731669, 'avgTopColCor': 0.017473107585373977, 'numCanDocs': 0.12603931139232749, 'maxTopColPCor': 0.058058640280468567, 'expTDocScore': 0.13062499455192011, 'avgColPCor': 0.019135483733733707, 'maxCDocScore': 0.070460147296543665, 'avgTopColPCor': 0.084211202471146579, 'maxColCor': 0.059144099410789248}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2047
#
# featureWeights = {'maxTopColCor': 0.14245503141803151, 'maxColPCor': 0.0089592201138998864, 'conIdf': 0.08479021085920363, 'avgCDocScore': 0.10550933270091051, 'topTermFrac': 0.043359374536698074, 'avgColCor': 0.11991685311782972, 'avgTopColCor': 0.12219167219564908, 'numCanDocs': 0.025445142796710382, 'maxTopColPCor': 0.046618429188663123, 'expTDocScore': 0.048974788733129958, 'avgColPCor': 0.086997012740107543, 'maxCDocScore': 0.067655495619445033, 'avgTopColPCor': 0.089575252360922661, 'maxColCor': 0.0075521836187988998}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2042
#
# featureWeights = {'maxTopColCor': 0.09299652054890914, 'maxColPCor': 0.11253630879984121, 'conIdf': 0.012522430803027517, 'avgCDocScore': 0.098515302582599051, 'topTermFrac': 0.0023598730171316869, 'avgColCor': 0.10147709863389152, 'avgTopColCor': 0.090418553923703932, 'numCanDocs': 0.014322464928176667, 'maxTopColPCor': 0.063881714880529836, 'expTDocScore': 0.0197137013692949, 'avgColPCor': 0.098632896465574174, 'maxCDocScore': 0.11849760602769389, 'avgTopColPCor': 0.049672497524515379, 'maxColCor': 0.12445303049511101}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2029
#
# featureWeights = {'maxTopColCor': 0.042388695829451144, 'maxColPCor': 0.062197622851486917, 'conIdf': 0.01787042398159281, 'avgCDocScore': 0.061763834784718558, 'topTermFrac': 0.11410952699361529, 'avgColCor': 0.091281876448349814, 'avgTopColCor': 0.0088299143068599952, 'numCanDocs': 0.034732498303147105, 'maxTopColPCor': 0.10111767339120253, 'expTDocScore': 0.11700953946048173, 'avgColPCor': 0.087263492361569717, 'maxCDocScore': 0.097361296473428421, 'avgTopColPCor': 0.080017549114784856, 'maxColCor': 0.084056055699311127}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2047
#
# featureWeights = {'maxTopColCor': 0.03869702043794556, 'maxColPCor': 0.053262325415132455, 'conIdf': 0.065430202246908445, 'avgCDocScore': 0.12453543879672642, 'topTermFrac': 0.072765478212525894, 'avgColCor': 0.032089505862720753, 'avgTopColCor': 0.039019214737954902, 'numCanDocs': 0.098869635946244067, 'maxTopColPCor': 0.047915933633620331, 'expTDocScore': 0.11303070387306149, 'avgColPCor': 0.086063945503575295, 'maxCDocScore': 0.016410299032272122, 'avgTopColPCor': 0.12240448232580867, 'maxColCor': 0.089505813975503445}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2043
#
# featureWeights = {'maxTopColCor': 0.078098576731243277, 'maxColPCor': 0.010170041020549135, 'conIdf': 0.087655594983848117, 'avgCDocScore': 0.089067237605659003, 'topTermFrac': 0.080515743892937516, 'avgColCor': 0.05480610282520354, 'avgTopColCor': 0.0098070970265478185, 'numCanDocs': 0.10747367030058373, 'maxTopColPCor': 0.065170084255318741, 'expTDocScore': 0.14021888669878813, 'avgColPCor': 0.036072956730800014, 'maxCDocScore': 0.081255287943652554, 'avgTopColPCor': 0.030722893980712224, 'maxColCor': 0.12896582600415624}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2044
#
# featureWeights = {'maxTopColCor': 0.055251330023139832, 'maxColPCor': 0.019531029582563891, 'conIdf': 0.073968184402595324, 'avgCDocScore': 0.092519068081532707, 'topTermFrac': 0.09987331130568515, 'avgColCor': 0.0094945251826442402, 'avgTopColCor': 0.10967815247711651, 'numCanDocs': 0.057857944930127143, 'maxTopColPCor': 0.075489971986342122, 'expTDocScore': 0.13307133488843312, 'avgColPCor': 0.11780041158361844, 'maxCDocScore': 0.048670749852635656, 'avgTopColPCor': 0.10234928762170825, 'maxColCor': 0.0044446980818576539}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2046
#
# featureWeights = {'maxTopColCor': 0.073801032407042236, 'maxColPCor': 0.10474065347589571, 'conIdf': 0.07319204555324671, 'avgCDocScore': 0.080916378956205889, 'topTermFrac': 0.098389924785420149, 'avgColCor': 0.11507809131694212, 'avgTopColCor': 0.010577071071990197, 'numCanDocs': 0.12516637045630852, 'maxTopColPCor': 0.018040328232267051, 'expTDocScore': 0.04575605873090062, 'avgColPCor': 0.0084860686066014854, 'maxCDocScore': 0.06439229221821724, 'avgTopColPCor': 0.09446587410707101, 'maxColCor': 0.086997810081890961}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2049
#
# featureWeights = {'maxTopColCor': 0.034680285613603638, 'maxColPCor': 0.10052852880985061, 'conIdf': 0.07041709978716984, 'avgCDocScore': 0.091969359271467405, 'topTermFrac': 0.084050853656156777, 'avgColCor': 0.027313472093040452, 'avgTopColCor': 0.030028754423808045, 'numCanDocs': 0.098584520130960904, 'maxTopColPCor': 0.027519173056610061, 'expTDocScore': 0.076313704270156366, 'avgColPCor': 0.11673212359840378, 'maxCDocScore': 0.015667937317750829, 'avgTopColPCor': 0.1106672174842686, 'maxColCor': 0.11552697048675284}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2048
#
# featureWeights = {'maxTopColCor': 0.044931579261058785, 'maxColPCor': 0.15522607765242749, 'conIdf': 0.13108546338039784, 'avgCDocScore': 0.084977211254077686, 'topTermFrac': 0.1504520206157422, 'avgColCor': 0.045603281696077545, 'avgTopColCor': 0.11322863469356631, 'numCanDocs': 0.011691447233121864, 'maxTopColPCor': 0.054811714121589666, 'expTDocScore': 0.064009297678285629, 'avgColPCor': 0.020668473943073525, 'maxCDocScore': 0.0025491633569158499, 'avgTopColPCor': 0.097863390889920715, 'maxColCor': 0.022902244223744803}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2056
#
# featureWeights = {'maxTopColCor': 0.037644659093634535, 'maxColPCor': 0.01282859204883661, 'conIdf': 0.06933532807289787, 'avgCDocScore': 0.10560004530223031, 'topTermFrac': 0.14203332935562102, 'avgColCor': 0.10061591041656456, 'avgTopColCor': 0.10582446695746257, 'numCanDocs': 0.025279178707075373, 'maxTopColPCor': 0.043917457329431621, 'expTDocScore': 0.12643975131829849, 'avgColPCor': 0.014569623910279262, 'maxCDocScore': 0.049871048275530842, 'avgTopColPCor': 0.078140612261826184, 'maxColCor': 0.087899996950310783}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2053
#
# featureWeights = {'maxTopColCor': 0.087405457967354605, 'maxColPCor': 0.037678507828103149, 'conIdf': 0.05556645092413965, 'avgCDocScore': 0.10859509975003549, 'topTermFrac': 0.071580413924589997, 'avgColCor': 0.02392677394080801, 'avgTopColCor': 0.073741555127610561, 'numCanDocs': 0.060451290142722679, 'maxTopColPCor': 0.11702035883736686, 'expTDocScore': 0.028712744315632768, 'avgColPCor': 0.034191931678966871, 'maxCDocScore': 0.13447614460380386, 'avgTopColPCor': 0.032947447856535347, 'maxColCor': 0.13370582310233023}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2046
#
# featureWeights = {'maxTopColCor': 0.039459342603648806, 'maxColPCor': 0.094091395860786659, 'conIdf': 0.108437149298796, 'avgCDocScore': 0.033197367896827389, 'topTermFrac': 0.084891899089736864, 'avgColCor': 0.063144017448793152, 'avgTopColCor': 0.11127429497935107, 'numCanDocs': 0.068573540204000458, 'maxTopColPCor': 0.090936207958673798, 'expTDocScore': 0.11365506351536805, 'avgColPCor': 0.0062835856791650527, 'maxCDocScore': 0.074460922005611885, 'avgTopColPCor': 0.023953087526879146, 'maxColCor': 0.087642125932361661}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2057
#
# featureWeights = {'maxTopColCor': 0.059199349902318191, 'maxColPCor': 0.12920419644528935, 'conIdf': 0.18347225039136239, 'avgCDocScore': 0.045002030086023083, 'topTermFrac': 0.017649496974132185, 'avgColCor': 0.016208991647197492, 'avgTopColCor': 0.032904342700766191, 'numCanDocs': 0.033506626620254602, 'maxTopColPCor': 0.022939905796436573, 'expTDocScore': 0.16025750795016838, 'avgColPCor': 0.13035959611616058, 'maxCDocScore': 0.058570661572691182, 'avgTopColPCor': 0.083751634202722497, 'maxColCor': 0.026973409594477363}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2042
#
# featureWeights = {'maxTopColCor': 0.10623424260984467, 'maxColPCor': 0.091511426270350596, 'conIdf': 0.071084001723414225, 'avgCDocScore': 0.0082390814124840006, 'topTermFrac': 0.1228126949254035, 'avgColCor': 0.061586005152711315, 'avgTopColCor': 0.043442041363076049, 'numCanDocs': 0.03264891436446709, 'maxTopColPCor': 0.10846598666488062, 'expTDocScore': 0.092645699099011353, 'avgColPCor': 0.07643554086400639, 'maxCDocScore': 0.019206360564645673, 'avgTopColPCor': 0.039334100372652135, 'maxColCor': 0.1263539046130524}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2043
#
# featureWeights = {'maxTopColCor': 0.048793028369809484, 'maxColPCor': 0.018584066719859169, 'conIdf': 0.010679368753653681, 'avgCDocScore': 0.15154293217737574, 'topTermFrac': 0.031304487362133884, 'avgColCor': 0.0029095796437266321, 'avgTopColCor': 0.13487770913671249, 'numCanDocs': 0.11511754994502363, 'maxTopColPCor': 0.11749768459976714, 'expTDocScore': 0.14369898835083589, 'avgColPCor': 0.12376642837569071, 'maxCDocScore': 0.071971353628462686, 'avgTopColPCor': 0.018272460863680808, 'maxColCor': 0.010984362073267952}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2040
#
# featureWeights = {'maxTopColCor': 0.069419341383343852, 'maxColPCor': 0.087497320412307997, 'conIdf': 0.10358928250143355, 'avgCDocScore': 0.12504443618011901, 'topTermFrac': 0.013508446600010838, 'avgColCor': 0.046124377585564882, 'avgTopColCor': 0.077133963841568121, 'numCanDocs': 0.13832597811386541, 'maxTopColPCor': 0.021952538356337158, 'expTDocScore': 0.013376554152165578, 'avgColPCor': 0.13150341563349086, 'maxCDocScore': 0.020308169780648075, 'avgTopColPCor': 0.12804500474867037, 'maxColCor': 0.024171170710474286}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2038
#
# featureWeights = {'maxTopColCor': 0.028326564043526979, 'maxColPCor': 0.049050331702974861, 'conIdf': 0.095918178144425909, 'avgCDocScore': 0.092830353736268439, 'topTermFrac': 0.077468606152017963, 'avgColCor': 0.057165509000096718, 'avgTopColCor': 0.068232485551599831, 'numCanDocs': 0.0049965909984050543, 'maxTopColPCor': 0.039590402589158531, 'expTDocScore': 0.12961640478697523, 'avgColPCor': 0.068957359361942722, 'maxCDocScore': 0.09155129367485311, 'avgTopColPCor': 0.098505342144244265, 'maxColCor': 0.097790578113510301}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2049
#
# featureWeights = {'maxTopColCor': 0.10832716065050246, 'maxColPCor': 0.14958148315853398, 'conIdf': 0.053066445994759417, 'avgCDocScore': 0.080819257461507407, 'topTermFrac': 0.15105211819146994, 'avgColCor': 0.080878665765870869, 'avgTopColCor': 0.048760266598268591, 'numCanDocs': 0.13011542070393339, 'maxTopColPCor': 0.041654489752828414, 'expTDocScore': 0.018303916952368632, 'avgColPCor': 0.051414541319584853, 'maxCDocScore': 0.07371506501383053, 'avgTopColPCor': 0.0064020832846753894, 'maxColCor': 0.0059090851518662207}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2043
#
# featureWeights = {'maxTopColCor': 0.073529445057238588, 'maxColPCor': 0.1145391061211028, 'conIdf': 0.019132697008404437, 'avgCDocScore': 0.12235662605024235, 'topTermFrac': 0.07921520658648247, 'avgColCor': 0.13531406943039959, 'avgTopColCor': 0.055806110447883146, 'numCanDocs': 0.0013635701947308898, 'maxTopColPCor': 0.1013317741393758, 'expTDocScore': 0.0049869055554452859, 'avgColPCor': 0.014059282938324803, 'maxCDocScore': 0.049129473403681248, 'avgTopColPCor': 0.1413704180381995, 'maxColCor': 0.087865315028489072}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2046
#
# featureWeights = {'maxTopColCor': 0.027787531882593385, 'maxColPCor': 0.048330680844926824, 'conIdf': 0.03811882352379984, 'avgCDocScore': 0.089163268468384932, 'topTermFrac': 0.1120588152639396, 'avgColCor': 0.13619168541970181, 'avgTopColCor': 0.064489093486918919, 'numCanDocs': 0.14163033521250459, 'maxTopColPCor': 0.065080180814662408, 'expTDocScore': 0.040061198491795159, 'avgColPCor': 0.026211337616751967, 'maxCDocScore': 0.085931130137153255, 'avgTopColPCor': 0.01747544381080551, 'maxColCor': 0.10747047502606194}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2051
#
# featureWeights = {'maxTopColCor': 0.054041113904224274, 'maxColPCor': 0.095417755575851762, 'conIdf': 0.076932285523305291, 'avgCDocScore': 0.090393927315219905, 'topTermFrac': 0.13884549367530211, 'avgColCor': 0.11191368288950806, 'avgTopColCor': 0.086663087883652637, 'numCanDocs': 0.02086944946222696, 'maxTopColPCor': 0.049213382514205116, 'expTDocScore': 0.039510208887834949, 'avgColPCor': 0.056737524448557584, 'maxCDocScore': 0.03876743031309917, 'avgTopColPCor': 0.087925957780027347, 'maxColCor': 0.052768699826984886}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2054
#
# featureWeights = {'maxTopColCor': 0.12864477222931012, 'maxColPCor': 0.11231927579384797, 'conIdf': 0.048911078471409929, 'avgCDocScore': 0.02304427738050804, 'topTermFrac': 0.083268891648974136, 'avgColCor': 0.0781570357228209, 'avgTopColCor': 0.016387738108010391, 'numCanDocs': 0.10556957811943571, 'maxTopColPCor': 0.099294755727884473, 'expTDocScore': 0.0077180693006180254, 'avgColPCor': 0.0012935921893399019, 'maxCDocScore': 0.089028851307297846, 'avgTopColPCor': 0.10758780019886989, 'maxColCor': 0.098774283801672705}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2047
#
# featureWeights = {'maxTopColCor': 0.029517624385957387, 'maxColPCor': 0.023144544989568135, 'conIdf': 0.056861231933351998, 'avgCDocScore': 0.045920503356225766, 'topTermFrac': 0.016946962827730998, 'avgColCor': 0.11943934132893008, 'avgTopColCor': 0.094783670066310929, 'numCanDocs': 0.094263373154296504, 'maxTopColPCor': 0.098326108931941839, 'expTDocScore': 0.12428783850752391, 'avgColPCor': 0.083269793097639627, 'maxCDocScore': 0.055986877779756979, 'avgTopColPCor': 0.040785533234678553, 'maxColCor': 0.11646659640608749}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2027
#
# featureWeights = {'maxTopColCor': 0.12471978879319824, 'maxColPCor': 0.072604750315586122, 'conIdf': 0.040531449869633585, 'avgCDocScore': 0.038878346067545533, 'topTermFrac': 0.13130878156232403, 'avgColCor': 0.046052101186195869, 'avgTopColCor': 0.16712482092262923, 'numCanDocs': 0.15190262550241648, 'maxTopColPCor': 0.062732162386224491, 'expTDocScore': 0.022307879283741928, 'avgColPCor': 0.068666559253693901, 'maxCDocScore': 0.049382227471733695, 'avgTopColPCor': 0.0027880234239937925, 'maxColCor': 0.021000483961083168}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2050
#
# featureWeights = {'maxTopColCor': 0.13106331423569231, 'maxColPCor': 0.1096921409857534, 'conIdf': 0.035488869310474083, 'avgCDocScore': 0.033411611500223704, 'topTermFrac': 0.072472132949321824, 'avgColCor': 0.079941190294440065, 'avgTopColCor': 0.027093832849265694, 'numCanDocs': 0.029439751052567655, 'maxTopColPCor': 0.031905593280958239, 'expTDocScore': 0.036515758619690884, 'avgColPCor': 0.077983065305672575, 'maxCDocScore': 0.12264097115680155, 'avgTopColPCor': 0.085467120464759225, 'maxColCor': 0.12688464799437879}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2038
#
# featureWeights = {'maxTopColCor': 0.10266212240210473, 'maxColPCor': 0.1093782854149328, 'conIdf': 0.010075683959295532, 'avgCDocScore': 0.077791896677982919, 'topTermFrac': 0.046902471921452589, 'avgColCor': 0.060900280281767645, 'avgTopColCor': 0.037188810937657475, 'numCanDocs': 0.079877221000924301, 'maxTopColPCor': 0.0010292299744251757, 'expTDocScore': 0.03784284561963628, 'avgColPCor': 0.11401376234438683, 'maxCDocScore': 0.071028434680098368, 'avgTopColPCor': 0.12083573722862734, 'maxColCor': 0.13047321755670802}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2035
#
# featureWeights = {'maxTopColCor': 0.086165374359730998, 'maxColPCor': 0.087384625322408732, 'conIdf': 0.059885101130072657, 'avgCDocScore': 0.1089547966048232, 'topTermFrac': 0.00093305513057087292, 'avgColCor': 0.030606124611305744, 'avgTopColCor': 0.097528362904175492, 'numCanDocs': 0.09458563908901467, 'maxTopColPCor': 0.09838077798798614, 'expTDocScore': 0.011312598144605925, 'avgColPCor': 0.10420795136107502, 'maxCDocScore': 0.0061100587379859335, 'avgTopColPCor': 0.11023576654894626, 'maxColCor': 0.10370976806729826}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2040
#
# featureWeights = {'maxTopColCor': 0.08925736722406831, 'maxColPCor': 0.10338878875565491, 'conIdf': 0.073122731051724787, 'avgCDocScore': 0.052234766318938947, 'topTermFrac': 0.07110186110642841, 'avgColCor': 0.048629319036750725, 'avgTopColCor': 0.055318759313440193, 'numCanDocs': 0.00075533533324673304, 'maxTopColPCor': 0.13295255619367016, 'expTDocScore': 0.00062898480918095105, 'avgColPCor': 0.11332115602835351, 'maxCDocScore': 0.14367315921682353, 'avgTopColPCor': 0.10952685549542691, 'maxColCor': 0.0060883601162920213}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2045
#
# featureWeights = {'maxTopColCor': 0.11270002609385456, 'maxColPCor': 0.079698886063370139, 'conIdf': 0.079694329833401481, 'avgCDocScore': 0.016315144521693085, 'topTermFrac': 0.055203193109930097, 'avgColCor': 0.10571377738155024, 'avgTopColCor': 0.01979815877498425, 'numCanDocs': 0.10743788799507058, 'maxTopColPCor': 0.049296967345754859, 'expTDocScore': 0.095593996664580447, 'avgColPCor': 0.031340979734549787, 'maxCDocScore': 0.082808971293467162, 'avgTopColPCor': 0.065561081751041847, 'maxColCor': 0.098836599436751466}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2035
#
# featureWeights = {'maxTopColCor': 0.12687653387680597, 'maxColPCor': 0.009693936885914663, 'conIdf': 0.13402898273543251, 'avgCDocScore': 0.14442880488530074, 'topTermFrac': 0.044586507302201157, 'avgColCor': 0.041643891882712142, 'avgTopColCor': 0.034423564128627064, 'numCanDocs': 0.024312965746750882, 'maxTopColPCor': 0.07518094973241278, 'expTDocScore': 0.021551948706492376, 'avgColPCor': 0.096702977944173624, 'maxCDocScore': 0.11030481985520295, 'avgTopColPCor': 0.11250525078819509, 'maxColCor': 0.023758865529778031}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2043
#
# featureWeights = {'maxTopColCor': 0.1020548661761007, 'maxColPCor': 0.07426666400479795, 'conIdf': 0.034430601687206137, 'avgCDocScore': 0.095392032768591414, 'topTermFrac': 0.13040229488454685, 'avgColCor': 0.048218426941814184, 'avgTopColCor': 0.067441544341582074, 'numCanDocs': 0.038432186077132426, 'maxTopColPCor': 0.0055507072650230098, 'expTDocScore': 0.071379032074524687, 'avgColPCor': 0.101283667461476, 'maxCDocScore': 0.031848085332536427, 'avgTopColPCor': 0.12326562432300571, 'maxColCor': 0.07603426666166245}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2049
#
# featureWeights = {'maxTopColCor': 0.13280137800717015, 'maxColPCor': 0.048144939482362752, 'conIdf': 0.027458409541344823, 'avgCDocScore': 0.098342868143668008, 'topTermFrac': 0.0051551157930397259, 'avgColCor': 0.054771940666218599, 'avgTopColCor': 0.038990178289314836, 'numCanDocs': 0.13117495950197053, 'maxTopColPCor': 0.093485316766276833, 'expTDocScore': 0.087356980132220374, 'avgColPCor': 0.029009037195302467, 'maxCDocScore': 0.044283401970743728, 'avgTopColPCor': 0.1394316781445816, 'maxColCor': 0.069593796365785596}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2044
#
# featureWeights = {'maxTopColCor': 0.061418868909153684, 'maxColPCor': 0.011643510318773824, 'conIdf': 0.095803870419593234, 'avgCDocScore': 0.096918088400152452, 'topTermFrac': 0.010056495767098647, 'avgColCor': 0.028298761713297021, 'avgTopColCor': 0.1328129202907313, 'numCanDocs': 0.043529417394376761, 'maxTopColPCor': 0.021681151222008768, 'expTDocScore': 0.13428787492016525, 'avgColPCor': 0.11755395425031163, 'maxCDocScore': 0.043835401636764727, 'avgTopColPCor': 0.10488072687409808, 'maxColCor': 0.097278957883474876}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2040
#
# featureWeights = {'maxTopColCor': 0.13272718975525838, 'maxColPCor': 0.038402406823936724, 'conIdf': 0.045555332523973022, 'avgCDocScore': 0.1007489893212347, 'topTermFrac': 0.087963145952443519, 'avgColCor': 0.14744713612287569, 'avgTopColCor': 0.09145963785186853, 'numCanDocs': 0.034453515306943405, 'maxTopColPCor': 0.002800909878623227, 'expTDocScore': 0.069965196141214978, 'avgColPCor': 0.099526700252228831, 'maxCDocScore': 0.12796892163681353, 'avgTopColPCor': 0.016877069455015228, 'maxColCor': 0.0041038489775701709}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2051
#
# featureWeights = {'maxTopColCor': 0.093897641771803847, 'maxColPCor': 0.050153671087057719, 'conIdf': 0.022465804350700745, 'avgCDocScore': 0.054072159950844495, 'topTermFrac': 0.028394929135378215, 'avgColCor': 0.081406511907237605, 'avgTopColCor': 0.058442745605305317, 'numCanDocs': 0.096117284033431019, 'maxTopColPCor': 0.081432192695997246, 'expTDocScore': 0.10917546422087383, 'avgColPCor': 0.036022106030435173, 'maxCDocScore': 0.13067869961074446, 'avgTopColPCor': 0.060971563320743404, 'maxColCor': 0.096769226279446813}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2035
#
# featureWeights = {'maxTopColCor': 0.039743659536554531, 'maxColPCor': 0.10935978374931121, 'conIdf': 0.037636369398496156, 'avgCDocScore': 0.029726917959060576, 'topTermFrac': 0.096998729726573779, 'avgColCor': 0.054618739460932472, 'avgTopColCor': 0.12719456533350262, 'numCanDocs': 0.067439250041778656, 'maxTopColPCor': 0.11443795254583851, 'expTDocScore': 0.059643007082592805, 'avgColPCor': 0.02898997277654276, 'maxCDocScore': 0.075008836514436059, 'avgTopColPCor': 0.049469622854682677, 'maxColCor': 0.10973259301969727}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2056
#
# featureWeights = {'maxTopColCor': 0.033896120353391401, 'maxColPCor': 0.09037274737742633, 'conIdf': 0.088620328058099121, 'avgCDocScore': 0.017559419584034508, 'topTermFrac': 0.061726361054514942, 'avgColCor': 0.054115003670110885, 'avgTopColCor': 0.071321592519135446, 'numCanDocs': 0.13086474153944688, 'maxTopColPCor': 0.011693946993135506, 'expTDocScore': 0.062333618087865306, 'avgColPCor': 0.13697371553200768, 'maxCDocScore': 0.014095889262146593, 'avgTopColPCor': 0.11405659363917067, 'maxColCor': 0.1123699223295148}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2041
#
# featureWeights = {'maxTopColCor': 0.077899916256499793, 'maxColPCor': 0.071944359014186388, 'conIdf': 0.097330967469195548, 'avgCDocScore': 0.13813826918424904, 'topTermFrac': 0.036163953226249927, 'avgColCor': 0.08440820476609813, 'avgTopColCor': 0.0083474935519590333, 'numCanDocs': 0.12121107926990073, 'maxTopColPCor': 0.0033966546643035907, 'expTDocScore': 0.0078601222695496922, 'avgColPCor': 0.06215113719485748, 'maxCDocScore': 0.010019779412161719, 'avgTopColPCor': 0.14379191110951434, 'maxColCor': 0.13733615261127452}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2044
#
# featureWeights = {'maxTopColCor': 0.12167840763324635, 'maxColPCor': 0.073215206548744999, 'conIdf': 0.031451889689731789, 'avgCDocScore': 0.032511347557426316, 'topTermFrac': 0.00078931546751667041, 'avgColCor': 0.10866643069066032, 'avgTopColCor': 0.052145108836367735, 'numCanDocs': 0.074153801836451858, 'maxTopColPCor': 0.1237558297435597, 'expTDocScore': 0.077785448766688567, 'avgColPCor': 0.11109454319846124, 'maxCDocScore': 0.064064023878185966, 'avgTopColPCor': 0.095371273012801155, 'maxColCor': 0.033317373140157404}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2028
#
# featureWeights = {'maxTopColCor': 0.05298288804320752, 'maxColPCor': 0.087946034854198468, 'conIdf': 0.050474110715722553, 'avgCDocScore': 0.073156493933945355, 'topTermFrac': 0.12204456969121885, 'avgColCor': 0.017807432851310194, 'avgTopColCor': 0.12526730535712605, 'numCanDocs': 0.099349864396930235, 'maxTopColPCor': 0.08483560043809335, 'expTDocScore': 0.090691590841577824, 'avgColPCor': 0.11285466160126564, 'maxCDocScore': 0.0050108136611352085, 'avgTopColPCor': 0.07416616912821776, 'maxColCor': 0.0034124644860511204}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2043
#
# featureWeights = {'maxTopColCor': 0.074409486190455509, 'maxColPCor': 0.091380772015938874, 'conIdf': 0.066524724874704913, 'avgCDocScore': 0.041489977361248376, 'topTermFrac': 0.0059600583957999326, 'avgColCor': 0.090115776938099357, 'avgTopColCor': 0.039097045497131541, 'numCanDocs': 0.068666722689301754, 'maxTopColPCor': 0.10173688805625457, 'expTDocScore': 0.062524473186723453, 'avgColPCor': 0.17310533803052558, 'maxCDocScore': 0.14741786183050529, 'avgTopColPCor': 0.0073497599597026108, 'maxColCor': 0.030221114973608226}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2017
#
# featureWeights = {'maxTopColCor': 0.12173026467264006, 'maxColPCor': 0.10028809275477156, 'conIdf': 0.027259601074318497, 'avgCDocScore': 0.10002890241470171, 'topTermFrac': 0.024815073222601167, 'avgColCor': 0.11731198991123079, 'avgTopColCor': 0.082297308215952131, 'numCanDocs': 0.017645527033707045, 'maxTopColPCor': 0.13314192438939867, 'expTDocScore': 0.0030236283038035266, 'avgColPCor': 0.023057872805240704, 'maxCDocScore': 0.13238861751747813, 'avgTopColPCor': 0.055190088596252802, 'maxColCor': 0.061821109087903094}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2033
#
# featureWeights = {'maxTopColCor': 0.045012698979504821, 'maxColPCor': 0.091869095985712745, 'conIdf': 0.12014354131697833, 'avgCDocScore': 0.0074314761697665396, 'topTermFrac': 0.11466792549764575, 'avgColCor': 0.038973883777645435, 'avgTopColCor': 0.075718883701691192, 'numCanDocs': 0.013419404103149873, 'maxTopColPCor': 0.13768118289894618, 'expTDocScore': 0.088184409615393353, 'avgColPCor': 0.01841129788760466, 'maxCDocScore': 0.11405439089325324, 'avgTopColPCor': 0.017841610942601224, 'maxColCor': 0.11659019823010655}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2052
#
# featureWeights = {'maxTopColCor': 0.088995078347508763, 'maxColPCor': 0.036292783363829358, 'conIdf': 0.1053104633892106, 'avgCDocScore': 0.0064090506439392009, 'topTermFrac': 0.12323817816643923, 'avgColCor': 0.044776473014228109, 'avgTopColCor': 0.08897797325391707, 'numCanDocs': 0.11841442909488888, 'maxTopColPCor': 0.029719702661734085, 'expTDocScore': 0.038570334476484218, 'avgColPCor': 0.10669519846216778, 'maxCDocScore': 0.074310050609932204, 'avgTopColPCor': 0.094036555789957121, 'maxColCor': 0.044253728725763414}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2052
#
# featureWeights = {'maxTopColCor': 0.10593315430867749, 'maxColPCor': 0.040027733246943482, 'conIdf': 0.09565493744987405, 'avgCDocScore': 0.10837358698054765, 'topTermFrac': 0.0251235427804859, 'avgColCor': 0.096970270324550509, 'avgTopColCor': 0.1037741659747816, 'numCanDocs': 0.018095121665377741, 'maxTopColPCor': 0.083632887271820069, 'expTDocScore': 0.10000949345703755, 'avgColPCor': 0.028562634681583942, 'maxCDocScore': 0.041410048709389483, 'avgTopColPCor': 0.072857959285978116, 'maxColCor': 0.079574463862952458}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2041
#
# featureWeights = {'maxTopColCor': 0.053492426285301133, 'maxColPCor': 0.014670788031594082, 'conIdf': 0.15320432540729878, 'avgCDocScore': 0.095475447803639091, 'topTermFrac': 0.027699100741683462, 'avgColCor': 0.16051997841032364, 'avgTopColCor': 0.13787811534827527, 'numCanDocs': 0.018080771131060193, 'maxTopColPCor': 0.058412721518898217, 'expTDocScore': 0.063295676008539845, 'avgColPCor': 0.00024186128240206525, 'maxCDocScore': 0.027372583399535484, 'avgTopColPCor': 0.11407701309255497, 'maxColCor': 0.075579191538893864}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2047
#
# featureWeights = {'maxTopColCor': 0.055617115239596102, 'maxColPCor': 0.014517709277277954, 'conIdf': 0.11764240193531769, 'avgCDocScore': 0.042125699284266883, 'topTermFrac': 0.12481852885302511, 'avgColCor': 0.057792160359249077, 'avgTopColCor': 0.0024688621737022414, 'numCanDocs': 0.083816664482527156, 'maxTopColPCor': 0.11726113908727995, 'expTDocScore': 0.12299291444328304, 'avgColPCor': 0.063480745588490095, 'maxCDocScore': 0.060402984838397081, 'avgTopColPCor': 0.02750250149505153, 'maxColCor': 0.10956057294253593}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2049
#
# featureWeights = {'maxTopColCor': 0.01163475033682258, 'maxColPCor': 0.010460216279862459, 'conIdf': 0.11537452384182185, 'avgCDocScore': 0.058566842729878547, 'topTermFrac': 0.11155031612319637, 'avgColCor': 0.061648939091702062, 'avgTopColCor': 0.050516608355805584, 'numCanDocs': 0.098458010716003463, 'maxTopColPCor': 0.07673554920182532, 'expTDocScore': 0.028584433518122739, 'avgColPCor': 0.10284345494514834, 'maxCDocScore': 0.13987499561687206, 'avgTopColPCor': 0.017532508268468004, 'maxColCor': 0.1162188509744707}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2049
#
# ...
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2031
#
# featureWeights = {'maxTopColCor': 0.015710209845495135, 'maxColPCor': 0.098087727867959634, 'conIdf': 0.071127152453435996, 'avgCDocScore': 0.13656316239980021, 'topTermFrac': 0.032629915094438168, 'avgColCor': 0.040300624937377814, 'avgTopColCor': 0.13067199904122112, 'numCanDocs': 0.039929396572199322, 'maxTopColPCor': 0.00069646945819741189, 'expTDocScore': 0.11886177342327547, 'avgColPCor': 0.0071254881523629306, 'maxCDocScore': 0.044520084719414627, 'avgTopColPCor': 0.12891556962313852, 'maxColCor': 0.13486042641168372}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2041
#
# featureWeights = {'maxTopColCor': 0.11107006016479401, 'maxColPCor': 0.15141734593431569, 'conIdf': 0.0015806309043216529, 'avgCDocScore': 0.077082761038198611, 'topTermFrac': 0.10085133766075575, 'avgColCor': 0.055983116691689296, 'avgTopColCor': 0.11464033092453538, 'numCanDocs': 0.011549108402018138, 'maxTopColPCor': 0.062576879736267896, 'expTDocScore': 0.012665840804696427, 'avgColPCor': 0.10344835741676188, 'maxCDocScore': 0.070045289209439157, 'avgTopColPCor': 0.12174166219705761, 'maxColCor': 0.0053472789151485824}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2046
#
# featureWeights = {'maxTopColCor': 0.020987577808265781, 'maxColPCor': 0.093566501714768838, 'conIdf': 0.12381523617594445, 'avgCDocScore': 0.13934948763456334, 'topTermFrac': 0.041241680882700915, 'avgColCor': 0.061092249517081552, 'avgTopColCor': 0.040700560158384448, 'numCanDocs': 0.054049049378538799, 'maxTopColPCor': 0.063555391001442932, 'expTDocScore': 0.04986680473631272, 'avgColPCor': 0.094302373298192438, 'maxCDocScore': 0.061022177599600456, 'avgTopColPCor': 0.13865511850640619, 'maxColCor': 0.01779579158779708}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2039
#
# featureWeights = {'maxTopColCor': 0.086764919887634351, 'maxColPCor': 0.090511619444862232, 'conIdf': 0.044883614768486367, 'avgCDocScore': 0.058665513933221711, 'topTermFrac': 0.06469220821066117, 'avgColCor': 0.0081343784405969923, 'avgTopColCor': 0.091983161468435437, 'numCanDocs': 0.01074021837224815, 'maxTopColPCor': 0.10755152411726175, 'expTDocScore': 0.095412529391181139, 'avgColPCor': 0.090417828299577716, 'maxCDocScore': 0.095888075676876738, 'avgTopColPCor': 0.073362571758869941, 'maxColCor': 0.080991836230086461}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2045
#
# featureWeights = {'maxTopColCor': 0.034517444496728056, 'maxColPCor': 0.12222032216853156, 'conIdf': 0.059299494456400911, 'avgCDocScore': 0.04123429130981901, 'topTermFrac': 0.10307289179557912, 'avgColCor': 0.015323771638795414, 'avgTopColCor': 0.0044531271802533594, 'numCanDocs': 0.074014383676223927, 'maxTopColPCor': 0.071912900284366754, 'expTDocScore': 0.1160266568071822, 'avgColPCor': 0.13565350795114195, 'maxCDocScore': 0.048917993761814514, 'avgTopColPCor': 0.13670010934742369, 'maxColCor': 0.036653105125739584}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2046
#
# featureWeights = {'maxTopColCor': 0.070565940316503747, 'maxColPCor': 0.028537140118064547, 'conIdf': 0.11231256394924247, 'avgCDocScore': 0.0028531035535624321, 'topTermFrac': 0.13466173941876725, 'avgColCor': 0.038672622681515174, 'avgTopColCor': 0.073961034524385461, 'numCanDocs': 0.0066219612523774089, 'maxTopColPCor': 0.12696613430073964, 'expTDocScore': 0.018447468560334714, 'avgColPCor': 0.088907880855389435, 'maxCDocScore': 0.12533213638108137, 'avgTopColPCor': 0.077607313443089673, 'maxColCor': 0.094552960644946629}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2053
#
# featureWeights = {'maxTopColCor': 0.02263792083223317, 'maxColPCor': 0.116968996460018, 'conIdf': 0.062557065899169359, 'avgCDocScore': 0.013127053949140597, 'topTermFrac': 0.037280706835147538, 'avgColCor': 0.09745007195894316, 'avgTopColCor': 0.098978700498381866, 'numCanDocs': 0.11612638453020604, 'maxTopColPCor': 0.027814791766507727, 'expTDocScore': 0.082318363055214935, 'avgColPCor': 0.049876687667996474, 'maxCDocScore': 0.15590725860654858, 'avgTopColPCor': 0.043210601892391641, 'maxColCor': 0.07574539604810096}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2031
#
# featureWeights = {'maxTopColCor': 0.11941729398256527, 'maxColPCor': 0.031435579827629033, 'conIdf': 0.13058917730182573, 'avgCDocScore': 0.072665509709316123, 'topTermFrac': 0.069990563764706873, 'avgColCor': 0.081888975376667825, 'avgTopColCor': 0.025119601323704371, 'numCanDocs': 0.0093091887037238998, 'maxTopColPCor': 0.10261643920600799, 'expTDocScore': 0.071739873445226796, 'avgColPCor': 0.1202009468971889, 'maxCDocScore': 0.081500383110221744, 'avgTopColPCor': 0.067137549983846578, 'maxColCor': 0.01638891736736884}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2049
#
# featureWeights = {'maxTopColCor': 0.028665315867944588, 'maxColPCor': 0.098389631772831415, 'conIdf': 0.082320060664322708, 'avgCDocScore': 0.093173923927287294, 'topTermFrac': 0.051607656947088569, 'avgColCor': 0.050578117850052833, 'avgTopColCor': 0.065390549091040848, 'numCanDocs': 0.07412832505119743, 'maxTopColPCor': 0.089777107094955538, 'expTDocScore': 0.1275855924456161, 'avgColPCor': 0.058209203898721924, 'maxCDocScore': 0.029120495248171386, 'avgTopColPCor': 0.020704225511376923, 'maxColCor': 0.13034979462939261}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2032
#
# featureWeights = {'maxTopColCor': 0.074459530962120185, 'maxColPCor': 2.7486911508732638e-06, 'conIdf': 0.078410422084177173, 'avgCDocScore': 0.090116479918456477, 'topTermFrac': 0.090869010103665965, 'avgColCor': 0.075368401157519693, 'avgTopColCor': 0.032811709000038707, 'numCanDocs': 0.078908925665798907, 'maxTopColPCor': 0.054794247019650341, 'expTDocScore': 0.063382261114559149, 'avgColPCor': 0.091588910733378034, 'maxCDocScore': 0.044624326582068677, 'avgTopColPCor': 0.11627632284359389, 'maxColCor': 0.10838670412382199}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2055
#
# featureWeights = {'maxTopColCor': 0.15559629413244558, 'maxColPCor': 0.023692207754384721, 'conIdf': 0.11136338640992748, 'avgCDocScore': 0.014587415591806239, 'topTermFrac': 0.15547686132030314, 'avgColCor': 0.02436973718937159, 'avgTopColCor': 0.088270547352891013, 'numCanDocs': 0.033836948064736784, 'maxTopColPCor': 0.013456385971455573, 'expTDocScore': 0.16908999497711016, 'avgColPCor': 0.0057017416581603853, 'maxCDocScore': 0.093122368389740265, 'avgTopColPCor': 0.015180327303780468, 'maxColCor': 0.096255783883886642}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2054
#
# featureWeights = {'maxTopColCor': 0.032725390779986464, 'maxColPCor': 0.064966283512468179, 'conIdf': 0.099674596475861077, 'avgCDocScore': 0.012285966887397897, 'topTermFrac': 0.0018611735693252307, 'avgColCor': 0.059034185088806486, 'avgTopColCor': 0.090678020240338331, 'numCanDocs': 0.050233907277309829, 'maxTopColPCor': 0.12410723375082953, 'expTDocScore': 0.12308446855770105, 'avgColPCor': 0.0091747271885888135, 'maxCDocScore': 0.11320994207127368, 'avgTopColPCor': 0.1256157327805944, 'maxColCor': 0.093348371819519063}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2046
#
# featureWeights = {'maxTopColCor': 0.093556916161237791, 'maxColPCor': 0.011488913574993374, 'conIdf': 0.039686633502244995, 'avgCDocScore': 0.030707465553373975, 'topTermFrac': 0.10507547983446733, 'avgColCor': 0.097572005061739533, 'avgTopColCor': 0.044721833378211596, 'numCanDocs': 0.11514125181036432, 'maxTopColPCor': 0.11452412392663658, 'expTDocScore': 0.030053306245118896, 'avgColPCor': 0.06864144645998399, 'maxCDocScore': 0.080430607062141959, 'avgTopColPCor': 0.082187751755479238, 'maxColCor': 0.086212265674006305}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2051
#
# featureWeights = {'maxTopColCor': 0.010542503070430101, 'maxColPCor': 0.0062489655350945767, 'conIdf': 0.032212168829059501, 'avgCDocScore': 0.03865440585156521, 'topTermFrac': 0.097236478792615114, 'avgColCor': 0.012138492853592321, 'avgTopColCor': 0.079253613244198218, 'numCanDocs': 0.11905382436647233, 'maxTopColPCor': 0.061568093701531587, 'expTDocScore': 0.14316046003568209, 'avgColPCor': 0.16078882093108315, 'maxCDocScore': 0.042425295432912048, 'avgTopColPCor': 0.18230991813284775, 'maxColCor': 0.01440695922291624}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2047
#
# featureWeights = {'maxTopColCor': 0.0067044539146985651, 'maxColPCor': 0.10007297919873635, 'conIdf': 0.022516304251691658, 'avgCDocScore': 0.13099511962528212, 'topTermFrac': 0.031817813024001287, 'avgColCor': 0.12391651106855378, 'avgTopColCor': 0.017183663628580679, 'numCanDocs': 0.12075966407498415, 'maxTopColPCor': 0.067905813277134366, 'expTDocScore': 0.013877164888820421, 'avgColPCor': 0.043865778617964112, 'maxCDocScore': 0.095280904890701568, 'avgTopColPCor': 0.098742309277641896, 'maxColCor': 0.12636152026120906}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2037
#
# featureWeights = {'maxTopColCor': 0.042255085997990265, 'maxColPCor': 0.10296217997715276, 'conIdf': 0.072753718609538831, 'avgCDocScore': 0.017169170995126628, 'topTermFrac': 0.099331715683101798, 'avgColCor': 0.063816462636116955, 'avgTopColCor': 0.11002167157292544, 'numCanDocs': 0.069421109927388577, 'maxTopColPCor': 0.09571269717600922, 'expTDocScore': 0.073237846978575258, 'avgColPCor': 0.088757195538045119, 'maxCDocScore': 0.079442257758234699, 'avgTopColPCor': 0.075617569226979583, 'maxColCor': 0.0095013179228149499}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2044
#
# featureWeights = {'maxTopColCor': 0.034393871922819098, 'maxColPCor': 0.11314385377005888, 'conIdf': 0.14124684184230885, 'avgCDocScore': 0.058552936888219755, 'topTermFrac': 0.035113406165621627, 'avgColCor': 0.10573220408981074, 'avgTopColCor': 0.13499340619561978, 'numCanDocs': 0.00011690741022083612, 'maxTopColPCor': 0.10425038319437416, 'expTDocScore': 0.018521631465683933, 'avgColPCor': 0.082143523333147991, 'maxCDocScore': 0.028289796746964267, 'avgTopColPCor': 0.034813615941614286, 'maxColCor': 0.10868762103353574}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2030
#
# featureWeights = {'maxTopColCor': 0.083739760001456054, 'maxColPCor': 0.084032284398215848, 'conIdf': 0.068549921072325298, 'avgCDocScore': 0.016411552265601738, 'topTermFrac': 0.075498493424223809, 'avgColCor': 0.085653711398273907, 'avgTopColCor': 0.096663509598397521, 'numCanDocs': 0.026773088592202451, 'maxTopColPCor': 0.027776356110723925, 'expTDocScore': 0.11750708774847138, 'avgColPCor': 0.074261134794214312, 'maxCDocScore': 0.095886803746301971, 'avgTopColPCor': 0.11960613070456666, 'maxColCor': 0.027640166145025045}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2046
# /home/fj9124/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:101: RuntimeWarning: invalid value encountered in double_scalars
# /home/fj9124/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:110: RuntimeWarning: invalid value encountered in double_scalars
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-140-7ade89a834f4> in <module>()
#      43     #featureWeights_1_new[ft] = wg_new
#      44     #featureWeights_l += [dict(featureWeights_1_new)]
# ---> 45     relText_stringAll, relWords_sel1, mapPrecs = precisionCompute(dist, origWordsAll, count_history, intCoeffs0, intCoeffs1, intCoeffs2, expansionCounts1, expansionCounts2, dirCoeffs, N1s_max, featureWeights_l, indriRunQuery_hist_, dumpindex_hist_)
#      46     count += 1
#
# <ipython-input-25-7b67a1692fa7> in precisionCompute(dist, origWordsAll, count_history, intCoeffs0, intCoeffs1, intCoeffs2, expansionCounts1, expansionCounts2, dirCoeffs, N1s, featureWeights_, indriRunQuery_hist_, dumpindex_hist_)
#      13                                     #res = getAllRelWords_p(count_history, rWords, origWordsAll, expansionCount1, N1, expansionCount2, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights)
#      14
# ---> 15                                     count_history, relText_stringAll, relWords_sel = getAllRelWords(dist, count_history, rWords, origWordsAll, expansionCount1, N1, expansionCount2, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights, indriRunQuery_hist_, dumpindex_hist_)
#      16
#      17                                     #print("len(relText_stringAll[1]) =", len(relText_stringAll[1]))
#
# <ipython-input-21-b1166ae44428> in getAllRelWords(dist, count_history, rWords, origWordsAll, expansionCount1, N1, expansionCount2, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights, indriRunQuery_hist_, dumpindex_hist_)
#       6         #print(str(c1), "---", docno, "---", origWords)
#       7         args = (count_history, rWords, dist, docno, origWords, expansionCount1, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights)
# ----> 8         count_history, relText_string_, relWords_sel_ = getRelWords(args, indriRunQuery_hist_, dumpindex_hist_)
#       9         #print("len(indriRunQuery_hist_), len(dumpindex_hist_['dcf']), len(dumpindex_hist_['ef']) =", len(indriRunQuery_hist_), len(dumpindex_hist_['dcf']), len(dumpindex_hist_['ef']))
#      10         relText_string[docno] = relText_string_
#
# <ipython-input-139-71469d9cca0d> in getRelWords(args, indriRunQuery_hist_, dumpindex_hist_)
#      89             relWords_unNorm = dict()
#      90             for relW in conceptnet5RelAll[ow].keys():
# ---> 91                 feature_ = weightRelConcept(dist, docno, origWords_, ow, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, count_history, featureWeights, indriRunQuery_hist_, dumpindex_hist_)
#      92                 if relW in relWords_unNorm:
#      93                     relWords_unNorm[relW] += feature_
#
# <ipython-input-130-bda66dbc59f0> in weightRelConcept(dist, docno, origWords_, ow, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, count_history, featureWeights, indriRunQuery_hist_, dumpindex_hist_)
#      72     features["avgColCor"] = avgColCor
#      73
# ---> 74     maxColCor = np.max(coocurDocumentsCount.values())
#      75     features["maxColCor"] = maxColCor
#      76
#
# /home/fj9124/anaconda2/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in amax(a, axis, out, keepdims)
#    2251             amax = a.max
#    2252         except AttributeError:
# -> 2253             return _methods._amax(a, axis=axis,
#    2254                                   out=out, keepdims=keepdims)
#    2255         # NOTE: Dropping the keepdims parameter
#
# KeyboardInterrupt:

# %%
"""
dist = str(2)
intCoeffs0 = [ 0.7 ]
intCoeffs1 = [ 0.5 ]
#intCoeffs2 = [ 0.18 ]
intCoeffs2 = [ 0.5 ]
#intCoeffs1 = np.arange(0.1, 1, 0.1)
expansionCounts1 = [ 10 ]
#expansionCounts2 = [ 145 ]
expansionCounts2 = [ 0 ]
#expansionCounts2 = range(15, 220, 5)
dirCoeffs = [ 1600 ]
#dirCoeffs = range(200, 4000, 200)
N1s = 2
N2s_max = [100]
rWords = dict()
featureWeights_1 = {'maxTopColCor': 0.1, 'expTDocScore': 0.1, 'maxColPCor': 0.1, 'avgCDocScore': 0.1, 'topTermFrac': 0.1, 'avgColCor': 0.1, 'avgTopColCor': 0.1, 'numCanDocs': 0.1, 'maxTopColPCor': 0.1, 'maxCDocScore': 0.1, 'avgColPCor': 0.1, 'conIdf': 0.1, 'avgTopColPCor': 0.1, 'maxColCor': 0.1}
featureWeights_l=[featureWeights_1]
relWords_sel1 = {k:v[0:N1s] for k,v in relWords_sel.iteritems()}
indriRunQuery_hist_, dumpindex_hist_ = precisionCompute_train(dist, relWords_sel1, count_history, intCoeffs0, intCoeffs1, intCoeffs2, expansionCounts1, expansionCounts2, dirCoeffs, N2s_max, featureWeights_l, indriRunQuery_hist_, dumpindex_hist_)
"""
#training
dist = str(1)
intCoeffs0 = [ 0.7 ]
intCoeffs1 = [ 0.3 ]
#intCoeffs2 = [ 0.18 ]
intCoeffs2 = [ 0.5 ]
#intCoeffs1 = np.arange(0.1, 1, 0.1)
expansionCounts1 = [ 85 ]
#expansionCounts2 = [ 145 ]
expansionCounts2 = [ 0 ]
#expansionCounts2 = range(15, 220, 5)
dirCoeffs = [ 1600 ]
#dirCoeffs = range(200, 4000, 200)
N2s_max = [0]
N1s = 2
rWords = dict()
featureWeights_1 = {'maxTopColCor': 0.1, 'expTDocScore': 0.1, 'maxColPCor': 0.1, 'avgCDocScore': 0.1, 'topTermFrac': 0.1, 'avgColCor': 0.1, 'avgTopColCor': 0.1, 'numCanDocs': 0.1, 'maxTopColPCor': 0.1, 'maxCDocScore': 0.1, 'avgColPCor': 0.1, 'conIdf': 0.1, 'avgTopColPCor': 0.1, 'maxColCor': 0.1}
featureWeights_l=[featureWeights_1]
relWords_sel1 = {k:v[0:N1s] for k,v in relWords_sel1.iteritems()}
count_history, indriRunQuery_hist_, dumpindex_hist_ = precisionCompute_train(dist, origWordsAll, count_history, intCoeffs0, intCoeffs1, intCoeffs2, expansionCounts1, expansionCounts2, dirCoeffs, N2s_max, featureWeights_l, indriRunQuery_hist_, dumpindex_hist_)
