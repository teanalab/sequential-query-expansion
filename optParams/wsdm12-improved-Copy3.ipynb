# %%
from __future__ import print_function 
from bs4 import BeautifulSoup
from BeautifulSoup import SoupStrainer as sopstrain
import subprocess
import os
import re
import sys
import numpy as np
import string
import operator
import csv
import urllib2
import json
from collections import defaultdict
import StringIO
import random
from multiprocessing import Pool

# %%
knowledgGraph = "cnet" # conceptnet5AssocMod, gov, conceptnet5AssocMi, conceptnet5AssocHdl
#knowledgGraph_ = ''.join([k.capitalize() if i>0 else k for i, k in enumerate(knowledgGraph)])
collection = "trec7n8"
method = "wsdmImpr" # hal, mi, assoc, assocMi, assocHal, assoc2
simMeasure = "" # mi, cnet
projectDir = "/home/fj9124/projects/ir/seq_kb_ir/" 
indexDir = "/scratch/index/indri_5_7/"
colMethodConfigsDir = os.path.join(projectDir, "configs", collection, method)
cfgInFileName = os.path.join(projectDir, "configs", collection, "query" + collection.capitalize()+"_tst1") 
print("cfgInFileName =", cfgInFileName)
cfgOutFileName=os.path.join(colMethodConfigsDir, knowledgGraph, "indriRunQuery.cfg") 
print("cfgOutFileName =", cfgOutFileName)
colIndexDir = os.path.join(indexDir, collection) 
print("colIndexDir =", colIndexDir)
if knowledgGraph in {"cnet"}:
    knowledgGraphIndexDir = os.path.join(indexDir, collection)   
else:
    knowledgGraphIndexDir = os.path.join(indexDir, knowledgGraph)   
print("knowledgGraph index Dir =", knowledgGraphIndexDir)
graphsDir = os.path.join(projectDir, "graphs")
#methodGraphsDir = os.path.join(graphsDir, method)
methodGraphsFileName = []
if method == "hal":
    methodGraphsFileName = [os.path.join(graphsDir, method, knowledgGraph + ".txt")]
    print("methodGraphsFileName =", methodGraphsFileName)
elif method.translate(None, string.digits) in {"mi", "assoc"}:
    methodGraphsFileName = [os.path.join(graphsDir, method.translate(None, string.digits), knowledgGraph, "graph.txt")]
    print("methodGraphsFileName =", methodGraphsFileName)
elif method in {"assocMi"}:
    if knowledgGraph == "conceptnet5AssocGov":
        methodGraphsFileName = [os.path.join(graphsDir, "assoc", collection, "conceptnet5AssocMod" + ".txt")]
        methodGraphsFileName += [os.path.join(graphsDir, "mi", collection, "gov" + ".txt")]
        print("methodGraphsFileName =", methodGraphsFileName)
elif method in {"assocHal"}:
    if knowledgGraph == "conceptnet5AssocGov":
        methodGraphsFileName = [os.path.join(graphsDir, "assoc", collection, "conceptnet5AssocMod" + ".txt")]
        methodGraphsFileName += [os.path.join(graphsDir, "hal", "gov" + ".txt")]
        print("methodGraphsFileName =", methodGraphsFileName)
qrelsDir = os.path.join(projectDir, "qrels")
colQrelsDir = os.path.join(qrelsDir, collection)
colQrelsFileName = os.path.join(colQrelsDir, "qrels.csv")
print("col Qrels File Name =", colQrelsFileName)
runsFileName = os.path.join(projectDir, "runs", method, collection, knowledgGraph, "indriRunQuery.runs") 
print("runsFileName =", runsFileName)
evalsFileName = os.path.join(projectDir, "evals", method, collection, knowledgGraph, "indriRunQuery.evals") 
print("evalsFileName =", evalsFileName)
dumpindexStatementFilename = os.path.join("/", "tmp", "sbsb", "statement" + "_" + collection + "_" + method + "_" + knowledgGraph )
print("dumpindexStatementFilename =", dumpindexStatementFilename)
occuranceCountFilename = os.path.join(projectDir, "occuranceCount", "occuranceCount")
print("occuranceCountFilename =", occuranceCountFilename)
countsResultsFile = os.path.join(projectDir,"occuranceCount","results",collection+".txt")
print("countsResultsFile =", countsResultsFile)
conceptnet5RelAllFilename ="/scratch/saeid/data/conceptnet5_simp.csv"
print("conceptnet5RelAllFilename =", conceptnet5RelAllFilename)
cfgTmpOutFileName = cfgOutFileName + ".tmp"
print("cfgTmpOutFileName =", cfgTmpOutFileName)
docIdNameMapFileName = os.path.join(projectDir, "occuranceCount", "results", collection + "_docIdNameMap.txt")
print("docIdNameMapFileName =", docIdNameMapFileName)
#dumpindexResFilename = os.path.join(projectDir,"occuranceCount","results",collection +"_dumpindexRes"+".txt")
#print("dumpindexResFilename =", dumpindexResFilename)
#expansionCount = 25
# Out:
# cfgInFileName = /home/fj9124/projects/ir/seq_kb_ir/configs/trec7n8/queryTrec7n8_tst1
# cfgOutFileName = /home/fj9124/projects/ir/seq_kb_ir/configs/trec7n8/wsdmImpr/cnet/indriRunQuery.cfg
# colIndexDir = /scratch/index/indri_5_7/trec7n8
# knowledgGraph index Dir = /scratch/index/indri_5_7/trec7n8
# col Qrels File Name = /home/fj9124/projects/ir/seq_kb_ir/qrels/trec7n8/qrels.csv
# runsFileName = /home/fj9124/projects/ir/seq_kb_ir/runs/wsdmImpr/trec7n8/cnet/indriRunQuery.runs
# evalsFileName = /home/fj9124/projects/ir/seq_kb_ir/evals/wsdmImpr/trec7n8/cnet/indriRunQuery.evals
# dumpindexStatementFilename = /tmp/sbsb/statement_trec7n8_wsdmImpr_cnet
# occuranceCountFilename = /home/fj9124/projects/ir/seq_kb_ir/occuranceCount/occuranceCount
# countsResultsFile = /home/fj9124/projects/ir/seq_kb_ir/occuranceCount/results/trec7n8.txt
# conceptnet5RelAllFilename = /scratch/saeid/data/conceptnet5_simp.csv
# cfgTmpOutFileName = /home/fj9124/projects/ir/seq_kb_ir/configs/trec7n8/wsdmImpr/cnet/indriRunQuery.cfg.tmp
# docIdNameMapFileName = /home/fj9124/projects/ir/seq_kb_ir/occuranceCount/results/trec7n8_docIdNameMap.txt
# cfgInFileName = /home/fj9124/projects/ir/seq_kb_ir/configs/trec7n8/queryTrec7n8_tst1
# cfgOutFileName = /home/fj9124/projects/ir/seq_kb_ir/configs/trec7n8/wsdmImpr/cnet/indriRunQuery.cfg
# colIndexDir = /scratch/index/indri_5_7/trec7n8
# knowledgGraph index Dir = /scratch/index/indri_5_7/trec7n8
# col Qrels File Name = /home/fj9124/projects/ir/seq_kb_ir/qrels/trec7n8/qrels.csv
# runsFileName = /home/fj9124/projects/ir/seq_kb_ir/runs/wsdmImpr/trec7n8/cnet/indriRunQuery.runs
# evalsFileName = /home/fj9124/projects/ir/seq_kb_ir/evals/wsdmImpr/trec7n8/cnet/indriRunQuery.evals
# dumpindexStatementFilename = /tmp/sbsb/statement_trec7n8_wsdmImpr_cnet
# occuranceCountFilename = /home/fj9124/projects/ir/seq_kb_ir/occuranceCount/occuranceCount
# countsResultsFile = /home/fj9124/projects/ir/seq_kb_ir/occuranceCount/results/trec7n8.txt
# conceptnet5RelAllFilename = /scratch/saeid/data/conceptnet5_simp.csv
# cfgTmpOutFileName = /home/fj9124/projects/ir/seq_kb_ir/configs/trec7n8/wsdmImpr/cnet/indriRunQuery.cfg.tmp
# docIdNameMapFileName = /home/fj9124/projects/ir/seq_kb_ir/occuranceCount/results/trec7n8_docIdNameMap.txt

# %%
# trec_eval -q ../qrels/trec7n8/qrels.csv indriRunQuery.res | grep map | grep -v all | awk '{if ($3 < 0.1) printf $2 ","}'
if collection == "gov":
    diffTopics = [4, 6, 7, 8, 9, 10, 12, 18, 19, 21, 22, 24, 26, 27, 30, 31, 32, 33, 36, 37, 40, 45, 46, 47, 48, 50, 52, 53, 54, 57, 58, 59, 63, 65, 66, 67, 70, 73, 78, 79, 80, 82, 84, 86, 92, 93, 94, 95, 96, 98, 99, 101, 102, 103, 104, 105, 106, 107, 109, 110, 111, 112, 113, 115, 116, 117, 118, 120, 123, 125, 126, 127, 129, 132, 133, 134, 135, 136, 137, 140, 142, 143, 147, 148, 149, 152, 153, 154, 155, 156, 157, 158, 160, 161, 162, 163, 165, 166, 167, 168, 169, 171, 175, 176, 177, 178, 179, 180, 182, 183, 185, 186, 188, 189, 191, 192, 194, 195, 196, 197, 200, 201, 202, 203, 204, 207, 208, 211, 212, 214, 215, 218, 219, 221, 224]
if collection == "robust":
    diffTopics = [301, 305, 309, 314, 315, 318, 319, 320, 322, 325, 327, 332, 336, 340, 342, 343, 344, 345, 346, 347, 350, 352, 354, 355, 356, 359, 363, 367, 371, 372, 376, 378, 379, 380, 381, 383, 386, 388, 389, 390, 393, 394, 397, 398, 401, 405, 409, 412, 419, 421, 426, 432, 435, 436, 437, 439, 440, 442, 448, 449, 605, 608, 610, 620, 622, 625, 626, 627, 638, 650, 651, 655, 659, 666, 668, 680, 683, 684, 688, 689, 690]
if collection == "trec7n8":
    diffTopics = [352,354,356,359,363,367,370,371,372,373,376,378,379,381,383,386,388,389,390,393,394,397,398,401,405,408,419,421,422,426,432,435,436,437,439,440,442,443,445,447,448,449]
diffTopic = [str(i) for i in diffTopics]

# %%
# generate docIdNameMapFileName
if not os.path.isfile(occuranceCountFilename):
    cmd = ' '.join([occuranceCountFilename, colIndexDir, "dm", ">", docIdNameMapFileName])
    res = subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE).stdout.read()

# %%
with open(docIdNameMapFileName, 'r') as f:
    reader = list(csv.reader(f, delimiter = ' '))
    print(reader[0])
    docIdNameMap = {i[1]:i[0] for i in reader}
    docNameIdMap = {i[0]:i[1] for i in reader}
for i, (k, v) in enumerate(docIdNameMap.iteritems()):
    print (k, '\t', v)
    if (i>20):
        break
# Out:
# ['1', 'FR940104-1-00001']
# LA082389-0020['1', 'FR940104-1-00001']
# LA082389-0020 	 441223
# FBIS3-32596 	 246524
# LA011890-0198 	 465144
# LA011890-0199 	 465145
# LA011890-0196 	 465142
# LA011890-0197 	 465143
# LA011890-0194 	 465140
# FT932-3799 	 88713
# LA011890-0192 	 465138
# LA011890-0193 	 465139
# LA011890-0190 	 465136
# LA011890-0191 	 465137
# FT932-3796 	 88710
# FT924-2868 	 187695
# FT924-2869 	 187696
# FT932-3797 	 88711
# FT924-2864 	 187691
# FT924-2865 	 187692
# FT924-2866 	 187693
# FT924-2867 	 187694
# FT924-2860 	 187687
# FT924-2861 	 187688
#  	 441223
# FBIS3-32596 	 246524
# LA011890-0198 	 465144
# LA011890-0199 	 465145
# LA011890-0196 	 465142
# LA011890-0197 	 465143
# LA011890-0194 	 465140
# FT932-3799 	 88713
# LA011890-0192 	 465138
# LA011890-0193 	 465139
# LA011890-0190 	 465136
# LA011890-0191 	 465137
# FT932-3796 	 88710
# FT924-2868 	 187695
# FT924-2869 	 187696
# FT932-3797 	 88711
# FT924-2864 	 187691
# FT924-2865 	 187692
# FT924-2866 	 187693
# FT924-2867 	 187694
# FT924-2860 	 187687
# FT924-2861 	 187688

# %%
count_history = dict()
if os.path.isfile(countsResultsFile):
    with open(countsResultsFile, 'r') as f:
        reader = csv.reader(f, delimiter = "\t")
        count_history = {k:int(float(v)) for k,v in list(reader)}
    print("size of count_history =", len(count_history))
    for i, (k, v) in enumerate(count_history.iteritems()):
        print (k, '\t', v)
        if (i>20):
            break
# Out:
# size of count_history = 81446
# #uw(#4( storm ) #4( be appear in sky )) 	 0
# #uw(#4( work on sundai )) 	 137
# #uw(#4( calm time )) 	 23
# #uw(#4( kill ) #4( prai )) 	 394
# #uw(#4( bank ) #4( teller offic )) 	 5
# #uw(#4( water ) #4( hydrogen )) 	 347
# #uw(#4( drug ) #4( take )) 	 8847
# #uw(#4( space ) #4( mostli empti )) 	 3
# #uw(#4( chang ) #4( edg )) 	 3803
# #uw(#4( happin )) 	 0
# #uw(#4( trade ) #4( countri )) 	 45838
# #uw(#4( game ) #4( leisur activ )) 	 23
# #uw(#4( round in shape )) 	 4
# #uw(#4( good ) #4( other person )) 	 411
# #uw(#4( smoke ) #4( fire )) 	 1842
# #uw(#4( spice up salad )) 	 1
# #uw(#4( be wound )) 	 410
# #uw(#4( good ) #4( hear nice new )) 	 0
# #uw(#4( teacher ) #4( teach student of class )) 	 0
# #uw(#4( deliveri )) 	 11268
# #uw(#4( bank ) #4( teller monei )) 	 23
# #uw(#4( swap share )) 	 106
# size of count_history = 81446
# #uw(#4( storm ) #4( be appear in sky )) 	 0
# #uw(#4( work on sundai )) 	 137
# #uw(#4( calm time )) 	 23
# #uw(#4( kill ) #4( prai )) 	 394
# #uw(#4( bank ) #4( teller offic )) 	 5
# #uw(#4( water ) #4( hydrogen )) 	 347
# #uw(#4( drug ) #4( take )) 	 8847
# #uw(#4( space ) #4( mostli empti )) 	 3
# #uw(#4( chang ) #4( edg )) 	 3803
# #uw(#4( happin )) 	 0
# #uw(#4( trade ) #4( countri )) 	 45838
# #uw(#4( game ) #4( leisur activ )) 	 23
# #uw(#4( round in shape )) 	 4
# #uw(#4( good ) #4( other person )) 	 411
# #uw(#4( smoke ) #4( fire )) 	 1842
# #uw(#4( spice up salad )) 	 1
# #uw(#4( be wound )) 	 410
# #uw(#4( good ) #4( hear nice new )) 	 0
# #uw(#4( teacher ) #4( teach student of class )) 	 0
# #uw(#4( deliveri )) 	 11268
# #uw(#4( bank ) #4( teller monei )) 	 23
# #uw(#4( swap share )) 	 106

# %%
conceptnet5RelAll = defaultdict(dict)
conceptnet5RelAllInv = defaultdict(dict)
with open(conceptnet5RelAllFilename, 'r') as f:
    reader = csv.reader(f, delimiter = ",")
    for line in list(reader):
        if line[0].strip() != "" and line[1].strip() != "" and line[2].strip() != "":
            if all(c in string.printable for c in line[0]) and all(c in string.printable for c in line[1]) and all(c in string.printable for c in line[2]):
                conceptnet5RelAll[line[1].strip()][line[2].strip()] = line[0].strip()
                conceptnet5RelAllInv[line[2].strip()][line[1].strip()] = line[0].strip()
print("size of conceptnet5RelAll =", len(conceptnet5RelAll))
for i, (k1, k2v) in enumerate(conceptnet5RelAll.iteritems()):
    for j, (k2, v) in enumerate(k2v.iteritems()):
        if (i>3 or j>3):
            break
        print (k1, '\t', k2, '\t', v)
# Out:
# size of conceptnet5RelAll = 2965684
# tripolitan 	 tripoline 	 Synonym
# tripolitan 	 tripoli 	 RelatedTo
# age of nemesis 	 band 	 IsA
# age of nemesis 	 organisation 	 InstanceOf
# age of nemesis 	 progressive rock 	 dbpedia/genre
# age of nemesis 	 progressive metal 	 dbpedia/genre
# joseph john annabring 	 person 	 InstanceOf
# british rail class 438 	 mean of transportation 	 InstanceOf
# british rail class 438 	 train 	 InstanceOf
# size of conceptnet5RelAll = 2965684
# tripolitan 	 tripoline 	 Synonym
# tripolitan 	 tripoli 	 RelatedTo
# age of nemesis 	 band 	 IsA
# age of nemesis 	 organisation 	 InstanceOf
# age of nemesis 	 progressive rock 	 dbpedia/genre
# age of nemesis 	 progressive metal 	 dbpedia/genre
# joseph john annabring 	 person 	 InstanceOf
# british rail class 438 	 mean of transportation 	 InstanceOf
# british rail class 438 	 train 	 InstanceOf

# %%
indriRunQuery_hist_= dict()
dumpindex_hist_ = dict()

# %%
def splitStemText(text):
    stemmedWords = []
    text = re.sub('/|-|\"|_',' ', text) # replace - and slash with space
    if method in {"assocRestful", "lr", "wsdmImpr"}:
        for text_ in text.split(' '):
            text = text_.replace(" ", "_")
            url = "http://conceptnet5.media.mit.edu/data/5.4/uri?language=en&text=" + text
            response = urllib2.urlopen(url)
            data = response.read()
            data_j = json.loads(data)
            text = os.path.basename(data_j[u'uri'])
            url = "http://conceptnet5.media.mit.edu/data/5.4/uri?language=en&text=" + text
            response = urllib2.urlopen(url)
            data = response.read()
            data_j = json.loads(data)
            #print("data_j =", data_j)
            #print("data_j[u'uri'] =", data_j[u'uri'])
            stemmedWords += [str(os.path.basename(data_j[u'uri']))]
        #print("stemmedWords =", stemmedWords)
        return (stemmedWords)
    else:
        words = text.split()
        for w in words:
            w = re.sub('\(|\)|\'s|,','', w) # remove paranthesis, apostrophe s, comma
            w = re.sub('\'','', w) # remove apostrophe
            cmd = "dumpindex " + knowledgGraphIndexDir + " t " + w + " | head -n1"
            #print("cmd =", cmd)
            stemmedWords.append(subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE).stdout.read().split()[1])
        return (stemmedWords)

print ("testing:", splitStemText("going reading"))
# Out:
# testing: ['go', 'read']
# testing: ['go', 'read']

# %%
def analyseQueries():
    #    #print("intCoeff =", intCoeff)
    with open(cfgInFileName, 'r') as inFile:
        reader = inFile.read()
        soup = BeautifulSoup(reader, 'lxml')
        if collection in {"aquaint", "gov"}:
            tags = soup.find_all(['doc'])
        elif collection in {"robust", "trec7n8", "gov2"}:
            tags = soup.find_all(['top'])
            #print(tags)
        
        origWordsAll = dict()
        for tag in tags:
            
            if collection in {"aquaint", "gov"}:
                docno = (tag.find('docno').string).strip()
            elif collection in {"robust", "trec7n8", "gov2"}:
                result = re.search('<num> Number: (.*)\n', str(tag))                
                docno = result.group(1).strip()
            
            if collection in {"aquaint", "gov"}:
                origWords = splitStemText(tag.find('text').string.strip())
            elif collection in {"robust", "trec7n8", "gov2"}:
                result = re.search('<title>(.*)\n', str(tag))                
                origWords = splitStemText(result.group(1).strip())
            #print("origWords =", origWords)
            origWordsAll[docno] = origWords
            
    return (origWordsAll)

# %%
cmd = ' '.join(["dumpindex", colIndexDir, "s", "|", "awk", "\'NR==2{print $2}\'"])
res = subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE).stdout.read()
colDocumentCount = int(np.float(res))
print("colDocumentCount =", colDocumentCount)
# Out:
# colDocumentCount = 472526
# colDocumentCount = 472526

# %%
def genMultSimpQuery(argss):
    #    #print("intCoeff =", intCoeff)
    soupNew = BeautifulSoup("", 'lxml')
    parameters_tag = soupNew.new_tag("parameters")
    index_tag = soupNew.new_tag("index")
    index_tag.string = colIndexDir
    parameters_tag.append(index_tag)
        #print(tags)

    for args in argss:
        #print("args =", args)
        (dist, docno, origWords_, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights, workingset) = args
        #print("(...) =", docno, origWords_, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights, workingset)
        doc_tag = soupNew.new_tag("query")

        docno_tag = soupNew.new_tag("number")
        if relW != "":
            docno_tag.string = '_'.join([dist, docno, ('_'.join(origWords_)).replace(' ', '_'), relW.replace(' ', '_')])
        else:
            docno_tag.string = '_'.join([dist, docno, ('_'.join(origWords_)).replace(' ', '_'), relW.replace(' ', '_')])

        doc_tag.append(docno_tag)

        text_tag = soupNew.new_tag("text")
        text_tag.string = "#weight(\n" 

        text_tag.string += str(intCoeff0) + " #combine(" 
        for ow in set(origWords_):
            ow = re.sub(ur"[^\w\d#(),:\-\s]+", ' ', ow)
            text_tag.string += ow + " "
        text_tag.string += ")\n"

        if len(relW)>0: 
            relText_string1 = re.sub(ur"[^\w\d#(),:\-\s]+",' ',relW)
            text_tag.string += str(intCoeff1) + " #combine(" 
            #print("relText_string1 =", relText_string1)
            text_tag.string += relText_string1.encode('utf-8')
            text_tag.string += ")\n"

        text_tag.string += ") "

        doc_tag.append(text_tag)
        
        if workingset[0] != "all":
            for d in workingset:
                workingSetDocno_tag = soupNew.new_tag("workingSetDocno")
                workingSetDocno_tag.string = d
                doc_tag.append(workingSetDocno_tag)

        parameters_tag.append(doc_tag)
        #print(doc_tag)

    rule_tag = soupNew.new_tag("rule")
    rule_tag.string = "method:dir,mu:" + str(dirCoeff)
    #rule_tag.string = "method:two"
    parameters_tag.append(rule_tag)

    threads_tag = soupNew.new_tag("threads")
    threads_tag.string = "32"
    parameters_tag.append(threads_tag)

    count_tag = soupNew.new_tag("count")
    count_tag.string = "10"
    parameters_tag.append(count_tag)

    trecFormat_tag = soupNew.new_tag("trecFormat")
    trecFormat_tag.string = "true"
    parameters_tag.append(trecFormat_tag)

    soupNew.append(parameters_tag)
    #print(soupNew.prettify())
    #print("cfgTmpOutFileName =", cfgTmpOutFileName)
    with open( cfgTmpOutFileName, 'a+') as outFile:
        soupNewStr = str(soupNew)
        soupNewStr = soupNewStr.replace("</text>", "\n</text>\n").replace("query>", "query>\n").replace("<text>", "\n<text>\n").replace("</index>", "</index>\n").replace("\n<index>", "<index>")

        outFile.write(soupNewStr)

# %%
def genCommandsinHist_i(dist, docno, origWords_, ow, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights):
    
    indriRunQuery_hist = [(dist, docno, origWords_, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, cfgTmpOutFileName, ['all'])]
    return indriRunQuery_hist

# %%
def runCommandsinHist_i(cfgTmpOutFileName, indriRunQuery_hist, indriRunQuery_hist_, featureWeights):
    with open( cfgTmpOutFileName, 'w+') as outFile:
        outFile.write("")
    args = []
    #print("indriRunQuery_hist =", indriRunQuery_hist, "\nlen(indriRunQuery_hist) =",len(indriRunQuery_hist))
    for (dist, docno, origWords_, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, cfgTmpOutFileName, workingset) in indriRunQuery_hist:
        #print("origWords_, relW (before if) =", origWords_, "---", relW)
        if '_'.join([dist, docno, ('_'.join(origWords_)).replace(' ', '_'), relW.replace(' ', '_')]) not in indriRunQuery_hist_:
            #print("origWords_, relW (after if) =", origWords_, "---", relW)
            args += [(dist, docno, origWords_, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights, workingset)]
    #print("args =", args)
    if len(args)>0:
        genMultSimpQuery(args)
    cmd = ' '.join(["IndriRunQuery", cfgTmpOutFileName])
    #print("cmd =", cmd)
    indriRun = subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE).stdout.read()
    #print("indriRun =", indriRun)
    indriRunQuery_hist_tmp = [[j for c, j in enumerate(i.split(' ')) if c in {0, 2, 4}] for i in indriRun.split('\n') if len(i)>0]
    #indriRunQuery_hist_ = dict()
    for i in indriRunQuery_hist_tmp:
        if i[0] in indriRunQuery_hist_:
            indriRunQuery_hist_[i[0]] += [[i[1], i[2]]]
        else:
            indriRunQuery_hist_[i[0]] = [[i[1], i[2]]]
    #indriRunQuery_hist_ = list(set(indriRunQuery_hist_))
    return indriRunQuery_hist_

# %%
def genCommandsinHist_id(indriRunQuery_hist_, dumpindex_hist, indriRunQuery_phCounter_hist, docno, origWords_, ow, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights):

    expr = '_'.join([dist, docno, '_'.join(origWords_), ""]).replace(' ', '_')
    #print("expr =", expr)
    indriRunQuery_hist_1 = indriRunQuery_hist_[expr]
    #print("indriRunQuery_hist_1 =", indriRunQuery_hist_1)
    topTDocs = [i[0] for i in indriRunQuery_hist_1]
    
    expr = "#4( " + regex.sub(' ', relW) + " )"
    #expr = '_'.join([dist, docno, '_'.join(origWords_), ""]).replace(' ', '_')
    #print("expr =", expr)
    cmd2 = [(dist, docno, [expr], "", intCoeff0, intCoeff1, intCoeff2, dirCoeff, cfgTmpOutFileName, topTDocs)]
    if cmd2 not in indriRunQuery_phCounter_hist:
        indriRunQuery_phCounter_hist += cmd2
    
    #print("relW =", relW)
    expr = "#4( " + regex.sub(' ', relW) + " )"
    cmd2 = ("fx", expr)
    if cmd2 not in dumpindex_hist:
        dumpindex_hist.add(cmd2)
    #print("dumpindex_hist =", dumpindex_hist)
    
    for documentName in topTDocs:
        cmd2 = ("dcf", docIdNameMap[documentName])
        if cmd2 not in dumpindex_hist:
            dumpindex_hist.add(cmd2)

    for ow in origWords_:
        phrase = ["#uw(#4( " + regex.sub(' ', ow) + " ) #4( " + regex.sub(' ', relW) + " ))"]
        #cmd2 = ("efb", "#uw(#4( " + regex.sub(' ', ow) + " ) #4( " + regex.sub(' ', relW) + " )):" + ','.join(topTDocs))
        cmd2 = [(dist, docno, phrase, "", intCoeff0, intCoeff1, intCoeff2, dirCoeff, cfgTmpOutFileName, topTDocs)]
        if cmd2 not in indriRunQuery_phCounter_hist:
            indriRunQuery_phCounter_hist += cmd2        
        cmd2 = ("fx", phrase[0])
        if cmd2 not in dumpindex_hist:
            dumpindex_hist.add(cmd2)
        
    for j1, ow1 in enumerate(origWords_):
        for j2, ow2 in enumerate(origWords_):
            if j1>j2:
                phrase = ["#uw(#4( " + regex.sub(' ', ow1) + " ) #4( " + regex.sub(' ', ow2) + " ) #4( " + regex.sub(' ', relW) + " ))"]
                cmd2 = [(dist, docno, phrase, "", intCoeff0, intCoeff1, intCoeff2, dirCoeff, cfgTmpOutFileName, topTDocs)]
                if cmd2 not in indriRunQuery_phCounter_hist:
                    indriRunQuery_phCounter_hist += cmd2        
                cmd2 = ("fx", phrase[0])
                if cmd2 not in dumpindex_hist:
                    dumpindex_hist.add(cmd2)
    #print("len(dumpindex_hist) =", len(dumpindex_hist))
    return dumpindex_hist

# %%
regex = re.compile('[%s]' % re.escape(string.punctuation))
def runCommandsinHist_d(dist, docno, dumpindex_hist, dumpindex_hist_):
    args = []
    dumpindex_hist_dict = dict()
    tmp = set()
    #print("dumpindex_hist =", dumpindex_hist)
    for i in dumpindex_hist:
        expr = '_'.join([dist, docno, '_'.join(i[0]), ""]).replace(' ', '_')
        if i[1] not in dumpindex_hist_.get(expr, dict()):
#        if i[1] not in dumpindex_hist_.get(dist + "_" + docno + "_" + i[0], dict()):
            if i[1] in tmp:
                continue
            #print("i =", i)
            tmp.add(i[1])
            if i[0] in dumpindex_hist_dict:
                dumpindex_hist_dict[i[0]] += [[re.sub(ur"[^\w\d#(),:\-\s]+",' ',j) for j in i[1:]]]
            else:
                dumpindex_hist_dict[i[0]] =  [[re.sub(ur"[^\w\d#(),:\-\s]+",' ',j) for j in i[1:]]]
                
    for k, v in dumpindex_hist_dict.iteritems():
        fileName = dumpindexStatementFilename + "_" + k + ".tmp"
        with open(fileName, 'w') as f:
            for i in v:
                f.write(' '.join(i) + '\n')
                #print("i =", i)
        cmd = ' '.join([occuranceCountFilename, colIndexDir, k, fileName])
        #print("cmd =", cmd)
        dumpindex_hist_tmp = subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE).stdout.read()
        #print("dumpindex_hist_tmp =", dumpindex_hist_tmp)
        dumpindex_hist_tmp = dict([tuple(j for c2, j in enumerate(i.split(':')) if c2 in {0,1} ) for i in dumpindex_hist_tmp.split("\n") if len(i)>0])
        #print("dumpindex_hist_tmp.get(\"#od4(travel)\",\"\") =", dumpindex_hist_tmp.get("#od4(travel)", dict()) )
        dumpindex_hist_tmp = {k1:v1.split(',') for k1,v1 in dumpindex_hist_tmp.iteritems()}
        dumpindex_hist_tmp = {k1:[i for i in v1 if len(i)>0] for k1,v1 in dumpindex_hist_tmp.iteritems()}
        #dumpindex_hist_tmp = {re.sub(ur"[^\w\d#()\s]+",' ',k1):[i for i in v1 if len(i)>0] for k1,v1 in dumpindex_hist_tmp.iteritems()}
        #dumpindex_tmp = [i for i in dumpindex_tmp.split("\n")]
        #print("dumpindex_hist_tmp =", dumpindex_hist_tmp)
        #dumpindex_hist_[k] = dumpindex_hist_tmp
        #expr = '_'.join([dist, docno, '_'.join(k), ""]).replace(' ', '_')    
        dumpindex_hist_[k] = dict(dumpindex_hist_.get(k, dict()).items() + dumpindex_hist_tmp.items())
        #dumpindex_hist_[dist + "_" + docno + "_" + k] = dict(dumpindex_hist_.get(dist + "_" + docno + "_" + k, dict()).items() + dumpindex_hist_tmp.items())
    #print("dumpindex_hist_['efb'].get('#od4(travel)', dict())]", dumpindex_hist_['efb'].get("#od4(travel)", dict()))
        #print("dumpindex_hist_[k].keys() =", dumpindex_hist_[k].keys())
    #print("dumpindex_hist_ =", dumpindex_hist_)
        
    return dumpindex_hist_

# %%
# keys of rWords are important
# values of rWords1 are important
regex = re.compile('[%s]' % re.escape(string.punctuation))
def getRelWords_train(args, indriRunQuery_hist_, dumpindex_hist_):
    #print("origWords =", origWords)
    text_string = ""
    
    count_history, rWords, dist, docno, origWords, expansionCount, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights = args
        
    relWords = dict()
    #if method == "relAll":
            
    if method in {"lr", "wsdmImpr"}:
        origWords_ = [w.replace(" ", "_") for w in origWords]
        #relWords_l = []
        indriRunQuery_phCounter_hist = []
        dumpindex_hist = set()
        for ow in origWords_:
            #print("ow =", ow)
            #relWords_l += list(conceptnet5RelAll[ow])
            #print(ow, "---", conceptnet5RelAll[ow])
            indriRunQuery_hist = []
            indriRunQuery_hist += genCommandsinHist_i(dist, docno, origWords_, ow, "", intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights)
            for relW in conceptnet5RelAll[ow].keys():
                indriRunQuery_hist += genCommandsinHist_i(dist, docno, origWords_, ow, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights)

            indriRunQuery_hist_ = runCommandsinHist_i(cfgTmpOutFileName, indriRunQuery_hist, indriRunQuery_hist_, featureWeights)
            
            
            
            for relW in conceptnet5RelAll[ow].keys():
                dumpindex_hist |= genCommandsinHist_id(indriRunQuery_hist_, dumpindex_hist, indriRunQuery_phCounter_hist, docno, origWords_, ow, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights)
                #print("indriRunQuery_phCounter_hist =", indriRunQuery_phCounter_hist)
                #indriRunQuery_phCounter_hist = [list(x) for x in set(tuple(x) for x in indriRunQuery_phCounter_hist)]
            
        dumpindex_hist_ = runCommandsinHist_d(dist, docno, dumpindex_hist, dumpindex_hist_)
        
        indriRunQuery_hist_ = runCommandsinHist_i(cfgTmpOutFileName, indriRunQuery_phCounter_hist, indriRunQuery_hist_, featureWeights)

    return(indriRunQuery_hist_, dumpindex_hist_)

# %%
regex = re.compile('[%s]' % re.escape(string.punctuation))
def documentLength(dist, docno, documentName, dumpindex_hist_):
    documentLength_ = int(dumpindex_hist_['dcf'][documentName][0])
    #documentLength_ = int(dumpindex_hist_['dcf'][dist + "_" + docno + "_" + documentName][0])
    return documentLength_

def weightRelConcept(dist, docno, origWords_, ow, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, count_history, featureWeights, indriRunQuery_hist_, dumpindex_hist_):
    
    features = dict()
    
    expr = '_'.join([dist, docno, '_'.join(origWords_), ""]).replace(' ', '_')
    #print("expr =", expr)
    indriRunQuery_hist_1 = indriRunQuery_hist_[expr]
    #print("indriRunQuery_hist_1 =", indriRunQuery_hist_1)
    topTDocs = [i[0] for i in indriRunQuery_hist_1]
    
    topTDocScores_d = {i[0]:np.float(i[1]) for i in indriRunQuery_hist_1}
    
    
    expTDocScore = np.float(indriRunQuery_hist_1[0][1])
    features["expTDocScore"] = expTDocScore
    
    expr = "#4( " + regex.sub(' ', relW) + " )"
    #expr = expr.replace(' ', '_')
    #print("expr =", expr)
    expr_i = '_'.join([dist, docno, '_'.join([expr.replace(' ', '_')]), ""]).replace(' ', '_')
    indriRunQuery_hist_1 = indriRunQuery_hist_[expr_i]
    #print("indriRunQuery_hist_1 =", indriRunQuery_hist_1)
    relWTopDocuments = list([i[0] for i in indriRunQuery_hist_1]) #deep copy
    
    numerator = len(relWTopDocuments) # relW term count in the collection
    denumerator = np.sum([documentLength(dist, docno, i, dumpindex_hist_) for i in topTDocs]) # number of terms in topDocs
    topTermFrac = numerator / np.float(denumerator)
    features["topTermFrac"] = topTermFrac
    
    numCanDocs = len(set([i[0] for i in relWTopDocuments]))
    features["numCanDocs"] = numCanDocs
    
    if numCanDocs > 0:
        avgCDocScore = np.sum([ topTDocScores_d[i] for i in set([i for i in relWTopDocuments])])/np.float(numCanDocs)
    else:
        avgCDocScore = 0
    features["avgCDocScore"] = avgCDocScore

    l = [ topTDocScores_d[i] for i in set(relWTopDocuments)]
    if len(l)>0:
        maxCDocScore = np.max(l)
    else:
        maxCDocScore = 0
    features["maxCDocScore"] = maxCDocScore
    
    colDocFreq = np.float(dumpindex_hist_['fx'][expr][0])
    if colDocFreq>0:
        conIdf = np.log(colDocumentCount / colDocFreq)
    else:
        conIdf = np.log(colDocumentCount / 1)
    features["conIdf"] = conIdf
    
    coocurDocumentsTop = dict()
    coocurDocumentsCount = dict()
    for ow in origWords_:
        expr = "#uw(#4( " + regex.sub(' ', ow) + " ) #4( " + regex.sub(' ', relW) + " ))"
        #expr = expr.replace(' ', '_')
        expr_i = '_'.join([dist, docno, '_'.join([expr.replace(' ', '_')]), ""]).replace(' ', '_')
        indriRunQuery_hist_1 = indriRunQuery_hist_[expr_i]
        coocurDocumentsTop[ow] = list([i[0] for i in indriRunQuery_hist_1])
        coocurDocumentsCount[ow] = np.float(dumpindex_hist_['fx'][expr][0])

    avgColCor = np.sum(coocurDocumentsCount.values())/np.float(len(coocurDocumentsCount.values())) 
    features["avgColCor"] = avgColCor
    
    maxColCor = np.max(coocurDocumentsCount.values())
    features["maxColCor"] = maxColCor
    
    avgTopColCor = np.sum([len(set(i)) for i in coocurDocumentsTop.values()])/np.float(len(coocurDocumentsTop.values())) 
    features["avgTopColCor"] = avgTopColCor
    
    l = [len(set(i)) for i in coocurDocumentsTop.values()]
    if len(l)>0:
        maxTopColCor = np.max(l)
    else:
        maxTopColCor = 0
    features["maxTopColCor"] = maxTopColCor

    coocurDocumentsTop = dict()
    coocurDocumentsCount = dict()
    for j1, ow1 in enumerate(origWords_):
        for j2, ow2 in enumerate(origWords_):
            if j1>j2:
                expr = "#uw(#4( " + regex.sub(' ', ow1) + " ) #4( " + regex.sub(' ', ow2) + " ) #4( " + regex.sub(' ', relW) + " ))"
                #expr = expr.replace(' ', '_')
                expr_i = '_'.join([dist, docno, '_'.join([expr.replace(' ', '_')]), ""]).replace(' ', '_')
                indriRunQuery_hist_1 = indriRunQuery_hist_[expr_i]
                #indriRunQuery_hist_1 = indriRunQuery_hist_['_'.join([dist, docno, expr]).replace(' ', '_')]
                coocurDocumentsTop[ow1+ow2] = list([i[0] for i in indriRunQuery_hist_1])
                coocurDocumentsCount[ow] = np.float(dumpindex_hist_['fx'][expr][0])

    avgColPCor = np.sum(coocurDocumentsCount.values())/np.float(len(coocurDocumentsCount.values()))  
    features["avgColPCor"] = avgColPCor

    if len(coocurDocumentsCount.values())>0:
        maxColPCor = np.max(coocurDocumentsCount.values())
    else:
        maxColPCor = 0
    features["maxColPCor"] = maxColPCor
    
    avgTopColPCor = np.sum([len(set(i)) for i in coocurDocumentsTop.values()])/np.float(len(coocurDocumentsTop.values())) 
    features["avgTopColPCor"] = avgTopColPCor

    l = [len(set(i)) for i in coocurDocumentsTop.values()] 
    if len(l)>0:
        maxTopColPCor = np.max(l)
    else:
        maxTopColPCor = 0
    features["maxTopColPCor"] = maxTopColPCor
        
    relWg = 0
    for feature, weight in featureWeights.iteritems():
        relWg += features[feature] * weight
    
    print("origWords_ =", origWords_)
    print("relW =", relW)
    print("features =", features)
    print("relWg =", relWg)

    return relWg

# %%
# keys of rWords are important
# values of rWords1 are important
regex = re.compile('[%s]' % re.escape(string.punctuation))
def getRelWords(args, indriRunQuery_hist_, dumpindex_hist_):
    #print("origWords =", origWords)
    text_string = ""
    
    count_history, rWords, dist, docno, origWords, expansionCount, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights = args
        
    relWords = dict()
    #if method == "relAll":
        
    if method == "assocRestful":
        origWords_ = [w.replace(" ", "_") for w in origWords]
        url = "http://conceptnet5.media.mit.edu/data/5.4/assoc/list/en/"+','.join(origWords_)
        response = urllib2.urlopen(url)
        data = response.read()
        data_j = json.loads(data)
        relWords = {str(d[0].encode('utf-8')).replace('/c/en/', '').replace('-', ' '):np.float(d[1]) for d in data_j[u'similar'] if '/c/en/' in str(d[0].encode('utf-8'))}
    
    elif method in {"lr", "wsdmImpr"}:
        origWords_ = [w.replace(" ", "_") for w in origWords]
        #relWords_l = []

        for ow in origWords_:
            #relWords_l += list(conceptnet5RelAll[ow])
            #print(ow, "---", conceptnet5RelAll[ow])
            for relW in conceptnet5RelAll[ow].keys():
                relWg = weightRelConcept(dist, docno, origWords_, ow, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, count_history, featureWeights, indriRunQuery_hist_, dumpindex_hist_)
                if relW in relWords:
                    relWords[relW] += relWg
                else:
                    relWords[relW] = relWg  
    
    else:
        count_history = countExpr(count_history, origWords, rWords)
        expressions = set()
        for ow in origWords:
            rWords_ow = rWords.get(ow, [])
            expressions.add("#4( " + ow.translate(None, string.punctuation) + " )")
            if ow.strip() == "":
                continue
            if simMeasure == "mi":
                N_w = countExpr_get_1(count_history, ow)
            for rw_wv in rWords_ow:
                (rw_w, rw_v) = rw_wv.items()[0]
                if rw_w.strip() == "":
                    continue           
                if simMeasure == "mi":
                    N_v = countExpr_get_1(count_history, rw_w)
                    N_wv = countExpr_get_2(count_history, ow, rw_w)
                    rw_v_ = mi_(N_w, N_v, N_wv)
                elif simMeasure == "cnet":
                    rw_v_ = rw_v
                relWords[rw_w] = relWords.get(rw_w, 0) + rw_v_
    
    relWords_sorted = sorted(relWords.items(), key=operator.itemgetter(1), reverse=True)
    #print ("origWords =", origWords)
    #print ("relWords_sorted =", relWords_sorted)
    #counter = 0
    relWords_sel = []
    for counter, (rw_w, rw_v) in enumerate(relWords_sorted):
        if (counter >= expansionCount):
            break
        if  all(c in string.printable for c in rw_w):
            if rw_w not in origWords:
                rw_w = regex.sub(' ', rw_w)
                text_string += rw_w + " "
                relWords_sel += [rw_w]
        #counter += 1
    #print("counter =", counter)
    #rint("relWords_sel =", relWords_sel)
#    return(relWords_sel)
    return(count_history, text_string, relWords_sel)

# %%
def getAllRelWords_train(dist, count_history, rWords, origWordsAll, expansionCount1, N1, expansionCount2, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights, indriRunQuery_hist_, dumpindex_hist_):
    relText_stringAll = []
    relText_string = dict()
    relWords_sel = dict()
    for c1, (docno, origWords) in enumerate(origWordsAll.iteritems()):
        print("c1 =", c1, "docno =", docno, "--- origWords =", origWords)
        args = (count_history, rWords, dist, docno, origWords, expansionCount1, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights)
        indriRunQuery_hist_, dumpindex_hist_ = getRelWords_train(args, indriRunQuery_hist_, dumpindex_hist_)
        #print("c1 =", c1, "- len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) =", len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())))
    
    #print("relText_stringAll =", relText_stringAll)
    return (indriRunQuery_hist_, dumpindex_hist_)

# %%
def getAllRelWords(dist, count_history, rWords, origWordsAll, expansionCount1, N1, expansionCount2, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights, indriRunQuery_hist_, dumpindex_hist_):
    relText_stringAll = []
    relText_string = dict()
    relWords_sel = dict()
    for c1, (docno, origWords) in enumerate(origWordsAll.iteritems()):
        #print(str(c1), "---", docno, "---", origWords)
        args = (count_history, rWords, dist, docno, origWords, expansionCount1, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights)
        count_history, relText_string_, relWords_sel_ = getRelWords(args, indriRunQuery_hist_, dumpindex_hist_)
        #print("len(indriRunQuery_hist_), len(dumpindex_hist_['dcf']), len(dumpindex_hist_['ef']) =", len(indriRunQuery_hist_), len(dumpindex_hist_['dcf']), len(dumpindex_hist_['ef']))
        relText_string[docno] = relText_string_
        relWords_sel[docno] = relWords_sel_[0:N1]
        #print(docno, "---", origWords, "---", relWords_sel_)
    relText_stringAll += [relText_string]
    """
    relText_string = dict()
    relWords_sel = dict()
    for docno, origWords_new in relWords_sel.iteritems():
        args = (count_history, rWords, docno, origWords, expansionCount1, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights)
        count_history, relText_string_, relWords_sel_ = getRelWords(args, indriRunQuery_hist_, dumpindex_hist_)
        relText_string[docno] = relText_string_
        relWords_sel[docno] = relWords_sel_
    relText_stringAll += [relText_string]
    """
    #print("relText_stringAll =", relText_stringAll)
    return (count_history, relText_stringAll, relWords_sel)

# %%
regex = re.compile('[%s]' % re.escape(string.punctuation))
def genQueries(cfgOutFileName_, origWordsAll, relText_stringAll, intCoeff0, intCoeff1, intCoeff2, dirCoeff):
    #    #print("intCoeff =", intCoeff)
    with open(cfgInFileName, 'r') as inFile:
        reader = inFile.read()
        soupNew = BeautifulSoup("", 'lxml')
        parameters_tag = soupNew.new_tag("parameters")
        index_tag = soupNew.new_tag("index")
        index_tag.string = colIndexDir
        parameters_tag.append(index_tag)
            #print(tags)

        for docno, origWords in origWordsAll.iteritems():
            doc_tag = soupNew.new_tag("query")

            docno_tag = soupNew.new_tag("number")
            docno_tag.string = docno
            doc_tag.append(docno_tag)

            text_tag = soupNew.new_tag("text")
            text_tag.string = "#weight(\n" 
                    
            text_tag.string += str(intCoeff0) + " #combine(" 
            for ow in set(origWords):
                ow = regex.sub(' ', ow)
                text_tag.string += ow + " "
            text_tag.string += ")\n"

            if len(relText_stringAll[0])>0:
                if len(relText_stringAll[0][docno]) > 3: 
                    relText_string1 = regex.sub(' ', relText_stringAll[0][docno])
                    text_tag.string += str(intCoeff1) + " #combine(" 
                    #print("relText_string1 =", relText_string1)
                    text_tag.string += relText_string1.encode('utf-8')
                    text_tag.string += ")\n"
            
            """
            #print(len(relText_stringAll[1]))
            if len(relText_stringAll[1])>0:
                if len(relText_stringAll[1][docno]) > 3: 
                    relText_string2 = regex.sub(' ', relText_stringAll[1][docno])
                    text_tag.string += str(intCoeff2) + " #combine(" 
                    #print("relText_string2 =", relText_string2)
                    text_tag.string += relText_string2.encode('utf-8')
                    text_tag.string += ")\n"
            """
            #print("origWords =", origWords)
            #print("relWords_sel1 =", relWords_sel1)
            #print("relWords_sel2 =", relWords_sel2)
            
            
            text_tag.string += ") "

            doc_tag.append(text_tag)

            parameters_tag.append(doc_tag)
            #print(doc_tag)

        rule_tag = soupNew.new_tag("rule")
        rule_tag.string = "method:dir,mu:" + str(dirCoeff)
        #rule_tag.string = "method:two"
        parameters_tag.append(rule_tag)

        #intCoeff_tag = soupNew.new_tag("intCoeff")
        #intCoeff_tag.string = "0.8"
        #parameters_tag.append(intCoeff_tag)

        threads_tag = soupNew.new_tag("threads")
        threads_tag.string = "32"
        parameters_tag.append(threads_tag)

        count_tag = soupNew.new_tag("count")
        count_tag.string = "1000"
        parameters_tag.append(count_tag)

        trecFormat_tag = soupNew.new_tag("trecFormat")
        trecFormat_tag.string = "true"
        parameters_tag.append(trecFormat_tag)

        soupNew.append(parameters_tag)
        #print(soupNew.prettify())
    #print("outFileName =", outFileName)
    with open( cfgOutFileName_, 'w') as outFile:
        soupNewStr = str(soupNew)
        soupNewStr = soupNewStr.replace("</text>", "\n</text>\n").replace("query>", "query>\n").replace("<text>", "\n<text>\n").replace("</index>", "</index>\n").replace("\n<index>", "<index>")

        outFile.write(soupNewStr)

# %%
def precisionCompute_train(dist, origWordsAll, count_history, intCoeffs0, intCoeffs1, intCoeffs2, expansionCounts1, expansionCounts2, dirCoeffs, N1s, featureWeights_, indriRunQuery_hist_, dumpindex_hist_):
    #randNum = random.randint(1,1e9)
    
    indriRunQuery_hist_, dumpindex_hist_ = getAllRelWords_train(dist, count_history, rWords, origWordsAll, expansionCounts1[0], N1s[0], expansionCounts2[0], intCoeffs0[0], intCoeffs1[0], intCoeffs2[0], dirCoeffs[0], featureWeights_[0], indriRunQuery_hist_, dumpindex_hist_)
                                    
    return count_history, indriRunQuery_hist_, dumpindex_hist_

# %%
#training
dist = str(1)
intCoeffs0 = [ 0.7 ]
intCoeffs1 = [ 0.3 ]
#intCoeffs2 = [ 0.18 ]
intCoeffs2 = [ 0.5 ]
#intCoeffs1 = np.arange(0.1, 1, 0.1)
expansionCounts1 = [ 85 ]
#expansionCounts2 = [ 145 ]
expansionCounts2 = [ 0 ]
#expansionCounts2 = range(15, 220, 5)
dirCoeffs = [ 1600 ]
#dirCoeffs = range(200, 4000, 200)
N1s = [0]
rWords = dict()
featureWeights_1 = {'maxTopColCor': 0.1, 'expTDocScore': 0.1, 'maxColPCor': 0.1, 'avgCDocScore': 0.1, 'topTermFrac': 0.1, 'avgColCor': 0.1, 'avgTopColCor': 0.1, 'numCanDocs': 0.1, 'maxTopColPCor': 0.1, 'maxCDocScore': 0.1, 'avgColPCor': 0.1, 'conIdf': 0.1, 'avgTopColPCor': 0.1, 'maxColCor': 0.1}
featureWeights_l=[featureWeights_1]
origWordsAll = analyseQueries()
count_history, indriRunQuery_hist_, dumpindex_hist_ = precisionCompute_train(dist, origWordsAll, count_history, intCoeffs0, intCoeffs1, intCoeffs2, expansionCounts1, expansionCounts2, dirCoeffs, N1s, featureWeights_l, indriRunQuery_hist_, dumpindex_hist_)
# Out:
# c1 = 0 docno = 351 --- origWords = ['falkland', 'petroleum', 'exploration']
# c1 = 0 docno = 351 --- origWords = ['falkland', 'petroleum', 'exploration']

# %%
def precisionCompute(dist, origWordsAll, count_history, intCoeffs0, intCoeffs1, intCoeffs2, expansionCounts1, expansionCounts2, dirCoeffs, N1s, featureWeights_, indriRunQuery_hist_, dumpindex_hist_):
    mapPrecs = []
    for featureWeights in featureWeights_:
        for N1 in N1s:
            for intCoeff0 in intCoeffs0:
                for intCoeff1 in intCoeffs1:
                    for intCoeff2 in intCoeffs2:
                        for expansionCount1 in expansionCounts1:
                            for expansionCount2 in expansionCounts2:
                                for dirCoeff in dirCoeffs:
                                    
                                    
                                    #res = getAllRelWords_p(count_history, rWords, origWordsAll, expansionCount1, N1, expansionCount2, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights)
                                    
                                    count_history, relText_stringAll, relWords_sel = getAllRelWords(dist, count_history, rWords, origWordsAll, expansionCount1, N1, expansionCount2, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights, indriRunQuery_hist_, dumpindex_hist_)
                                    
                                    #print("len(relText_stringAll[1]) =", len(relText_stringAll[1]))
                                    ##########
                                    #cfgOutFileName = os.path.join("tmp","sbsb",str(randNum)+".cfg")
                                    #runsFileName = os.path.join("tmp","sbsb",str(randNum)+".run")
                                    #evalsFileName = os.path.join("tmp","sbsb",str(randNum)+".eval")
                                    ##########
                                    genQueries(cfgOutFileName, origWordsAll, relText_stringAll, intCoeff0, intCoeff1, intCoeff2, dirCoeff)
                                    subprocess.Popen("IndriRunQuery " + cfgOutFileName + " > " + runsFileName, shell=True, stdout=subprocess.PIPE).stdout.read()
                                    cmd = "trec_eval -q " + colQrelsFileName + " " + runsFileName + " > " + evalsFileName
                                    subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE).stdout.read()
                                    cmd = "cat " + evalsFileName + " | grep map | grep all | grep -v gm | awk '{print $3}' "
                                    #print ("cmd = ", cmd)
                                    mapPrec = subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE).stdout.read()
                                    mapPrecs += [mapPrec]
                                    print("featureWeights =", featureWeights)
                                    print("intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 =", intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, N1, mapPrec)
                                    #mapPrecs[intCoeff] = mapPrec
    return relText_stringAll, relWords_sel, mapPrecs

# %%
dist = str(1)
intCoeffs0 = [ 0.7 ]
intCoeffs1 = [ 0.5 ]
#intCoeffs2 = [ 0.18 ]
intCoeffs2 = [ 0.5 ]
#intCoeffs1 = np.arange(0.1, 1, 0.1)
expansionCounts1 = [ 10 ]
#expansionCounts2 = [ 145 ]
expansionCounts2 = [ 0 ]
#expansionCounts1 = range(0, 220, 5)
dirCoeffs = [ 1600 ]
#dirCoeffs = range(200, 4000, 200)
N1s_max = [100]
#N1s = range(1, 30, 1)
#mapPrecs = 
rWords = dict()
featureWeights_l=[]
featureWeights_1 = {'maxTopColCor': 500, 'expTDocScore': 500, 'maxColPCor': 500, 'avgCDocScore': 500, 'topTermFrac': 0, 'avgColCor': -0.05, 'avgTopColCor': 0.1, 'numCanDocs': 0.1, 'maxTopColPCor': 0.1, 'maxCDocScore': -500, 'avgColPCor': 0.1, 'conIdf': -0.05, 'avgTopColPCor': 0.1, 'maxColCor': 0.1}
#for conIdf in [-0.05] :
#for conIdf in [-5000, -500, -50, -5, -0.5, -0.05, 0, 0.05, 0.5, 5, 50, 500, 5000] :
for conIdf in np.arange(-1,1,0.2):
    featureWeights_1["conIdf"] = conIdf
    featureWeights_l += [dict(featureWeights_1)]
relText_stringAll, relWords_sel1, mapPrecs = precisionCompute(dist, origWordsAll, count_history, intCoeffs0, intCoeffs1, intCoeffs2, expansionCounts1, expansionCounts2, dirCoeffs, N1s_max, featureWeights_l, indriRunQuery_hist_, dumpindex_hist_)
# Out:
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = falklands
# features = {'maxTopColCor': 10, 'maxColPCor': 3.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 256.0, 'avgColPCor': 3.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 6.4949650885174766, 'avgTopColPCor': 10.0, 'maxColCor': 714.0}
# relWg = -31494.4149651
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = place
# features = {'maxTopColCor': 10, 'maxColPCor': 248.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 1478.3333333333333, 'avgColPCor': 248.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 1.3434237010880858, 'avgTopColPCor': 10.0, 'maxColCor': 2986.0}
# relWg = 91201.3199096
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = build
# features = {'maxTopColCor': 10, 'maxColPCor': 279.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 1408.0, 'avgColPCor': 279.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 1.4537924387296588, 'avgTopColPCor': 10.0, 'maxColCor': 2828.0}
# relWg = 106692.026208
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = falkland islander
# features = {'maxTopColCor': 10, 'maxColPCor': 3.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 84.333333333333329, 'avgColPCor': 3.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 7.6952100227293982, 'avgTopColPCor': 10.0, 'maxColCor': 216.0}
# relWg = -31536.8318767
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = falkland island
# features = {'maxTopColCor': 10, 'maxColPCor': 3.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 84.333333333333329, 'avgColPCor': 3.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 7.6952100227293982, 'avgTopColPCor': 10.0, 'maxColCor': 216.0}
# relWg = -31536.8318767
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = architectural structure
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 0.33333333333333331, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 10.021325613133639, 'avgTopColPCor': 10.0, 'maxColCor': 1.0}
# relWg = -33056.7579923
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = oil
# features = {'maxTopColCor': 10, 'maxColPCor': 1073.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 3138.3333333333335, 'avgColPCor': 1073.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 1.9473290666382634, 'avgTopColPCor': 10.0, 'maxColCor': 4886.0}
# relWg = 503890.216004
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = commodity
# features = {'maxTopColCor': 10, 'maxColPCor': 163.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 548.33333333333337, 'avgColPCor': 163.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 3.2015692115462135, 'avgTopColPCor': 10.0, 'maxColCor': 837.0}
# relWg = 48522.5617641
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = asphalt
# features = {'maxTopColCor': 10, 'maxColPCor': 8.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 24.666666666666668, 'avgColPCor': 8.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 6.6739309374644593, 'avgTopColPCor': 10.0, 'maxColCor': 52.0}
# relWg = -29048.7272643
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = unrefined oil
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 0.0, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 12.372700870297116, 'avgTopColPCor': 10.0, 'maxColCor': 0.0}
# relWg = -33059.1927009
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = petrol
# features = {'maxTopColCor': 10, 'maxColPCor': 51.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 105.33333333333333, 'avgColPCor': 51.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 5.0817260921541338, 'avgTopColPCor': 10.0, 'maxColCor': 215.0}
# relWg = -7530.56839276
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = gas
# features = {'maxTopColCor': 10, 'maxColPCor': 664.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 1573.0, 'avgColPCor': 664.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 2.5030803872725649, 'avgTopColPCor': 10.0, 'maxColCor': 2392.0}
# relWg = 299177.62692
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = energy
# features = {'maxTopColCor': 10, 'maxColPCor': 412.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 1227.6666666666667, 'avgColPCor': 412.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 2.4272559680004808, 'avgTopColPCor': 10.0, 'maxColCor': 1835.0}
# relWg = 173114.069411
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = fossil fuel
# features = {'maxTopColCor': 10, 'maxColPCor': 8.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 21.666666666666668, 'avgColPCor': 8.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 6.776132479948064, 'avgTopColPCor': 10.0, 'maxColCor': 40.0}
# relWg = -29049.8794658
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = gasoline
# features = {'maxTopColCor': 10, 'maxColPCor': 52.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 222.33333333333334, 'avgColPCor': 52.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 4.7410267520882794, 'avgTopColPCor': 10.0, 'maxColCor': 546.0}
# relWg = -7002.87769342
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = just store solar energy
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 0.0, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 13.065848050857062, 'avgTopColPCor': 10.0, 'maxColCor': 0.0}
# relWg = -33059.8858481
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = liquid hydrocarbon mixture
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 0.0, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 13.065848050857062, 'avgTopColPCor': 10.0, 'maxColCor': 0.0}
# relWg = -33059.8858481
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = combustible fluid
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 0.0, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 13.065848050857062, 'avgTopColPCor': 10.0, 'maxColCor': 0.0}
# relWg = -33059.8858481
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = big problem
# features = {'maxTopColCor': 10, 'maxColPCor': 7.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 21.666666666666668, 'avgColPCor': 7.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 6.190615963580484, 'avgTopColPCor': 10.0, 'maxColCor': 46.0}
# relWg = -29548.7939493
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = carbon
# features = {'maxTopColCor': 10, 'maxColPCor': 43.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 114.0, 'avgColPCor': 43.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 4.6946059149251278, 'avgTopColPCor': 10.0, 'maxColCor': 197.0}
# relWg = -11533.2146059
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = linoleum
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 2.0, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 8.3930192163951549, 'avgTopColPCor': 10.0, 'maxColCor': 3.0}
# relWg = -33055.0130192
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = hydrocarbon
# features = {'maxTopColCor': 10, 'maxColPCor': 63.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 124.0, 'avgColPCor': 63.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 6.1093026077054917, 'avgTopColPCor': 10.0, 'maxColCor': 224.0}
# relWg = -1530.42930261
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = old
# features = {'maxTopColCor': 10, 'maxColPCor': 161.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 1027.3333333333333, 'avgColPCor': 161.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 1.6233557798546752, 'avgTopColPCor': 10.0, 'maxColCor': 2274.0}
# relWg = 47643.6899776
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = gather information
# features = {'maxTopColCor': 10, 'maxColPCor': 7.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 16.333333333333332, 'avgColPCor': 7.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 6.6589680647877465, 'avgTopColPCor': 10.0, 'maxColCor': 31.0}
# relWg = -29550.4956347
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = clark
# features = {'maxTopColCor': 10, 'maxColPCor': 10.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 89.666666666666671, 'avgColPCor': 10.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 3.4951794164442433, 'avgTopColPCor': 10.0, 'maxColCor': 165.0}
# relWg = -28037.2985127
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = find new
# features = {'maxTopColCor': 10, 'maxColPCor': 20.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 56.333333333333336, 'avgColPCor': 20.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 5.5434478194699359, 'avgTopColPCor': 10.0, 'maxColCor': 119.0}
# relWg = -23041.2801145
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = lewis
# features = {'maxTopColCor': 10, 'maxColPCor': 4.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 48.0, 'avgColPCor': 4.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 4.2023737446861071, 'avgTopColPCor': 10.0, 'maxColCor': 109.0}
# relWg = -31042.1223737
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = adventure
# features = {'maxTopColCor': 10, 'maxColPCor': 5.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 129.0, 'avgColPCor': 5.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 4.7748029197753326, 'avgTopColPCor': 10.0, 'maxColCor': 354.0}
# relWg = -30522.1448029
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = consideration
# features = {'maxTopColCor': 10, 'maxColPCor': 160.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 625.66666666666663, 'avgColPCor': 160.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 2.6753461256584807, 'avgTopColPCor': 10.0, 'maxColCor': 1092.0}
# relWg = 47044.4213205
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = find
# features = {'maxTopColCor': 10, 'maxColPCor': 282.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 1165.0, 'avgColPCor': 282.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 1.8818156173846519, 'avgTopColPCor': 10.0, 'maxColCor': 2508.0}
# relWg = 108172.048184
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = album
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 41.333333333333336, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 4.3093230479300892, 'avgTopColPCor': 10.0, 'maxColCor': 120.0}
# relWg = -33041.1959897
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = style
# features = {'maxTopColCor': 10, 'maxColPCor': 44.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 426.33333333333331, 'avgColPCor': 44.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 2.9146023862428043, 'avgTopColPCor': 10.0, 'maxColCor': 1089.0}
# relWg = -10957.7512691
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = end
# features = {'maxTopColCor': 10, 'maxColPCor': 408.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 1896.3333333333333, 'avgColPCor': 408.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 0.9730392927333199, 'avgTopColPCor': 10.0, 'maxColCor': 3448.0}
# relWg = 171242.990294
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = wilderness
# features = {'maxTopColCor': 10, 'maxColPCor': 6.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 58.0, 'avgColPCor': 6.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 5.3660056434600749, 'avgTopColPCor': 10.0, 'maxColCor': 149.0}
# relWg = -30039.5860056
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = exploratory
# features = {'maxTopColCor': 10, 'maxColPCor': 46.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 81.333333333333329, 'avgColPCor': 46.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 6.4673390222425455, 'avgTopColPCor': 10.0, 'maxColCor': 164.0}
# relWg = -10036.3540057
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = musical work
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 5.0, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 7.9241844943544013, 'avgTopColPCor': 10.0, 'maxColCor': 14.0}
# relWg = -33053.5941845
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = travel
# features = {'maxTopColCor': 10, 'maxColPCor': 51.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 447.33333333333331, 'avgColPCor': 51.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 2.6426147771803836, 'avgTopColPCor': 10.0, 'maxColCor': 996.0}
# relWg = -7467.12928144
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = expedition
# features = {'maxTopColCor': 10, 'maxColPCor': 37.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 150.33333333333334, 'avgColPCor': 37.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 5.2204320142645768, 'avgTopColPCor': 10.0, 'maxColCor': 364.0}
# relWg = -14519.4570987
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = into unknown
# features = {'maxTopColCor': 10, 'maxColPCor': 1.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 4.333333333333333, 'avgColPCor': 1.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 8.2783563080750149, 'avgTopColPCor': 10.0, 'maxColCor': 11.0}
# relWg = -32554.115023
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = tv show
# features = {'maxTopColCor': 10, 'maxColPCor': 2.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 13.0, 'avgColPCor': 2.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 6.1752389307098943, 'avgTopColPCor': 10.0, 'maxColCor': 34.0}
# relWg = -32050.0452389
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = examination
# features = {'maxTopColCor': 10, 'maxColPCor': 80.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 385.33333333333331, 'avgColPCor': 80.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 3.099479600281732, 'avgTopColPCor': 10.0, 'maxColCor': 822.0}
# relWg = 7021.01385373
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = great search
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 0.66666666666666663, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 9.7700111848527325, 'avgTopColPCor': 10.0, 'maxColCor': 1.0}
# relWg = -33056.5233445
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = lewis clark
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 2.0, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 9.4549301382128359, 'avgTopColPCor': 10.0, 'maxColCor': 6.0}
# relWg = -33055.7749301
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = into
# features = {'maxTopColCor': 10, 'maxColPCor': 485.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 2693.3333333333335, 'avgColPCor': 485.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 0.58800551278530067, 'avgTopColPCor': 10.0, 'maxColCor': 5333.0}
# relWg = 209899.725328
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = discovery
# features = {'maxTopColCor': 10, 'maxColPCor': 168.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 300.66666666666669, 'avgColPCor': 168.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 4.5984755544247795, 'avgTopColPCor': 10.0, 'maxColCor': 644.0}
# relWg = 51014.7481911
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = columbus
# features = {'maxTopColCor': 10, 'maxColPCor': 1.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 26.333333333333332, 'avgColPCor': 1.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 5.834561046529446, 'avgTopColPCor': 10.0, 'maxColCor': 71.0}
# relWg = -32546.7712277
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = explorer
# features = {'maxTopColCor': 10, 'maxColPCor': 1222.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 4870.666666666667, 'avgColPCor': 1222.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 3.5672507716782551, 'avgTopColPCor': 10.0, 'maxColCor': 13341.0}
# relWg = 579162.379416
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = jazz
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 48.666666666666664, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 4.414298806941745, 'avgTopColPCor': 10.0, 'maxColCor': 138.0}
# relWg = -33039.8676321
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = great
# features = {'maxTopColCor': 10, 'maxColPCor': 178.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 1155.6666666666667, 'avgColPCor': 178.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 1.8539736260775681, 'avgTopColPCor': 10.0, 'maxColCor': 2489.0}
# relWg = 56160.242693
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = explore
# features = {'maxTopColCor': 10, 'maxColPCor': 1222.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 4870.666666666667, 'avgColPCor': 1222.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 3.5672507716782551, 'avgTopColPCor': 10.0, 'maxColCor': 13341.0}
# relWg = 579162.379416
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = television show
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 11.0, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 6.0253116606411057, 'avgTopColPCor': 10.0, 'maxColCor': 29.0}
# relWg = -33050.4953117
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = into wilderness
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 3.3333333333333335, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 8.8463403456809537, 'avgTopColPCor': 10.0, 'maxColCor': 8.0}
# relWg = -33055.033007
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = new
# features = {'maxTopColCor': 10, 'maxColPCor': 874.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 4136.333333333333, 'avgColPCor': 874.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': -0.12687872509946682, 'avgTopColPCor': 10.0, 'maxColCor': 7983.0}
# relWg = 404632.190212
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = penetrate
# features = {'maxTopColCor': 10, 'maxColPCor': 20.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 77.333333333333329, 'avgColPCor': 20.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 4.9044730276595745, 'avgTopColPCor': 10.0, 'maxColCor': 154.0}
# relWg = -23038.1911397
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = search
# features = {'maxTopColCor': 10, 'maxColPCor': 85.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 356.33333333333331, 'avgColPCor': 85.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 3.2761452876275534, 'avgTopColPCor': 10.0, 'maxColCor': 786.0}
# relWg = 9519.18718805
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = computer game
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 6.333333333333333, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 6.9566004680926961, 'avgTopColPCor': 10.0, 'maxColCor': 17.0}
# relWg = -33052.3932671
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = world
# features = {'maxTopColCor': 10, 'maxColPCor': 387.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 2056.3333333333335, 'avgColPCor': 387.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 0.98704075637276356, 'avgTopColPCor': 10.0, 'maxColCor': 3952.0}
# relWg = 160783.276293
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = old style
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 8.3333333333333339, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 6.4879866931360146, 'avgTopColPCor': 10.0, 'maxColCor': 23.0}
# relWg = -33051.4246534
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = strategy game
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 0.0, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 10.357797849754851, 'avgTopColPCor': 10.0, 'maxColCor': 0.0}
# relWg = -33057.1777978
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = world travel
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 7.666666666666667, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 7.627768741933866, 'avgTopColPCor': 10.0, 'maxColCor': 21.0}
# relWg = -33052.7311021
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = range
# features = {'maxTopColCor': 10, 'maxColPCor': 138.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 763.66666666666663, 'avgColPCor': 138.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 2.3375492925822896, 'avgTopColPCor': 10.0, 'maxColCor': 1482.0}
# relWg = 36074.6591174
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = expo
# features = {'maxTopColCor': 10, 'maxColPCor': 1.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 11.0, 'avgColPCor': 1.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 5.908112566607155, 'avgTopColPCor': 10.0, 'maxColCor': 18.0}
# relWg = -32551.3781126
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = unknown
# features = {'maxTopColCor': 10, 'maxColPCor': 14.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 92.0, 'avgColPCor': 14.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 4.406461093737648, 'avgTopColPCor': 10.0, 'maxColCor': 174.0}
# relWg = -26037.0264611
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = video game
# features = {'maxTopColCor': 10, 'maxColPCor': 1.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 11.666666666666666, 'avgColPCor': 1.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 6.1026580649868238, 'avgTopColPCor': 10.0, 'maxColCor': 27.0}
# relWg = -32550.7059914
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = discovery adventure
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 0.0, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 13.065848050857062, 'avgTopColPCor': 10.0, 'maxColCor': 0.0}
# relWg = -33059.8858481
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = software
# features = {'maxTopColCor': 10, 'maxColPCor': 34.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 126.66666666666667, 'avgColPCor': 34.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 3.527787919397567, 'avgTopColPCor': 10.0, 'maxColCor': 248.0}
# relWg = -16028.4811213
# featureWeights =origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = falklands
# features = {'maxTopColCor': 10, 'maxColPCor': 3.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 256.0, 'avgColPCor': 3.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 6.4949650885174766, 'avgTopColPCor': 10.0, 'maxColCor': 714.0}
# relWg = -31494.4149651
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = place
# features = {'maxTopColCor': 10, 'maxColPCor': 248.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 1478.3333333333333, 'avgColPCor': 248.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 1.3434237010880858, 'avgTopColPCor': 10.0, 'maxColCor': 2986.0}
# relWg = 91201.3199096
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = build
# features = {'maxTopColCor': 10, 'maxColPCor': 279.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 1408.0, 'avgColPCor': 279.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 1.4537924387296588, 'avgTopColPCor': 10.0, 'maxColCor': 2828.0}
# relWg = 106692.026208
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = falkland islander
# features = {'maxTopColCor': 10, 'maxColPCor': 3.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 84.333333333333329, 'avgColPCor': 3.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 7.6952100227293982, 'avgTopColPCor': 10.0, 'maxColCor': 216.0}
# relWg = -31536.8318767
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = falkland island
# features = {'maxTopColCor': 10, 'maxColPCor': 3.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 84.333333333333329, 'avgColPCor': 3.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 7.6952100227293982, 'avgTopColPCor': 10.0, 'maxColCor': 216.0}
# relWg = -31536.8318767
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = architectural structure
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 0.33333333333333331, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 10.021325613133639, 'avgTopColPCor': 10.0, 'maxColCor': 1.0}
# relWg = -33056.7579923
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = oil
# features = {'maxTopColCor': 10, 'maxColPCor': 1073.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 3138.3333333333335, 'avgColPCor': 1073.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 1.9473290666382634, 'avgTopColPCor': 10.0, 'maxColCor': 4886.0}
# relWg = 503890.216004
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = commodity
# features = {'maxTopColCor': 10, 'maxColPCor': 163.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 548.33333333333337, 'avgColPCor': 163.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 3.2015692115462135, 'avgTopColPCor': 10.0, 'maxColCor': 837.0}
# relWg = 48522.5617641
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = asphalt
# features = {'maxTopColCor': 10, 'maxColPCor': 8.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 24.666666666666668, 'avgColPCor': 8.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 6.6739309374644593, 'avgTopColPCor': 10.0, 'maxColCor': 52.0}
# relWg = -29048.7272643
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = unrefined oil
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 0.0, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 12.372700870297116, 'avgTopColPCor': 10.0, 'maxColCor': 0.0}
# relWg = -33059.1927009
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = petrol
# features = {'maxTopColCor': 10, 'maxColPCor': 51.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 105.33333333333333, 'avgColPCor': 51.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 5.0817260921541338, 'avgTopColPCor': 10.0, 'maxColCor': 215.0}
# relWg = -7530.56839276
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = gas
# features = {'maxTopColCor': 10, 'maxColPCor': 664.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 1573.0, 'avgColPCor': 664.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 2.5030803872725649, 'avgTopColPCor': 10.0, 'maxColCor': 2392.0}
# relWg = 299177.62692
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = energy
# features = {'maxTopColCor': 10, 'maxColPCor': 412.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 1227.6666666666667, 'avgColPCor': 412.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 2.4272559680004808, 'avgTopColPCor': 10.0, 'maxColCor': 1835.0}
# relWg = 173114.069411
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = fossil fuel
# features = {'maxTopColCor': 10, 'maxColPCor': 8.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 21.666666666666668, 'avgColPCor': 8.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 6.776132479948064, 'avgTopColPCor': 10.0, 'maxColCor': 40.0}
# relWg = -29049.8794658
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = gasoline
# features = {'maxTopColCor': 10, 'maxColPCor': 52.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 222.33333333333334, 'avgColPCor': 52.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 4.7410267520882794, 'avgTopColPCor': 10.0, 'maxColCor': 546.0}
# relWg = -7002.87769342
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = just store solar energy
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 0.0, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 13.065848050857062, 'avgTopColPCor': 10.0, 'maxColCor': 0.0}
# relWg = -33059.8858481
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = liquid hydrocarbon mixture
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 0.0, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 13.065848050857062, 'avgTopColPCor': 10.0, 'maxColCor': 0.0}
# relWg = -33059.8858481
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = combustible fluid
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 0.0, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 13.065848050857062, 'avgTopColPCor': 10.0, 'maxColCor': 0.0}
# relWg = -33059.8858481
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = big problem
# features = {'maxTopColCor': 10, 'maxColPCor': 7.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 21.666666666666668, 'avgColPCor': 7.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 6.190615963580484, 'avgTopColPCor': 10.0, 'maxColCor': 46.0}
# relWg = -29548.7939493
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = carbon
# features = {'maxTopColCor': 10, 'maxColPCor': 43.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 114.0, 'avgColPCor': 43.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 4.6946059149251278, 'avgTopColPCor': 10.0, 'maxColCor': 197.0}
# relWg = -11533.2146059
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = linoleum
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 2.0, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 8.3930192163951549, 'avgTopColPCor': 10.0, 'maxColCor': 3.0}
# relWg = -33055.0130192
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = hydrocarbon
# features = {'maxTopColCor': 10, 'maxColPCor': 63.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 124.0, 'avgColPCor': 63.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 6.1093026077054917, 'avgTopColPCor': 10.0, 'maxColCor': 224.0}
# relWg = -1530.42930261
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = old
# features = {'maxTopColCor': 10, 'maxColPCor': 161.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 1027.3333333333333, 'avgColPCor': 161.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 1.6233557798546752, 'avgTopColPCor': 10.0, 'maxColCor': 2274.0}
# relWg = 47643.6899776
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = gather information
# features = {'maxTopColCor': 10, 'maxColPCor': 7.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 16.333333333333332, 'avgColPCor': 7.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 6.6589680647877465, 'avgTopColPCor': 10.0, 'maxColCor': 31.0}
# relWg = -29550.4956347
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = clark
# features = {'maxTopColCor': 10, 'maxColPCor': 10.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 89.666666666666671, 'avgColPCor': 10.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 3.4951794164442433, 'avgTopColPCor': 10.0, 'maxColCor': 165.0}
# relWg = -28037.2985127
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = find new
# features = {'maxTopColCor': 10, 'maxColPCor': 20.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 56.333333333333336, 'avgColPCor': 20.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 5.5434478194699359, 'avgTopColPCor': 10.0, 'maxColCor': 119.0}
# relWg = -23041.2801145
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = lewis
# features = {'maxTopColCor': 10, 'maxColPCor': 4.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 48.0, 'avgColPCor': 4.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 4.2023737446861071, 'avgTopColPCor': 10.0, 'maxColCor': 109.0}
# relWg = -31042.1223737
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = adventure
# features = {'maxTopColCor': 10, 'maxColPCor': 5.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 129.0, 'avgColPCor': 5.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 4.7748029197753326, 'avgTopColPCor': 10.0, 'maxColCor': 354.0}
# relWg = -30522.1448029
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = consideration
# features = {'maxTopColCor': 10, 'maxColPCor': 160.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 625.66666666666663, 'avgColPCor': 160.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 2.6753461256584807, 'avgTopColPCor': 10.0, 'maxColCor': 1092.0}
# relWg = 47044.4213205
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = find
# features = {'maxTopColCor': 10, 'maxColPCor': 282.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 1165.0, 'avgColPCor': 282.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 1.8818156173846519, 'avgTopColPCor': 10.0, 'maxColCor': 2508.0}
# relWg = 108172.048184
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = album
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 41.333333333333336, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 4.3093230479300892, 'avgTopColPCor': 10.0, 'maxColCor': 120.0}
# relWg = -33041.1959897
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = style
# features = {'maxTopColCor': 10, 'maxColPCor': 44.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 426.33333333333331, 'avgColPCor': 44.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 2.9146023862428043, 'avgTopColPCor': 10.0, 'maxColCor': 1089.0}
# relWg = -10957.7512691
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = end
# features = {'maxTopColCor': 10, 'maxColPCor': 408.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 1896.3333333333333, 'avgColPCor': 408.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 0.9730392927333199, 'avgTopColPCor': 10.0, 'maxColCor': 3448.0}
# relWg = 171242.990294
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = wilderness
# features = {'maxTopColCor': 10, 'maxColPCor': 6.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 58.0, 'avgColPCor': 6.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 5.3660056434600749, 'avgTopColPCor': 10.0, 'maxColCor': 149.0}
# relWg = -30039.5860056
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = exploratory
# features = {'maxTopColCor': 10, 'maxColPCor': 46.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 81.333333333333329, 'avgColPCor': 46.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 6.4673390222425455, 'avgTopColPCor': 10.0, 'maxColCor': 164.0}
# relWg = -10036.3540057
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = musical work
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 5.0, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 7.9241844943544013, 'avgTopColPCor': 10.0, 'maxColCor': 14.0}
# relWg = -33053.5941845
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = travel
# features = {'maxTopColCor': 10, 'maxColPCor': 51.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 447.33333333333331, 'avgColPCor': 51.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 2.6426147771803836, 'avgTopColPCor': 10.0, 'maxColCor': 996.0}
# relWg = -7467.12928144
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = expedition
# features = {'maxTopColCor': 10, 'maxColPCor': 37.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 150.33333333333334, 'avgColPCor': 37.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 5.2204320142645768, 'avgTopColPCor': 10.0, 'maxColCor': 364.0}
# relWg = -14519.4570987
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = into unknown
# features = {'maxTopColCor': 10, 'maxColPCor': 1.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 4.333333333333333, 'avgColPCor': 1.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 8.2783563080750149, 'avgTopColPCor': 10.0, 'maxColCor': 11.0}
# relWg = -32554.115023
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = tv show
# ...
# relWg = -10952.5049848
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = end
# features = {'maxTopColCor': 10, 'maxColPCor': 408.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 1896.3333333333333, 'avgColPCor': 408.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 0.9730392927333199, 'avgTopColPCor': 10.0, 'maxColCor': 3448.0}
# relWg = 171244.741765
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = wilderness
# features = {'maxTopColCor': 10, 'maxColPCor': 6.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 58.0, 'avgColPCor': 6.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 5.3660056434600749, 'avgTopColPCor': 10.0, 'maxColCor': 149.0}
# relWg = -30029.9271955
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = exploratory
# features = {'maxTopColCor': 10, 'maxColPCor': 46.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 81.333333333333329, 'avgColPCor': 46.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 6.4673390222425455, 'avgTopColPCor': 10.0, 'maxColCor': 164.0}
# relWg = -10024.7127954
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = musical work
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 5.0, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 7.9241844943544013, 'avgTopColPCor': 10.0, 'maxColCor': 14.0}
# relWg = -33039.3306524
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = travel
# features = {'maxTopColCor': 10, 'maxColPCor': 51.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 447.33333333333331, 'avgColPCor': 51.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 2.6426147771803836, 'avgTopColPCor': 10.0, 'maxColCor': 996.0}
# relWg = -7462.37257484
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = expedition
# features = {'maxTopColCor': 10, 'maxColPCor': 37.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 150.33333333333334, 'avgColPCor': 37.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 5.2204320142645768, 'avgTopColPCor': 10.0, 'maxColCor': 364.0}
# relWg = -14510.0603211
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = into unknown
# features = {'maxTopColCor': 10, 'maxColPCor': 1.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 4.333333333333333, 'avgColPCor': 1.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 8.2783563080750149, 'avgTopColPCor': 10.0, 'maxColCor': 11.0}
# relWg = -32539.2139816
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = tv show
# features = {'maxTopColCor': 10, 'maxColPCor': 2.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 13.0, 'avgColPCor': 2.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 6.1752389307098943, 'avgTopColPCor': 10.0, 'maxColCor': 34.0}
# relWg = -32038.9298089
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = examination
# features = {'maxTopColCor': 10, 'maxColPCor': 80.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 385.33333333333331, 'avgColPCor': 80.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 3.099479600281732, 'avgTopColPCor': 10.0, 'maxColCor': 822.0}
# relWg = 7026.59291701
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = great search
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 0.66666666666666663, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 9.7700111848527325, 'avgTopColPCor': 10.0, 'maxColCor': 1.0}
# relWg = -33038.9373244
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = lewis clark
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 2.0, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 9.4549301382128359, 'avgTopColPCor': 10.0, 'maxColCor': 6.0}
# relWg = -33038.7560559
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = into
# features = {'maxTopColCor': 10, 'maxColPCor': 485.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 2693.3333333333335, 'avgColPCor': 485.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 0.58800551278530067, 'avgTopColPCor': 10.0, 'maxColCor': 5333.0}
# relWg = 209900.783738
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = discovery
# features = {'maxTopColCor': 10, 'maxColPCor': 168.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 300.66666666666669, 'avgColPCor': 168.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 4.5984755544247795, 'avgTopColPCor': 10.0, 'maxColCor': 644.0}
# relWg = 51023.0254471
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = columbus
# features = {'maxTopColCor': 10, 'maxColPCor': 1.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 26.333333333333332, 'avgColPCor': 1.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 5.834561046529446, 'avgTopColPCor': 10.0, 'maxColCor': 71.0}
# relWg = -32536.2690178
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = explorer
# features = {'maxTopColCor': 10, 'maxColPCor': 1222.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 4870.666666666667, 'avgColPCor': 1222.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 3.5672507716782551, 'avgTopColPCor': 10.0, 'maxColCor': 13341.0}
# relWg = 579168.800467
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = jazz
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 48.666666666666664, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 4.414298806941745, 'avgTopColPCor': 10.0, 'maxColCor': 138.0}
# relWg = -33031.9218943
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = great
# features = {'maxTopColCor': 10, 'maxColPCor': 178.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 1155.6666666666667, 'avgColPCor': 178.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 1.8539736260775681, 'avgTopColPCor': 10.0, 'maxColCor': 2489.0}
# relWg = 56163.5798456
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = explore
# features = {'maxTopColCor': 10, 'maxColPCor': 1222.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 4870.666666666667, 'avgColPCor': 1222.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 3.5672507716782551, 'avgTopColPCor': 10.0, 'maxColCor': 13341.0}
# relWg = 579168.800467
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = television show
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 11.0, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 6.0253116606411057, 'avgTopColPCor': 10.0, 'maxColCor': 29.0}
# relWg = -33039.6497507
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = into wilderness
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 3.3333333333333335, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 8.8463403456809537, 'avgTopColPCor': 10.0, 'maxColCor': 8.0}
# relWg = -33039.1095944
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = new
# features = {'maxTopColCor': 10, 'maxColPCor': 874.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 4136.333333333333, 'avgColPCor': 874.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': -0.12687872509946682, 'avgTopColPCor': 10.0, 'maxColCor': 7983.0}
# relWg = 404631.96183
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = penetrate
# features = {'maxTopColCor': 10, 'maxColPCor': 20.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 77.333333333333329, 'avgColPCor': 20.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 4.9044730276595745, 'avgTopColPCor': 10.0, 'maxColCor': 154.0}
# relWg = -23029.3630882
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = search
# features = {'maxTopColCor': 10, 'maxColPCor': 85.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 356.33333333333331, 'avgColPCor': 85.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 3.2761452876275534, 'avgTopColPCor': 10.0, 'maxColCor': 786.0}
# relWg = 9525.08424956
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = computer game
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 6.333333333333333, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 6.9566004680926961, 'avgTopColPCor': 10.0, 'maxColCor': 17.0}
# relWg = -33039.8713863
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = world
# features = {'maxTopColCor': 10, 'maxColPCor': 387.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 2056.3333333333335, 'avgColPCor': 387.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 0.98704075637276356, 'avgTopColPCor': 10.0, 'maxColCor': 3952.0}
# relWg = 160785.052966
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = old style
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 8.3333333333333339, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 6.4879866931360146, 'avgTopColPCor': 10.0, 'maxColCor': 23.0}
# relWg = -33039.7462773
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = strategy game
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 0.0, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 10.357797849754851, 'avgTopColPCor': 10.0, 'maxColCor': 0.0}
# relWg = -33038.5337617
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = world travel
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 7.666666666666667, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 7.627768741933866, 'avgTopColPCor': 10.0, 'maxColCor': 21.0}
# relWg = -33039.0011183
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = range
# features = {'maxTopColCor': 10, 'maxColPCor': 138.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 763.66666666666663, 'avgColPCor': 138.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 2.3375492925822896, 'avgTopColPCor': 10.0, 'maxColCor': 1482.0}
# relWg = 36078.8667061
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = expo
# features = {'maxTopColCor': 10, 'maxColPCor': 1.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 11.0, 'avgColPCor': 1.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 5.908112566607155, 'avgTopColPCor': 10.0, 'maxColCor': 18.0}
# relWg = -32540.7435099
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = unknown
# features = {'maxTopColCor': 10, 'maxColPCor': 14.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 92.0, 'avgColPCor': 14.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 4.406461093737648, 'avgTopColPCor': 10.0, 'maxColCor': 174.0}
# relWg = -26029.0948311
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = video game
# features = {'maxTopColCor': 10, 'maxColPCor': 1.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 11.666666666666666, 'avgColPCor': 1.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 6.1026580649868238, 'avgTopColPCor': 10.0, 'maxColCor': 27.0}
# relWg = -32539.7212069
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = discovery adventure
# features = {'maxTopColCor': 10, 'maxColPCor': 0.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 0.0, 'avgColPCor': 0.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 13.065848050857062, 'avgTopColPCor': 10.0, 'maxColCor': 0.0}
# relWg = -33036.3673216
# origWords_ = ['falkland', 'petroleum', 'exploration']
# relW = software
# features = {'maxTopColCor': 10, 'maxColPCor': 34.0, 'avgCDocScore': -76.09984, 'topTermFrac': 0.002583979328165375, 'avgColCor': 126.66666666666667, 'avgColPCor': 34.0, 'avgTopColCor': 10.0, 'numCanDocs': 1, 'maxTopColPCor': 10, 'maxCDocScore': -7.2415799999999999, 'expTDocScore': -7.24158, 'conIdf': 3.527787919397567, 'avgTopColPCor': 10.0, 'maxColCor': 248.0}
# relWg = -16022.131103
# featureWeights = {'maxTopColCor': 500, 'maxColPCor': 500, 'conIdf': 0.7999999999999996, 'expTDocScore': 500, 'topTermFrac': 0, 'avgColCor': -0.05, 'avgTopColCor': 0.1, 'numCanDocs': 0.1, 'maxTopColPCor': 0.1, 'avgCDocScore': 500, 'avgColPCor': 0.1, 'maxCDocScore': -500, 'avgTopColPCor': 0.1, 'maxColCor': 0.1}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 10 0 1600 100 0.2352

# %%
"""
dist = str(2)
intCoeffs0 = [ 0.7 ]
intCoeffs1 = [ 0.5 ]
#intCoeffs2 = [ 0.18 ]
intCoeffs2 = [ 0.5 ]
#intCoeffs1 = np.arange(0.1, 1, 0.1)
expansionCounts1 = [ 10 ]
#expansionCounts2 = [ 145 ]
expansionCounts2 = [ 0 ]
#expansionCounts2 = range(15, 220, 5)
dirCoeffs = [ 1600 ]
#dirCoeffs = range(200, 4000, 200)
N1s = 2
N2s_max = [100]
rWords = dict()
featureWeights_1 = {'maxTopColCor': 0.1, 'expTDocScore': 0.1, 'maxColPCor': 0.1, 'avgCDocScore': 0.1, 'topTermFrac': 0.1, 'avgColCor': 0.1, 'avgTopColCor': 0.1, 'numCanDocs': 0.1, 'maxTopColPCor': 0.1, 'maxCDocScore': 0.1, 'avgColPCor': 0.1, 'conIdf': 0.1, 'avgTopColPCor': 0.1, 'maxColCor': 0.1}
featureWeights_l=[featureWeights_1]
relWords_sel1 = {k:v[0:N1s] for k,v in relWords_sel.iteritems()}
indriRunQuery_hist_, dumpindex_hist_ = precisionCompute_train(dist, relWords_sel1, count_history, intCoeffs0, intCoeffs1, intCoeffs2, expansionCounts1, expansionCounts2, dirCoeffs, N2s_max, featureWeights_l, indriRunQuery_hist_, dumpindex_hist_)
"""
#training
dist = str(1)
intCoeffs0 = [ 0.7 ]
intCoeffs1 = [ 0.3 ]
#intCoeffs2 = [ 0.18 ]
intCoeffs2 = [ 0.5 ]
#intCoeffs1 = np.arange(0.1, 1, 0.1)
expansionCounts1 = [ 85 ]
#expansionCounts2 = [ 145 ]
expansionCounts2 = [ 0 ]
#expansionCounts2 = range(15, 220, 5)
dirCoeffs = [ 1600 ]
#dirCoeffs = range(200, 4000, 200)
N2s_max = [0]
N1s = 2
rWords = dict()
featureWeights_1 = {'maxTopColCor': 0.1, 'expTDocScore': 0.1, 'maxColPCor': 0.1, 'avgCDocScore': 0.1, 'topTermFrac': 0.1, 'avgColCor': 0.1, 'avgTopColCor': 0.1, 'numCanDocs': 0.1, 'maxTopColPCor': 0.1, 'maxCDocScore': 0.1, 'avgColPCor': 0.1, 'conIdf': 0.1, 'avgTopColPCor': 0.1, 'maxColCor': 0.1}
featureWeights_l=[featureWeights_1]
relWords_sel1 = {k:v[0:N1s] for k,v in relWords_sel1.iteritems()}
count_history, indriRunQuery_hist_, dumpindex_hist_ = precisionCompute_train(dist, origWordsAll, count_history, intCoeffs0, intCoeffs1, intCoeffs2, expansionCounts1, expansionCounts2, dirCoeffs, N2s_max, featureWeights_l, indriRunQuery_hist_, dumpindex_hist_)
