# %%
from __future__ import print_function 
from bs4 import BeautifulSoup
from BeautifulSoup import SoupStrainer as sopstrain
import subprocess
import os
import re
import sys
import numpy as np
import string
import operator
import csv
import urllib2
import json
from collections import defaultdict
import StringIO
import random
from multiprocessing import Pool

# %%
knowledgGraph = "cnet" # conceptnet5AssocMod, gov, conceptnet5AssocMi, conceptnet5AssocHdl
#knowledgGraph_ = ''.join([k.capitalize() if i>0 else k for i, k in enumerate(knowledgGraph)])
collection = "trec7n8"
method = "wsdmImprPr" # hal, mi, assoc, assocMi, assocHal, assoc2
simMeasure = "" # mi, cnet
projectDir = "/home/fj9124/projects/ir/seq_kb_ir/" 
indexDir = "/scratch/index/indri_5_7/"
colMethodConfigsDir = os.path.join(projectDir, "configs", collection, method)
cfgInFileName = os.path.join(projectDir, "configs", collection, "query" + collection.capitalize()) 
print("cfgInFileName =", cfgInFileName)
cfgOutFileName=os.path.join(colMethodConfigsDir, knowledgGraph, "indriRunQuery.cfg") 
print("cfgOutFileName =", cfgOutFileName)
colIndexDir = os.path.join(indexDir, collection) 
print("colIndexDir =", colIndexDir)
if knowledgGraph in {"cnet"}:
    knowledgGraphIndexDir = os.path.join(indexDir, collection)   
else:
    knowledgGraphIndexDir = os.path.join(indexDir, knowledgGraph)   
print("knowledgGraph index Dir =", knowledgGraphIndexDir)
graphsDir = os.path.join(projectDir, "graphs")
#methodGraphsDir = os.path.join(graphsDir, method)
methodGraphsFileName = []
if method == "hal":
    methodGraphsFileName = [os.path.join(graphsDir, method, knowledgGraph + ".txt")]
    print("methodGraphsFileName =", methodGraphsFileName)
elif method.translate(None, string.digits) in {"mi", "assoc"}:
    methodGraphsFileName = [os.path.join(graphsDir, method.translate(None, string.digits), knowledgGraph, "graph.txt")]
    print("methodGraphsFileName =", methodGraphsFileName)
elif method in {"assocMi"}:
    if knowledgGraph == "conceptnet5AssocGov":
        methodGraphsFileName = [os.path.join(graphsDir, "assoc", collection, "conceptnet5AssocMod" + ".txt")]
        methodGraphsFileName += [os.path.join(graphsDir, "mi", collection, "gov" + ".txt")]
        print("methodGraphsFileName =", methodGraphsFileName)
elif method in {"assocHal"}:
    if knowledgGraph == "conceptnet5AssocGov":
        methodGraphsFileName = [os.path.join(graphsDir, "assoc", collection, "conceptnet5AssocMod" + ".txt")]
        methodGraphsFileName += [os.path.join(graphsDir, "hal", "gov" + ".txt")]
        print("methodGraphsFileName =", methodGraphsFileName)
qrelsDir = os.path.join(projectDir, "qrels")
colQrelsDir = os.path.join(qrelsDir, collection)
colQrelsFileName = os.path.join(colQrelsDir, "qrels.csv")
print("col Qrels File Name =", colQrelsFileName)
runsFileName = os.path.join(projectDir, "runs", method, collection, knowledgGraph, "indriRunQuery.runs") 
print("runsFileName =", runsFileName)
evalsFileName = os.path.join(projectDir, "evals", method, collection, knowledgGraph, "indriRunQuery.evals") 
print("evalsFileName =", evalsFileName)
dumpindexStatementFilename = os.path.join("/", "tmp", "sbsb", "statement" + "_" + collection + "_" + method + "_" + knowledgGraph )
print("dumpindexStatementFilename =", dumpindexStatementFilename)
occuranceCountFilename = os.path.join(projectDir, "occuranceCount", "occuranceCount")
print("occuranceCountFilename =", occuranceCountFilename)
countsResultsFile = os.path.join(projectDir,"occuranceCount","results",collection+".txt")
print("countsResultsFile =", countsResultsFile)
conceptnet5RelAllFilename ="/scratch/saeid/data/conceptnet5_simp.csv"
print("conceptnet5RelAllFilename =", conceptnet5RelAllFilename)
cfgTmpOutFileName = cfgOutFileName + ".tmp"
print("cfgTmpOutFileName =", cfgTmpOutFileName)
docIdNameMapFileName = os.path.join(projectDir, "occuranceCount", "results", collection + "_docIdNameMap.txt")
print("docIdNameMapFileName =", docIdNameMapFileName)
#dumpindexResFilename = os.path.join(projectDir,"occuranceCount","results",collection +"_dumpindexRes"+".txt")
#print("dumpindexResFilename =", dumpindexResFilename)
#expansionCount = 25
# Out:
# cfgInFileName = /home/fj9124/projects/ir/seq_kb_ir/configs/trec7n8/queryTrec7n8
# cfgOutFileName = /home/fj9124/projects/ir/seq_kb_ir/configs/trec7n8/wsdmImprPr/cnet/indriRunQuery.cfg
# colIndexDir = /scratch/index/indri_5_7/trec7n8
# knowledgGraph index Dir = /scratch/index/indri_5_7/trec7n8
# col Qrels File Name = /home/fj9124/projects/ir/seq_kb_ir/qrels/trec7n8/qrels.csv
# runsFileName = /home/fj9124/projects/ir/seq_kb_ir/runs/wsdmImprPr/trec7n8/cnet/indriRunQuery.runs
# evalsFileName = /home/fj9124/projects/ir/seq_kb_ir/evals/wsdmImprPr/trec7n8/cnet/indriRunQuery.evals
# dumpindexStatementFilename = /tmp/sbsb/statement_trec7n8_wsdmImprPr_cnet
# occuranceCountFilename = /home/fj9124/projects/ir/seq_kb_ir/occuranceCount/occuranceCount
# countsResultsFile = /home/fj9124/projects/ir/seq_kb_ir/occuranceCount/results/trec7n8.txt
# conceptnet5RelAllFilename = /scratch/saeid/data/conceptnet5_simp.csv
# cfgTmpOutFileName = /home/fj9124/projects/ir/seq_kb_ir/configs/trec7n8/wsdmImprPr/cnet/indriRunQuery.cfg.tmp
# docIdNameMapFileName = /home/fj9124/projects/ir/seq_kb_ir/occuranceCount/results/trec7n8_docIdNameMap.txt

# %%
# trec_eval -q ../qrels/trec7n8/qrels.csv indriRunQuery.res | grep map | grep -v all | awk '{if ($3 < 0.1) printf $2 ","}'
if collection == "gov":
    diffTopics = [4, 6, 7, 8, 9, 10, 12, 18, 19, 21, 22, 24, 26, 27, 30, 31, 32, 33, 36, 37, 40, 45, 46, 47, 48, 50, 52, 53, 54, 57, 58, 59, 63, 65, 66, 67, 70, 73, 78, 79, 80, 82, 84, 86, 92, 93, 94, 95, 96, 98, 99, 101, 102, 103, 104, 105, 106, 107, 109, 110, 111, 112, 113, 115, 116, 117, 118, 120, 123, 125, 126, 127, 129, 132, 133, 134, 135, 136, 137, 140, 142, 143, 147, 148, 149, 152, 153, 154, 155, 156, 157, 158, 160, 161, 162, 163, 165, 166, 167, 168, 169, 171, 175, 176, 177, 178, 179, 180, 182, 183, 185, 186, 188, 189, 191, 192, 194, 195, 196, 197, 200, 201, 202, 203, 204, 207, 208, 211, 212, 214, 215, 218, 219, 221, 224]
if collection == "robust":
    diffTopics = [301, 305, 309, 314, 315, 318, 319, 320, 322, 325, 327, 332, 336, 340, 342, 343, 344, 345, 346, 347, 350, 352, 354, 355, 356, 359, 363, 367, 371, 372, 376, 378, 379, 380, 381, 383, 386, 388, 389, 390, 393, 394, 397, 398, 401, 405, 409, 412, 419, 421, 426, 432, 435, 436, 437, 439, 440, 442, 448, 449, 605, 608, 610, 620, 622, 625, 626, 627, 638, 650, 651, 655, 659, 666, 668, 680, 683, 684, 688, 689, 690]
if collection == "trec7n8":
    diffTopics = [352,354,356,359,363,367,370,371,372,373,376,378,379,381,383,386,388,389,390,393,394,397,398,401,405,408,419,421,422,426,432,435,436,437,439,440,442,443,445,447,448,449]
diffTopic = [str(i) for i in diffTopics]

# %%
# generate docIdNameMapFileName
if not os.path.isfile(occuranceCountFilename):
    cmd = ' '.join([occuranceCountFilename, colIndexDir, "dm", ">", docIdNameMapFileName])
    res = subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE).stdout.read()

# %%
with open(docIdNameMapFileName, 'r') as f:
    reader = list(csv.reader(f, delimiter = ' '))
    print(reader[0])
    docIdNameMap = {i[1]:i[0] for i in reader}
    docNameIdMap = {i[0]:i[1] for i in reader}
for i, (k, v) in enumerate(docIdNameMap.iteritems()):
    print (k, '\t', v)
    if (i>20):
        break
# Out:
# ['1', 'FR940104-1-00001']
# LA082389-0020 	 441223
# FBIS3-32596 	 246524
# LA011890-0198 	 465144
# LA011890-0199 	 465145
# LA011890-0196 	 465142
# LA011890-0197 	 465143
# LA011890-0194 	 465140
# FT932-3799 	 88713
# LA011890-0192 	 465138
# LA011890-0193 	 465139
# LA011890-0190 	 465136
# LA011890-0191 	 465137
# FT932-3796 	 88710
# FT924-2868 	 187695
# FT924-2869 	 187696
# FT932-3797 	 88711
# FT924-2864 	 187691
# FT924-2865 	 187692
# FT924-2866 	 187693
# FT924-2867 	 187694
# FT924-2860 	 187687
# FT924-2861 	 187688

# %%
count_history = dict()
if os.path.isfile(countsResultsFile):
    with open(countsResultsFile, 'r') as f:
        reader = csv.reader(f, delimiter = "\t")
        count_history = {k:int(float(v)) for k,v in list(reader)}
    print("size of count_history =", len(count_history))
    for i, (k, v) in enumerate(count_history.iteritems()):
        print (k, '\t', v)
        if (i>20):
            break
# Out:
# size of count_history = 81446
# #uw(#4( storm ) #4( be appear in sky )) 	 0
# #uw(#4( work on sundai )) 	 137
# #uw(#4( calm time )) 	 23
# #uw(#4( kill ) #4( prai )) 	 394
# #uw(#4( bank ) #4( teller offic )) 	 5
# #uw(#4( water ) #4( hydrogen )) 	 347
# #uw(#4( drug ) #4( take )) 	 8847
# #uw(#4( space ) #4( mostli empti )) 	 3
# #uw(#4( chang ) #4( edg )) 	 3803
# #uw(#4( happin )) 	 0
# #uw(#4( trade ) #4( countri )) 	 45838
# #uw(#4( game ) #4( leisur activ )) 	 23
# #uw(#4( round in shape )) 	 4
# #uw(#4( good ) #4( other person )) 	 411
# #uw(#4( smoke ) #4( fire )) 	 1842
# #uw(#4( spice up salad )) 	 1
# #uw(#4( be wound )) 	 410
# #uw(#4( good ) #4( hear nice new )) 	 0
# #uw(#4( teacher ) #4( teach student of class )) 	 0
# #uw(#4( deliveri )) 	 11268
# #uw(#4( bank ) #4( teller monei )) 	 23
# #uw(#4( swap share )) 	 106

# %%
conceptnet5RelAll = defaultdict(dict)
conceptnet5RelAllInv = defaultdict(dict)
with open(conceptnet5RelAllFilename, 'r') as f:
    reader = csv.reader(f, delimiter = ",")
    for line in list(reader):
        if line[0].strip() != "" and line[1].strip() != "" and line[2].strip() != "":
            if all(c in string.printable for c in line[0]) and all(c in string.printable for c in line[1]) and all(c in string.printable for c in line[2]):
                conceptnet5RelAll[line[1].strip()][line[2].strip()] = line[0].strip()
                conceptnet5RelAllInv[line[2].strip()][line[1].strip()] = line[0].strip()
print("size of conceptnet5RelAll =", len(conceptnet5RelAll))
for i, (k1, k2v) in enumerate(conceptnet5RelAll.iteritems()):
    for j, (k2, v) in enumerate(k2v.iteritems()):
        if (i>3 or j>3):
            break
        print (k1, '\t', k2, '\t', v)
# Out:
# size of conceptnet5RelAll = 2965684
# tripolitan 	 tripoline 	 Synonym
# tripolitan 	 tripoli 	 RelatedTo
# age of nemesis 	 band 	 IsA
# age of nemesis 	 organisation 	 InstanceOf
# age of nemesis 	 progressive rock 	 dbpedia/genre
# age of nemesis 	 progressive metal 	 dbpedia/genre
# joseph john annabring 	 person 	 InstanceOf
# british rail class 438 	 mean of transportation 	 InstanceOf
# british rail class 438 	 train 	 InstanceOf

# %%
indriRunQuery_hist_= dict()
dumpindex_hist_ = dict()

# %%
def splitStemText(text):
    stemmedWords = []
    text = re.sub('/|-|\"|_',' ', text) # replace - and slash with space
    if method in {"assocRestful", "lr", "wsdmImpr", "wsdmImprPr"}:
        for text_ in text.split(' '):
            text = text_.replace(" ", "_")
            url = "http://conceptnet5.media.mit.edu/data/5.4/uri?language=en&text=" + text
            response = urllib2.urlopen(url)
            data = response.read()
            data_j = json.loads(data)
            text = os.path.basename(data_j[u'uri'])
            url = "http://conceptnet5.media.mit.edu/data/5.4/uri?language=en&text=" + text
            response = urllib2.urlopen(url)
            data = response.read()
            data_j = json.loads(data)
            #print("data_j =", data_j)
            #print("data_j[u'uri'] =", data_j[u'uri'])
            stemmedWords += [str(os.path.basename(data_j[u'uri']))]
        #print("stemmedWords =", stemmedWords)
        return (stemmedWords)
    else:
        words = text.split()
        for w in words:
            w = re.sub('\(|\)|\'s|,','', w) # remove paranthesis, apostrophe s, comma
            w = re.sub('\'','', w) # remove apostrophe
            cmd = "dumpindex " + knowledgGraphIndexDir + " t " + w + " | head -n1"
            #print("cmd =", cmd)
            stemmedWords.append(subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE).stdout.read().split()[1])
        return (stemmedWords)

print ("testing:", splitStemText("going reading"))
# Out:
# testing: ['go', 'read']

# %%
def analyseQueries():
    #    #print("intCoeff =", intCoeff)
    with open(cfgInFileName, 'r') as inFile:
        reader = inFile.read()
        soup = BeautifulSoup(reader, 'lxml')
        if collection in {"aquaint", "gov"}:
            tags = soup.find_all(['doc'])
        elif collection in {"robust", "trec7n8", "gov2"}:
            tags = soup.find_all(['top'])
            #print(tags)
        
        origWordsAll = dict()
        for tag in tags:
            
            if collection in {"aquaint", "gov"}:
                docno = (tag.find('docno').string).strip()
            elif collection in {"robust", "trec7n8", "gov2"}:
                result = re.search('<num> Number: (.*)\n', str(tag))                
                docno = result.group(1).strip()
            
            if collection in {"aquaint", "gov"}:
                origWords = splitStemText(tag.find('text').string.strip())
            elif collection in {"robust", "trec7n8", "gov2"}:
                result = re.search('<title>(.*)\n', str(tag))                
                origWords = splitStemText(result.group(1).strip())
            #print("origWords =", origWords)
            origWordsAll[docno] = origWords
            
    return (origWordsAll)

# %%
cmd = ' '.join(["dumpindex", colIndexDir, "s", "|", "awk", "\'NR==2{print $2}\'"])
res = subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE).stdout.read()
colDocumentCount = int(np.float(res))
print("colDocumentCount =", colDocumentCount)
# Out:
# colDocumentCount = 472526

# %%
def genMultSimpQuery(argss):
    #    #print("intCoeff =", intCoeff)
    soupNew = BeautifulSoup("", 'lxml')
    parameters_tag = soupNew.new_tag("parameters")
    index_tag = soupNew.new_tag("index")
    index_tag.string = colIndexDir
    parameters_tag.append(index_tag)
        #print(tags)

    for args in argss:
        #print("args =", args)
        (dist, docno, origWords_, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights, workingset) = args
        #print("(...) =", docno, origWords_, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights, workingset)
        doc_tag = soupNew.new_tag("query")

        docno_tag = soupNew.new_tag("number")
        if relW != "":
            docno_tag.string = '_'.join([dist, docno, ('_'.join(origWords_)).replace(' ', '_'), relW.replace(' ', '_')])
        else:
            docno_tag.string = '_'.join([dist, docno, ('_'.join(origWords_)).replace(' ', '_'), relW.replace(' ', '_')])

        doc_tag.append(docno_tag)

        text_tag = soupNew.new_tag("text")
        text_tag.string = "#weight(\n" 

        text_tag.string += str(intCoeff0) + " #combine(" 
        for ow in set(origWords_):
            ow = re.sub(ur"[^\w\d#(),:\-\s]+", ' ', ow)
            text_tag.string += ow + " "
        text_tag.string += ")\n"

        if len(relW)>0: 
            relText_string1 = re.sub(ur"[^\w\d#(),:\-\s]+",' ',relW)
            text_tag.string += str(intCoeff1) + " #combine(" 
            #print("relText_string1 =", relText_string1)
            text_tag.string += relText_string1.encode('utf-8')
            text_tag.string += ")\n"

        text_tag.string += ") "

        doc_tag.append(text_tag)
        
        if workingset[0] != "all":
            for d in workingset:
                workingSetDocno_tag = soupNew.new_tag("workingSetDocno")
                workingSetDocno_tag.string = d
                doc_tag.append(workingSetDocno_tag)

        parameters_tag.append(doc_tag)
        #print(doc_tag)

    rule_tag = soupNew.new_tag("rule")
    rule_tag.string = "method:dir,mu:" + str(dirCoeff)
    #rule_tag.string = "method:two"
    parameters_tag.append(rule_tag)

    threads_tag = soupNew.new_tag("threads")
    threads_tag.string = "32"
    parameters_tag.append(threads_tag)

    count_tag = soupNew.new_tag("count")
    count_tag.string = "10"
    parameters_tag.append(count_tag)

    trecFormat_tag = soupNew.new_tag("trecFormat")
    trecFormat_tag.string = "true"
    parameters_tag.append(trecFormat_tag)

    soupNew.append(parameters_tag)
    #print(soupNew.prettify())
    #print("cfgTmpOutFileName =", cfgTmpOutFileName)
    with open( cfgTmpOutFileName, 'a+') as outFile:
        soupNewStr = str(soupNew)
        soupNewStr = soupNewStr.replace("</text>", "\n</text>\n").replace("query>", "query>\n").replace("<text>", "\n<text>\n").replace("</index>", "</index>\n").replace("\n<index>", "<index>")

        outFile.write(soupNewStr)

# %%
def genCommandsinHist_i(dist, docno, origWords_, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights):
    
    indriRunQuery_hist = [(dist, docno, origWords_, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, cfgTmpOutFileName, ['all'])]
    return indriRunQuery_hist

# %%
def runCommandsinHist_i(cfgTmpOutFileName, indriRunQuery_hist, indriRunQuery_hist_, featureWeights):
    with open( cfgTmpOutFileName, 'w+') as outFile:
        outFile.write("")
    args = []
    #print("indriRunQuery_hist =", indriRunQuery_hist, "\nlen(indriRunQuery_hist) =",len(indriRunQuery_hist))
    for (dist, docno, origWords_, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, cfgTmpOutFileName, workingset) in indriRunQuery_hist:
        #print("origWords_, relW (before if) =", origWords_, "---", relW)
        if '_'.join([dist, docno, ('_'.join(origWords_)).replace(' ', '_'), relW.replace(' ', '_')]) not in indriRunQuery_hist_:
            #print("origWords_, relW (after if) =", origWords_, "---", relW)
            args += [(dist, docno, origWords_, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights, workingset)]
    #print("args =", args)
    if len(args)>0:
        genMultSimpQuery(args)
    cmd = ' '.join(["IndriRunQuery", cfgTmpOutFileName])
    #print("cmd =", cmd)
    indriRun = subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE).stdout.read()
    #print("indriRun =", indriRun)
    indriRunQuery_hist_tmp = [[j for c, j in enumerate(i.split(' ')) if c in {0, 2, 4}] for i in indriRun.split('\n') if len(i)>0]
    #indriRunQuery_hist_ = dict()
    for i in indriRunQuery_hist_tmp:
        if i[0] in indriRunQuery_hist_:
            indriRunQuery_hist_[i[0]] += [[i[1], i[2]]]
        else:
            indriRunQuery_hist_[i[0]] = [[i[1], i[2]]]
    #indriRunQuery_hist_ = list(set(indriRunQuery_hist_))
    return indriRunQuery_hist_

# %%
def genCommandsinHist_d(indriRunQuery_hist_, dumpindex_hist, dist, docno, origWords_, ow, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights):

    expr = '_'.join([dist, docno, '_'.join(origWords_), ""]).replace(' ', '_')
    #print("expr =", expr)
    indriRunQuery_hist_1 = indriRunQuery_hist_[expr]
    #print("indriRunQuery_hist_1 =", indriRunQuery_hist_1)
    topTDocs = [i[0] for i in indriRunQuery_hist_1]
    
    expr = "#4( " + regex.sub(' ', relW) + " )"
    #expr = '_'.join([dist, docno, '_'.join(origWords_), ""]).replace(' ', '_')
    #print("expr =", expr)
    #cmd2 = [(dist, docno, [expr], "", intCoeff0, intCoeff1, intCoeff2, dirCoeff, cfgTmpOutFileName, topTDocs)]
    #if cmd2 not in indriRunQuery_phCounter_hist:
    #    indriRunQuery_phCounter_hist += cmd2
    cmd2 = ("efb", expr + ":" + ','.join(topTDocs))
    if cmd2 not in dumpindex_hist:
        dumpindex_hist.add(cmd2)
    
    #print("relW =", relW)
    expr = "#4( " + regex.sub(' ', relW) + " )"
    cmd2 = ("fx", expr)
    if cmd2 not in dumpindex_hist:
        dumpindex_hist.add(cmd2)
    #print("dumpindex_hist =", dumpindex_hist)
    
    for documentName in topTDocs:
        cmd2 = ("dcf", docIdNameMap[documentName])
        if cmd2 not in dumpindex_hist:
            dumpindex_hist.add(cmd2)

    for ow in origWords_:
        phrase = ["#uw(#4( " + regex.sub(' ', ow) + " ) #4( " + regex.sub(' ', relW) + " ))"]
        #cmd2 = ("efb", "#uw(#4( " + regex.sub(' ', ow) + " ) #4( " + regex.sub(' ', relW) + " )):" + ','.join(topTDocs))
        #cmd2 = [(dist, docno, phrase, "", intCoeff0, intCoeff1, intCoeff2, dirCoeff, cfgTmpOutFileName, topTDocs)]
        #if cmd2 not in indriRunQuery_phCounter_hist:
        #    indriRunQuery_phCounter_hist += cmd2        
        cmd2 = ("fx", phrase[0])
        if cmd2 not in dumpindex_hist:
            dumpindex_hist.add(cmd2)
        
        cmd2 = ("efb", phrase[0] + ":" + ','.join(topTDocs))
        if cmd2 not in dumpindex_hist:
            dumpindex_hist.add(cmd2)
            
    for j1, ow1 in enumerate(origWords_):
        for j2, ow2 in enumerate(origWords_):
            if j1>j2:
                phrase = ["#uw(#4( " + regex.sub(' ', ow1) + " ) #4( " + regex.sub(' ', ow2) + " ) #4( " + regex.sub(' ', relW) + " ))"]
                #cmd2 = [(dist, docno, phrase, "", intCoeff0, intCoeff1, intCoeff2, dirCoeff, cfgTmpOutFileName, topTDocs)]
                #if cmd2 not in indriRunQuery_phCounter_hist:
                #    indriRunQuery_phCounter_hist += cmd2        
                #cmd2 = ("fx", phrase[0])
                cmd2 = ("fx", phrase[0])
                if cmd2 not in dumpindex_hist:
                    dumpindex_hist.add(cmd2)
                cmd2 = ("efb", phrase[0] + ":" + ','.join(topTDocs))
                if cmd2 not in dumpindex_hist:
                    dumpindex_hist.add(cmd2)
    #print("len(dumpindex_hist) =", len(dumpindex_hist))
    return dumpindex_hist

# %%
regex = re.compile('[%s]' % re.escape(string.punctuation))
def runCommandsinHist_d(dist, docno, dumpindex_hist, dumpindex_hist_):
    args = []
    dumpindex_hist_dict = dict()
    tmp = set()
    #print("dumpindex_hist =", dumpindex_hist)
    for i in dumpindex_hist:
        expr = '_'.join([dist, docno, '_'.join(i[0]), ""]).replace(' ', '_')
        if i[1] not in dumpindex_hist_.get(expr, dict()):
#        if i[1] not in dumpindex_hist_.get(dist + "_" + docno + "_" + i[0], dict()):
            if i[1] in tmp:
                continue
            #print("i =", i)
            tmp.add(i[1])
            if i[0] in dumpindex_hist_dict:
                dumpindex_hist_dict[i[0]] += [[re.sub(ur"[^\w\d#(),:\-\s]+",' ',j) for j in i[1:]]]
            else:
                dumpindex_hist_dict[i[0]] =  [[re.sub(ur"[^\w\d#(),:\-\s]+",' ',j) for j in i[1:]]]
                
    for k, v in dumpindex_hist_dict.iteritems():
        fileName = dumpindexStatementFilename + "_" + k + ".tmp"
        with open(fileName, 'w') as f:
            for i in v:
                f.write(' '.join(i) + '\n')
                #print("i =", i)
        cmd = ' '.join([occuranceCountFilename, colIndexDir, k, fileName])
        #print("cmd =", cmd)
        dumpindex_hist_tmp = subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE).stdout.read()
        #print("dumpindex_hist_tmp =", dumpindex_hist_tmp)
        dumpindex_hist_tmp = dict([tuple(j for c2, j in enumerate(i.split(':')) if c2 in {0,1} ) for i in dumpindex_hist_tmp.split("\n") if len(i)>0])
        #print("dumpindex_hist_tmp.get(\"#od4(travel)\",\"\") =", dumpindex_hist_tmp.get("#od4(travel)", dict()) )
        dumpindex_hist_tmp = {k1:v1.split(',') for k1,v1 in dumpindex_hist_tmp.iteritems()}
        dumpindex_hist_tmp = {dist + "_" + docno + "_" + k1:[i for i in v1 if len(i)>0] for k1,v1 in dumpindex_hist_tmp.iteritems()}
        #dumpindex_hist_tmp = {re.sub(ur"[^\w\d#()\s]+",' ',k1):[i for i in v1 if len(i)>0] for k1,v1 in dumpindex_hist_tmp.iteritems()}
        #dumpindex_tmp = [i for i in dumpindex_tmp.split("\n")]
        #print("dumpindex_hist_tmp =", dumpindex_hist_tmp)
        #dumpindex_hist_[k] = dumpindex_hist_tmp
        #expr = '_'.join([dist, docno, '_'.join(k), ""]).replace(' ', '_')    
        dumpindex_hist_[k] = dict(dumpindex_hist_.get(k, dict()).items() + dumpindex_hist_tmp.items())
        #dumpindex_hist_[dist + "_" + docno + "_" + k] = dict(dumpindex_hist_.get(dist + "_" + docno + "_" + k, dict()).items() + dumpindex_hist_tmp.items())
    #print("dumpindex_hist_['efb'].get('#od4(travel)', dict())]", dumpindex_hist_['efb'].get("#od4(travel)", dict()))
        #print("dumpindex_hist_[k].keys() =", dumpindex_hist_[k].keys())
    #print("dumpindex_hist_ =", dumpindex_hist_)
        
    return dumpindex_hist_

# %%
# keys of rWords are important
# values of rWords1 are important
regex = re.compile('[%s]' % re.escape(string.punctuation))
def getRelWords_train(args, indriRunQuery_hist_, dumpindex_hist_):
    #print("origWords =", origWords)
    text_string = ""
    
    count_history, rWords, dist, docno, origWords, expansionCount, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights = args
        
    relWords = dict()
    #if method == "relAll":
            
    if method in {"lr", "wsdmImpr", "wsdmImprPr"}:
        origWords_ = [w.replace(" ", "_") for w in origWords]
        #relWords_l = []
        dumpindex_hist = set()

        indriRunQuery_hist = []
        indriRunQuery_hist += genCommandsinHist_i(dist, docno, origWords_, "", intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights)
        #for relW in conceptnet5RelAll[ow].keys():
        #    indriRunQuery_hist += genCommandsinHist_i(dist, docno, origWords_, ow, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights)

        indriRunQuery_hist_ = runCommandsinHist_i(cfgTmpOutFileName, indriRunQuery_hist, indriRunQuery_hist_, featureWeights)
        #print("indriRunQuery_hist =", indriRunQuery_hist)
        for ow in origWords_:
            #print("ow =", ow)
            #relWords_l += list(conceptnet5RelAll[ow])
            #print(ow, "---", conceptnet5RelAll[ow])

            
            
            for relW in conceptnet5RelAll[ow].keys():
                dumpindex_hist |= genCommandsinHist_d(indriRunQuery_hist_, dumpindex_hist, dist, docno, origWords_, ow, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights)
                #dumpindex_hist |= genCommandsinHist_id(indriRunQuery_hist_, dumpindex_hist, indriRunQuery_phCounter_hist, docno, origWords_, ow, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights)
                #print("indriRunQuery_phCounter_hist =", indriRunQuery_phCounter_hist)
                #indriRunQuery_phCounter_hist = [list(x) for x in set(tuple(x) for x in indriRunQuery_phCounter_hist)]
            
        dumpindex_hist_ = runCommandsinHist_d(dist, docno, dumpindex_hist, dumpindex_hist_)
        
        #indriRunQuery_hist_ = runCommandsinHist_i(cfgTmpOutFileName, indriRunQuery_phCounter_hist, indriRunQuery_hist_, featureWeights)

    return(indriRunQuery_hist_, dumpindex_hist_)

# %%
regex = re.compile('[%s]' % re.escape(string.punctuation))
def documentLength(dist, docno, documentName, dumpindex_hist_):
    #documentLength_ = int(dumpindex_hist_['dcf'][documentName][0])
    documentLength_ = int(dumpindex_hist_['dcf'][dist + "_" + docno + "_" + documentName][0])
    return documentLength_

def weightRelConcept(dist, docno, origWords_, ow, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, count_history, featureWeights, indriRunQuery_hist_, dumpindex_hist_):
    
    features = dict()
    
    expr_i = '_'.join([dist, docno, '_'.join(origWords_), ""]).replace(' ', '_')
    #print("expr_i =", expr_i)
    indriRunQuery_hist_1 = indriRunQuery_hist_[expr_i]
    #print("indriRunQuery_hist_1 =", indriRunQuery_hist_1)
    topTDocs = [i[0] for i in indriRunQuery_hist_1]
    
    topTDocScores_d = {i[0]:np.float(i[1]) for i in indriRunQuery_hist_1}
    
    
    expTDocScore = np.float(indriRunQuery_hist_1[0][1])
    features["expTDocScore"] = expTDocScore
    
    expr = "#4( " + regex.sub(' ', relW) + " )"
    #expr = expr.replace(' ', '_')
    #print("expr =", expr)
    #expr_i = '_'.join([dist, docno, '_'.join([expr.replace(' ', '_')]), ""]).replace(' ', '_')
    #indriRunQuery_hist_1 = indriRunQuery_hist_[expr_i]
    #print("indriRunQuery_hist_1 =", indriRunQuery_hist_1)
    relWTopDocuments = dumpindex_hist_['efb'][dist + "_" + docno + "_" + expr][1:]
    #relWTopDocuments = list([i[0] for i in indriRunQuery_hist_1]) #deep copy
    
    numerator = len(relWTopDocuments) # relW term count in the collection
    denumerator = np.sum([documentLength(dist, docno, i, dumpindex_hist_) for i in topTDocs]) # number of terms in topDocs
    topTermFrac = numerator / np.float(denumerator)
    features["topTermFrac"] = topTermFrac
    
    numCanDocs = len(set([i[0] for i in relWTopDocuments]))
    features["numCanDocs"] = numCanDocs
    
    if numCanDocs > 0:
        avgCDocScore = np.sum([ topTDocScores_d[i] for i in set([i for i in relWTopDocuments])])/np.float(numCanDocs)
    else:
        avgCDocScore = 0
    features["avgCDocScore"] = avgCDocScore

    l = [ topTDocScores_d[i] for i in set(relWTopDocuments)]
    if len(l)>0:
        maxCDocScore = np.max(l)
    else:
        maxCDocScore = 0
    features["maxCDocScore"] = maxCDocScore
    
    colDocFreq = np.float(dumpindex_hist_['fx'][dist + "_" + docno + "_" + expr][0])
    if colDocFreq>0:
        conIdf = np.log(colDocumentCount / colDocFreq)
    else:
        conIdf = np.log(colDocumentCount / 1)
    features["conIdf"] = conIdf
    
    coocurDocumentsTop = dict()
    coocurDocumentsCount = dict()
    for ow in origWords_:
        expr = "#uw(#4( " + regex.sub(' ', ow) + " ) #4( " + regex.sub(' ', relW) + " ))"
        #expr = expr.replace(' ', '_')
        #expr_i = '_'.join([dist, docno, '_'.join([expr.replace(' ', '_')]), ""]).replace(' ', '_')
        #indriRunQuery_hist_1 = indriRunQuery_hist_[expr_i]
        coocurDocumentsTop[ow] = dumpindex_hist_['efb'][dist + "_" + docno + "_" + expr][1:]
        #coocurDocumentsTop[ow] = list([i[0] for i in indriRunQuery_hist_1])
        coocurDocumentsCount[ow] = np.float(dumpindex_hist_['fx'][dist + "_" + docno + "_" + expr][0])

    avgColCor = np.sum(coocurDocumentsCount.values())/np.float(len(coocurDocumentsCount.values())) 
    features["avgColCor"] = avgColCor
    
    maxColCor = np.max(coocurDocumentsCount.values())
    features["maxColCor"] = maxColCor
    
    avgTopColCor = np.sum([len(set(i)) for i in coocurDocumentsTop.values()])/np.float(len(coocurDocumentsTop.values())) 
    features["avgTopColCor"] = avgTopColCor
    
    l = [len(set(i)) for i in coocurDocumentsTop.values()]
    if len(l)>0:
        maxTopColCor = np.max(l)
    else:
        maxTopColCor = 0
    features["maxTopColCor"] = maxTopColCor

    coocurDocumentsTop = dict()
    coocurDocumentsCount = dict()
    for j1, ow1 in enumerate(origWords_):
        for j2, ow2 in enumerate(origWords_):
            if j1>j2:
                expr = "#uw(#4( " + regex.sub(' ', ow1) + " ) #4( " + regex.sub(' ', ow2) + " ) #4( " + regex.sub(' ', relW) + " ))"
                #expr = expr.replace(' ', '_')
                #expr_i = '_'.join([dist, docno, '_'.join([expr.replace(' ', '_')]), ""]).replace(' ', '_')
                #indriRunQuery_hist_1 = indriRunQuery_hist_[expr_i]
                #indriRunQuery_hist_1 = indriRunQuery_hist_['_'.join([dist, docno, expr]).replace(' ', '_')]
                coocurDocumentsTop[ow1+ow2] = dumpindex_hist_['efb'][dist + "_" + docno + "_" + expr][1:]
                #coocurDocumentsTop[ow1+ow2] = list([i[0] for i in indriRunQuery_hist_1])
                coocurDocumentsCount[ow] = np.float(dumpindex_hist_['fx'][dist + "_" + docno + "_" + expr][0])

    avgColPCor = np.sum(coocurDocumentsCount.values())/np.float(len(coocurDocumentsCount.values()))  
    features["avgColPCor"] = avgColPCor

    if len(coocurDocumentsCount.values())>0:
        maxColPCor = np.max(coocurDocumentsCount.values())
    else:
        maxColPCor = 0
    features["maxColPCor"] = maxColPCor
    
    avgTopColPCor = np.sum([len(set(i)) for i in coocurDocumentsTop.values()])/np.float(len(coocurDocumentsTop.values())) 
    features["avgTopColPCor"] = avgTopColPCor

    l = [len(set(i)) for i in coocurDocumentsTop.values()] 
    if len(l)>0:
        maxTopColPCor = np.max(l)
    else:
        maxTopColPCor = 0
    features["maxTopColPCor"] = maxTopColPCor
    
    """
    relWg = 0
    for feature, weight in featureWeights.iteritems():
        relWg += features[feature] * weight
    """
    #print("origWords_ =", origWords_)
    #print("relW =", relW)
    #print("features =", features)
    #print("relWg =", relWg)

    #return relWg
    features = {k:np.abs(np.nan_to_num(v)) for k,v in features.iteritems()}
    return features

# %%
def normDictOfDicts(_dict_):
    dict_ = dict(_dict_)
    dSum = dict()
    #dMax = dict()
    #dMin = dict()
    for k, v in dict_.iteritems():
        """
        for k1, v1 in v.iteritems():
            dMax[k1] = max(dMax.get(k1, -(np.inf)), v1)
            dMin[k1] = min(dMin.get(k1,  (np.inf)), v1)
        """
        #print ("type(v) = ", type(v))
        dSum = { k1:dSum.get(k1,0)+v1 for k1, v1 in v.items()}
        #dMax = { k1:max(dMax.get(k1, -(np.inf)), v1) for k1, v1 in v.items()}
        #dMin = { k1:min(dMin.get(k1,  np.inf), v1) for k1, v1 in v.items()}
    #print("dict_ =", dict_)
    dict_r = dict()
    for k, v in dict_.items():
        dict_r[k] = { k1:v1/dSum[k1] if dSum[k1] != 0 else 0 for k1, v1 in v.items()}
        #dict_[k] = { k1:dict_[k][k1]/dSum[k1] if dSum[k1] != 0 else dict_[k][k1] for k1, v1 in v.items()}
        """
        #dict_r[k] = { k1:(dict_[k][k1]-dMin[k1])/(dMax[k1]-dMin[k1]) if (dMax[k1]-dMin[k1]) != 0 else dict_[k][k1] for k1, v1 in v.items()}
        dict_r1 = dict()
        for k1, v1 in v.items():
            if (dMax[k1]-dMin[k1]) != 0: 
                dict_r1[k1] = (v1-dMin[k1])/(dMax[k1]-dMin[k1])
            elif dict_r1[k1]!=0: 
                dict_r1[k1] = 1
            else: 
                dict_r1[k1] = 0
        dict_r[k] = dict_r1
        """
    return dict_r

d_tst = {1:{2:3, 4:5}, 3:{2:3.2, 4:5.4}, 5:{2:3.4, 4:5.5}}
print("dict of dicts before normalization =", d_tst)
d_tst = normDictOfDicts(d_tst)
print("dict of dicts after normalization =", d_tst)

def weightedCombineDicts(ddict_, dict_):
    dict_cmb = dict()
    for k, v in ddict_.items():
        cmb = 0
        for k1, v1 in v.items():
            cmb += dict_[k1] * v1
        dict_cmb[k] = cmb
    return dict_cmb

cmb_tst = { 2:0.4, 4:0.6}
print("cmb_tst =", cmb_tst)
dCombtst = weightedCombineDicts(d_tst, cmb_tst)
print("dCombtst =", dCombtst)

# keys of rWords are important
# values of rWords1 are important
regex = re.compile('[%s]' % re.escape(string.punctuation))
def getRelWords(args, indriRunQuery_hist_, dumpindex_hist_):
    #print("origWords =", origWords)
    text_string = ""
    
    count_history, rWords, dist, docno, origWords, expansionCount, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights = args
        
    relWords = dict()
    #if method == "relAll":
        
    if method == "assocRestful":
        origWords_ = [w.replace(" ", "_") for w in origWords]
        url = "http://conceptnet5.media.mit.edu/data/5.4/assoc/list/en/"+','.join(origWords_)
        response = urllib2.urlopen(url)
        data = response.read()
        data_j = json.loads(data)
        relWords = {str(d[0].encode('utf-8')).replace('/c/en/', '').replace('-', ' '):np.float(d[1]) for d in data_j[u'similar'] if '/c/en/' in str(d[0].encode('utf-8'))}
    
    elif method in {"lr", "wsdmImpr", "wsdmImprPr"}:
        origWords_ = [w.replace(" ", "_") for w in origWords]
        #relWords_l = []

        for ow in origWords_:
            #relWords_l += list(conceptnet5RelAll[ow])
            #print(ow, "---", conceptnet5RelAll[ow])
            """
            for relW in conceptnet5RelAll[ow].keys():
                relWg = weightRelConcept(dist, docno, origWords_, ow, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, count_history, featureWeights, indriRunQuery_hist_, dumpindex_hist_)
                if relW in relWords:
                    relWords[relW] += relWg
                else:
                    relWords[relW] = relWg  
            """
            relWords_unNorm = dict()
            for relW in conceptnet5RelAll[ow].keys():
                feature_ = weightRelConcept(dist, docno, origWords_, ow, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, count_history, featureWeights, indriRunQuery_hist_, dumpindex_hist_)
                if relW in relWords_unNorm:
                    relWords_unNorm[relW] += feature_
                else:
                    relWords_unNorm[relW] = feature_
            #print("relWords before =", relWords_unNorm)
            relWordsNorm = normDictOfDicts(relWords_unNorm)
            #print("relWordsNorm =", relWordsNorm)
            relWords = weightedCombineDicts(relWordsNorm, featureWeights)
            #print("relWords after comb =", relWords)
            
            
    else:
        count_history = countExpr(count_history, origWords, rWords)
        expressions = set()
        for ow in origWords:
            rWords_ow = rWords.get(ow, [])
            expressions.add("#4( " + ow.translate(None, string.punctuation) + " )")
            if ow.strip() == "":
                continue
            if simMeasure == "mi":
                N_w = countExpr_get_1(count_history, ow)
            for rw_wv in rWords_ow:
                (rw_w, rw_v) = rw_wv.items()[0]
                if rw_w.strip() == "":
                    continue           
                if simMeasure == "mi":
                    N_v = countExpr_get_1(count_history, rw_w)
                    N_wv = countExpr_get_2(count_history, ow, rw_w)
                    rw_v_ = mi_(N_w, N_v, N_wv)
                elif simMeasure == "cnet":
                    rw_v_ = rw_v
                relWords[rw_w] = relWords.get(rw_w, 0) + rw_v_
    
    relWords_sorted = sorted(relWords.items(), key=operator.itemgetter(1), reverse=True)
    #print ("origWords =", origWords)
    #print ("relWords_sorted =", relWords_sorted)
    
    #counter = 0
    relWords_sel = []
    for counter, (rw_w, rw_v) in enumerate(relWords_sorted):
        #print ("rw_w, rw_v =", rw_w, rw_v)
        #print ("expansionCount =", expansionCount)
        if (counter >= expansionCount):
        #if (rw_v < expansionCount):
            break
        if  all(c in string.printable for c in rw_w):
            if rw_w not in origWords:
                rw_w = regex.sub(' ', rw_w)
                text_string += rw_w + " "
                relWords_sel += [rw_w]
        #1/0
        #counter += 1
    #print("counter =", counter)
    #rint("relWords_sel =", relWords_sel)
#    return(relWords_sel)
    return(count_history, text_string, relWords_sel)
# Out:
# dict of dicts before normalization = {1: {2: 3, 4: 5}, 3: {2: 3.2, 4: 5.4}, 5: {2: 3.4, 4: 5.5}}
# dict of dicts after normalization = {1: {2: 0.3125, 4: 0.31446540880503143}, 3: {2: 0.33333333333333337, 4: 0.339622641509434}, 5: {2: 0.3541666666666667, 4: 0.34591194968553457}}
# cmb_tst = {2: 0.4, 4: 0.6}
# dCombtst = {1: 0.3136792452830188, 3: 0.33710691823899375, 5: 0.3492138364779874}

# %%
def getAllRelWords_train(dist, count_history, rWords, origWordsAll, expansionCount1, N1, expansionCount2, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights, indriRunQuery_hist_, dumpindex_hist_):
    relText_stringAll = []
    relText_string = dict()
    relWords_sel = dict()
    for c1, (docno, origWords) in enumerate(origWordsAll.iteritems()):
        print("c1 =", c1, "docno =", docno, "--- origWords =", origWords)
        args = (count_history, rWords, dist, docno, origWords, expansionCount1, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights)
        indriRunQuery_hist_, dumpindex_hist_ = getRelWords_train(args, indriRunQuery_hist_, dumpindex_hist_)
        #print("c1 =", c1, "- len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) =", len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())))
    
    #print("relText_stringAll =", relText_stringAll)
    return (indriRunQuery_hist_, dumpindex_hist_)

# %%
def getAllRelWords(dist, count_history, rWords, origWordsAll, expansionCount1, N1, expansionCount2, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights, indriRunQuery_hist_, dumpindex_hist_):
    relText_stringAll = []
    relText_string = dict()
    relWords_sel = dict()
    for c1, (docno, origWords) in enumerate(origWordsAll.iteritems()):
        #print(str(c1), "---", docno, "---", origWords)
        args = (count_history, rWords, dist, docno, origWords, expansionCount1, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights)
        count_history, relText_string_, relWords_sel_ = getRelWords(args, indriRunQuery_hist_, dumpindex_hist_)
        #print("len(indriRunQuery_hist_), len(dumpindex_hist_['dcf']), len(dumpindex_hist_['ef']) =", len(indriRunQuery_hist_), len(dumpindex_hist_['dcf']), len(dumpindex_hist_['ef']))
        relText_string[docno] = relText_string_
        relWords_sel[docno] = relWords_sel_[0:N1]
        #print(docno, "---", origWords, "---", relWords_sel_)
    relText_stringAll += [relText_string]
    """
    relText_string = dict()
    relWords_sel = dict()
    for docno, origWords_new in relWords_sel.iteritems():
        args = (count_history, rWords, docno, origWords, expansionCount1, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights)
        count_history, relText_string_, relWords_sel_ = getRelWords(args, indriRunQuery_hist_, dumpindex_hist_)
        relText_string[docno] = relText_string_
        relWords_sel[docno] = relWords_sel_
    relText_stringAll += [relText_string]
    """
    #print("relText_stringAll =", relText_stringAll)
    return (count_history, relText_stringAll, relWords_sel)

# %%
regex = re.compile('[%s]' % re.escape(string.punctuation))
def genQueries(cfgOutFileName_, origWordsAll, relText_stringAll, intCoeff0, intCoeff1, intCoeff2, dirCoeff):
    #    #print("intCoeff =", intCoeff)
    with open(cfgInFileName, 'r') as inFile:
        reader = inFile.read()
        soupNew = BeautifulSoup("", 'lxml')
        parameters_tag = soupNew.new_tag("parameters")
        index_tag = soupNew.new_tag("index")
        index_tag.string = colIndexDir
        parameters_tag.append(index_tag)
            #print(tags)

        for docno, origWords in origWordsAll.iteritems():
            doc_tag = soupNew.new_tag("query")

            docno_tag = soupNew.new_tag("number")
            docno_tag.string = docno
            doc_tag.append(docno_tag)

            text_tag = soupNew.new_tag("text")
            text_tag.string = "#weight(\n" 
                    
            text_tag.string += str(intCoeff0) + " #combine(" 
            for ow in set(origWords):
                ow = regex.sub(' ', ow)
                text_tag.string += ow + " "
            text_tag.string += ")\n"

            if len(relText_stringAll[0])>0:
                if len(relText_stringAll[0][docno]) > 3: 
                    relText_string1 = regex.sub(' ', relText_stringAll[0][docno])
                    text_tag.string += str(intCoeff1) + " #combine(" 
                    #print("relText_string1 =", relText_string1)
                    text_tag.string += relText_string1.encode('utf-8')
                    text_tag.string += ")\n"
            
            """
            #print(len(relText_stringAll[1]))
            if len(relText_stringAll[1])>0:
                if len(relText_stringAll[1][docno]) > 3: 
                    relText_string2 = regex.sub(' ', relText_stringAll[1][docno])
                    text_tag.string += str(intCoeff2) + " #combine(" 
                    #print("relText_string2 =", relText_string2)
                    text_tag.string += relText_string2.encode('utf-8')
                    text_tag.string += ")\n"
            """
            #print("origWords =", origWords)
            #print("relWords_sel1 =", relWords_sel1)
            #print("relWords_sel2 =", relWords_sel2)
            
            
            text_tag.string += ") "

            doc_tag.append(text_tag)

            parameters_tag.append(doc_tag)
            #print(doc_tag)

        rule_tag = soupNew.new_tag("rule")
        rule_tag.string = "method:dir,mu:" + str(dirCoeff)
        #rule_tag.string = "method:two"
        parameters_tag.append(rule_tag)

        #intCoeff_tag = soupNew.new_tag("intCoeff")
        #intCoeff_tag.string = "0.8"
        #parameters_tag.append(intCoeff_tag)

        threads_tag = soupNew.new_tag("threads")
        threads_tag.string = "32"
        parameters_tag.append(threads_tag)

        count_tag = soupNew.new_tag("count")
        count_tag.string = "1000"
        parameters_tag.append(count_tag)

        trecFormat_tag = soupNew.new_tag("trecFormat")
        trecFormat_tag.string = "true"
        parameters_tag.append(trecFormat_tag)

        soupNew.append(parameters_tag)
        #print(soupNew.prettify())
    #print("outFileName =", outFileName)
    with open( cfgOutFileName_, 'w') as outFile:
        soupNewStr = str(soupNew)
        soupNewStr = soupNewStr.replace("</text>", "\n</text>\n").replace("query>", "query>\n").replace("<text>", "\n<text>\n").replace("</index>", "</index>\n").replace("\n<index>", "<index>")

        outFile.write(soupNewStr)

# %%
def precisionCompute_train(dist, origWordsAll, count_history, intCoeffs0, intCoeffs1, intCoeffs2, expansionCounts1, expansionCounts2, dirCoeffs, N1s, featureWeights_, indriRunQuery_hist_, dumpindex_hist_):
    #randNum = random.randint(1,1e9)
    indriRunQuery_hist_, dumpindex_hist_ = getAllRelWords_train(dist, count_history, rWords, origWordsAll, expansionCounts1[0], N1s[0], expansionCounts2[0], intCoeffs0[0], intCoeffs1[0], intCoeffs2[0], dirCoeffs[0], featureWeights_[0], indriRunQuery_hist_, dumpindex_hist_)
                                    
    return count_history, indriRunQuery_hist_, dumpindex_hist_

# %%
#training
dist = str(1)
intCoeffs0 = [ 0.7 ]
intCoeffs1 = [ 0.3 ]
#intCoeffs2 = [ 0.18 ]
intCoeffs2 = [ 0.5 ]
#intCoeffs1 = np.arange(0.1, 1, 0.1)
expansionCounts1 = [ 85 ]
#expansionCounts2 = [ 145 ]
expansionCounts2 = [ 0 ]
#expansionCounts2 = range(15, 220, 5)
dirCoeffs = [ 1600 ]
#dirCoeffs = range(200, 4000, 200)
N1s = [0]
rWords = dict()
featureWeights_1 = {'maxTopColCor': 0.1, 'expTDocScore': 0.1, 'maxColPCor': 0.1, 'avgCDocScore': 0.1, 'topTermFrac': 0.1, 'avgColCor': 0.1, 'avgTopColCor': 0.1, 'numCanDocs': 0.1, 'maxTopColPCor': 0.1, 'maxCDocScore': 0.1, 'avgColPCor': 0.1, 'conIdf': 0.1, 'avgTopColPCor': 0.1, 'maxColCor': 0.1}
featureWeights_l=[featureWeights_1]
origWordsAll = analyseQueries()

count_history, indriRunQuery_hist_, dumpindex_hist_ = precisionCompute_train(dist, origWordsAll, count_history, intCoeffs0, intCoeffs1, intCoeffs2, expansionCounts1, expansionCounts2, dirCoeffs, N1s, featureWeights_l, indriRunQuery_hist_, dumpindex_hist_)
# Out:
# c1 = 0 docno = 407 --- origWords = ['poach', 'wildlife', 'preserve']
# c1 = 1 docno = 406 --- origWords = ["parkinson's", 'disease']
# c1 = 2 docno = 405 --- origWords = ['cosmic', 'event']
# c1 = 3 docno = 404 --- origWords = ['ireland', 'peace', 'talk']
# c1 = 4 docno = 403 --- origWords = ['osteoporosis']
# c1 = 5 docno = 402 --- origWords = ['behavioral', 'genetics']
# c1 = 6 docno = 401 --- origWords = ['foreign', 'minority', 'germany']
# c1 = 7 docno = 400 --- origWords = ['amazon', 'rain', 'forest']
# c1 = 8 docno = 409 --- origWords = ['legal', 'pan', 'be', '103']
# c1 = 9 docno = 408 --- origWords = ['tropical', 'storm']
# c1 = 10 docno = 366 --- origWords = ['commercial', 'cyanide', 'use']
# c1 = 11 docno = 420 --- origWords = ['carbon', 'monoxide', 'poison']
# c1 = 12 docno = 364 --- origWords = ['rabies']
# c1 = 13 docno = 422 --- origWords = ['art', 'steal', 'forge']
# c1 = 14 docno = 425 --- origWords = ['counterfeit', 'money']
# c1 = 15 docno = 363 --- origWords = ['transportation', 'tunnel', 'disaster']
# c1 = 16 docno = 379 --- origWords = ['mainstreaming']
# c1 = 17 docno = 378 --- origWords = ['euro', 'opposition']
# c1 = 18 docno = 416 --- origWords = ['three', 'gorge', 'project']
# c1 = 19 docno = 417 --- origWords = ['creativity']
# c1 = 20 docno = 410 --- origWords = ['schengen', 'agreement']
# c1 = 21 docno = 427 --- origWords = ['uv', 'damage', 'eye']
# c1 = 22 docno = 412 --- origWords = ['airport', 'security']
# c1 = 23 docno = 413 --- origWords = ['steel', 'production']
# c1 = 24 docno = 371 --- origWords = ['health', 'insurance', 'holistic']
# c1 = 25 docno = 370 --- origWords = ['food', 'drug', 'law']
# c1 = 26 docno = 373 --- origWords = ['encryption', 'equipment', 'export']
# c1 = 27 docno = 361 --- origWords = ['clothe', 'sweatshop']
# c1 = 28 docno = 418 --- origWords = ['quilt', 'income']
# c1 = 29 docno = 419 --- origWords = ['recycle', 'automobile', 'tire']
# c1 = 30 docno = 377 --- origWords = ['cigar', 'smoke']
# c1 = 31 docno = 376 --- origWords = ['world', 'court']
# c1 = 32 docno = 393 --- origWords = ['mercy', 'kill']
# c1 = 33 docno = 392 --- origWords = ['robotics']
# c1 = 34 docno = 391 --- origWords = ['r', 'drug', 'price']
# c1 = 35 docno = 390 --- origWords = ['orphan', 'drug']
# c1 = 36 docno = 397 --- origWords = ['automobile', 'recall']
# c1 = 37 docno = 396 --- origWords = ['sick', 'build', 'syndrome']
# c1 = 38 docno = 395 --- origWords = ['tourism']
# c1 = 39 docno = 394 --- origWords = ['home', 'school']
# c1 = 40 docno = 399 --- origWords = ['oceanographic', 'vessel']
# c1 = 41 docno = 398 --- origWords = ['dismantle', "europe's", 'arsenal']
# c1 = 42 docno = 414 --- origWords = ['cuba', 'sugar', 'export']
# c1 = 43 docno = 415 --- origWords = ['drug', 'golden', 'triangle']
# c1 = 44 docno = 429 --- origWords = ['legionnaire', 'disease']
# c1 = 45 docno = 428 --- origWords = ['decline', 'birth', 'rate']
# c1 = 46 docno = 368 --- origWords = ['in', 'vitro', 'fertilization']
# c1 = 47 docno = 369 --- origWords = ['anorexia', 'nervosa', 'bulimia']
# c1 = 48 docno = 421 --- origWords = ['industrial', 'waste', 'disposal']
# c1 = 49 docno = 367 --- origWords = ['piracy']
# c1 = 50 docno = 423 --- origWords = ['milosevic', 'mirjana', 'markovic']
# c1 = 51 docno = 365 --- origWords = ['el', 'nino']
# c1 = 52 docno = 362 --- origWords = ['human', 'smuggle']
# c1 = 53 docno = 424 --- origWords = ['suicide']
# c1 = 54 docno = 360 --- origWords = ['drug', 'legalization', 'benefit']
# c1 = 55 docno = 426 --- origWords = ['law', 'enforcement', 'dog']
# c1 = 56 docno = 449 --- origWords = ['antibiotic', 'ineffectiveness']
# c1 = 57 docno = 448 --- origWords = ['ship', 'loss']
# c1 = 58 docno = 443 --- origWords = ['u_s', 'investment', 'africa']
# c1 = 59 docno = 442 --- origWords = ['heroic', 'act']
# c1 = 60 docno = 441 --- origWords = ['lyme', 'disease']
# c1 = 61 docno = 440 --- origWords = ['child', 'labor']
# c1 = 62 docno = 447 --- origWords = ['stirling', 'engine']
# c1 = 63 docno = 446 --- origWords = ['tourist', 'violence']
# c1 = 64 docno = 445 --- origWords = ['woman', 'clergy']
# c1 = 65 docno = 444 --- origWords = ['supercritical', 'fluid']
# c1 = 66 docno = 380 --- origWords = ['obesity', 'medical', 'treatment']
# c1 = 67 docno = 381 --- origWords = ['alternative', 'medicine']
# c1 = 68 docno = 382 --- origWords = ['hydrogen', 'fuel', 'automobile']
# c1 = 69 docno = 383 --- origWords = ['mental', 'illness', 'drug']
# c1 = 70 docno = 384 --- origWords = ['space', 'station', 'moon']
# c1 = 71 docno = 385 --- origWords = ['hybrid', 'fuel', 'car']
# c1 = 72 docno = 386 --- origWords = ['teach', 'disable', 'child']
# c1 = 73 docno = 387 --- origWords = ['radioactive', 'waste']
# c1 = 74 docno = 388 --- origWords = ['organic', 'soil', 'enhancement']
# c1 = 75 docno = 389 --- origWords = ['illegal', 'technology', 'transfer']
# c1 = 76 docno = 411 --- origWords = ['salvage', 'shipwreck', 'treasure']
# c1 = 77 docno = 372 --- origWords = ['native', 'american', 'casino']
# c1 = 78 docno = 375 --- origWords = ['hydrogen', 'energy']
# c1 = 79 docno = 374 --- origWords = ['nobel', 'prize', 'winner']
# c1 = 80 docno = 438 --- origWords = ['tourism', 'increase']
# c1 = 81 docno = 439 --- origWords = ['invention', 'scientific', 'discovery']
# c1 = 82 docno = 436 --- origWords = ['railway', 'accident']
# c1 = 83 docno = 437 --- origWords = ['deregulation', 'gas', 'electric']
# c1 = 84 docno = 434 --- origWords = ['estonia', 'economy']
# c1 = 85 docno = 435 --- origWords = ['curb', 'population', 'growth']
# c1 = 86 docno = 432 --- origWords = ['profile', 'motorist', 'police']
# c1 = 87 docno = 433 --- origWords = ['greek', 'philosophy', 'stoicism']
# c1 = 88 docno = 430 --- origWords = ['killer', 'bee', 'attack']
# c1 = 89 docno = 431 --- origWords = ['robotic', 'technology']
# c1 = 90 docno = 450 --- origWords = ['king', 'hussein', 'peace']
# c1 = 91 docno = 357 --- origWords = ['territorial', 'water', 'dispute']
# c1 = 92 docno = 356 --- origWords = ['postmenopausal', 'estrogen', 'britain']
# c1 = 93 docno = 355 --- origWords = ['ocean', 'remote', 'sense']
# c1 = 94 docno = 354 --- origWords = ['journalist', 'risk']
# c1 = 95 docno = 353 --- origWords = ['antarctica', 'exploration']
# c1 = 96 docno = 352 --- origWords = ['british', 'chunnel', 'impact']
# c1 = 97 docno = 351 --- origWords = ['falkland', 'petroleum', 'exploration']
# c1 = 98 docno = 359 --- origWords = ['mutual', 'fund', 'predictor']
# c1 = 99 docno = 358 --- origWords = ['blood', 'alcohol', 'fatality']

# %%
def precisionCompute(dist, origWordsAll, count_history, intCoeffs0, intCoeffs1, intCoeffs2, expansionCounts1, expansionCounts2, dirCoeffs, N1s, featureWeights_, indriRunQuery_hist_, dumpindex_hist_):
    mapPrecs = []
    for featureWeights in featureWeights_:
        for N1 in N1s:
            for intCoeff0 in intCoeffs0:
                for intCoeff1 in intCoeffs1:
                    for intCoeff2 in intCoeffs2:
                        for expansionCount1 in expansionCounts1:
                            for expansionCount2 in expansionCounts2:
                                for dirCoeff in dirCoeffs:
                                    
                                    
                                    #res = getAllRelWords_p(count_history, rWords, origWordsAll, expansionCount1, N1, expansionCount2, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights)
                                    
                                    count_history, relText_stringAll, relWords_sel = getAllRelWords(dist, count_history, rWords, origWordsAll, expansionCount1, N1, expansionCount2, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights, indriRunQuery_hist_, dumpindex_hist_)
                                    
                                    #print("len(relText_stringAll[1]) =", len(relText_stringAll[1]))
                                    ##########
                                    #cfgOutFileName = os.path.join("tmp","sbsb",str(randNum)+".cfg")
                                    #runsFileName = os.path.join("tmp","sbsb",str(randNum)+".run")
                                    #evalsFileName = os.path.join("tmp","sbsb",str(randNum)+".eval")
                                    ##########
                                    genQueries(cfgOutFileName, origWordsAll, relText_stringAll, intCoeff0, intCoeff1, intCoeff2, dirCoeff)
                                    subprocess.Popen("IndriRunQuery " + cfgOutFileName + " > " + runsFileName, shell=True, stdout=subprocess.PIPE).stdout.read()
                                    cmd = "trec_eval -q " + colQrelsFileName + " " + runsFileName + " > " + evalsFileName
                                    subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE).stdout.read()
                                    cmd = "cat " + evalsFileName + " | grep map | grep all | grep -v gm | awk '{print $3}' "
                                    #print ("cmd = ", cmd)
                                    mapPrec = subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE).stdout.read()
                                    mapPrecs += [mapPrec]
                                    print("featureWeights =", featureWeights)
                                    print("intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 =", intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, N1, mapPrec)
                                    #mapPrecs[intCoeff] = mapPrec
    return relText_stringAll, relWords_sel, mapPrecs

# %%
dist = str(1)
intCoeffs0 = [ 0.7 ]
intCoeffs1 = [ 0.5 ]
#intCoeffs2 = [ 0.18 ]
intCoeffs2 = [ 0.5 ]
#intCoeffs1 = np.arange(0.1, 1, 0.1)
expansionCounts1 = [ 0.0050 ]
expansionCounts1 = [ 20 ]
#expansionCounts2 = [ 145 ]
expansionCounts2 = [ 0 ]
#expansionCounts1 = range(0, 220, 5)
dirCoeffs = [ 1600 ]
#dirCoeffs = range(200, 4000, 200)
N1s_max = [100]
#N1s = range(1, 30, 1)
#mapPrecs = 
rWords = dict()
maxIteration = 1e4
featureWeights_l=[]
featureWeights_1 = {'maxTopColCor': 0.1, 'expTDocScore': 0.1, 'maxColPCor': 0.1, 'avgCDocScore': 0.1, 'topTermFrac': 0.1, 'avgColCor': 0.1, 'avgTopColCor': 0.1, 'numCanDocs': 0.1, 'maxTopColPCor': 0.1, 'maxCDocScore': 0.1, 'avgColPCor': 0.1, 'conIdf': 0.1, 'avgTopColPCor': 0.1, 'maxColCor': 0.1}
"""
for conIdf in [0.1] :
#for conIdf in [-5000, -500, -50, -5, -0.5, -0.05, 0, 0.05, 0.5, 5, 50, 500, 5000] :
#for conIdf in np.arange(-1,1,0.2):
    featureWeights_1["conIdf"] = conIdf
    featureWeights_l += [dict(featureWeights_1)]
relText_stringAll, relWords_sel1, mapPrecs = precisionCompute(dist, origWordsAll, count_history, intCoeffs0, intCoeffs1, intCoeffs2, expansionCounts1, expansionCounts2, dirCoeffs, N1s_max, featureWeights_l, indriRunQuery_hist_, dumpindex_hist_)
"""
#for ft, wg in featureWeights_1.iteritems():
# initialize:
featureWeights_1_new = { k:0.0 for k in featureWeights_1.keys()}
#featureWeights_1_new = {'maxTopColCor': 0.0, 'expTDocScore': 0.0, 'maxColPCor': 0.0, 'avgCDocScore': 0.0, 'topTermFrac': 0.0, 'avgColCor': 0.0, 'avgTopColCor': 0.0, 'numCanDocs': 0.0, 'maxTopColPCor': 0.0, 'maxCDocScore': 0.0, 'avgColPCor': 0.0, 'conIdf': 0.1, 'avgTopColPCor': 0.1, 'maxColCor': 0.1}
#for wg_new in np.arange(-1.0,1.1,1.0):
count = 0
while(count < maxIteration):
    #print("feature =", ft, " weight =", wg_new)
    rNums = np.random.rand(1, len(featureWeights_1))
    rNums = [np.abs(i) for i in rNums]
    rNums = rNums/np.sum(rNums) # normalize
    #print ("rNums =", rNums[0])
    featureWeights_l = [{ k:rNums[0][c1] for c1, k in enumerate(featureWeights_1.keys())}]
    #eatureWeights_l=[]
    #featureWeights_1_new[ft] = wg_new
    #featureWeights_l += [dict(featureWeights_1_new)]
    relText_stringAll, relWords_sel1, mapPrecs = precisionCompute(dist, origWordsAll, count_history, intCoeffs0, intCoeffs1, intCoeffs2, expansionCounts1, expansionCounts2, dirCoeffs, N1s_max, featureWeights_l, indriRunQuery_hist_, dumpindex_hist_)
    count += 1
# Out:
# featureWeights = {'maxTopColCor': 0.06015686607437358, 'maxColPCor': 0.034958041984018522, 'conIdf': 0.12744275094302576, 'avgCDocScore': 0.10262320770465544, 'topTermFrac': 0.051964978670243869, 'avgColCor': 0.11187161274753489, 'avgTopColCor': 0.071348619361293317, 'numCanDocs': 0.050813974463601218, 'maxTopColPCor': 0.04081373582146576, 'expTDocScore': 0.091690944992595294, 'avgColPCor': 0.021167311778780045, 'maxCDocScore': 0.10065801992031434, 'avgTopColPCor': 0.094634470359369949, 'maxColCor': 0.039855465178727997}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2046
#
# featureWeights = {'maxTopColCor': 0.090329058289431496, 'maxColPCor': 0.12985295538989144, 'conIdf': 0.14028782611979992, 'avgCDocScore': 0.0038803717698618293, 'topTermFrac': 0.084012490290654024, 'avgColCor': 0.027523054639258727, 'avgTopColCor': 0.095520645660904069, 'numCanDocs': 0.047759446502180135, 'maxTopColPCor': 0.060345473924149587, 'expTDocScore': 0.10428016324978023, 'avgColPCor': 0.016537449151995887, 'maxCDocScore': 0.05439448242644427, 'avgTopColPCor': 0.032292761275651422, 'maxColCor': 0.11298382130999689}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2053
#
# featureWeights = {'maxTopColCor': 0.077535784312467992, 'maxColPCor': 0.050116679409762353, 'conIdf': 0.095786288509922837, 'avgCDocScore': 0.079683423429228406, 'topTermFrac': 0.079567715318848126, 'avgColCor': 0.091609826678340528, 'avgTopColCor': 0.10605435832174796, 'numCanDocs': 0.049372702778642773, 'maxTopColPCor': 0.05412439098256619, 'expTDocScore': 0.053734010648313492, 'avgColPCor': 0.058409905982588127, 'maxCDocScore': 0.079629819508680116, 'avgTopColPCor': 0.018773915385162227, 'maxColCor': 0.10560117873372898}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2051
#
# featureWeights = {'maxTopColCor': 0.10169643102884936, 'maxColPCor': 0.063167194519026762, 'conIdf': 0.029239576565816699, 'avgCDocScore': 0.08813952167282188, 'topTermFrac': 0.010761057439672131, 'avgColCor': 0.1109612052960125, 'avgTopColCor': 0.11401309485549332, 'numCanDocs': 0.076682651768404164, 'maxTopColPCor': 0.065193506866039266, 'expTDocScore': 0.076090499407117096, 'avgColPCor': 0.087478014652664526, 'maxCDocScore': 0.078420949645494287, 'avgTopColPCor': 0.039456710594846615, 'maxColCor': 0.058699585687741453}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2038
#
# featureWeights = {'maxTopColCor': 0.018456359555189414, 'maxColPCor': 0.051242470752856747, 'conIdf': 0.10171547401417003, 'avgCDocScore': 0.11023155499827716, 'topTermFrac': 0.033846733242702556, 'avgColCor': 0.068358406094306101, 'avgTopColCor': 0.04190646179017727, 'numCanDocs': 0.051690085536562465, 'maxTopColPCor': 0.1387137058917346, 'expTDocScore': 0.10619438183463262, 'avgColPCor': 0.00041199649414099985, 'maxCDocScore': 0.071416535743165269, 'avgTopColPCor': 0.13688512239415457, 'maxColCor': 0.068930711657930174}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2044
#
# featureWeights = {'maxTopColCor': 0.058318675159017251, 'maxColPCor': 0.027978866797625332, 'conIdf': 0.015163383070363983, 'avgCDocScore': 0.11719018067641705, 'topTermFrac': 0.098374064621686783, 'avgColCor': 0.097592085427260528, 'avgTopColCor': 0.12957804255758523, 'numCanDocs': 0.090822680778850667, 'maxTopColPCor': 0.085403824993845107, 'expTDocScore': 0.0073506715952856086, 'avgColPCor': 0.029828432025380124, 'maxCDocScore': 0.023583736408431876, 'avgTopColPCor': 0.10499200899259861, 'maxColCor': 0.11382334689565177}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2054
#
# featureWeights = {'maxTopColCor': 0.06203464045678421, 'maxColPCor': 0.031937238602093063, 'conIdf': 0.030714727446667426, 'avgCDocScore': 0.075867357398833671, 'topTermFrac': 0.0119105698777892, 'avgColCor': 0.12889246806348104, 'avgTopColCor': 0.053751883066077866, 'numCanDocs': 0.10630733032874914, 'maxTopColPCor': 0.079751044536405233, 'expTDocScore': 0.10949274088349854, 'avgColPCor': 0.047685619120869521, 'maxCDocScore': 0.10763227085483142, 'avgTopColPCor': 0.058796650120760241, 'maxColCor': 0.095225459243159685}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2033
#
# featureWeights = {'maxTopColCor': 0.067069895949213171, 'maxColPCor': 0.074722140581562027, 'conIdf': 0.11812493159630699, 'avgCDocScore': 0.0085901216847952804, 'topTermFrac': 0.025070974815474375, 'avgColCor': 0.12157607111814607, 'avgTopColCor': 0.10806615652330295, 'numCanDocs': 0.083380066297615588, 'maxTopColPCor': 0.070464926860694235, 'expTDocScore': 0.037674056580335062, 'avgColPCor': 0.072788092712114019, 'maxCDocScore': 0.046542037814551546, 'avgTopColPCor': 0.11984822946898765, 'maxColCor': 0.046082297996900945}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2038
#
# featureWeights = {'maxTopColCor': 0.025761495535091349, 'maxColPCor': 0.030424031824834798, 'conIdf': 0.051203051853262994, 'avgCDocScore': 0.055730995551132832, 'topTermFrac': 0.011541369579016953, 'avgColCor': 0.097283510770192178, 'avgTopColCor': 0.084506097533142477, 'numCanDocs': 0.11128991592480462, 'maxTopColPCor': 0.049668103748726974, 'expTDocScore': 0.10667652152125216, 'avgColPCor': 0.048306630347493634, 'maxCDocScore': 0.12722698147223435, 'avgTopColPCor': 0.11877932777597451, 'maxColCor': 0.081601966562840259}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2046
#
# featureWeights = {'maxTopColCor': 0.016383237004691058, 'maxColPCor': 0.10243502676524467, 'conIdf': 0.089102197246464246, 'avgCDocScore': 0.011176112075801109, 'topTermFrac': 0.042738391677004939, 'avgColCor': 0.090339992013826642, 'avgTopColCor': 0.11641585905489948, 'numCanDocs': 0.08467710280079703, 'maxTopColPCor': 0.078197107819978365, 'expTDocScore': 0.051231236580066557, 'avgColPCor': 0.14718263177448349, 'maxCDocScore': 0.09721639958955948, 'avgTopColPCor': 0.02851403632082845, 'maxColCor': 0.044390669276354239}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2036
#
# featureWeights = {'maxTopColCor': 0.12369429761801355, 'maxColPCor': 0.027584747121638005, 'conIdf': 0.083452034922313734, 'avgCDocScore': 0.090470335805743277, 'topTermFrac': 0.073307837618876021, 'avgColCor': 0.085794203493102572, 'avgTopColCor': 0.11378893674363856, 'numCanDocs': 0.073547279683866568, 'maxTopColPCor': 0.040222369405836234, 'expTDocScore': 0.080999048944587593, 'avgColPCor': 0.050953923151787803, 'maxCDocScore': 0.05022122918427252, 'avgTopColPCor': 0.077541627031558716, 'maxColCor': 0.028422129274764986}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2050
#
# featureWeights = {'maxTopColCor': 0.13653871198522455, 'maxColPCor': 0.048368569688536291, 'conIdf': 0.097887215607634331, 'avgCDocScore': 0.087681623207751899, 'topTermFrac': 0.013454088534676268, 'avgColCor': 0.066693395769595237, 'avgTopColCor': 0.017071507689732052, 'numCanDocs': 0.041170645475639332, 'maxTopColPCor': 0.023951438931606079, 'expTDocScore': 0.14875091300883306, 'avgColPCor': 0.11756048570190254, 'maxCDocScore': 0.085729923940920119, 'avgTopColPCor': 0.02013932970023399, 'maxColCor': 0.095002150757714343}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2027
#
# featureWeights = {'maxTopColCor': 0.027837595125730152, 'maxColPCor': 0.0073081152975475261, 'conIdf': 0.066410292483908007, 'avgCDocScore': 0.064981116278198775, 'topTermFrac': 0.069143269613413091, 'avgColCor': 0.080920216950737728, 'avgTopColCor': 0.11329239370308035, 'numCanDocs': 0.090485598836753292, 'maxTopColPCor': 0.10310780350511287, 'expTDocScore': 0.049598959037453226, 'avgColPCor': 0.08768410170902477, 'maxCDocScore': 0.07982974486640311, 'avgTopColPCor': 0.11514908533993654, 'maxColCor': 0.044251707252700292}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2050
#
# featureWeights = {'maxTopColCor': 0.028351081679954343, 'maxColPCor': 0.08460051500192009, 'conIdf': 0.087993722049285752, 'avgCDocScore': 0.063567276744220025, 'topTermFrac': 0.076423418225324696, 'avgColCor': 0.09149949681713028, 'avgTopColCor': 0.049554258959305215, 'numCanDocs': 0.0099065754655560025, 'maxTopColPCor': 0.076456734362874743, 'expTDocScore': 0.064291132131609335, 'avgColPCor': 0.12869756422028314, 'maxCDocScore': 0.1280854261819532, 'avgTopColPCor': 0.0027325702563242107, 'maxColCor': 0.107840227904259}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2031
#
# featureWeights = {'maxTopColCor': 0.10604668555143204, 'maxColPCor': 0.015167584012575897, 'conIdf': 0.099497069432869442, 'avgCDocScore': 0.073467317582165209, 'topTermFrac': 0.08449202781927842, 'avgColCor': 0.099635778986271809, 'avgTopColCor': 0.024691839194433941, 'numCanDocs': 0.083025123280574542, 'maxTopColPCor': 0.074548519418917658, 'expTDocScore': 0.048643383738541886, 'avgColPCor': 0.044154707233877162, 'maxCDocScore': 0.039423410329662678, 'avgTopColPCor': 0.10558811582911894, 'maxColCor': 0.1016184375902803}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2048
#
# featureWeights = {'maxTopColCor': 0.075854371391958955, 'maxColPCor': 0.13285723113468562, 'conIdf': 0.03158291381539631, 'avgCDocScore': 0.13685397192446752, 'topTermFrac': 0.13790761394610832, 'avgColCor': 0.065641136628658461, 'avgTopColCor': 0.0042115163340138645, 'numCanDocs': 0.057709756610842308, 'maxTopColPCor': 0.0075332608534599511, 'expTDocScore': 0.051181086474849022, 'avgColPCor': 0.081937360519395208, 'maxCDocScore': 0.078452465323934253, 'avgTopColPCor': 0.018387054474697774, 'maxColCor': 0.1198902605675326}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2041
#
# featureWeights = {'maxTopColCor': 0.054982512293631054, 'maxColPCor': 0.0479400380670362, 'conIdf': 0.088091698083101203, 'avgCDocScore': 0.13261363261921871, 'topTermFrac': 0.0074067920704586048, 'avgColCor': 0.1060795386896176, 'avgTopColCor': 0.022304414481585263, 'numCanDocs': 0.027779420233519165, 'maxTopColPCor': 0.034031092504017924, 'expTDocScore': 0.069448738019981041, 'avgColPCor': 0.076426147382269702, 'maxCDocScore': 0.10098712958766072, 'avgTopColPCor': 0.086695597192539511, 'maxColCor': 0.14521324877536326}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2032
#
# featureWeights = {'maxTopColCor': 0.085650013893441942, 'maxColPCor': 0.05460545462754688, 'conIdf': 0.15063367005644082, 'avgCDocScore': 0.044745221014833921, 'topTermFrac': 0.004832814533371272, 'avgColCor': 0.08131192778329438, 'avgTopColCor': 0.035810482196607686, 'numCanDocs': 0.17282173181403077, 'maxTopColPCor': 0.095156684598338898, 'expTDocScore': 0.0047789529557603974, 'avgColPCor': 0.024490998927890226, 'maxCDocScore': 0.054952200954309124, 'avgTopColPCor': 0.16869637523440964, 'maxColCor': 0.021513471409723987}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2042
#
# featureWeights = {'maxTopColCor': 0.085985587200604494, 'maxColPCor': 0.027273552420261381, 'conIdf': 0.13423343802085702, 'avgCDocScore': 0.11878870027008447, 'topTermFrac': 0.098530174761861933, 'avgColCor': 0.015341441340727529, 'avgTopColCor': 0.11730487765944203, 'numCanDocs': 0.07677339341496725, 'maxTopColPCor': 0.05840112492711852, 'expTDocScore': 0.0085361500938824532, 'avgColPCor': 0.11534128151039114, 'maxCDocScore': 0.083492997857787396, 'avgTopColPCor': 0.040500110512835967, 'maxColCor': 0.019497170009178388}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2047
#
# featureWeights = {'maxTopColCor': 0.075976157179445253, 'maxColPCor': 0.10725755409967515, 'conIdf': 0.0075801277376036473, 'avgCDocScore': 0.089287775083080001, 'topTermFrac': 0.11219513597971797, 'avgColCor': 0.054910413547412613, 'avgTopColCor': 0.034368224582739595, 'numCanDocs': 0.0058625128606048437, 'maxTopColPCor': 0.10381443000259634, 'expTDocScore': 0.071237682169447605, 'avgColPCor': 0.10741958409014819, 'maxCDocScore': 0.049389375586952632, 'avgTopColPCor': 0.10020147601197059, 'maxColCor': 0.08049955106860561}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2049
#
# featureWeights = {'maxTopColCor': 0.15191555010305632, 'maxColPCor': 0.11216430238629452, 'conIdf': 0.14389917069403677, 'avgCDocScore': 0.01538003012967043, 'topTermFrac': 0.13739420167225616, 'avgColCor': 0.018462170652267202, 'avgTopColCor': 0.064739890769920969, 'numCanDocs': 0.01402561317369923, 'maxTopColPCor': 0.0041866148192842611, 'expTDocScore': 0.043525927159527092, 'avgColPCor': 0.033745941936128468, 'maxCDocScore': 0.053008991484425644, 'avgTopColPCor': 0.11475867945515404, 'maxColCor': 0.092792915564278849}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2053
#
# featureWeights = {'maxTopColCor': 0.081247561524778189, 'maxColPCor': 0.045650675496671032, 'conIdf': 0.028297653976365952, 'avgCDocScore': 0.067991701450462932, 'topTermFrac': 0.031074998529466529, 'avgColCor': 0.096772035777650214, 'avgTopColCor': 0.087156813739275515, 'numCanDocs': 0.10636120259288433, 'maxTopColPCor': 0.033281528886098109, 'expTDocScore': 0.014759835632813707, 'avgColPCor': 0.085006622249650873, 'maxCDocScore': 0.090072528705202645, 'avgTopColPCor': 0.13424771350380679, 'maxColCor': 0.098079127934873112}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2044
#
# featureWeights = {'maxTopColCor': 0.078084203609408015, 'maxColPCor': 0.070567853881614045, 'conIdf': 0.086338332238126869, 'avgCDocScore': 0.010083261947816974, 'topTermFrac': 0.067714324357999095, 'avgColCor': 0.13012377965251576, 'avgTopColCor': 0.092308643222224762, 'numCanDocs': 0.061305347807179875, 'maxTopColPCor': 0.076706835071089621, 'expTDocScore': 0.076818737020338243, 'avgColPCor': 0.01462277117576857, 'maxCDocScore': 0.017881532148074239, 'avgTopColPCor': 0.097815231868118843, 'maxColCor': 0.11962914599972516}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2042
#
# featureWeights = {'maxTopColCor': 0.066886158848718111, 'maxColPCor': 0.040939081800099364, 'conIdf': 0.1531109085511112, 'avgCDocScore': 0.0075688721139945099, 'topTermFrac': 0.014242245287148868, 'avgColCor': 0.0073007027555310302, 'avgTopColCor': 0.034454782246451911, 'numCanDocs': 0.13471753147815535, 'maxTopColPCor': 0.053817397447324458, 'expTDocScore': 0.065424558444183559, 'avgColPCor': 0.16358254266125774, 'maxCDocScore': 0.11505230591605647, 'avgTopColPCor': 0.018434990308472902, 'maxColCor': 0.12446792214149457}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2023
#
# featureWeights = {'maxTopColCor': 0.018928049942523919, 'maxColPCor': 0.062029472481164839, 'conIdf': 0.075361215737262996, 'avgCDocScore': 0.048251658684250832, 'topTermFrac': 0.18017755412869807, 'avgColCor': 0.12715785394303247, 'avgTopColCor': 0.16159853255823409, 'numCanDocs': 0.0049831199262887231, 'maxTopColPCor': 0.01751463104982022, 'expTDocScore': 0.093236977033410703, 'avgColPCor': 0.10900874352154455, 'maxCDocScore': 0.017522628239232327, 'avgTopColPCor': 0.080247264056920647, 'maxColCor': 0.0039822986976156376}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2047
#
# featureWeights = {'maxTopColCor': 0.096590666937636599, 'maxColPCor': 0.1010544205884147, 'conIdf': 0.11525569906064574, 'avgCDocScore': 0.061886691897506098, 'topTermFrac': 0.13317149573200415, 'avgColCor': 0.086362862985844308, 'avgTopColCor': 0.0033341865142894988, 'numCanDocs': 0.0033134598953821971, 'maxTopColPCor': 0.049809242754594182, 'expTDocScore': 0.00066322294597158935, 'avgColPCor': 0.066612548797153212, 'maxCDocScore': 0.065224955438760002, 'avgTopColPCor': 0.11343665656939762, 'maxColCor': 0.10328388988240009}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2054
#
# featureWeights = {'maxTopColCor': 0.035336518947859739, 'maxColPCor': 0.092848753743875273, 'conIdf': 0.061399440895647431, 'avgCDocScore': 0.12912458333023066, 'topTermFrac': 0.038914692592861483, 'avgColCor': 0.036199894206767315, 'avgTopColCor': 0.073257359765593763, 'numCanDocs': 0.025404913242354284, 'maxTopColPCor': 0.05750750172744331, 'expTDocScore': 0.12273812660621664, 'avgColPCor': 0.021138298765201981, 'maxCDocScore': 0.11038857997542807, 'avgTopColPCor': 0.11755399029202468, 'maxColCor': 0.078187345908495354}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2039
#
# featureWeights = {'maxTopColCor': 0.080715146323747225, 'maxColPCor': 0.022807029712192031, 'conIdf': 0.029893201048195685, 'avgCDocScore': 0.027485728731794182, 'topTermFrac': 0.047049061850026878, 'avgColCor': 0.069378355082978502, 'avgTopColCor': 0.026111627799308822, 'numCanDocs': 0.013535160106023595, 'maxTopColPCor': 0.055467908493328132, 'expTDocScore': 0.18772392416356615, 'avgColPCor': 0.087472551883853819, 'maxCDocScore': 0.091813973757189374, 'avgTopColPCor': 0.14092111131547955, 'maxColCor': 0.11962521973231596}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2041
#
# featureWeights = {'maxTopColCor': 0.0021138805526650147, 'maxColPCor': 0.18789285878740658, 'conIdf': 0.056953807271286981, 'avgCDocScore': 0.083435308521545681, 'topTermFrac': 0.0066484351817093163, 'avgColCor': 0.074073941648636385, 'avgTopColCor': 0.029501208401746852, 'numCanDocs': 0.068601580641647425, 'maxTopColPCor': 0.03459877124302025, 'expTDocScore': 0.12182459700492043, 'avgColPCor': 0.18918280020827008, 'maxCDocScore': 0.0036275358527655347, 'avgTopColPCor': 0.087563861925101211, 'maxColCor': 0.053981412759278258}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2027
#
# featureWeights = {'maxTopColCor': 0.053921932445198113, 'maxColPCor': 0.057906080282717688, 'conIdf': 0.0090588287378340279, 'avgCDocScore': 0.061591245886588479, 'topTermFrac': 0.15883816757509137, 'avgColCor': 0.16320933280653266, 'avgTopColCor': 0.045207786253628882, 'numCanDocs': 0.031282092804593709, 'maxTopColPCor': 0.095510449217109938, 'expTDocScore': 0.014837671007127878, 'avgColPCor': 0.080857693137975029, 'maxCDocScore': 0.069942811368179106, 'avgTopColPCor': 0.15645841451714071, 'maxColCor': 0.0013774939602822886}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2057
#
# featureWeights = {'maxTopColCor': 0.0089323350307958741, 'maxColPCor': 0.087702417104862582, 'conIdf': 0.042379377593122367, 'avgCDocScore': 0.078699632053967239, 'topTermFrac': 0.12170007637447681, 'avgColCor': 0.050343377776240865, 'avgTopColCor': 0.12940575576593691, 'numCanDocs': 0.015174108561032079, 'maxTopColPCor': 0.13073170655101585, 'expTDocScore': 0.034432096473628514, 'avgColPCor': 0.017434015667302107, 'maxCDocScore': 0.146364808688663, 'avgTopColPCor': 0.044075562687965156, 'maxColCor': 0.092624729670990558}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2052
#
# featureWeights = {'maxTopColCor': 0.09305167415052841, 'maxColPCor': 0.064378568311182896, 'conIdf': 0.10816882782322944, 'avgCDocScore': 0.11176686124487496, 'topTermFrac': 0.020359745722398716, 'avgColCor': 0.052181125065555105, 'avgTopColCor': 0.070462793414684158, 'numCanDocs': 0.043918447986494941, 'maxTopColPCor': 0.081234470906726669, 'expTDocScore': 0.034269954112988658, 'avgColPCor': 0.084246055946659945, 'maxCDocScore': 0.10431388757699384, 'avgTopColPCor': 0.033650194746633687, 'maxColCor': 0.097997392991048787}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2039
#
# featureWeights = {'maxTopColCor': 0.061902846130508282, 'maxColPCor': 0.05087792551073396, 'conIdf': 0.001267778763278092, 'avgCDocScore': 0.031953507232593908, 'topTermFrac': 0.10257676032534556, 'avgColCor': 0.11582808178497842, 'avgTopColCor': 0.1239691843853811, 'numCanDocs': 0.06326525821951183, 'maxTopColPCor': 0.091182750087668352, 'expTDocScore': 0.058577865348118867, 'avgColPCor': 0.11560642852947428, 'maxCDocScore': 0.077045093520378152, 'avgTopColPCor': 0.024710842510467911, 'maxColCor': 0.08123567765156138}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2050
#
# featureWeights = {'maxTopColCor': 0.078552171271365712, 'maxColPCor': 0.033441048091249155, 'conIdf': 0.065970070078941845, 'avgCDocScore': 0.0020966540687333275, 'topTermFrac': 0.10406202731896563, 'avgColCor': 0.11423149298620337, 'avgTopColCor': 0.095114791717643449, 'numCanDocs': 0.045771008000651536, 'maxTopColPCor': 0.083082897302151681, 'expTDocScore': 0.038899080096590141, 'avgColPCor': 0.12020253756788427, 'maxCDocScore': 0.094773680006624658, 'avgTopColPCor': 0.10123360239975503, 'maxColCor': 0.022568939093240155}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2053
#
# featureWeights = {'maxTopColCor': 0.099535975165834206, 'maxColPCor': 0.10563291564609774, 'conIdf': 0.045132756212510505, 'avgCDocScore': 0.061677686781335728, 'topTermFrac': 0.035468340242615595, 'avgColCor': 0.06958777661129778, 'avgTopColCor': 0.099838833647492672, 'numCanDocs': 0.0079217409689054195, 'maxTopColPCor': 0.12037482670500763, 'expTDocScore': 0.057100378697972604, 'avgColPCor': 0.060619043739916507, 'maxCDocScore': 0.083798429003854535, 'avgTopColPCor': 0.039986595557878299, 'maxColCor': 0.1133247010192808}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2031
#
# featureWeights = {'maxTopColCor': 0.10705130182712677, 'maxColPCor': 0.049305007798363859, 'conIdf': 0.10538116105946528, 'avgCDocScore': 0.083261245558871905, 'topTermFrac': 0.083355450345766441, 'avgColCor': 0.043402197663216791, 'avgTopColCor': 0.10124391332632565, 'numCanDocs': 0.016219378078864841, 'maxTopColPCor': 0.038646597554203216, 'expTDocScore': 0.054878791387865458, 'avgColPCor': 0.07217431194447968, 'maxCDocScore': 0.11289634939938377, 'avgTopColPCor': 0.0211286356700243, 'maxColCor': 0.11105565838604212}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2054
#
# featureWeights = {'maxTopColCor': 0.09720441272855708, 'maxColPCor': 0.14489440505511103, 'conIdf': 0.061595438501631267, 'avgCDocScore': 0.090658349299664653, 'topTermFrac': 0.1173656295473469, 'avgColCor': 0.0079470891885468475, 'avgTopColCor': 0.090563101936262033, 'numCanDocs': 0.073547492602238071, 'maxTopColPCor': 0.049439441278682925, 'expTDocScore': 0.089084767402430196, 'avgColPCor': 0.021711757870699958, 'maxCDocScore': 0.045829737733839429, 'avgTopColPCor': 0.04466098568132925, 'maxColCor': 0.065497391173660366}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2041
#
# featureWeights = {'maxTopColCor': 0.057234543235160036, 'maxColPCor': 0.079591946150990661, 'conIdf': 0.065270932467751508, 'avgCDocScore': 0.053140642376991974, 'topTermFrac': 0.13711583283801354, 'avgColCor': 0.076361566908091011, 'avgTopColCor': 0.025945631683621927, 'numCanDocs': 0.069679742054119559, 'maxTopColPCor': 0.049297981162420644, 'expTDocScore': 0.059533293910104909, 'avgColPCor': 0.13581111767788523, 'maxCDocScore': 0.10998428667545913, 'avgTopColPCor': 0.00065199517150765004, 'maxColCor': 0.08038048768788221}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2039
#
# featureWeights = {'maxTopColCor': 0.06457670271389207, 'maxColPCor': 0.10225066418874328, 'conIdf': 0.033685938370329946, 'avgCDocScore': 0.10560135419987872, 'topTermFrac': 0.0046110609897524919, 'avgColCor': 0.0013110215678747859, 'avgTopColCor': 0.0088442556208276363, 'numCanDocs': 0.11807336090208857, 'maxTopColPCor': 0.11180784231329711, 'expTDocScore': 0.11243081887272856, 'avgColPCor': 0.10946839878722081, 'maxCDocScore': 0.036296307696948769, 'avgTopColPCor': 0.073255162943171484, 'maxColCor': 0.11778711083324582}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2030
#
# featureWeights = {'maxTopColCor': 0.11558414463495791, 'maxColPCor': 0.14731268531684674, 'conIdf': 0.14999200317107167, 'avgCDocScore': 0.14072782990005206, 'topTermFrac': 0.02253335384799153, 'avgColCor': 0.036596898978584758, 'avgTopColCor': 0.11169687844111208, 'numCanDocs': 0.00013250682628114562, 'maxTopColPCor': 0.049384102195983985, 'expTDocScore': 0.011361051124610085, 'avgColPCor': 0.051968116604426115, 'maxCDocScore': 0.084948836915212683, 'avgTopColPCor': 0.054789753743793849, 'maxColCor': 0.022971838299075266}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2040
#
# featureWeights = {'maxTopColCor': 0.093673712982301108, 'maxColPCor': 0.10504402067406592, 'conIdf': 0.0290024646900718, 'avgCDocScore': 0.01525992478399618, 'topTermFrac': 0.053532963946834343, 'avgColCor': 0.072646969113655716, 'avgTopColCor': 0.088209590538206095, 'numCanDocs': 0.11290474105516357, 'maxTopColPCor': 0.10746542260525141, 'expTDocScore': 0.023858769245957683, 'avgColPCor': 0.0095025031079287951, 'maxCDocScore': 0.056298391331440475, 'avgTopColPCor': 0.10967404737602267, 'maxColCor': 0.12292647854910417}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2044
#
# featureWeights = {'maxTopColCor': 0.13053292040808087, 'maxColPCor': 0.0059828883704846781, 'conIdf': 0.14986201674995886, 'avgCDocScore': 0.067095900073861625, 'topTermFrac': 0.033345902144559639, 'avgColCor': 0.0017190127981438477, 'avgTopColCor': 0.078160809504704581, 'numCanDocs': 0.0016593513975969665, 'maxTopColPCor': 0.13213079864664323, 'expTDocScore': 0.1110059319457968, 'avgColPCor': 0.030342728652982699, 'maxCDocScore': 0.14493728572654863, 'avgTopColPCor': 0.061730066949350536, 'maxColCor': 0.051494386631287123}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2049
#
# featureWeights = {'maxTopColCor': 0.014746537987451284, 'maxColPCor': 0.08195640537516255, 'conIdf': 0.1166968212830002, 'avgCDocScore': 0.068228910934781423, 'topTermFrac': 0.025011038850030396, 'avgColCor': 0.079495293674654924, 'avgTopColCor': 0.14588930118895901, 'numCanDocs': 0.11688109982880188, 'maxTopColPCor': 0.088909023580396929, 'expTDocScore': 0.072793468309324011, 'avgColPCor': 0.077367498092901638, 'maxCDocScore': 0.071574125079892317, 'avgTopColPCor': 0.035228314109066461, 'maxColCor': 0.0052221617055769765}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2040
#
# featureWeights = {'maxTopColCor': 0.1272165251126329, 'maxColPCor': 0.041352544542309751, 'conIdf': 0.12306802055099135, 'avgCDocScore': 0.012359261481555752, 'topTermFrac': 0.12362102195504371, 'avgColCor': 0.080987624816698314, 'avgTopColCor': 0.090613533147943556, 'numCanDocs': 0.0087412843057684264, 'maxTopColPCor': 0.074921053982040534, 'expTDocScore': 0.031030941803340623, 'avgColPCor': 0.12119336880983281, 'maxCDocScore': 0.042671635655873744, 'avgTopColPCor': 0.10662119019966328, 'maxColCor': 0.015601993636305123}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2050
#
# featureWeights = {'maxTopColCor': 0.059482303959399727, 'maxColPCor': 0.11659451824564852, 'conIdf': 0.0055446738806038268, 'avgCDocScore': 0.090619058233289168, 'topTermFrac': 0.10276369612944623, 'avgColCor': 0.12802145356709899, 'avgTopColCor': 0.024550885255727812, 'numCanDocs': 0.047183912061913837, 'maxTopColPCor': 0.038629288004834797, 'expTDocScore': 0.058865208027133638, 'avgColPCor': 0.033915204197304379, 'maxCDocScore': 0.11872999005299156, 'avgTopColPCor': 0.11901715424414638, 'maxColCor': 0.056082654140460965}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2052
#
# featureWeights = {'maxTopColCor': 0.061599191139805977, 'maxColPCor': 0.12220651302679433, 'conIdf': 0.075127842491370875, 'avgCDocScore': 0.044991317624270243, 'topTermFrac': 0.096377264210135538, 'avgColCor': 0.068888685237240274, 'avgTopColCor': 0.07995291059082224, 'numCanDocs': 0.066914635550639534, 'maxTopColPCor': 0.05827795628579556, 'expTDocScore': 0.089804091780264994, 'avgColPCor': 0.07239220604262557, 'maxCDocScore': 0.028025164920274875, 'avgTopColPCor': 0.036992552686295012, 'maxColCor': 0.098449668413664884}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2046
#
# featureWeights = {'maxTopColCor': 0.076411504349203019, 'maxColPCor': 0.019911983693011632, 'conIdf': 0.055241243324627182, 'avgCDocScore': 0.042225559288501767, 'topTermFrac': 0.084715720076496859, 'avgColCor': 0.069728233240425333, 'avgTopColCor': 0.03377668732073081, 'numCanDocs': 0.097243552722795737, 'maxTopColPCor': 0.12789452171263629, 'expTDocScore': 0.029018396224286726, 'avgColPCor': 0.10070224726508216, 'maxCDocScore': 0.067488334606022479, 'avgTopColPCor': 0.081269289459000915, 'maxColCor': 0.11437272671717925}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2048
#
# featureWeights = {'maxTopColCor': 0.11523257735545384, 'maxColPCor': 0.10417203878214597, 'conIdf': 0.106560131867963, 'avgCDocScore': 0.04097118774740139, 'topTermFrac': 0.051103798170886568, 'avgColCor': 0.099704331553169837, 'avgTopColCor': 0.037949703289264718, 'numCanDocs': 0.021270047154984567, 'maxTopColPCor': 0.10622549422721268, 'expTDocScore': 0.10019182507685295, 'avgColPCor': 0.072859963683581955, 'maxCDocScore': 0.064634259282571938, 'avgTopColPCor': 0.012858090301754792, 'maxColCor': 0.066266551506755741}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2029
#
# featureWeights = {'maxTopColCor': 0.063513410285421165, 'maxColPCor': 0.044755567620474959, 'conIdf': 0.10466172172931554, 'avgCDocScore': 0.10644172070390193, 'topTermFrac': 0.056411426185220673, 'avgColCor': 0.0023419763611356864, 'avgTopColCor': 0.12030456413600342, 'numCanDocs': 0.034106796804216799, 'maxTopColPCor': 0.084588958858242552, 'expTDocScore': 0.059261568663611437, 'avgColPCor': 0.07739917266050772, 'maxCDocScore': 0.057380471201321948, 'avgTopColPCor': 0.067571318957446128, 'maxColCor': 0.12126132583317999}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2044
#
# featureWeights = {'maxTopColCor': 0.071556181719371587, 'maxColPCor': 0.077410099098928986, 'conIdf': 0.066567457817513498, 'avgCDocScore': 0.076018735419504588, 'topTermFrac': 0.079632018561588441, 'avgColCor': 0.085536511277622573, 'avgTopColCor': 0.018698861884043915, 'numCanDocs': 0.0246212719081484, 'maxTopColPCor': 0.08741913178612, 'expTDocScore': 0.030648244709193306, 'avgColPCor': 0.056955334424960272, 'maxCDocScore': 0.089236512843918564, 'avgTopColPCor': 0.10872384270589548, 'maxColCor': 0.12697579584319049}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2049
#
# featureWeights = {'maxTopColCor': 0.063379848665917948, 'maxColPCor': 0.1250450687673714, 'conIdf': 0.028061114991069218, 'avgCDocScore': 0.065792364879708409, 'topTermFrac': 0.12712213038011708, 'avgColCor': 0.059680393315631471, 'avgTopColCor': 0.043434841651425006, 'numCanDocs': 0.094066678207736745, 'maxTopColPCor': 0.10610410065627333, 'expTDocScore': 0.10526608499399702, 'avgColPCor': 0.03211047512082521, 'maxCDocScore': 0.027109137325056772, 'avgTopColPCor': 0.10826786283203389, 'maxColCor': 0.014559898212836665}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2054
#
# featureWeights = {'maxTopColCor': 0.16679695710542042, 'maxColPCor': 0.10479800181964806, 'conIdf': 0.07734688873200897, 'avgCDocScore': 0.00588242212936023, 'topTermFrac': 0.071815916902706542, 'avgColCor': 0.010818792983769809, 'avgTopColCor': 0.048048848760917182, 'numCanDocs': 0.094696950827739615, 'maxTopColPCor': 0.010088276617741823, 'expTDocScore': 0.060779006195180528, 'avgColPCor': 0.12128709776886752, 'maxCDocScore': 0.087290834040933879, 'avgTopColPCor': 0.0028562283861656395, 'maxColCor': 0.13749377772953988}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2032
#
# featureWeights = {'maxTopColCor': 0.093475538920088697, 'maxColPCor': 0.044460030607354643, 'conIdf': 0.076663961259753527, 'avgCDocScore': 0.010205210930921369, 'topTermFrac': 0.048563716004752726, 'avgColCor': 0.15359001911413361, 'avgTopColCor': 0.13185332070859782, 'numCanDocs': 0.019173307026193832, 'maxTopColPCor': 0.080364120154349794, 'expTDocScore': 0.1498302641180162, 'avgColPCor': 0.026625710028535358, 'maxCDocScore': 0.020679168767448863, 'avgTopColPCor': 0.039338071547279113, 'maxColCor': 0.10517756081257439}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2029
#
# featureWeights = {'maxTopColCor': 0.14066636396023538, 'maxColPCor': 0.09737653091704411, 'conIdf': 0.11262721041359976, 'avgCDocScore': 0.016872346414786948, 'topTermFrac': 0.057496840535562914, 'avgColCor': 0.0057093063079637048, 'avgTopColCor': 0.10971092547771583, 'numCanDocs': 0.040741861791961854, 'maxTopColPCor': 0.035999567635104174, 'expTDocScore': 0.016594448231132146, 'avgColPCor': 0.03976948773219631, 'maxCDocScore': 0.095952286614207932, 'avgTopColPCor': 0.12936131857415606, 'maxColCor': 0.10112150539433289}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2050
#
# featureWeights = {'maxTopColCor': 0.045492307770449998, 'maxColPCor': 0.078242611624072464, 'conIdf': 0.10935092859459002, 'avgCDocScore': 0.068852245692825442, 'topTermFrac': 0.072393639755678002, 'avgColCor': 0.049151113183122611, 'avgTopColCor': 0.1136250358284857, 'numCanDocs': 0.0017743072140567354, 'maxTopColPCor': 0.072036678128228393, 'expTDocScore': 0.088459681501984355, 'avgColPCor': 0.13135621755335208, 'maxCDocScore': 0.099974489087407067, 'avgTopColPCor': 0.052554185700478658, 'maxColCor': 0.016736558365268477}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2048
#
# featureWeights = {'maxTopColCor': 0.097607301145414174, 'maxColPCor': 0.063390027003054197, 'conIdf': 0.14300361047427537, 'avgCDocScore': 0.088806351312066378, 'topTermFrac': 0.14542374824104481, 'avgColCor': 0.11695810861346573, 'avgTopColCor': 0.13333858552058689, 'numCanDocs': 0.064404291727890861, 'maxTopColPCor': 0.0098688995520330031, 'expTDocScore': 0.020320637486348513, 'avgColPCor': 0.064571920160024401, 'maxCDocScore': 0.023967732802005579, 'avgTopColPCor': 0.023298364052649369, 'maxColCor': 0.0050404219091407798}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2048
#
# featureWeights = {'maxTopColCor': 0.12985695979903422, 'maxColPCor': 0.13947225866673257, 'conIdf': 0.14443276124372692, 'avgCDocScore': 0.10051346583596325, 'topTermFrac': 0.018294387594657988, 'avgColCor': 0.1113978606351724, 'avgTopColCor': 0.075413573343434556, 'numCanDocs': 0.013018762124687959, 'maxTopColPCor': 0.068783770739712591, 'expTDocScore': 0.018068143204109984, 'avgColPCor': 0.09016509666340812, 'maxCDocScore': 0.0016409464246879019, 'avgTopColPCor': 0.05461448107713044, 'maxColCor': 0.034327532647541154}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2037
#
# featureWeights = {'maxTopColCor': 0.13888750385249299, 'maxColPCor': 0.13571529335744065, 'conIdf': 0.044395655338275539, 'avgCDocScore': 0.11664819232942465, 'topTermFrac': 0.069291346722267166, 'avgColCor': 0.0071923088030535435, 'avgTopColCor': 0.004400952605112452, 'numCanDocs': 0.14174250353802298, 'maxTopColPCor': 0.15911991279913204, 'expTDocScore': 0.0043984500122083627, 'avgColPCor': 0.02402249424759707, 'maxCDocScore': 0.059027478070171467, 'avgTopColPCor': 0.068813671115177305, 'maxColCor': 0.026344237209623887}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2039
#
# featureWeights = {'maxTopColCor': 0.021308781199274832, 'maxColPCor': 0.12514989792152778, 'conIdf': 0.13608873654376422, 'avgCDocScore': 0.12502239053881922, 'topTermFrac': 0.10115356435624621, 'avgColCor': 0.0097867496895381687, 'avgTopColCor': 0.083216330656415663, 'numCanDocs': 0.091164291691125596, 'maxTopColPCor': 0.10301281323378672, 'expTDocScore': 0.012011614416164662, 'avgColPCor': 0.091567698250139967, 'maxCDocScore': 0.0012949295011854727, 'avgTopColPCor': 0.074609366742157748, 'maxColCor': 0.024612835259853826}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2048
#
# featureWeights = {'maxTopColCor': 0.093963908977337196, 'maxColPCor': 0.032600429100023101, 'conIdf': 0.096696100088604381, 'avgCDocScore': 0.030872113826691777, 'topTermFrac': 0.10685067917653683, 'avgColCor': 0.11461079646076075, 'avgTopColCor': 0.072435901785480608, 'numCanDocs': 0.071266338612096733, 'maxTopColPCor': 0.087909740582224616, 'expTDocScore': 0.058378245104691757, 'avgColPCor': 0.010411622508418627, 'maxCDocScore': 0.038519674492334642, 'avgTopColPCor': 0.097951950930942083, 'maxColCor': 0.087532498353856847}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2054
#
# featureWeights = {'maxTopColCor': 0.018559330057952517, 'maxColPCor': 0.081017258647989907, 'conIdf': 0.091265651249327881, 'avgCDocScore': 0.060457693492443294, 'topTermFrac': 0.048355235494163998, 'avgColCor': 0.010622932254593645, 'avgTopColCor': 0.10949312013945436, 'numCanDocs': 0.069352944640584016, 'maxTopColPCor': 0.018090807581930358, 'expTDocScore': 0.088820090358865789, 'avgColPCor': 0.10637615379398795, 'maxCDocScore': 0.13903982597560557, 'avgTopColPCor': 0.12763473859735713, 'maxColCor': 0.030914217715743719}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2045
#
# featureWeights = {'maxTopColCor': 0.084016319392945057, 'maxColPCor': 0.12806380342033535, 'conIdf': 0.14343207757640139, 'avgCDocScore': 0.010868163198475715, 'topTermFrac': 0.041285722095465299, 'avgColCor': 0.044409013022866484, 'avgTopColCor': 0.068173515472366303, 'numCanDocs': 0.15215909032102859, 'maxTopColPCor': 0.05160331611307898, 'expTDocScore': 0.1084533219155602, 'avgColPCor': 0.090044815988860757, 'maxCDocScore': 0.021512598913880264, 'avgTopColPCor': 0.020177240878477685, 'maxColCor': 0.035801001690258065}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2043
#
# featureWeights = {'maxTopColCor': 0.06793362211809767, 'maxColPCor': 0.041591330964823585, 'conIdf': 0.0014249889874392734, 'avgCDocScore': 0.15794715022937789, 'topTermFrac': 0.12651344457371377, 'avgColCor': 0.094824359545682094, 'avgTopColCor': 0.027516741531077159, 'numCanDocs': 0.0049774600661043689, 'maxTopColPCor': 0.018274083616178272, 'expTDocScore': 0.13183415690650466, 'avgColPCor': 0.10815208510623821, 'maxCDocScore': 0.15021537689493056, 'avgTopColPCor': 0.066809215863199906, 'maxColCor': 0.001985983596632674}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2043
#
# featureWeights = {'maxTopColCor': 0.1029055134969161, 'maxColPCor': 0.10296572926640195, 'conIdf': 0.053285068291204836, 'avgCDocScore': 0.022099499827005705, 'topTermFrac': 0.060314743847755863, 'avgColCor': 0.10476070264419322, 'avgTopColCor': 0.025029475627999634, 'numCanDocs': 0.07438805393712114, 'maxTopColPCor': 0.050649701507796636, 'expTDocScore': 0.029250885946769025, 'avgColPCor': 0.1213577488561117, 'maxCDocScore': 0.12615707493198428, 'avgTopColPCor': 0.066068827334895386, 'maxColCor': 0.060766974483844473}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2031
#
# featureWeights = {'maxTopColCor': 0.072521507797152565, 'maxColPCor': 0.046877369170473922, 'conIdf': 0.039227674490927657, 'avgCDocScore': 0.067386418651811719, 'topTermFrac': 0.075297549060313579, 'avgColCor': 0.10406369576139059, 'avgTopColCor': 0.094208842123464309, 'numCanDocs': 0.065983204993807845, 'maxTopColPCor': 0.099708234221332417, 'expTDocScore': 0.090284687049458884, 'avgColPCor': 0.029474459197230202, 'maxCDocScore': 0.096500594006417847, 'avgTopColPCor': 0.091381174138626842, 'maxColCor': 0.027084589337591444}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2050
#
# featureWeights = {'maxTopColCor': 0.052066168071075322, 'maxColPCor': 0.13526106766594623, 'conIdf': 0.046915401462708811, 'avgCDocScore': 0.13078363393188991, 'topTermFrac': 0.11817899396236176, 'avgColCor': 0.020194115602145134, 'avgTopColCor': 0.020657249924216466, 'numCanDocs': 0.036013296288486076, 'maxTopColPCor': 0.071885695607139144, 'expTDocScore': 0.047240346972240548, 'avgColPCor': 0.13955461882416467, 'maxCDocScore': 0.031799183818827688, 'avgTopColPCor': 0.087969915590210848, 'maxColCor': 0.061480312278587364}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2047
#
# featureWeights = {'maxTopColCor': 0.038955469362986862, 'maxColPCor': 0.034235552342862817, 'conIdf': 0.023423160286039423, 'avgCDocScore': 0.087454138980552973, 'topTermFrac': 0.035259218465150538, 'avgColCor': 0.10567188028226931, 'avgTopColCor': 0.087957135040864498, 'numCanDocs': 0.049776286598455899, 'maxTopColPCor': 0.13822316774100601, 'expTDocScore': 0.11001024375524458, 'avgColPCor': 0.052443267924487454, 'maxCDocScore': 0.10507620949513752, 'avgTopColPCor': 0.10679875035726674, 'maxColCor': 0.024715519367675479}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2041
#
# featureWeights = {'maxTopColCor': 0.013172774768051558, 'maxColPCor': 0.065375826373064147, 'conIdf': 0.056020315232540988, 'avgCDocScore': 0.026957044907382918, 'topTermFrac': 0.12363334364772335, 'avgColCor': 0.081972781540225553, 'avgTopColCor': 0.070549268037859686, 'numCanDocs': 0.02614890159729872, 'maxTopColPCor': 0.062059107661673572, 'expTDocScore': 0.11119884789238969, 'avgColPCor': 0.15540917176809424, 'maxCDocScore': 0.14298451242329807, 'avgTopColPCor': 0.043210370866213085, 'maxColCor': 0.021307733284184557}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2052
#
# featureWeights = {'maxTopColCor': 0.0016725780216089944, 'maxColPCor': 0.014581728790660253, 'conIdf': 0.073538313821935097, 'avgCDocScore': 0.14118461648271788, 'topTermFrac': 0.078255913564338586, 'avgColCor': 0.1040071251927633, 'avgTopColCor': 0.0056811661766100153, 'numCanDocs': 0.11768054002773935, 'maxTopColPCor': 0.046979461358085783, 'expTDocScore': 0.088179471413300473, 'avgColPCor': 0.064808007053772168, 'maxCDocScore': 0.099516831153142291, 'avgTopColPCor': 0.12889506301507528, 'maxColCor': 0.035019183928250507}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2047
#
# featureWeights = {'maxTopColCor': 0.034691321351710845, 'maxColPCor': 0.10337248001641999, 'conIdf': 0.062373584644209765, 'avgCDocScore': 0.0210759045553039, 'topTermFrac': 0.10285462968400301, 'avgColCor': 0.12366426586205272, 'avgTopColCor': 0.0522303329699738, 'numCanDocs': 0.089478954928922078, 'maxTopColPCor': 0.040918521381402256, 'expTDocScore': 0.14026388116492119, 'avgColPCor': 0.016117816702074753, 'maxCDocScore': 0.034366622720687481, 'avgTopColPCor': 0.12787006106385754, 'maxColCor': 0.050721622954460907}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2053
#
# featureWeights = {'maxTopColCor': 0.1424772613338344, 'maxColPCor': 0.07456778854765693, 'conIdf': 0.036658915562997517, 'avgCDocScore': 0.02604056362856107, 'topTermFrac': 0.15201889037458344, 'avgColCor': 0.037266116304403817, 'avgTopColCor': 0.12645746550928158, 'numCanDocs': 0.0043178439587740428, 'maxTopColPCor': 0.017472879046885367, 'expTDocScore': 0.15180955888503161, 'avgColPCor': 0.017126836588350642, 'maxCDocScore': 0.061688721640165693, 'avgTopColPCor': 0.018048316540980821, 'maxColCor': 0.13404884207849305}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2053
#
# featureWeights = {'maxTopColCor': 0.15808608253079826, 'maxColPCor': 0.030601403693257409, 'conIdf': 0.12405953331265962, 'avgCDocScore': 0.014216122777125853, 'topTermFrac': 0.068872664421931712, 'avgColCor': 0.0078949146842732711, 'avgTopColCor': 0.084556327818343116, 'numCanDocs': 0.044429143521176863, 'maxTopColPCor': 0.029107445966342987, 'expTDocScore': 0.047717034080000498, 'avgColPCor': 0.15599905829445912, 'maxCDocScore': 0.039288098272220663, 'avgTopColPCor': 0.13547108294676566, 'maxColCor': 0.059701087680644992}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2047
#
# ...
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2039
#
# featureWeights = {'maxTopColCor': 0.13806123651553337, 'maxColPCor': 0.060007278179995217, 'conIdf': 0.021151504865493675, 'avgCDocScore': 0.084972667842890648, 'topTermFrac': 0.10403574052423384, 'avgColCor': 0.037265245556040542, 'avgTopColCor': 0.037942474831236001, 'numCanDocs': 0.052257767866809454, 'maxTopColPCor': 0.05659742469692601, 'expTDocScore': 0.0037057664727573403, 'avgColPCor': 0.085302842824367092, 'maxCDocScore': 0.1201913860204236, 'avgTopColPCor': 0.1141745123054641, 'maxColCor': 0.084334151497828982}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2051
#
# featureWeights = {'maxTopColCor': 0.13125746752082099, 'maxColPCor': 0.071220338145954867, 'conIdf': 0.12859331241289929, 'avgCDocScore': 0.0038620852869659292, 'topTermFrac': 0.052279267610838072, 'avgColCor': 0.11328074233275733, 'avgTopColCor': 0.080447829884008892, 'numCanDocs': 0.017178622162619148, 'maxTopColPCor': 0.0040589128521636968, 'expTDocScore': 0.07939703635065215, 'avgColPCor': 0.085076062734900454, 'maxCDocScore': 0.060893089631029615, 'avgTopColPCor': 0.094973960219570927, 'maxColCor': 0.077481272854818747}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2039
#
# featureWeights = {'maxTopColCor': 0.046805690582351456, 'maxColPCor': 0.046271706255525999, 'conIdf': 0.054238252869285963, 'avgCDocScore': 0.021737455227214372, 'topTermFrac': 0.15000562551963065, 'avgColCor': 0.10699192844995126, 'avgTopColCor': 0.11309824312729318, 'numCanDocs': 0.013743904655370939, 'maxTopColPCor': 0.025419349216133452, 'expTDocScore': 0.13262384920531164, 'avgColPCor': 0.082500599916159073, 'maxCDocScore': 0.079839782607626752, 'avgTopColPCor': 0.063670632630264026, 'maxColCor': 0.063052979737881126}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2050
#
# featureWeights = {'maxTopColCor': 0.059712728394258632, 'maxColPCor': 0.098310110908310627, 'conIdf': 0.055890623644116656, 'avgCDocScore': 0.0045494277169344875, 'topTermFrac': 0.14788301305247464, 'avgColCor': 0.064534503621562905, 'avgTopColCor': 0.028657736817131081, 'numCanDocs': 0.097195030375052713, 'maxTopColPCor': 0.025869763341182819, 'expTDocScore': 0.0090920431483125959, 'avgColPCor': 0.04178406459920328, 'maxCDocScore': 0.11154853235671551, 'avgTopColPCor': 0.15826511329417831, 'maxColCor': 0.09670730873056585}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2053
#
# featureWeights = {'maxTopColCor': 0.10079779182510694, 'maxColPCor': 0.079100628068448933, 'conIdf': 0.044360583199608367, 'avgCDocScore': 0.016880218909555426, 'topTermFrac': 0.019251818990554195, 'avgColCor': 0.0012295795356845603, 'avgTopColCor': 0.10486312984477138, 'numCanDocs': 0.096771882540999082, 'maxTopColPCor': 0.10769342516463283, 'expTDocScore': 0.14699579947313585, 'avgColPCor': 0.035354282248427744, 'maxCDocScore': 0.030630343169431411, 'avgTopColPCor': 0.084445060654887882, 'maxColCor': 0.13162545637475534}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2045
#
# featureWeights = {'maxTopColCor': 0.071687378024390125, 'maxColPCor': 0.052784145403988077, 'conIdf': 0.090836908923287912, 'avgCDocScore': 0.024396079928285786, 'topTermFrac': 0.073273056487019317, 'avgColCor': 0.10290882525443946, 'avgTopColCor': 0.04226354460534526, 'numCanDocs': 0.028537286808532361, 'maxTopColPCor': 0.090429680313737423, 'expTDocScore': 0.076830109628705165, 'avgColPCor': 0.098159766074340779, 'maxCDocScore': 0.052018760286812203, 'avgTopColPCor': 0.099586103673694248, 'maxColCor': 0.096288354587421784}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2041
#
# featureWeights = {'maxTopColCor': 0.014603090991060309, 'maxColPCor': 0.12717264666504965, 'conIdf': 0.10557959640708393, 'avgCDocScore': 0.10351930033524534, 'topTermFrac': 0.0048508362490265146, 'avgColCor': 0.050198648442480065, 'avgTopColCor': 0.10404137362854889, 'numCanDocs': 0.09663712590562977, 'maxTopColPCor': 0.0089466315350200908, 'expTDocScore': 0.056521108114214097, 'avgColPCor': 0.15691800545141074, 'maxCDocScore': 0.00083948283733815499, 'avgTopColPCor': 0.078925615875595878, 'maxColCor': 0.091246537562296504}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2033
#
# featureWeights = {'maxTopColCor': 0.065673177275894071, 'maxColPCor': 0.015647271099531748, 'conIdf': 0.094764979392359089, 'avgCDocScore': 0.10259555718505019, 'topTermFrac': 0.12159897828882245, 'avgColCor': 0.030132787085960296, 'avgTopColCor': 0.075562847864144481, 'numCanDocs': 0.048426123292916276, 'maxTopColPCor': 0.13717583512766859, 'expTDocScore': 0.090715995710260053, 'avgColPCor': 0.056141047028755046, 'maxCDocScore': 0.10149887877758317, 'avgTopColPCor': 0.030817231199028104, 'maxColCor': 0.029249290672026522}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2053
#
# featureWeights = {'maxTopColCor': 0.15882748869324151, 'maxColPCor': 0.005296035519078526, 'conIdf': 0.0076805469437545189, 'avgCDocScore': 0.034691011198188675, 'topTermFrac': 0.13348559081859304, 'avgColCor': 0.011885602138028282, 'avgTopColCor': 0.047177590483535752, 'numCanDocs': 0.047372593124661189, 'maxTopColPCor': 0.1440121434259333, 'expTDocScore': 0.014740943719571967, 'avgColPCor': 0.16060251477336462, 'maxCDocScore': 0.066677399427855291, 'avgTopColPCor': 0.10815434590501632, 'maxColCor': 0.059396193829176998}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2052
#
# featureWeights = {'maxTopColCor': 0.045222417433474292, 'maxColPCor': 0.077524316417238004, 'conIdf': 0.13590082534007689, 'avgCDocScore': 0.0039101914210638924, 'topTermFrac': 0.014661946966467833, 'avgColCor': 0.025227797502503313, 'avgTopColCor': 0.016291507803235336, 'numCanDocs': 0.090224484164350222, 'maxTopColPCor': 0.10803381398680642, 'expTDocScore': 0.1191262199332922, 'avgColPCor': 0.13268156782827334, 'maxCDocScore': 0.062164497862747109, 'avgTopColPCor': 0.034954780269011873, 'maxColCor': 0.13407563307145903}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2022
#
# featureWeights = {'maxTopColCor': 0.10591576021405323, 'maxColPCor': 0.10608523869545478, 'conIdf': 0.011103914746004378, 'avgCDocScore': 0.0029140008208783734, 'topTermFrac': 0.068628849483662782, 'avgColCor': 0.10673349311206656, 'avgTopColCor': 0.088645921259110555, 'numCanDocs': 0.0071847354602521526, 'maxTopColPCor': 0.11405395221182246, 'expTDocScore': 0.0047229193499525018, 'avgColPCor': 0.12250053741508771, 'maxCDocScore': 0.12116558358089342, 'avgTopColPCor': 0.039582388735481068, 'maxColCor': 0.10076270491527999}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2031
#
# featureWeights = {'maxTopColCor': 0.010189465909372157, 'maxColPCor': 0.11185380242417937, 'conIdf': 0.1402707642961801, 'avgCDocScore': 0.092268732163875725, 'topTermFrac': 0.035837248136803966, 'avgColCor': 0.12186313617639208, 'avgTopColCor': 0.12753006380003368, 'numCanDocs': 0.034832254790988518, 'maxTopColPCor': 0.0072006702835162133, 'expTDocScore': 0.095334511445961348, 'avgColPCor': 0.070844194691854906, 'maxCDocScore': 0.087341557512949239, 'avgTopColPCor': 0.025347219781965098, 'maxColCor': 0.039286378585927574}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2042
#
# featureWeights = {'maxTopColCor': 0.023160667295201116, 'maxColPCor': 0.12395110718823606, 'conIdf': 0.071469813638922769, 'avgCDocScore': 0.011875760356440748, 'topTermFrac': 0.055057611064412766, 'avgColCor': 0.107473725495476, 'avgTopColCor': 0.064899160483226401, 'numCanDocs': 0.11866062443191688, 'maxTopColPCor': 0.11651371996249417, 'expTDocScore': 0.020122990731554644, 'avgColPCor': 0.084854377158949459, 'maxCDocScore': 0.082200394434957344, 'avgTopColPCor': 0.10769979261546675, 'maxColCor': 0.012060255142744988}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2045
#
# featureWeights = {'maxTopColCor': 0.094865979030415576, 'maxColPCor': 0.084830749161870639, 'conIdf': 0.12037603933330469, 'avgCDocScore': 0.082583774602431881, 'topTermFrac': 0.083159064184413753, 'avgColCor': 0.072523350929260058, 'avgTopColCor': 0.069741115943098966, 'numCanDocs': 0.047759358393692823, 'maxTopColPCor': 0.097880219104760663, 'expTDocScore': 0.083135658448511007, 'avgColPCor': 0.0061529680134414259, 'maxCDocScore': 0.046140700668921467, 'avgTopColPCor': 0.10772445403352193, 'maxColCor': 0.0031265681523548832}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2054
#
# featureWeights = {'maxTopColCor': 0.10455516731374612, 'maxColPCor': 0.080682618781554472, 'conIdf': 0.09816525140714312, 'avgCDocScore': 0.11318955250385568, 'topTermFrac': 0.060992015193965111, 'avgColCor': 0.020119009483478514, 'avgTopColCor': 0.078226171240829215, 'numCanDocs': 0.09769198667788849, 'maxTopColPCor': 0.032433257965114259, 'expTDocScore': 0.088179789628362731, 'avgColPCor': 0.093688211826025991, 'maxCDocScore': 0.0083316353458903515, 'avgTopColPCor': 0.095708084679505423, 'maxColCor': 0.028037247952640541}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2046
#
# featureWeights = {'maxTopColCor': 0.041572005524790276, 'maxColPCor': 0.10364717339649758, 'conIdf': 0.082851015829438449, 'avgCDocScore': 0.029610998250579376, 'topTermFrac': 0.069189456761230297, 'avgColCor': 0.049113477172231544, 'avgTopColCor': 0.10333129894801882, 'numCanDocs': 0.059510868566186828, 'maxTopColPCor': 0.086576670032648656, 'expTDocScore': 0.056361974111585098, 'avgColPCor': 0.076264915907860331, 'maxCDocScore': 0.079197472618440942, 'avgTopColPCor': 0.055864400507307461, 'maxColCor': 0.10690827237318455}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2047
#
# featureWeights = {'maxTopColCor': 0.064989738670110903, 'maxColPCor': 0.13569844410099161, 'conIdf': 0.024190295036692792, 'avgCDocScore': 0.12350009727232912, 'topTermFrac': 0.08511402332453219, 'avgColCor': 0.096301288706316046, 'avgTopColCor': 0.13105106801507943, 'numCanDocs': 0.1340742444254642, 'maxTopColPCor': 0.015960865857196048, 'expTDocScore': 0.019620223217514894, 'avgColPCor': 0.017769522323051339, 'maxCDocScore': 0.010246382988140462, 'avgTopColPCor': 0.11930861427601379, 'maxColCor': 0.022175191786567162}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2046
#
# featureWeights = {'maxTopColCor': 0.010396069857367827, 'maxColPCor': 0.17425344638696533, 'conIdf': 0.13449008837302517, 'avgCDocScore': 0.10903994162953601, 'topTermFrac': 0.012471635768678086, 'avgColCor': 0.13157937822398749, 'avgTopColCor': 0.16289842348335401, 'numCanDocs': 0.041373093760150116, 'maxTopColPCor': 0.0021166116734494295, 'expTDocScore': 0.0087963992394615182, 'avgColPCor': 0.0037929932769634237, 'maxCDocScore': 0.086149402183833421, 'avgTopColPCor': 0.10841459151506307, 'maxColCor': 0.014227924628165084}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2042
#
# featureWeights = {'maxTopColCor': 0.10584513287425087, 'maxColPCor': 0.062662028051954172, 'conIdf': 0.051618041403787007, 'avgCDocScore': 0.09824221961566805, 'topTermFrac': 0.087492374510527313, 'avgColCor': 0.11361622182867027, 'avgTopColCor': 0.10466990235399672, 'numCanDocs': 0.019684095608032862, 'maxTopColPCor': 0.098321557376774907, 'expTDocScore': 0.040255826837627344, 'avgColPCor': 0.015321704470801265, 'maxCDocScore': 0.046442050682303213, 'avgTopColPCor': 0.10449521614652692, 'maxColCor': 0.051333628239079096}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2050
#
# featureWeights = {'maxTopColCor': 0.038780944106776502, 'maxColPCor': 0.094245216343875282, 'conIdf': 0.09678443104500789, 'avgCDocScore': 0.022730586666419753, 'topTermFrac': 0.09911003880662049, 'avgColCor': 0.024711402667411772, 'avgTopColCor': 0.075608933548271529, 'numCanDocs': 0.1382453058590653, 'maxTopColPCor': 0.045851029414924103, 'expTDocScore': 0.11021897439082211, 'avgColPCor': 0.058543449466187544, 'maxCDocScore': 0.029833483078039978, 'avgTopColPCor': 0.14693973629914256, 'maxColCor': 0.018396468307435195}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2050
#
# featureWeights = {'maxTopColCor': 0.028879397037395709, 'maxColPCor': 0.072619282078120531, 'conIdf': 0.074501325184415337, 'avgCDocScore': 0.09900715781863742, 'topTermFrac': 0.016403908644605131, 'avgColCor': 0.071566209368972844, 'avgTopColCor': 0.097097833351814558, 'numCanDocs': 0.040342832757373298, 'maxTopColPCor': 0.094490944965312032, 'expTDocScore': 0.1024081296680333, 'avgColPCor': 0.097336554416305066, 'maxCDocScore': 0.06236134772118445, 'avgTopColPCor': 0.084426338225727676, 'maxColCor': 0.058558738762102498}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2039
#
# featureWeights = {'maxTopColCor': 0.11813324960258129, 'maxColPCor': 0.049630680399001488, 'conIdf': 0.064612943326408281, 'avgCDocScore': 0.083781617825398183, 'topTermFrac': 0.10222783961736341, 'avgColCor': 0.035460612772007724, 'avgTopColCor': 0.11625715953970218, 'numCanDocs': 0.036846902067645286, 'maxTopColPCor': 0.12919221563948338, 'expTDocScore': 0.050340874224150615, 'avgColPCor': 0.0023174545368645455, 'maxCDocScore': 0.0036821185861764935, 'avgTopColPCor': 0.09637781126621095, 'maxColCor': 0.11113852059700616}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2053
#
# featureWeights = {'maxTopColCor': 0.023281078547488381, 'maxColPCor': 0.042954963882383408, 'conIdf': 0.079100004168896593, 'avgCDocScore': 0.085159125212290909, 'topTermFrac': 0.11610209966590453, 'avgColCor': 0.059254906928622071, 'avgTopColCor': 0.10030411756738621, 'numCanDocs': 0.029073494135331678, 'maxTopColPCor': 0.05036781155607753, 'expTDocScore': 0.053288368958451765, 'avgColPCor': 0.10085821214850485, 'maxCDocScore': 0.04688628738331857, 'avgTopColPCor': 0.075139317564081515, 'maxColCor': 0.13823021228126203}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2055
#
# featureWeights = {'maxTopColCor': 0.12550554408288417, 'maxColPCor': 0.1661993932202348, 'conIdf': 0.15854195181735545, 'avgCDocScore': 0.11215331678185819, 'topTermFrac': 0.14124057898562528, 'avgColCor': 0.091137815252782473, 'avgTopColCor': 0.023040835734078301, 'numCanDocs': 0.0021212127613872553, 'maxTopColPCor': 0.061203187383168219, 'expTDocScore': 0.0071271252584351637, 'avgColPCor': 0.055978069409999491, 'maxCDocScore': 0.010625271710036369, 'avgTopColPCor': 0.038771375437148668, 'maxColCor': 0.0063543221650061606}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.5 0.5 20 0 1600 100 0.2046
#
# featureWeights =

# %%
"""
dist = str(2)
intCoeffs0 = [ 0.7 ]
intCoeffs1 = [ 0.5 ]
#intCoeffs2 = [ 0.18 ]
intCoeffs2 = [ 0.5 ]
#intCoeffs1 = np.arange(0.1, 1, 0.1)
expansionCounts1 = [ 10 ]
#expansionCounts2 = [ 145 ]
expansionCounts2 = [ 0 ]
#expansionCounts2 = range(15, 220, 5)
dirCoeffs = [ 1600 ]
#dirCoeffs = range(200, 4000, 200)
N1s = 2
N2s_max = [100]
rWords = dict()
featureWeights_1 = {'maxTopColCor': 0.1, 'expTDocScore': 0.1, 'maxColPCor': 0.1, 'avgCDocScore': 0.1, 'topTermFrac': 0.1, 'avgColCor': 0.1, 'avgTopColCor': 0.1, 'numCanDocs': 0.1, 'maxTopColPCor': 0.1, 'maxCDocScore': 0.1, 'avgColPCor': 0.1, 'conIdf': 0.1, 'avgTopColPCor': 0.1, 'maxColCor': 0.1}
featureWeights_l=[featureWeights_1]
relWords_sel1 = {k:v[0:N1s] for k,v in relWords_sel.iteritems()}
indriRunQuery_hist_, dumpindex_hist_ = precisionCompute_train(dist, relWords_sel1, count_history, intCoeffs0, intCoeffs1, intCoeffs2, expansionCounts1, expansionCounts2, dirCoeffs, N2s_max, featureWeights_l, indriRunQuery_hist_, dumpindex_hist_)
"""
#training
dist = str(1)
intCoeffs0 = [ 0.7 ]
intCoeffs1 = [ 0.3 ]
#intCoeffs2 = [ 0.18 ]
intCoeffs2 = [ 0.5 ]
#intCoeffs1 = np.arange(0.1, 1, 0.1)
expansionCounts1 = [ 85 ]
#expansionCounts2 = [ 145 ]
expansionCounts2 = [ 0 ]
#expansionCounts2 = range(15, 220, 5)
dirCoeffs = [ 1600 ]
#dirCoeffs = range(200, 4000, 200)
N2s_max = [0]
N1s = 2
rWords = dict()
featureWeights_1 = {'maxTopColCor': 0.1, 'expTDocScore': 0.1, 'maxColPCor': 0.1, 'avgCDocScore': 0.1, 'topTermFrac': 0.1, 'avgColCor': 0.1, 'avgTopColCor': 0.1, 'numCanDocs': 0.1, 'maxTopColPCor': 0.1, 'maxCDocScore': 0.1, 'avgColPCor': 0.1, 'conIdf': 0.1, 'avgTopColPCor': 0.1, 'maxColCor': 0.1}
featureWeights_l=[featureWeights_1]
relWords_sel1 = {k:v[0:N1s] for k,v in relWords_sel1.iteritems()}
count_history, indriRunQuery_hist_, dumpindex_hist_ = precisionCompute_train(dist, origWordsAll, count_history, intCoeffs0, intCoeffs1, intCoeffs2, expansionCounts1, expansionCounts2, dirCoeffs, N2s_max, featureWeights_l, indriRunQuery_hist_, dumpindex_hist_)

# %%
print(dist)
