# %%
from __future__ import print_function 
from bs4 import BeautifulSoup
from BeautifulSoup import SoupStrainer as sopstrain
import subprocess
import os
import re
import sys
import numpy as np
import string
import operator
import csv
import urllib2
import json
from collections import defaultdict
import StringIO
import random
from multiprocessing import Pool

# %%
knowledgGraph = "cnet" # conceptnet5AssocMod, gov, conceptnet5AssocMi, conceptnet5AssocHdl
#knowledgGraph_ = ''.join([k.capitalize() if i>0 else k for i, k in enumerate(knowledgGraph)])
collection = "gov"
method = "lr" # hal, mi, assoc, assocMi, assocHal, assoc2
simMeasure = "" # mi, cnet
projectDir = "/home/fj9124/projects/ir/seq_kb_ir/" 
indexDir = "/scratch/index/indri_5_7/"
colMethodConfigsDir = os.path.join(projectDir, "configs", collection, method)
cfgInFileName = os.path.join(projectDir, "configs", collection, "query" + collection.capitalize()) 
print("cfgInFileName =", cfgInFileName)
cfgOutFileName=os.path.join(colMethodConfigsDir, knowledgGraph, "indriRunQuery.cfg") 
print("cfgOutFileName =", cfgOutFileName)
colIndexDir = os.path.join(indexDir, collection) 
print("colIndexDir =", colIndexDir)
if knowledgGraph in {"cnet"}:
    knowledgGraphIndexDir = os.path.join(indexDir, collection)   
else:
    knowledgGraphIndexDir = os.path.join(indexDir, knowledgGraph)   
print("knowledgGraph index Dir =", knowledgGraphIndexDir)
graphsDir = os.path.join(projectDir, "graphs")
#methodGraphsDir = os.path.join(graphsDir, method)
methodGraphsFileName = []
if method == "hal":
    methodGraphsFileName = [os.path.join(graphsDir, method, knowledgGraph + ".txt")]
    print("methodGraphsFileName =", methodGraphsFileName)
elif method.translate(None, string.digits) in {"mi", "assoc"}:
    methodGraphsFileName = [os.path.join(graphsDir, method.translate(None, string.digits), knowledgGraph, "graph.txt")]
    print("methodGraphsFileName =", methodGraphsFileName)
elif method in {"assocMi"}:
    if knowledgGraph == "conceptnet5AssocGov":
        methodGraphsFileName = [os.path.join(graphsDir, "assoc", collection, "conceptnet5AssocMod" + ".txt")]
        methodGraphsFileName += [os.path.join(graphsDir, "mi", collection, "gov" + ".txt")]
        print("methodGraphsFileName =", methodGraphsFileName)
elif method in {"assocHal"}:
    if knowledgGraph == "conceptnet5AssocGov":
        methodGraphsFileName = [os.path.join(graphsDir, "assoc", collection, "conceptnet5AssocMod" + ".txt")]
        methodGraphsFileName += [os.path.join(graphsDir, "hal", "gov" + ".txt")]
        print("methodGraphsFileName =", methodGraphsFileName)
qrelsDir = os.path.join(projectDir, "qrels")
colQrelsDir = os.path.join(qrelsDir, collection)
colQrelsFileName = os.path.join(colQrelsDir, "qrels.csv")
print("col Qrels File Name =", colQrelsFileName)
runsFileName = os.path.join(projectDir, "runs", method, collection, knowledgGraph, "indriRunQuery.runs") 
print("runsFileName =", runsFileName)
evalsFileName = os.path.join(projectDir, "evals", method, collection, knowledgGraph, "indriRunQuery.evals") 
print("evalsFileName =", evalsFileName)
dumpindexStatementFilename = os.path.join("/", "tmp", "sbsb", "statement" + "_" + collection + "_" + method + "_" + knowledgGraph )
print("dumpindexStatementFilename =", dumpindexStatementFilename)
occuranceCountFilename = os.path.join(projectDir, "occuranceCount", "occuranceCount")
print("occuranceCountFilename =", occuranceCountFilename)
countsResultsFile = os.path.join(projectDir,"occuranceCount","results",collection+".txt")
print("countsResultsFile =", countsResultsFile)
conceptnet5RelAllFilename ="/scratch/saeid/data/conceptnet5_simp.csv"
print("conceptnet5RelAllFilename =", conceptnet5RelAllFilename)
cfgTmpOutFileName = cfgOutFileName + ".tmp"
print("cfgTmpOutFileName =", cfgTmpOutFileName)
docIdNameMapFileName = os.path.join(projectDir, "occuranceCount", "results", collection + "_docIdNameMap.txt")
print("docIdNameMapFileName =", docIdNameMapFileName)
#dumpindexResFilename = os.path.join(projectDir,"occuranceCount","results",collection +"_dumpindexRes"+".txt")
#print("dumpindexResFilename =", dumpindexResFilename)
#expansionCount = 25
# Out:
# cfgInFileName = /home/fj9124/projects/ir/seq_kb_ir/configs/gov/queryGov
# cfgOutFileName = /home/fj9124/projects/ir/seq_kb_ir/configs/gov/lr/cnet/indriRunQuery.cfg
# colIndexDir = /scratch/index/indri_5_7/gov
# knowledgGraph index Dir = /scratch/index/indri_5_7/gov
# col Qrels File Name = /home/fj9124/projects/ir/seq_kb_ir/qrels/gov/qrels.csv
# runsFileName = /home/fj9124/projects/ir/seq_kb_ir/runs/lr/gov/cnet/indriRunQuery.runs
# evalsFileName = /home/fj9124/projects/ir/seq_kb_ir/evals/lr/gov/cnet/indriRunQuery.evals
# dumpindexStatementFilename = /tmp/sbsb/statement_gov_lr_cnet
# occuranceCountFilename = /home/fj9124/projects/ir/seq_kb_ir/occuranceCount/occuranceCount
# countsResultsFile = /home/fj9124/projects/ir/seq_kb_ir/occuranceCount/results/gov.txt
# conceptnet5RelAllFilename = /scratch/saeid/data/conceptnet5_simp.csv
# cfgTmpOutFileName = /home/fj9124/projects/ir/seq_kb_ir/configs/gov/lr/cnet/indriRunQuery.cfg.tmp
# docIdNameMapFileName = /home/fj9124/projects/ir/seq_kb_ir/occuranceCount/results/gov_docIdNameMap.txt

# %%
# trec_eval -q ../qrels/trec7n8/qrels.csv indriRunQuery.res | grep map | grep -v all | awk '{if ($3 < 0.1) printf $2 ","}'
if collection == "gov":
    diffTopics = [4, 6, 7, 8, 9, 10, 12, 18, 19, 21, 22, 24, 26, 27, 30, 31, 32, 33, 36, 37, 40, 45, 46, 47, 48, 50, 52, 53, 54, 57, 58, 59, 63, 65, 66, 67, 70, 73, 78, 79, 80, 82, 84, 86, 92, 93, 94, 95, 96, 98, 99, 101, 102, 103, 104, 105, 106, 107, 109, 110, 111, 112, 113, 115, 116, 117, 118, 120, 123, 125, 126, 127, 129, 132, 133, 134, 135, 136, 137, 140, 142, 143, 147, 148, 149, 152, 153, 154, 155, 156, 157, 158, 160, 161, 162, 163, 165, 166, 167, 168, 169, 171, 175, 176, 177, 178, 179, 180, 182, 183, 185, 186, 188, 189, 191, 192, 194, 195, 196, 197, 200, 201, 202, 203, 204, 207, 208, 211, 212, 214, 215, 218, 219, 221, 224]
if collection == "robust":
    diffTopics = [301, 305, 309, 314, 315, 318, 319, 320, 322, 325, 327, 332, 336, 340, 342, 343, 344, 345, 346, 347, 350, 352, 354, 355, 356, 359, 363, 367, 371, 372, 376, 378, 379, 380, 381, 383, 386, 388, 389, 390, 393, 394, 397, 398, 401, 405, 409, 412, 419, 421, 426, 432, 435, 436, 437, 439, 440, 442, 448, 449, 605, 608, 610, 620, 622, 625, 626, 627, 638, 650, 651, 655, 659, 666, 668, 680, 683, 684, 688, 689, 690]
if collection == "trec7n8":
    diffTopics = [352,354,356,359,363,367,370,371,372,373,376,378,379,381,383,386,388,389,390,393,394,397,398,401,405,408,419,421,422,426,432,435,436,437,439,440,442,443,445,447,448,449]

# %%
# generate docIdNameMapFileName
if not os.path.isfile(occuranceCountFilename):
    cmd = ' '.join([occuranceCountFilename, colIndexDir, "dm", ">", docIdNameMapFileName])
    res = subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE).stdout.read()

# %%
with open(docIdNameMapFileName, 'r') as f:
    reader = list(csv.reader(f, delimiter = ' '))
    print(reader[0])
    docIdNameMap = {i[1]:i[0] for i in reader}
    docNameIdMap = {i[0]:i[1] for i in reader}
for i, (k, v) in enumerate(docIdNameMap.iteritems()):
    print (k, '\t', v)
    if (i>20):
        break
# Out:
# ['1', 'G45-42-0000000']
# G27-29-4040585 	 1220122
# G06-40-3131996 	 281807
# G32-16-0767517 	 336566
# G38-20-1081477 	 35031
# G09-37-0269135 	 606264
# G35-90-1409165 	 1000554
# G45-00-1993329 	 6030
# G02-14-0310925 	 409727
# G24-75-3379489 	 482494
# G41-54-1115839 	 613900
# G08-45-4056636 	 443549
# G07-57-3916819 	 649375
# G18-64-1809424 	 382013
# G01-53-1599922 	 56902
# G09-45-1860255 	 607278
# G10-84-0819779 	 126372
# G07-75-1332741 	 640405
# G41-16-2022415 	 612570
# G28-26-3010045 	 735202
# G40-48-0701479 	 932948
# G10-12-3054008 	 136841
# G27-23-2273389 	 1206944

# %%
count_history = dict()
if os.path.isfile(countsResultsFile):
    with open(countsResultsFile, 'r') as f:
        reader = csv.reader(f, delimiter = "\t")
        count_history = {k:int(float(v)) for k,v in list(reader)}
    print("size of count_history =", len(count_history))
    for i, (k, v) in enumerate(count_history.iteritems()):
        print (k, '\t', v)
        if (i>20):
            break

# %%
conceptnet5RelAll = defaultdict(dict)
conceptnet5RelAllInv = defaultdict(dict)
with open(conceptnet5RelAllFilename, 'r') as f:
    reader = csv.reader(f, delimiter = ",")
    for line in list(reader):
        if line[0].strip() != "" and line[1].strip() != "" and line[2].strip() != "":
            if all(c in string.printable for c in line[0]) and all(c in string.printable for c in line[1]) and all(c in string.printable for c in line[2]):
                conceptnet5RelAll[line[1].strip()][line[2].strip()] = line[0].strip()
                conceptnet5RelAllInv[line[2].strip()][line[1].strip()] = line[0].strip()
print("size of conceptnet5RelAll =", len(conceptnet5RelAll))
for i, (k1, k2v) in enumerate(conceptnet5RelAll.iteritems()):
    for j, (k2, v) in enumerate(k2v.iteritems()):
        if (i>3 or j>3):
            break
        print (k1, '\t', k2, '\t', v)
# Out:
# size of conceptnet5RelAll = 2965684
# tripolitan 	 tripoline 	 Synonym
# tripolitan 	 tripoli 	 RelatedTo
# age of nemesis 	 band 	 IsA
# age of nemesis 	 organisation 	 InstanceOf
# age of nemesis 	 progressive rock 	 dbpedia/genre
# age of nemesis 	 progressive metal 	 dbpedia/genre
# joseph john annabring 	 person 	 InstanceOf
# british rail class 438 	 mean of transportation 	 InstanceOf
# british rail class 438 	 train 	 InstanceOf

# %%
def splitStemText(text):
    stemmedWords = []
    text = re.sub('/|-|\"|_',' ', text) # replace - and slash with space
    if method in {"assocRestful", "lr"}:
        for text_ in text.split(' '):
            text = text_.replace(" ", "_")
            url = "http://conceptnet5.media.mit.edu/data/5.4/uri?language=en&text=" + text
            response = urllib2.urlopen(url)
            data = response.read()
            data_j = json.loads(data)
            text = os.path.basename(data_j[u'uri'])
            url = "http://conceptnet5.media.mit.edu/data/5.4/uri?language=en&text=" + text
            response = urllib2.urlopen(url)
            data = response.read()
            data_j = json.loads(data)
            #print("data_j =", data_j)
            #print("data_j[u'uri'] =", data_j[u'uri'])
            stemmedWords += [str(os.path.basename(data_j[u'uri']))]
        #print("stemmedWords =", stemmedWords)
        return (stemmedWords)
    else:
        words = text.split()
        for w in words:
            w = re.sub('\(|\)|\'s|,','', w) # remove paranthesis, apostrophe s, comma
            w = re.sub('\'','', w) # remove apostrophe
            cmd = "dumpindex " + knowledgGraphIndexDir + " t " + w + " | head -n1"
            #print("cmd =", cmd)
            stemmedWords.append(subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE).stdout.read().split()[1])
        return (stemmedWords)

print ("testing:", splitStemText("going reading"))
# Out:
# testing: ['go', 'read']

# %%
def analyseQueries():
    #    #print("intCoeff =", intCoeff)
    with open(cfgInFileName, 'r') as inFile:
        reader = inFile.read()
        soup = BeautifulSoup(reader, 'lxml')
        if collection in {"aquaint", "gov"}:
            tags = soup.find_all(['doc'])
        elif collection in {"robust", "trec7n8", "gov2"}:
            tags = soup.find_all(['top'])
            #print(tags)
        
        origWordsAll = dict()
        for tag in tags:
            
            if collection in {"aquaint", "gov"}:
                docno = (tag.find('docno').string).strip()
            elif collection in {"robust", "trec7n8", "gov2"}:
                result = re.search('<num> Number: (.*)\n', str(tag))                
                docno = result.group(1).strip()
            
            if collection in {"aquaint", "gov"}:
                origWords = splitStemText(tag.find('text').string.strip())
            elif collection in {"robust", "trec7n8", "gov2"}:
                result = re.search('<title>(.*)\n', str(tag))                
                origWords = splitStemText(result.group(1).strip())
            #print("origWords =", origWords)
            origWordsAll[docno] = origWords
            
    return (origWordsAll)

# %%
cmd = ' '.join(["dumpindex", colIndexDir, "s", "|", "awk", "\'NR==2{print $2}\'"])
res = subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE).stdout.read()
colDocumentCount = int(np.float(res))
print("colDocumentCount =", colDocumentCount)
# Out:
# colDocumentCount = 1247753

# %%
regex = re.compile('[%s]' % re.escape(string.punctuation))
def genMultSimpQuery(argss):
    #    #print("intCoeff =", intCoeff)
    soupNew = BeautifulSoup("", 'lxml')
    parameters_tag = soupNew.new_tag("parameters")
    index_tag = soupNew.new_tag("index")
    index_tag.string = colIndexDir
    parameters_tag.append(index_tag)
        #print(tags)

    for args in argss:
        #print("args =", args)
        (docno, origWords_, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights) = args
        #print("(...) =", docno, origWords_, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights)
        doc_tag = soupNew.new_tag("query")

        docno_tag = soupNew.new_tag("number")
        docno_tag.string = '_'.join([docno, ('_'.join(origWords_)).replace(' ', '_'), relW.replace(' ', '_')])
        doc_tag.append(docno_tag)

        text_tag = soupNew.new_tag("text")
        text_tag.string = "#weight(\n" 

        text_tag.string += str(intCoeff0) + " #combine(" 
        for ow in set(origWords_):
            ow = regex.sub(' ', ow)
            text_tag.string += ow + " "
        text_tag.string += ")\n"

        if len(relW)>0: 
            relText_string1 = regex.sub(' ', relW)
            text_tag.string += str(intCoeff1) + " #combine(" 
            #print("relText_string1 =", relText_string1)
            text_tag.string += relText_string1.encode('utf-8')
            text_tag.string += ")\n"

        text_tag.string += ") "

        doc_tag.append(text_tag)

        parameters_tag.append(doc_tag)
        #print(doc_tag)

    rule_tag = soupNew.new_tag("rule")
    rule_tag.string = "method:dir,mu:" + str(dirCoeff)
    #rule_tag.string = "method:two"
    parameters_tag.append(rule_tag)

    #intCoeff_tag = soupNew.new_tag("intCoeff")
    #intCoeff_tag.string = "0.8"
    #parameters_tag.append(intCoeff_tag)

    threads_tag = soupNew.new_tag("threads")
    threads_tag.string = "32"
    parameters_tag.append(threads_tag)

    count_tag = soupNew.new_tag("count")
    count_tag.string = "10"
    parameters_tag.append(count_tag)

    trecFormat_tag = soupNew.new_tag("trecFormat")
    trecFormat_tag.string = "true"
    parameters_tag.append(trecFormat_tag)

    soupNew.append(parameters_tag)
    #print(soupNew.prettify())
    #print("cfgTmpOutFileName =", cfgTmpOutFileName)
    with open( cfgTmpOutFileName, 'a+') as outFile:
        soupNewStr = str(soupNew)
        soupNewStr = soupNewStr.replace("</text>", "\n</text>\n").replace("query>", "query>\n").replace("<text>", "\n<text>\n").replace("</index>", "</index>\n").replace("\n<index>", "<index>")

        outFile.write(soupNewStr)

# %%
def weightRelConcept_hist_i(docno, origWords_, ow, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights):
    
    indriRunQuery_hist = [(docno, origWords_, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, cfgTmpOutFileName)]
    return indriRunQuery_hist

# %%
def runCommandsinHist_i(cfgTmpOutFileName, indriRunQuery_hist, indriRunQuery_hist_, featureWeights):
    with open( cfgTmpOutFileName, 'w+') as outFile:
        outFile.write("")
    args = []
    #print("indriRunQuery_hist =", indriRunQuery_hist)
    for (docno, origWords_, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, cfgTmpOutFileName) in indriRunQuery_hist:
        #print("cfgTmpOutFileName =", cfgTmpOutFileName)
        if '_'.join([docno, ('_'.join(origWords_)).replace(' ', '_'), relW.replace(' ', '_')]) not in indriRunQuery_hist_:
            args += [(docno, origWords_, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights)]
    #print("args =", args)
    if len(args)>0:
        genMultSimpQuery(args)
    cmd = ' '.join(["IndriRunQuery", cfgTmpOutFileName])
    #print("cmd =", cmd)
    indriRun = subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE).stdout.read()
    #print("indriRun =", indriRun)
    indriRunQuery_hist_tmp = [[j for c, j in enumerate(i.split(' ')) if c in {0, 2, 4}] for i in indriRun.split('\n') if len(i)>0]
    #indriRunQuery_hist_ = dict()
    for i in indriRunQuery_hist_tmp:
        if i[0] in indriRunQuery_hist_:
            indriRunQuery_hist_[i[0]] += [[i[1], i[2]]]
        else:
            indriRunQuery_hist_[i[0]] = [[i[1], i[2]]]
    #indriRunQuery_hist_ = list(set(indriRunQuery_hist_))
    return indriRunQuery_hist_

# %%
def weightRelConcept_hist_d(indriRunQuery_hist_, dumpindex_hist, docno, origWords_, ow, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights):

    #print("'_'.join([docno, '_'.join(origWords_), relW]).replace(' ', '_') =", '_'.join([docno, '_'.join(origWords_), relW]).replace(' ', '_'))
    indriRunQuery_hist_1 = indriRunQuery_hist_['_'.join([docno, '_'.join(origWords_), relW]).replace(' ', '_')]
    #print("indriRunQuery_hist_1 =", indriRunQuery_hist_1)
    topTDocs = [i[0] for i in indriRunQuery_hist_1]
    #print("topTDocs =", topTDocs)
    
    expr = "#od4(" + regex.sub(' ', relW) + "):" + ','.join(topTDocs)
    cmd2 = ("efb", expr)
    #print("expr =", expr)
    if cmd2 not in dumpindex_hist:
        dumpindex_hist.add(cmd2)
    
    #print("topTDocs =", topTDocs)
    
    for documentName in topTDocs:
        cmd2 = ("dcf", docIdNameMap[documentName])
        if cmd2 not in dumpindex_hist:
            dumpindex_hist.add(cmd2)

    for ow in origWords_:
        cmd2 = ("efb", "#uw(#4( " + regex.sub(' ', ow) + " ) #4( " + regex.sub(' ', relW) + " )):" + ','.join(topTDocs))
        if cmd2 not in dumpindex_hist:
            dumpindex_hist.add(cmd2)
        
    for j1, ow1 in enumerate(origWords_):
        for j2, ow2 in enumerate(origWords_):
            if j1>j2:
                cmd2 = ("efb", "#uw(#4( " + regex.sub(' ', ow1) + " ) #4( " + regex.sub(' ', ow2) + " ) #4( " + regex.sub(' ', relW) + " )):" + ','.join(topTDocs))
                if cmd2 not in dumpindex_hist:
                    dumpindex_hist.add(cmd2)
    return dumpindex_hist

# %%
regex = re.compile('[%s]' % re.escape(string.punctuation))
def runCommandsinHist_d(docno, dumpindex_hist, dumpindex_hist_):
    args = []
    dumpindex_hist_dict = dict()
    tmp = set()
    for i in dumpindex_hist:
        if i[1] not in dumpindex_hist_.get(docno + "_" + i[0], dict()):
            if i[1] in tmp:
                continue
            tmp.add(i[1])
            if i[0] in dumpindex_hist_dict:
                dumpindex_hist_dict[i[0]] += [[re.sub(ur"[^\w\d#(),:\-\s]+",' ',j) for j in i[1:]]]
            else:
                dumpindex_hist_dict[i[0]] =  [[re.sub(ur"[^\w\d#(),:\-\s]+",' ',j) for j in i[1:]]]
                
    for k, v in dumpindex_hist_dict.iteritems():
        fileName = dumpindexStatementFilename+"_"+k+".tmp"
        with open(fileName, 'w') as f:
            for i in v:
                f.write(' '.join(i) + '\n')
                #print("i =", i)
        cmd = ' '.join([occuranceCountFilename, colIndexDir, k, fileName])
        #print("cmd =", cmd)
        dumpindex_hist_tmp = subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE).stdout.read()
        #print("dumpindex_hist_tmp =", dumpindex_hist_tmp)
        dumpindex_hist_tmp = dict([tuple(j for c2, j in enumerate(i.split(':')) if c2 in {0,1} ) for i in dumpindex_hist_tmp.split("\n") if len(i)>0])
        #print("dumpindex_hist_tmp.get(\"#od4(travel)\",\"\") =", dumpindex_hist_tmp.get("#od4(travel)", dict()) )
        dumpindex_hist_tmp = {k1:v1.split(',') for k1,v1 in dumpindex_hist_tmp.iteritems()}
        dumpindex_hist_tmp = {k1:[i for i in v1 if len(i)>0] for k1,v1 in dumpindex_hist_tmp.iteritems()}
        #dumpindex_hist_tmp = {re.sub(ur"[^\w\d#()\s]+",' ',k1):[i for i in v1 if len(i)>0] for k1,v1 in dumpindex_hist_tmp.iteritems()}
        #dumpindex_tmp = [i for i in dumpindex_tmp.split("\n")]
        #print("dumpindex_hist_tmp =", dumpindex_hist_tmp)
        #dumpindex_hist_[k] = dumpindex_hist_tmp
        dumpindex_hist_[docno + "_" + k] = dict(dumpindex_hist_.get(docno + "_" + k, dict()).items() + dumpindex_hist_tmp.items())
    #print("dumpindex_hist_['efb'].get('#od4(travel)', dict())]", dumpindex_hist_['efb'].get("#od4(travel)", dict()))
        #print("dumpindex_hist_[k].keys() =", dumpindex_hist_[k].keys())
    #print("dumpindex_hist_ =", dumpindex_hist_)
        
    return dumpindex_hist_

# %%
regex = re.compile('[%s]' % re.escape(string.punctuation))
def documentLength(docno, documentName):
    #cmd = ' '.join(["dumpindex", colIndexDir, "dv", docIdNameMap[documentName], "|", "awk", "\'END{print $1}\'"])
    #cmd2 = ["dv", docIdNameMap[documentName], "|", "awk", "\'END{print $1}\'"]
    #print("cmd =", cmd)
    #documentLength_ = int(dumpindex_colIndexDir(cmd2))
    documentLength_ = int(dumpindex_hist_[docno + "_" + 'dcf'][documentName][0])
    return documentLength_

#print("docIdNameMap[\"FT944-15973\"] = ", docIdNameMap["FT944-15973"])
#print("documentLength(\"FT944-15973\") =", documentLength("FT944-15973"))

def weightRelConcept(docno, origWords_, ow, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, count_history, featureWeights):
    
    features = dict()
    
    ##########
    #cfgTmpOutFileName = os.path.join("/","tmp","sbsb",str(random.randint(1,1e6))+"_tmp.cfg")
    ##########
    #(docno, origWords_, relW, intCoeff0, intCoeff1, dirCoeff, cfgTmpOutFileName)
    #genOneSimpQuery(docno, origWords_, relW, intCoeff0, intCoeff1, dirCoeff, cfgTmpOutFileName)
    
    #indriRun = indriRunQuery_([cfgTmpOutFileName])
    #subprocess.Popen(' '.join(["rm", cfgTmpOutFileName]), shell=True, stdout=subprocess.PIPE).stdout.read()
    #indriRun = [i.split(' ') for i in indriRun.split('\n')]
    #indriRun = [i for i in indriRun if len(i)>1] # remove empty arrays
    #print("'_'.join([docno, '_'.join(origWords_), relW]).replace(' ', '_') =", '_'.join([docno, '_'.join(origWords_), relW]).replace(' ', '_'))
    indriRunQuery_hist_1 = indriRunQuery_hist_['_'.join([docno, '_'.join(origWords_), relW]).replace(' ', '_')]
    #print("indriRunQuery_hist_1 =", indriRunQuery_hist_1)
    topTDocs = [i[0] for i in indriRunQuery_hist_1]
    
    #topTDocScores_d = {i[2]:np.float(i[4]) for i in indriRun}
    topTDocScores_d = {i[0]:np.float(i[1]) for i in indriRunQuery_hist_1}
    #print("topTDocScores_d =", topTDocScores_d)
    
    #scores = [ np.float(i[4]) for i in indriRun]
    #topTDocs = [i[2] for i in indriRun]

    #print("indriRun =", indriRun)
    #topTDocScore = np.sum([ np.float(i[4]) for i in indriRun])
    #expTDocScore = np.float(indriRun[0][4])
    expTDocScore = np.float(indriRunQuery_hist_1[0][1])
    features["expTDocScore"] = expTDocScore
    #print("expTDocScore =", features["expTDocScore"])
    
    #cmd =' '.join(["dumpindex", colIndexDir, "e", "\"#od4(" + relW + ")\""])
    #cmd2 = ["e", "\"#od4(" + relW + ")\""]
    #print("cmd =", cmd)
    #relWDocuments = dumpindex_colIndexDir(cmd2)
    expr = "#od4(" + regex.sub(' ', relW) + ")"
    #print ("dumpindex_hist_ =", dumpindex_hist_)
    #print ("expr =", expr)
    #print ("docno + '_' + 'efb' =", docno + '_' + 'efb')
    relWTopDocuments = list(dumpindex_hist_[docno + "_" + 'efb'][expr])
    #print("relWTopDocuments =", relWTopDocuments)
    colTermFreq = np.float(relWTopDocuments[0])
    del relWTopDocuments[0] # the first element was colTermFreq
    #relWDocuments = subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE).stdout.read()
    #relWDocuments = [i.split(' ') for i in relWDocuments.split('\n')]
    #print("relWDocuments =", relWDocuments)
    #relWDocuments = [[docNameIdMap[i[0]], i[1], i[2], i[3]] for j, i in enumerate(relWDocuments) if len(i)==4 and j>0] # remove empty arrays
    
    #relWTopDocuments = [i for i in relWDocuments if i[0] in topTDocs]
    #relWTopDocuments = [i for i in relWDocuments if i in topTDocs]
    #relWTopDocuments = [[i, topTDocScores_d[i]] for i in relWDocuments if i in topTDocs] # topdocs and their scores that contain relW
    #print("relWTopDocuments =", relWTopDocuments)
    #numerator = np.sum([int(i[1]) for i in relWTopDocuments]) # term count in the collection
    numerator = colTermFreq # relW term count in the collection
    #print("topTDocs =", topTDocs)
    denumerator = np.sum([documentLength(docno, i) for i in topTDocs]) # number of terms in topDocs
    topTermFrac = numerator / np.float(denumerator)
    #print("numerator, denumerator, topTermFrac =", numerator, denumerator, topTermFrac)
    features["topTermFrac"] = topTermFrac
    
    numCanDocs = len(set([i[0] for i in relWTopDocuments]))
    features["numCanDocs"] = numCanDocs
    #print("numCanDocs =", features["numCanDocs"])
    
    if numCanDocs > 0:
        avgCDocScore = np.sum([ topTDocScores_d[i] for i in set([i for i in relWTopDocuments])])/np.float(numCanDocs)
    else:
        avgCDocScore = 0
    features["avgCDocScore"] = avgCDocScore
    #print("avgCDocScore =", features["avgCDocScore"])

    #for i in set([i[0] for i in relWTopDocuments]):
    #    print(i, topTDocScores_d[i])
    
    l = [ topTDocScores_d[i] for i in set(relWTopDocuments)]
    if len(l)>0:
        maxCDocScore = np.max(l)
    else:
        maxCDocScore = 0
    features["maxCDocScore"] = maxCDocScore
    #print("maxCDocScore =", features["maxCDocScore"])
    
    if colTermFreq>0:
        conIdf = np.log(colDocumentCount / colTermFreq)
    else:
        conIdf = np.log(colDocumentCount / 1)
    features["conIdf"] = conIdf
    #print("conIdf =", features["conIdf"])
    
    coocurDocuments = dict()
    coocurDocumentsTop = dict()
    for ow in origWords_:
        #cmd = ' '.join(["dumpindex", colIndexDir, "e", "\"#uw(#4( " + ow + " ) #4( " + relW + " ))\""])
        #cmd2 = ["e", "\"#uw(#4( " + ow + " ) #4( " + relW + " ))\""]
        #print("cmd =", cmd)
        #coocurDocuments_ = subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE).stdout.read()
        #coocurDocuments_ = dumpindex_colIndexDir(cmd2)
        #coocurDocuments_ = [i.split(' ') for i in coocurDocuments_.split('\n')]
        coocurDocuments[ow] = [i for i in dumpindex_hist_[docno + "_" + 'efb']["#uw(#4( " + regex.sub(' ', ow) + " ) #4( " + regex.sub(' ', relW) + " ))"]]
        #coocurDocuments[ow] = [docNameIdMap[i[0]] for i in coocurDocuments_ if len(i)==4] # remove empty arrays
        #print("topTDocs =", topTDocs)
        coocurDocumentsTop[ow] = [i for i in coocurDocuments[ow] if i in topTDocs ] # remove empty arrays

    #for k, v in coocurDocuments.iteritems():
    #    print(k, len(v))
        
    #for v in coocurDocumentsTop.values():
    #    print(v)
    #    print(len(set(v)))
        
    avgColCor = np.sum([len(set(i)) for i in coocurDocuments.values()])/np.float(len(coocurDocuments)) 
    features["avgColCor"] = avgColCor
    #print("avgColCor =", features["avgColCor"])
    
    maxColCor = np.max([len(set(i)) for i in coocurDocuments.values()])
    features["maxColCor"] = maxColCor
    #print("maxColCor =", features["maxColCor"])
    
    avgTopColCor = np.sum([len(set(i)) for i in coocurDocumentsTop.values()])/np.float(len(coocurDocumentsTop)) 
    features["avgTopColCor"] = avgTopColCor
    #print("avgTopColCor =", features["avgTopColCor"])
    
    l = [len(set(i)) for i in coocurDocumentsTop.values()]
    if len(l)>0:
        maxTopColCor = np.max(l)
    else:
        maxTopColCor = 0
    features["maxTopColCor"] = maxTopColCor
    #print("maxTopColCor =", features["maxTopColCor"])

    for j1, ow1 in enumerate(origWords_):
        for j2, ow2 in enumerate(origWords_):
            if j1>j2:
                #coocurDocuments_ = subprocess.Popen(' '.join(["dumpindex", colIndexDir, "e", "\"#uw(#4( " + ow1 + " ) #4( " + ow2 + " ) #4( " + relW + " ))\""]), shell=True, stdout=subprocess.PIPE).stdout.read()
                #cmd2 = [ "e", "\"#uw(#4( " + ow1 + " ) #4( " + ow2 + " ) #4( " + relW + " ))\""]
                #coocurDocuments_ = dumpindex_colIndexDir(cmd2)
                #coocurDocuments_ = [i.split(' ') for i in coocurDocuments_.split('\n')]
                coocurDocuments[ow1+ow2] = [i for i in dumpindex_hist_[docno + "_" + 'efb']["#uw(#4( " + regex.sub(' ', ow1) + " ) #4( " + regex.sub(' ', ow2) + " ) #4( " + regex.sub(' ', relW) + " ))"]]
                #coocurDocuments[ow1+ow2] = [docNameIdMap[i[0]] for i in coocurDocuments_ if len(i)==4] # remove empty arrays
                coocurDocumentsTop[ow1+ow2] = [i for i in coocurDocuments[ow1+ow2] if i in topTDocs ] # remove empty arrays

    avgColPCor = np.sum([len(set(i)) for i in coocurDocuments.values()])/np.float(len(coocurDocuments)) 
    features["avgColPCor"] = avgColPCor
    #print("avgColPCor =", features["avgColPCor"])

    l = [len(set(i)) for i in coocurDocuments.values()]
    if len(l)>0:
        maxColPCor = np.max(l)
    else:
        maxColPCor = 0
    features["maxColPCor"] = maxColPCor
    #print("maxColPCor =", features["maxColPCor"])
    
    avgTopColPCor = np.sum([len(set(i)) for i in coocurDocumentsTop.values()])/np.float(len(coocurDocumentsTop)) 
    features["avgTopColPCor"] = avgTopColPCor
    #print("avgTopColPCor =", features["avgTopColPCor"])

    l = [len(set(i)) for i in coocurDocumentsTop.values()] 
    if len(l)>0:
        maxTopColPCor = np.max(l)
    else:
        maxTopColPCor = 0
    features["maxTopColPCor"] = maxTopColPCor
    #print("maxTopColPCor =", features["maxTopColPCor"])
    
    #print("docno, origWords_, relW =", docno, origWords_, relW)
    #print("features =", features)
    
    relWg = 0
    for feature, weight in featureWeights.iteritems():
        relWg += features[feature] * weight
    
    #print("features.keys() =", features.keys())
    return relWg

# %%
# keys of rWords are important
# values of rWords1 are important
regex = re.compile('[%s]' % re.escape(string.punctuation))
def getRelWords_train(args, indriRunQuery_hist_, dumpindex_hist_):
    #print("origWords =", origWords)
    text_string = ""
    
    count_history, rWords, docno, origWords, expansionCount, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights = args
        
    relWords = dict()
    #if method == "relAll":
            
    if method == "lr":
        origWords_ = [w.replace(" ", "_") for w in origWords]
        #relWords_l = []
        for ow in origWords_:
            #print("ow =", ow)
            #relWords_l += list(conceptnet5RelAll[ow])
            #print(ow, "---", conceptnet5RelAll[ow])
            indriRunQuery_hist = []
            for relW in conceptnet5RelAll[ow].keys():
                indriRunQuery_hist += weightRelConcept_hist_i(docno, origWords_, ow, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights)
            #print("len(indriRunQuery_hist) =", len(indriRunQuery_hist))
            indriRunQuery_hist_ = runCommandsinHist_i(cfgTmpOutFileName, indriRunQuery_hist, indriRunQuery_hist_, featureWeights)
            #print("len(indriRunQuery_hist_) =", len(indriRunQuery_hist_))
            
            dumpindex_hist = set()
            for relW in conceptnet5RelAll[ow].keys():
                dumpindex_hist |= weightRelConcept_hist_d(indriRunQuery_hist_, dumpindex_hist, docno, origWords_, ow, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights)
            #print("dumpindex_hist =", dumpindex_hist)
            dumpindex_hist_ = runCommandsinHist_d(docno, dumpindex_hist, dumpindex_hist_)
            #print("dumpindex_hist_ =", dumpindex_hist_)
            #print("len(dumpindex_hist_['ef']) =", len(dumpindex_hist_['ef']))
            #print("len(dumpindex_hist_['dcf']) =", len(dumpindex_hist_['dcf']))

    return(indriRunQuery_hist_, dumpindex_hist_)

# %%
# keys of rWords are important
# values of rWords1 are important
regex = re.compile('[%s]' % re.escape(string.punctuation))
def getRelWords(args, indriRunQuery_hist_, dumpindex_hist_):
    #print("origWords =", origWords)
    text_string = ""
    
    count_history, rWords, docno, origWords, expansionCount, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights = args
        
    relWords = dict()
    #if method == "relAll":
        
    if method == "assocRestful":
        origWords_ = [w.replace(" ", "_") for w in origWords]
        url = "http://conceptnet5.media.mit.edu/data/5.4/assoc/list/en/"+','.join(origWords_)
        response = urllib2.urlopen(url)
        data = response.read()
        data_j = json.loads(data)
        relWords = {str(d[0].encode('utf-8')).replace('/c/en/', '').replace('-', ' '):np.float(d[1]) for d in data_j[u'similar'] if '/c/en/' in str(d[0].encode('utf-8'))}
    
    elif method == "lr":
        origWords_ = [w.replace(" ", "_") for w in origWords]
        #relWords_l = []

        for ow in origWords_:
            #relWords_l += list(conceptnet5RelAll[ow])
            #print(ow, "---", conceptnet5RelAll[ow])
            for relW in conceptnet5RelAll[ow].keys():
                relWg = weightRelConcept(docno, origWords_, ow, relW, intCoeff0, intCoeff1, intCoeff2, dirCoeff, count_history, featureWeights)
                if relW in relWords:
                    relWords[relW] += relWg
                else:
                    relWords[relW] = relWg  
    
    else:
        count_history = countExpr(count_history, origWords, rWords)
        expressions = set()
        for ow in origWords:
            rWords_ow = rWords.get(ow, [])
            expressions.add("#4( " + ow.translate(None, string.punctuation) + " )")
            if ow.strip() == "":
                continue
            if simMeasure == "mi":
                N_w = countExpr_get_1(count_history, ow)
            for rw_wv in rWords_ow:
                (rw_w, rw_v) = rw_wv.items()[0]
                if rw_w.strip() == "":
                    continue           
                if simMeasure == "mi":
                    N_v = countExpr_get_1(count_history, rw_w)
                    N_wv = countExpr_get_2(count_history, ow, rw_w)
                    rw_v_ = mi_(N_w, N_v, N_wv)
                elif simMeasure == "cnet":
                    rw_v_ = rw_v
                relWords[rw_w] = relWords.get(rw_w, 0) + rw_v_
    
    relWords_sorted = sorted(relWords.items(), key=operator.itemgetter(1), reverse=True)
    #print ("origWords =", origWords)
    #print ("relWords_sorted =", relWords_sorted)
    #counter = 0
    relWords_sel = []
    for counter, (rw_w, rw_v) in enumerate(relWords_sorted):
        if (counter >= expansionCount):
            break
        if  all(c in string.printable for c in rw_w):
            if rw_w not in origWords:
                rw_w = regex.sub(' ', rw_w)
                text_string += rw_w + " "
                relWords_sel += [rw_w]
        #counter += 1
    #print("counter =", counter)
#    return(relWords_sel)
    return(count_history, text_string, relWords_sel)

# %%
def getAllRelWords_train(count_history, rWords, origWordsAll, expansionCount1, N1, expansionCount2, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights, indriRunQuery_hist_, dumpindex_hist_):
    relText_stringAll = []
    relText_string = dict()
    relWords_sel = dict()
    for c1, (docno, origWords) in enumerate(origWordsAll.iteritems()):
        print("c1 =", c1, "docno =", docno, "--- origWords =", origWords)
        args = (count_history, rWords, docno, origWords, expansionCount1, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights)
        indriRunQuery_hist_, dumpindex_hist_ = getRelWords_train(args, indriRunQuery_hist_, dumpindex_hist_)
        print("c1 =", c1, "- len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) =", len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())))
    
    #print("relText_stringAll =", relText_stringAll)
    return (indriRunQuery_hist_, dumpindex_hist_)

# %%
def getAllRelWords(count_history, rWords, origWordsAll, expansionCount1, N1, expansionCount2, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights, indriRunQuery_hist_, dumpindex_hist_):
    relText_stringAll = []
    relText_string = dict()
    relWords_sel = dict()
    for c1, (docno, origWords) in enumerate(origWordsAll.iteritems()):
        #print(str(c1), "---", docno, "---", origWords)
        args = (count_history, rWords, docno, origWords, expansionCount1, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights)
        count_history, relText_string_, relWords_sel_ = getRelWords(args, indriRunQuery_hist_, dumpindex_hist_)
        #print("len(indriRunQuery_hist_), len(dumpindex_hist_['dcf']), len(dumpindex_hist_['ef']) =", len(indriRunQuery_hist_), len(dumpindex_hist_['dcf']), len(dumpindex_hist_['ef']))
        relText_string[docno] = relText_string_
        relWords_sel[docno] = relWords_sel_[0:N1]
        #print(docno, "---", origWords, "---", relWords_sel_)
    relText_stringAll += [relText_string]
    
    relText_string = dict()
    relWords_sel = dict()
    for docno, origWords_new in relWords_sel.iteritems():
        args = (count_history, rWords, docno, origWords, expansionCount1, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights)
        count_history, relText_string_, relWords_sel_ = getRelWords(args, indriRunQuery_hist_, dumpindex_hist_)
        relText_string[docno] = relText_string_
        relWords_sel[docno] = relWords_sel_
    relText_stringAll += [relText_string]
    
    #print("relText_stringAll =", relText_stringAll)
    return (count_history, relText_stringAll)

# %%
regex = re.compile('[%s]' % re.escape(string.punctuation))
def genQueries(cfgOutFileName_, origWordsAll, relText_stringAll, intCoeff0, intCoeff1, intCoeff2, dirCoeff):
    #    #print("intCoeff =", intCoeff)
    with open(cfgInFileName, 'r') as inFile:
        reader = inFile.read()
        soupNew = BeautifulSoup("", 'lxml')
        parameters_tag = soupNew.new_tag("parameters")
        index_tag = soupNew.new_tag("index")
        index_tag.string = colIndexDir
        parameters_tag.append(index_tag)
            #print(tags)

        for docno, origWords in origWordsAll.iteritems():
            doc_tag = soupNew.new_tag("query")

            docno_tag = soupNew.new_tag("number")
            docno_tag.string = docno
            doc_tag.append(docno_tag)

            text_tag = soupNew.new_tag("text")
            text_tag.string = "#weight(\n" 
                    
            text_tag.string += str(intCoeff0) + " #combine(" 
            for ow in set(origWords):
                ow = regex.sub(' ', ow)
                text_tag.string += ow + " "
            text_tag.string += ")\n"

            if len(relText_stringAll[0])>0:
                if len(relText_stringAll[0][docno]) > 3: 
                    relText_string1 = regex.sub(' ', relText_stringAll[0][docno])
                    text_tag.string += str(intCoeff1) + " #combine(" 
                    #print("relText_string1 =", relText_string1)
                    text_tag.string += relText_string1.encode('utf-8')
                    text_tag.string += ")\n"
            
            #print(len(relText_stringAll[1]))
            if len(relText_stringAll[1])>0:
                if len(relText_stringAll[1][docno]) > 3: 
                    relText_string2 = regex.sub(' ', relText_stringAll[1][docno])
                    text_tag.string += str(intCoeff2) + " #combine(" 
                    #print("relText_string2 =", relText_string2)
                    text_tag.string += relText_string2.encode('utf-8')
                    text_tag.string += ")\n"
            
            #print("origWords =", origWords)
            #print("relWords_sel1 =", relWords_sel1)
            #print("relWords_sel2 =", relWords_sel2)
            
            
            text_tag.string += ") "

            doc_tag.append(text_tag)

            parameters_tag.append(doc_tag)
            #print(doc_tag)

        rule_tag = soupNew.new_tag("rule")
        rule_tag.string = "method:dir,mu:" + str(dirCoeff)
        #rule_tag.string = "method:two"
        parameters_tag.append(rule_tag)

        #intCoeff_tag = soupNew.new_tag("intCoeff")
        #intCoeff_tag.string = "0.8"
        #parameters_tag.append(intCoeff_tag)

        threads_tag = soupNew.new_tag("threads")
        threads_tag.string = "32"
        parameters_tag.append(threads_tag)

        count_tag = soupNew.new_tag("count")
        count_tag.string = "1000"
        parameters_tag.append(count_tag)

        trecFormat_tag = soupNew.new_tag("trecFormat")
        trecFormat_tag.string = "true"
        parameters_tag.append(trecFormat_tag)

        soupNew.append(parameters_tag)
        #print(soupNew.prettify())
    #print("outFileName =", outFileName)
    with open( cfgOutFileName_, 'w') as outFile:
        soupNewStr = str(soupNew)
        soupNewStr = soupNewStr.replace("</text>", "\n</text>\n").replace("query>", "query>\n").replace("<text>", "\n<text>\n").replace("</index>", "</index>\n").replace("\n<index>", "<index>")

        outFile.write(soupNewStr)

# %%
def precisionCompute_train(count_history, intCoeffs0, intCoeffs1, intCoeffs2, expansionCounts1, expansionCounts2, dirCoeffs, N1s, featureWeights_, indriRunQuery_hist_, dumpindex_hist_):
    #randNum = random.randint(1,1e9)
    origWordsAll = analyseQueries()
    indriRunQuery_hist_, dumpindex_hist_ = getAllRelWords_train(count_history, rWords, origWordsAll, expansionCounts1[0], N1s[0], expansionCounts2[0], intCoeffs0[0], intCoeffs1[0], intCoeffs2[0], dirCoeffs[0], featureWeights_[0], indriRunQuery_hist_, dumpindex_hist_)
                                    
    return origWordsAll, count_history, indriRunQuery_hist_, dumpindex_hist_

# %%
#training
indriRunQuery_hist_= dict()
dumpindex_hist_ = dict()
intCoeffs0 = [ 0.7 ]
intCoeffs1 = [ 0.3 ]
#intCoeffs2 = [ 0.18 ]
intCoeffs2 = [ 0.5 ]
#intCoeffs1 = np.arange(0.1, 1, 0.1)
expansionCounts1 = [ 85 ]
#expansionCounts2 = [ 145 ]
expansionCounts2 = [ 0 ]
#expansionCounts2 = range(15, 220, 5)
dirCoeffs = [ 1600 ]
#dirCoeffs = range(200, 4000, 200)
N1s = [0]
rWords = dict()
featureWeights_1 = {'maxTopColCor': 0.1, 'expTDocScore': 0.1, 'maxColPCor': 0.1, 'avgCDocScore': 0.1, 'topTermFrac': 0.1, 'avgColCor': 0.1, 'avgTopColCor': 0.1, 'numCanDocs': 0.1, 'maxTopColPCor': 0.1, 'maxCDocScore': 0.1, 'avgColPCor': 0.1, 'conIdf': 0.1, 'avgTopColPCor': 0.1, 'maxColCor': 0.1}
featureWeights_l=[featureWeights_1]
origWordsAll, count_history, indriRunQuery_hist_, dumpindex_hist_ = precisionCompute_train(count_history, intCoeffs0, intCoeffs1, intCoeffs2, expansionCounts1, expansionCounts2, dirCoeffs, N1s, featureWeights_l, indriRunQuery_hist_, dumpindex_hist_)
# Out:
# c1 = 0 docno = 216 --- origWords = ['windandsea']
# c1 = 0 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 0 0 0
# c1 = 1 docno = 217 --- origWords = ['astronaut', 'biography']
# c1 = 1 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 84 0 0
# c1 = 2 docno = 214 --- origWords = ['local', 'area', 'unemployment', 'statistic', 'home']
# c1 = 2 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 1030 0 0
# c1 = 3 docno = 215 --- origWords = ['nih', 'video', 'cast']
# c1 = 3 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 1240 0 0
# c1 = 4 docno = 212 --- origWords = ['national', 'mediation', 'board']
# c1 = 4 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 1875 0 0
# c1 = 5 docno = 213 --- origWords = ['school', 'bus', 'recall']
# c1 = 5 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 2451 0 0
# c1 = 6 docno = 210 --- origWords = ['california', 'state', 'park', 'job']
# c1 = 6 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 2843 0 0
# c1 = 7 docno = 211 --- origWords = ['national', 'conference', 'advance', 'cholesterol', 'management']
# c1 = 7 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 3169 0 0
# c1 = 8 docno = 165 --- origWords = ['national', 'laboratory']
# c1 = 8 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 3218 0 0
# c1 = 9 docno = 218 --- origWords = ['medwatch']
# c1 = 9 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 3218 0 0
# c1 = 10 docno = 219 --- origWords = ['west', 'indian', 'manatee', 'information']
# c1 = 10 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 3521 0 0
# c1 = 11 docno = 133 --- origWords = ['human', 'genome', 'research']
# c1 = 11 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 5074 0 0
# c1 = 12 docno = 132 --- origWords = ['food', 'illness', 'report']
# c1 = 12 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 5741 0 0
# c1 = 13 docno = 131 --- origWords = ['persian', 'gulf', 'war', 'veteran', 'lou', 'gehrig', 'disease']
# c1 = 13 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 6573 0 0
# c1 = 14 docno = 130 --- origWords = ['bay', 'area', 'terrorism', 'hazard']
# c1 = 14 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 6880 0 0
# c1 = 15 docno = 137 --- origWords = ['map', 'map', 'cartography']
# c1 = 15 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 7104 0 0
# c1 = 16 docno = 136 --- origWords = ['career', 'information']
# c1 = 16 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 7294 0 0
# c1 = 17 docno = 135 --- origWords = ['laura', 'welch', 'bush']
# c1 = 17 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 7441 0 0
# c1 = 18 docno = 134 --- origWords = ['national', 'park']
# c1 = 18 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 7626 0 0
# c1 = 19 docno = 139 --- origWords = ['poetry', 'read', 'poem', 'online']
# c1 = 19 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 8450 0 0
# c1 = 20 docno = 138 --- origWords = ['risk', 'tattoo', 'permanent', 'makeup']
# c1 = 20 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 8699 0 0
# c1 = 21 docno = 166 --- origWords = ['art', 'white', 'house']
# c1 = 21 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 9828 0 0
# c1 = 22 docno = 24 --- origWords = ['child', 'care']
# c1 = 22 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 11443 0 0
# c1 = 23 docno = 25 --- origWords = ['history', 'phoenix', 'symbol']
# c1 = 23 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 11931 0 0
# c1 = 24 docno = 26 --- origWords = ['white', 'house', 'president', 'bush', 'cabinet']
# c1 = 24 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 12986 0 0
# c1 = 25 docno = 27 --- origWords = ['opm', 'new', 'retiree']
# c1 = 25 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 13134 0 0
# c1 = 26 docno = 20 --- origWords = ['tuskegee', 'airman', 'observance']
# c1 = 26 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 13172 0 0
# c1 = 27 docno = 21 --- origWords = ['substance', 'abuse']
# c1 = 27 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 13256 0 0
# c1 = 28 docno = 22 --- origWords = ['national', 'atlas', 'map']
# c1 = 28 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 13569 0 0
# c1 = 29 docno = 23 --- origWords = ['iraq', 'kuwait', 'threat', 'history']
# c1 = 29 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 13963 0 0
# c1 = 30 docno = 160 --- origWords = ['scholarship', 'program']
# c1 = 30 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 14156 0 0
# c1 = 31 docno = 28 --- origWords = ['fda', '2002', 'press', 'release']
# c1 = 31 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 14482 0 0
# c1 = 32 docno = 29 --- origWords = ['grand', 'canyon', 'monitor', 'research', 'center']
# c1 = 32 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 14836 0 0
# c1 = 33 docno = 161 --- origWords = ['tornado', 'outbreak', 'record']
# c1 = 33 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 15680 0 0
# c1 = 34 docno = 4 --- origWords = ['jpl', 'stardust', 'comet', 'wild']
# c1 = 34 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 15860 0 0
# c1 = 35 docno = 8 --- origWords = ['philippine']
# c1 = 35 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 15880 0 0
# c1 = 36 docno = 163 --- origWords = ['bioterrorism']
# c1 = 36 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 15886 0 0
# c1 = 37 docno = 119 --- origWords = ['groundhog', 'day', 'punxsutawney']
# c1 = 37 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 16162 0 0
# c1 = 38 docno = 120 --- origWords = ['st', 'paul', 'sidewalk', 'snow', 'shovel', 'ordnance']
# c1 = 38 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 16855 0 0
# c1 = 39 docno = 121 --- origWords = ['identity', 'theft']
# c1 = 39 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 16928 0 0
# c1 = 40 docno = 122 --- origWords = ['white', 'house', 'fellowship']
# c1 = 40 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 17559 0 0
# c1 = 41 docno = 123 --- origWords = ['cave', 'explore', 'lesson', 'plan']
# c1 = 41 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 18006 0 0
# c1 = 42 docno = 124 --- origWords = ['detail', 'information', 'humpback', 'whale']
# c1 = 42 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 18386 0 0
# c1 = 43 docno = 125 --- origWords = ['english', 'second', 'language']
# c1 = 43 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 18817 0 0
# c1 = 44 docno = 126 --- origWords = ['trademark', 'faq']
# c1 = 44 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 18847 0 0
# c1 = 45 docno = 127 --- origWords = ['gps']
# c1 = 45 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 18856 0 0
# c1 = 46 docno = 128 --- origWords = ['planetary', 'balloon', 'program']
# c1 = 46 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 19218 0 0
# c1 = 47 docno = 129 --- origWords = ['nodc', 'coastal', 'water', 'temp']
# c1 = 47 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 20144 0 0
# c1 = 48 docno = 167 --- origWords = ['school', 'program']
# c1 = 48 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 20696 0 0
# c1 = 49 docno = 118 --- origWords = ['california', 'board', 'correction']
# c1 = 49 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 21380 0 0
# c1 = 50 docno = 59 --- origWords = ['health', 'resource', 'service', 'administration']
# c1 = 50 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 21701 0 0
# c1 = 51 docno = 58 --- origWords = ['automobile', 'emission', 'vehicle', 'pollution']
# c1 = 51 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 22000 0 0
# c1 = 52 docno = 55 --- origWords = ['budget', 'process', 'us', 'department', 'education']
# c1 = 52 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 22632 0 0
# c1 = 53 docno = 54 --- origWords = ['food', 'drug', 'administration']
# c1 = 53 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 23154 0 0
# c1 = 54 docno = 57 --- origWords = ['religious', 'belief']
# c1 = 54 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 23229 0 0
# c1 = 55 docno = 56 --- origWords = ['kudzu', 'invasive', 'specie']
# c1 = 55 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 23296 0 0
# c1 = 56 docno = 51 --- origWords = ['consumer', 'food', 'advice']
# c1 = 56 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 23703 0 0
# c1 = 57 docno = 50 --- origWords = ['money', 'launder']
# c1 = 57 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 24241 0 0
# c1 = 58 docno = 53 --- origWords = ['telecommuting']
# c1 = 58 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 24247 0 0
# c1 = 59 docno = 52 --- origWords = ['monterey', 'bay', 'national', 'marine', 'sanctuary']
# c1 = 59 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 24475 0 0
# c1 = 60 docno = 164 --- origWords = ['winter', 'weather', 'safety']
# c1 = 60 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 25215 0 0
# c1 = 61 docno = 201 --- origWords = ['social', 'security', 'inspector', 'general']
# c1 = 61 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 25614 0 0
# c1 = 62 docno = 199 --- origWords = ['adhd', 'clinical', 'trial']
# c1 = 62 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 25749 0 0
# c1 = 63 docno = 179 --- origWords = ['gpo', 'subscription', 'catalog']
# c1 = 63 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 25772 0 0
# c1 = 64 docno = 200 --- origWords = ['maritime', 'trade']
# c1 = 64 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 26006 0 0
# c1 = 65 docno = 195 --- origWords = ['firstgov', 'worker']
# c1 = 65 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 26109 0 0
# c1 = 66 docno = 194 --- origWords = ['cigarette', 'nicotine', 'health']
# c1 = 66 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 26450 0 0
# c1 = 67 docno = 197 --- origWords = ['vietnam', 'war']
# c1 = 67 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 26896 0 0
# c1 = 68 docno = 178 --- origWords = ['recycle']
# c1 = 68 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 26929 0 0
# c1 = 69 docno = 191 --- origWords = ['coral', 'reef', 'system']
# c1 = 69 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 27142 0 0
# c1 = 70 docno = 190 --- origWords = ['child', 'butterfly', 'site', 'life', 'cycle', 'page']
# c1 = 70 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 29248 0 0
# c1 = 71 docno = 193 --- origWords = ['dinosaur', 'fact', 'fiction']
# c1 = 71 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 29467 0 0
# c1 = 72 docno = 192 --- origWords = ['drunk', 'drive']
# c1 = 72 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 30413 0 0
# c1 = 73 docno = 115 --- origWords = ['information', 'security']
# c1 = 73 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 30608 0 0
# c1 = 74 docno = 114 --- origWords = ['laguna', 'canyon', 'landslide']
# c1 = 74 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 30661 0 0
# c1 = 75 docno = 88 --- origWords = ['frank', 'lloyd', 'wright']
# c1 = 75 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 30770 0 0
# c1 = 76 docno = 89 --- origWords = ['cdc', 'rabies', 'homepage']
# c1 = 76 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 30795 0 0
# c1 = 77 docno = 111 --- origWords = ['specie', 'identification']
# c1 = 77 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 30871 0 0
# c1 = 78 docno = 110 --- origWords = ['fema', 'victim', 'disaster', 'information']
# c1 = 78 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 31128 0 0
# c1 = 79 docno = 113 --- origWords = ['fermilab', 'flora', 'fauna']
# c1 = 79 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 31183 0 0
# c1 = 80 docno = 112 --- origWords = ['oak', 'ridge', 'tennesse', 'doe']
# c1 = 80 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 31375 0 0
# c1 = 81 docno = 82 --- origWords = ['1000', 'popular', 'give', 'name', 'birth', '2000']
# c1 = 81 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 32080 0 0
# c1 = 82 docno = 83 --- origWords = ['nsa', 'home', 'kid']
# c1 = 82 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 32977 0 0
# c1 = 83 docno = 80 --- origWords = ['department', 'labor', 'wage', 'hour', 'division']
# c1 = 83 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 33814 0 0
# c1 = 84 docno = 81 --- origWords = ['mosquito', 'control']
# c1 = 84 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 34129 0 0
# c1 = 85 docno = 86 --- origWords = ['california', 'state', 'auditor']
# c1 = 85 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 34305 0 0
# c1 = 86 docno = 87 --- origWords = ['chronic', 'pain']
# c1 = 86 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 34715 0 0
# c1 = 87 docno = 84 --- origWords = ['national', 'institute', 'alcohol', 'abuse', 'alcoholism', 'homepage']
# c1 = 87 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 35042 0 0
# c1 = 88 docno = 85 --- origWords = ['international', 'parental', 'child', 'abduction']
# c1 = 88 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 36415 0 0
# c1 = 89 docno = 198 --- origWords = ['acupuncture', 'effectiveness']
# c1 = 89 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 36448 0 0
# c1 = 90 docno = 206 --- origWords = ['bird', 'monitor', 'north', 'america']
# c1 = 90 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 37273 0 0
# c1 = 91 docno = 3 --- origWords = ['citizen', 'attitude', 'prairie', 'dog']
# c1 = 91 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 38682 0 0
# c1 = 92 docno = 177 --- origWords = ['minority', 'business']
# c1 = 92 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 38985 0 0
# c1 = 93 docno = 7 --- origWords = ['togo', 'embassy']
# c1 = 93 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 39032 0 0
# c1 = 94 docno = 225 --- origWords = ['japanese', 'surrender', 'document']
# c1 = 94 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 39203 0 0
# c1 = 95 docno = 108 --- origWords = ['panic', 'disorder', 'nimh']
# c1 = 95 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 39324 0 0
# c1 = 96 docno = 109 --- origWords = ['mojave', 'desert', 'ecology']
# c1 = 96 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 39634 0 0
# c1 = 97 docno = 102 --- origWords = ['diet', 'nutrition', 'weight', 'management']
# c1 = 97 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 40093 0 0
# c1 = 98 docno = 103 --- origWords = ['vanity', 'license', 'plate']
# c1 = 98 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 41003 0 0
# c1 = 99 docno = 100 --- origWords = ['stable', 'isotope', 'bird', 'migration']
# c1 = 99 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 41643 0 0
# c1 = 100 docno = 101 --- origWords = ['migrant', 'farm', 'worker']
# c1 = 100 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 42475 0 0
# c1 = 101 docno = 106 --- origWords = ['national', 'gamble', 'impact', 'study', 'commission']
# c1 = 101 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 42883 0 0
# c1 = 102 docno = 107 --- origWords = ['small', 'business']
# c1 = 102 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 43235 0 0
# c1 = 103 docno = 104 --- origWords = ['space', 'exploration']
# c1 = 103 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 43949 0 0
# c1 = 104 docno = 105 --- origWords = ['presidential', 'rank', 'merit', 'award', 'federal', 'employee']
# c1 = 104 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 44406 0 0
# c1 = 105 docno = 39 --- origWords = ['child', 'support', 'enforcement', 'cost', 'benefit']
# c1 = 105 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 46312 0 0
# c1 = 106 docno = 38 --- origWords = ['ohio', 'dam', 'lock']
# c1 = 106 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 46533 0 0
# c1 = 107 docno = 33 --- origWords = ['teen', 'pregnancy']
# c1 = 107 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 46589 0 0
# c1 = 108 docno = 32 --- origWords = ['history', 'american', 'agriculture']
# c1 = 108 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 47007 0 0
# c1 = 109 docno = 31 --- origWords = ['origin', 'universe']
# c1 = 109 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 47146 0 0
# c1 = 110 docno = 30 --- origWords = ['hiv', 'aid']
# c1 = 110 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 47270 0 0
# c1 = 111 docno = 37 --- origWords = ['magnetism']
# c1 = 111 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 47283 0 0
# c1 = 112 docno = 36 --- origWords = ['art', 'education']
# c1 = 112 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 47900 0 0
# c1 = 113 docno = 35 --- origWords = ['religious', 'freedom', 'amendment']
# c1 = 113 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 48103 0 0
# c1 = 114 docno = 34 --- origWords = ['ntp', 'herbal', 'medicine', 'factsheet']
# c1 = 114 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 48284 0 0
# c1 = 115 docno = 205 --- origWords = ['state', 'department', 'bureau', 'intelligence', 'research']
# c1 = 115 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 48984 0 0
# c1 = 116 docno = 223 --- origWords = ['wright', 'brother', 'history']
# c1 = 116 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 49510 0 0
# c1 = 117 docno = 176 --- origWords = ['hurricane']
# c1 = 117 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 49659 0 0
# c1 = 118 docno = 60 --- origWords = ['plant', 'hardiness', 'zone']
# c1 = 118 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 50324 0 0
# c1 = 119 docno = 61 --- origWords = ['cosmology', 'peebles', 'turner']
# c1 = 119 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 50416 0 0
# c1 = 120 docno = 62 --- origWords = ['firstgov', 'kid', 'computer']
# c1 = 120 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 51265 0 0
# c1 = 121 docno = 63 --- origWords = ['art', 'museum']
# c1 = 121 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 51903 0 0
# c1 = 122 docno = 64 --- origWords = ['cell', 'phone', 'radiation']
# c1 = 122 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 52520 0 0
# c1 = 123 docno = 65 --- origWords = ['california', 'art', 'council']
# c1 = 123 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 53313 0 0
# c1 = 124 docno = 66 --- origWords = ['intelligence', 'analysis']
# c1 = 124 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 53477 0 0
# c1 = 125 docno = 67 --- origWords = ['state', 'local', 'gateway']
# c1 = 125 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 53763 0 0
# c1 = 126 docno = 68 --- origWords = ['woman', 'health', 'binge', 'eat', 'disorder']
# c1 = 126 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 55059 0 0
# c1 = 127 docno = 69 --- origWords = ['mono', 'basin', 'national', 'forest', 'lake']
# c1 = 127 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 55567 0 0
# c1 = 128 docno = 175 --- origWords = ['social', 'security', 'benefit', 'application']
# c1 = 128 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 55812 0 0
# c1 = 129 docno = 174 --- origWords = ['keep', 'cholesterol', 'control']
# c1 = 129 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 56175 0 0
# c1 = 130 docno = 173 --- origWords = ['internet', 'business', 'card']
# c1 = 130 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 57197 0 0
# c1 = 131 docno = 172 --- origWords = ['fcc', 'freedom', 'information', 'act']
# c1 = 131 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 57729 0 0
# c1 = 132 docno = 171 --- origWords = ['agricultural', 'research', 'service']
# c1 = 132 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 57906 0 0
# c1 = 133 docno = 170 --- origWords = ['science', 'fair', 'competition']
# c1 = 133 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 58583 0 0
# c1 = 134 docno = 203 --- origWords = ['art', 'embassy', 'exhibition']
# c1 = 134 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 59173 0 0
# c1 = 135 docno = 222 --- origWords = ['home', 'equity', 'credit', 'line']
# c1 = 135 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 60427 0 0
# c1 = 136 docno = 181 --- origWords = ['ahrq', 'clinical', 'practice', 'guideline']
# c1 = 136 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 60649 0 0
# c1 = 137 docno = 182 --- origWords = ['federal', 'consumer', 'information', 'center', 'scam']
# c1 = 137 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 60931 0 0
# c1 = 138 docno = 183 --- origWords = ['near', 'earth', 'asteroid']
# c1 = 138 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 61472 0 0
# c1 = 139 docno = 180 --- origWords = ['greenwich', 'mean', 'time']
# c1 = 139 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 62272 0 0
# c1 = 140 docno = 2 --- origWords = ['ireland', 'consular', 'information', 'sheet']
# c1 = 140 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 62579 0 0
# c1 = 141 docno = 162 --- origWords = ['fda', 'clear', 'medical', 'device']
# c1 = 141 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 62911 0 0
# c1 = 142 docno = 187 --- origWords = ['backyard', 'bird', 'habitat']
# c1 = 142 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 63532 0 0
# c1 = 143 docno = 184 --- origWords = ['child', 'leave']
# c1 = 143 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 65042 0 0
# c1 = 144 docno = 6 --- origWords = ['philadelphia', 'street']
# c1 = 144 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 65408 0 0
# c1 = 145 docno = 220 --- origWords = ['wildfire', 'usgs', 'wildland', 'fire', 'research']
# c1 = 145 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 66110 0 0
# c1 = 146 docno = 186 --- origWords = ['piglet', 'anti', 'inflammatory']
# c1 = 146 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 66140 0 0
# c1 = 147 docno = 188 --- origWords = ['study', 'comet']
# c1 = 147 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 66463 0 0
# c1 = 148 docno = 189 --- origWords = ['homeopathic', 'medicine']
# c1 = 148 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 66641 0 0
# c1 = 149 docno = 202 --- origWords = ['farm', 'service', 'agency', 'online']
# c1 = 149 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 67483 0 0
# c1 = 150 docno = 196 --- origWords = ['new', 'york', 'city', 'employee', 'pension']
# c1 = 150 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 68183 0 0
# c1 = 151 docno = 221 --- origWords = ['homeland', 'security']
# c1 = 151 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 68274 0 0
# c1 = 152 docno = 185 --- origWords = ['estuary', 'conservation']
# c1 = 152 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 68445 0 0
# c1 = 153 docno = 99 --- origWords = ['salmon']
# c1 = 153 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 68490 0 0
# c1 = 154 docno = 98 --- origWords = ['mine', 'safety', 'health', 'administration']
# c1 = 154 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 69044 0 0
# c1 = 155 docno = 168 --- origWords = ['maryland', 'rural', 'development']
# c1 = 155 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 69178 0 0
# c1 = 156 docno = 169 --- origWords = ['save', 'energy']
# c1 = 156 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 69711 0 0
# c1 = 157 docno = 91 --- origWords = ['opm', 'dual', 'employment']
# c1 = 157 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 69838 0 0
# c1 = 158 docno = 90 --- origWords = ['healthy', 'home', 'lead', 'hazard', 'control']
# c1 = 158 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 71106 0 0
# c1 = 159 docno = 93 --- origWords = ['head', 'start', 'home']
# c1 = 159 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 72421 0 0
# c1 = 160 docno = 92 --- origWords = ['doe', 'illness', 'compensation']
# c1 = 160 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 72539 0 0
# c1 = 161 docno = 95 --- origWords = ['flu', 'unite', 'state']
# c1 = 161 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 72740 0 0
# c1 = 162 docno = 94 --- origWords = ['florida', 'key', 'marine', 'sanctuary']
# c1 = 162 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 73097 0 0
# c1 = 163 docno = 97 --- origWords = ['ufo']
# c1 = 163 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 73146 0 0
# c1 = 164 docno = 96 --- origWords = ['planet', 'mar']
# c1 = 164 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 73497 0 0
# c1 = 165 docno = 11 --- origWords = ['pileat', 'woodpecker']
# c1 = 165 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 73514 0 0
# c1 = 166 docno = 10 --- origWords = ['well', 'water', 'contamination']
# c1 = 166 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 74574 0 0
# c1 = 167 docno = 13 --- origWords = ['eruption', 'mount', 'st', 'helen']
# c1 = 167 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 74689 0 0
# c1 = 168 docno = 12 --- origWords = ['oil', 'petroleum', 'resource']
# c1 = 168 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 75401 0 0
# c1 = 169 docno = 15 --- origWords = ['welfare', 'reform']
# c1 = 169 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 75555 0 0
# c1 = 170 docno = 14 --- origWords = ['club', 'drug']
# c1 = 170 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 76095 0 0
# c1 = 171 docno = 17 --- origWords = ['secure', 'linux']
# c1 = 171 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 76157 0 0
# c1 = 172 docno = 16 --- origWords = ['sandhil', 'crane', 'platte', 'river']
# c1 = 172 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 76801 0 0
# c1 = 173 docno = 19 --- origWords = ['toxic', 'waste']
# c1 = 173 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 77216 0 0
# c1 = 174 docno = 18 --- origWords = ['copyright', 'basic']
# c1 = 174 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 77285 0 0
# c1 = 175 docno = 117 --- origWords = ['san', 'diego', 'water', 'supply']
# c1 = 175 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 78262 0 0
# c1 = 176 docno = 116 --- origWords = ['fafsa']
# c1 = 176 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 78262 0 0
# c1 = 177 docno = 204 --- origWords = ['endanger', 'specie']
# c1 = 177 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 78329 0 0
# c1 = 178 docno = 151 --- origWords = ['institution', 'university', 'fuel', 'cell', 'research']
# c1 = 178 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 79095 0 0
# c1 = 179 docno = 150 --- origWords = ['snake', 'bite', 'aid']
# c1 = 179 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 79879 0 0
# c1 = 180 docno = 153 --- origWords = ['technology', 'transfer']
# c1 = 180 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 79976 0 0
# c1 = 181 docno = 152 --- origWords = ['bioengineer', 'food', 'crop']
# c1 = 181 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 80733 0 0
# c1 = 182 docno = 155 --- origWords = ['federal', 'government', 'outsource']
# c1 = 182 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 80968 0 0
# c1 = 183 docno = 154 --- origWords = ['kid', 'state']
# c1 = 183 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 81293 0 0
# c1 = 184 docno = 157 --- origWords = ['federal', 'grant', 'program']
# c1 = 184 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 81506 0 0
# c1 = 185 docno = 156 --- origWords = ['cpsc', 'recall']
# c1 = 185 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 81560 0 0
# c1 = 186 docno = 159 --- origWords = ['tax', 'cut', 'deja', 'voo', 'doo']
# c1 = 186 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 82603 0 0
# c1 = 187 docno = 158 --- origWords = ['ethic', 'congress', 'representative']
# c1 = 187 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 82734 0 0
# c1 = 188 docno = 207 --- origWords = ['annual', 'parade']
# c1 = 188 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 82839 0 0
# c1 = 189 docno = 224 --- origWords = ['york', 'county']
# c1 = 189 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 82914 0 0
# c1 = 190 docno = 48 --- origWords = ['federal', 'state', 'statistic']
# c1 = 190 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 83068 0 0
# c1 = 191 docno = 49 --- origWords = ['fcc', 'consumer', 'bureau']
# c1 = 191 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 83150 0 0
# c1 = 192 docno = 46 --- origWords = ['local', 'drink', 'water']
# c1 = 192 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 84790 0 0
# c1 = 193 docno = 47 --- origWords = ['medical', 'residency']
# c1 = 193 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 84812 0 0
# c1 = 194 docno = 44 --- origWords = ['dash', 'combination', 'diet']
# c1 = 194 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 85005 0 0
# c1 = 195 docno = 45 --- origWords = ['faith', 'base', 'initiative']
# c1 = 195 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 85500 0 0
# c1 = 196 docno = 42 --- origWords = ['sibir', 'air', 'anatomy', 'disaster']
# c1 = 196 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 85937 0 0
# c1 = 197 docno = 43 --- origWords = ['vehicle', 'registration', 'california']
# c1 = 197 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 86112 0 0
# c1 = 198 docno = 40 --- origWords = ['public', 'school', 'standard', 'performance']
# c1 = 198 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 86721 0 0
# c1 = 199 docno = 41 --- origWords = ['historic', 'preservation']
# c1 = 199 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 86738 0 0
# c1 = 200 docno = 1 --- origWords = ['electoral', 'college']
# c1 = 200 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 86971 0 0
# c1 = 201 docno = 5 --- origWords = ['american', 'music']
# c1 = 201 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 88038 0 0
# c1 = 202 docno = 9 --- origWords = ['baltimore']
# c1 = 202 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 88065 0 0
# c1 = 203 docno = 146 --- origWords = ['astrobiology']
# c1 = 203 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 88071 0 0
# c1 = 204 docno = 147 --- origWords = ['hear', 'balance', 'loud']
# c1 = 204 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 88396 0 0
# c1 = 205 docno = 144 --- origWords = ['california', 'tahoe', 'conservancy']
# c1 = 205 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 88468 0 0
# c1 = 206 docno = 145 --- origWords = ['national', 'fall', 'firefighter', 'memorial']
# c1 = 206 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 89128 0 0
# c1 = 207 docno = 142 --- origWords = ['hev', 'program', 'homepage']
# c1 = 207 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 89300 0 0
# c1 = 208 docno = 143 --- origWords = ['fema', 'kid', 'hurricane', 'fact']
# c1 = 208 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 89802 0 0
# c1 = 209 docno = 140 --- origWords = ['natural', 'resource', 'conservation', 'service']
# c1 = 209 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 90121 0 0
# c1 = 210 docno = 141 --- origWords = ['international', 'monetary', 'fund']
# c1 = 210 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 90178 0 0
# c1 = 211 docno = 209 --- origWords = ['radon']
# c1 = 211 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 90193 0 0
# c1 = 212 docno = 208 --- origWords = ['bill', 'right', 'amendment']
# c1 = 212 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 90802 0 0
# c1 = 213 docno = 148 --- origWords = ['low', 'income', 'house']
# c1 = 213 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 91462 0 0
# c1 = 214 docno = 149 --- origWords = ['national', 'science', 'bowl']
# c1 = 214 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 92133 0 0
# c1 = 215 docno = 77 --- origWords = ['hcfa', 'manual']
# c1 = 215 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 92163 0 0
# c1 = 216 docno = 76 --- origWords = ['streamline', 'fha', 'mortgage']
# c1 = 216 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 92276 0 0
# c1 = 217 docno = 75 --- origWords = ['noaa', 'fishery', 'northwest', 'region']
# c1 = 217 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 92348 0 0
# c1 = 218 docno = 74 --- origWords = ['skin', 'cancer']
# c1 = 218 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 92650 0 0
# c1 = 219 docno = 73 --- origWords = ['solar', 'flare']
# c1 = 219 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 92805 0 0
# c1 = 220 docno = 72 --- origWords = ['edy', 'ice', 'cream', 'recall']
# c1 = 220 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 93179 0 0
# c1 = 221 docno = 71 --- origWords = ['duck', 'identification', 'guide']
# c1 = 221 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 93643 0 0
# c1 = 222 docno = 70 --- origWords = ['social', 'security', 'office', 'locator']
# c1 = 222 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 94037 0 0
# c1 = 223 docno = 79 --- origWords = ['international', 'trade']
# c1 = 223 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 94285 0 0
# c1 = 224 docno = 78 --- origWords = ['us', 'antarctic', 'program', 'science', 'section']
# c1 = 224 - len(indriRunQuery_hist_), len(dumpindex_hist_.get('efb', dict())), len(dumpindex_hist_.get('dcf', dict())) = 94930 0 0

# %%
def precisionCompute(origWordsAll, count_history, intCoeffs0, intCoeffs1, intCoeffs2, expansionCounts1, expansionCounts2, dirCoeffs, N1s, featureWeights_, indriRunQuery_hist_, dumpindex_hist_):
    #mapPrecs = dict()
    for featureWeights in featureWeights_:
        for N1 in N1s:
            for intCoeff0 in intCoeffs0:
                for intCoeff1 in intCoeffs1:
                    for intCoeff2 in intCoeffs2:
                        for expansionCount1 in expansionCounts1:
                            for expansionCount2 in expansionCounts2:
                                for dirCoeff in dirCoeffs:
                                    
                                    
                                    #res = getAllRelWords_p(count_history, rWords, origWordsAll, expansionCount1, N1, expansionCount2, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights)
                                    
                                    count_history, relText_stringAll = getAllRelWords(count_history, rWords, origWordsAll, expansionCount1, N1, expansionCount2, intCoeff0, intCoeff1, intCoeff2, dirCoeff, featureWeights, indriRunQuery_hist_, dumpindex_hist_)
                                    
                                    #print("len(relText_stringAll[1]) =", len(relText_stringAll[1]))
                                    ##########
                                    #cfgOutFileName = os.path.join("tmp","sbsb",str(randNum)+".cfg")
                                    #runsFileName = os.path.join("tmp","sbsb",str(randNum)+".run")
                                    #evalsFileName = os.path.join("tmp","sbsb",str(randNum)+".eval")
                                    ##########
                                    genQueries(cfgOutFileName, origWordsAll, relText_stringAll, intCoeff0, intCoeff1, intCoeff2, dirCoeff)
                                    subprocess.Popen("IndriRunQuery " + cfgOutFileName + " > " + runsFileName, shell=True, stdout=subprocess.PIPE).stdout.read()
                                    cmd = "trec_eval -q " + colQrelsFileName + " " + runsFileName + " > " + evalsFileName
                                    subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE).stdout.read()
                                    cmd = "cat " + evalsFileName + " | grep map | grep all | grep -v gm | awk '{print $3}' "
                                    #print ("cmd = ", cmd)
                                    mapPrec = subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE).stdout.read()
                                    print("featureWeights =", featureWeights)
                                    print("intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 =", intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, N1, mapPrec)
                                    #mapPrecs[intCoeff] = mapPrec

# %%
intCoeffs0 = [ 0.7 ]
intCoeffs1 = [ 0.3 ]
#intCoeffs2 = [ 0.18 ]
intCoeffs2 = [ 0.5 ]
#intCoeffs1 = np.arange(0.1, 1, 0.1)
expansionCounts1 = [ 25 ]
#expansionCounts2 = [ 145 ]
expansionCounts2 = [ 0 ]
#expansionCounts2 = range(15, 220, 5)
dirCoeffs = [ 1600 ]
dirCoeffs = [400]
N1s = [0]
#N1s = range(1, 30, 1)
#mapPrecs = 
rWords = dict()
featureWeights_l=[]
featureWeights_1 = {'maxTopColCor': 400, 'expTDocScore': 190, 'maxColPCor': 0.1, 'avgCDocScore': 0.1, 'topTermFrac': 0.1, 'avgColCor': 0.1, 'avgTopColCor': 0.1, 'numCanDocs': 0.1, 'maxTopColPCor': 0.1, 'maxCDocScore': 0.1, 'avgColPCor': 0.1, 'conIdf': 0.1, 'avgTopColPCor': 0.1, 'maxColCor': 0.1}
#for avgCDocScore in [ -1000, 1000, -500, 500, -50, 50, -5, 5, -0.5, 0.5 ]:
for avgCDocScore in [ 0.1 ]:
    featureWeights_1["avgCDocScore"] = avgCDocScore
    featureWeights_l += [dict(featureWeights_1)]
precisionCompute(origWordsAll, count_history, intCoeffs0, intCoeffs1, intCoeffs2, expansionCounts1, expansionCounts2, dirCoeffs, N1s, featureWeights_l, indriRunQuery_hist_, dumpindex_hist_)
# Out:
# featureWeights = {'maxTopColCor': 400, 'maxColPCor': 0.1, 'conIdf': 0.1, 'expTDocScore': 190, 'topTermFrac': 0.1, 'avgColCor': 0.1, 'avgTopColCor': 0.1, 'numCanDocs': 0.1, 'maxTopColPCor': 0.1, 'avgCDocScore': 0.1, 'avgColPCor': 0.1, 'maxCDocScore': 0.1, 'avgTopColPCor': 0.1, 'maxColCor': 0.1}
# intCoeff0, intCoeff1, intCoeff2, expansionCount1, expansionCount2, dirCoeff, map precision, N1 = 0.7 0.3 0.5 25 0 400 0 0.2531
